# %% [markdown]
# <a href="https://colab.research.google.com/github/kshero18/Research-Project/blob/main/Final_Research_Project_Code_Part_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# !pip install ace_tools
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)
# Requirement already satisfied: ace_tools in /usr/local/lib/python3.10/dist-packages (0.0)

# %%
import numpy as np
import simpy

# Define parameters
lambda_1 = 4  # Arrival rate for primary questions (customers per minute)
lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
mu_1 = 3      # Service rate for less experienced agent (customers per minute)
mu_2 = 4      # Service rate for more experienced agent (customers per minute)
M = 5         # Maximum number of calls in the system
T = 40        # Simulation time horizon in minutes
dt = 0.1

overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)


class CallCenter:
    def __init__(self, env, dt, use_longest_waiting=True):
        self.env = env
        self.dt = dt
        self.use_longest_waiting = use_longest_waiting
        self.queue_1 = simpy.Store(env)  # Queue for primary questions
        self.queue_2 = simpy.Store(env)  # Queue for complex questions
        self.agent_1 = simpy.Resource(env, capacity=1)
        self.agent_2 = simpy.Resource(env, capacity=1)
        self.total_waiting_time = 0
        self.total_agent_overtime_cost = 0  # Track only agent overtime costs
        self.customers_served = 0
        self.transition_counts = {}  # Track state transitions
        self.state_counts = {}  # Count visits to states
        self.total_rewards = 0

    def record_transition(self, current_state, next_state):
        """Records state transitions for computing probabilities."""
        self.transition_counts[(current_state, next_state)] = (
            self.transition_counts.get((current_state, next_state), 0) + 1
        )
        self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

    def calculate_transition_probabilities(self):
        """Calculates transition probabilities from recorded transitions."""
        probabilities = {}
        for (current_state, next_state), count in self.transition_counts.items():
            total_transitions_from_state = self.state_counts[current_state]
            probabilities[(current_state, next_state)] = count / total_transitions_from_state
        return probabilities

    def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
      with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
          yield request
          service_time = np.random.exponential(1 / service_rate)
          end_time = self.env.now + service_time  # Calculate when the service will end

          # Simulate the service time
          yield self.env.timeout(service_time)

          wait_time = self.env.now - arrival_time  # Calculate wait time
          self.total_waiting_time += wait_time

          # Initialize agent_overtime_cost to zero
          agent_overtime_cost = 0

          # Check for overtime due to working beyond T
          if end_time > T:
              overtime_hours = end_time - T
              agent_overtime_cost = overtime_hours * overtime_cost_rate
              self.total_agent_overtime_cost += agent_overtime_cost

          self.customers_served += 1

          next_state = (len(self.queue_1.items), len(self.queue_2.items))

          # Record the state transition
          self.record_transition(state, next_state)

          # Log details
          print(
              f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
              f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
              f"(Overtime cost: {agent_overtime_cost:.2f})"
          )
          print(f"    Transition: State {state} -> State {next_state}")

    def assign_customer(self):
        while True:
            if self.agent_1.count == 0 or self.agent_2.count == 0:
                queue, customer_type, arrival_time = self.select_customer()

                if queue is not None:
                    state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state
                    yield queue.get()

                    chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"
                    service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

                    # Start handling the customer
                    self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

            # Update rewards based on current queue lengths
            self.total_rewards += -(len(self.queue_1.items) + len(self.queue_2.items))

            yield self.env.timeout(dt)  # Allow other processes to run

    def select_customer(self):
        """Selects the customer based on the queue and waiting strategy."""
        if self.use_longest_waiting:
            return self.select_longest_waiting_customer()
        return self.select_first_come_first_served_customer()

    def select_longest_waiting_customer(self):
        """Select the longest waiting customer from the queues."""
        if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            customer_2, arrival_time_2 = self.queue_2.items[0]
            if arrival_time_1 <= arrival_time_2:
                return self.queue_1, customer_1, arrival_time_1
            else:
                return self.queue_2, customer_2, arrival_time_2
        elif len(self.queue_1.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            return self.queue_1, customer_1, arrival_time_1
        elif len(self.queue_2.items) > 0:
            customer_2, arrival_time_2 = self.queue_2.items[0]
            return self.queue_2, customer_2, arrival_time_2
        else:
            return None, None, None

    def select_first_come_first_served_customer(self):
        """Select the first customer from queue 1 or queue 2."""
        if len(self.queue_1.items) > 0:
            return self.queue_1, *self.queue_1.items[0]
        elif len(self.queue_2.items) > 0:
            return self.queue_2, *self.queue_2.items[0]
        return None, None, None

    def customer_arrival(self, customer_type, arrival_rate):
        while True:
            inter_arrival_time = np.random.exponential(1 / arrival_rate)
            yield self.env.timeout(inter_arrival_time)
            arrival_time = self.env.now

            if customer_type == 1:
                self.queue_1.put((customer_type, arrival_time))
            else:
                self.queue_2.put((customer_type, arrival_time))

            self.env.process(self.assign_customer())


def run_simulation(simulation_time, use_longest_waiting=True):
    env = simpy.Environment()
    call_center = CallCenter(env, dt, use_longest_waiting)

    env.process(call_center.customer_arrival(1, lambda_1))
    env.process(call_center.customer_arrival(2, lambda_2))

    env.run(until=simulation_time)

    print(f"\nTotal customers served: {call_center.customers_served}")
    print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
    print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
    print(f"Average waiting time per customer: "
          f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

    # Calculate and display transition probabilities
    probabilities = call_center.calculate_transition_probabilities()
    print("\nTransition Probabilities:")
    for (initial_state, final_state), prob in probabilities.items():
        print(f"  P({final_state} | {initial_state}) = {prob:.4f}")

    return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, probabilities


# Run the simulations
simulation_time = 60

# With longest waiting customer function
waiting_time_longest, agent_overtime_longest, served_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# Without longest waiting customer function
waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)

# Comparison of results
print("\nComparison of Waiting Times:")
print(f"With Longest Waiting Customer Function: {waiting_time_longest:.2f} minutes")
print(f"Without Longest Waiting Customer Function: {waiting_time_fcfs:.2f} minutes")
print(f"Difference in Waiting Time: {waiting_time_fcfs - waiting_time_longest:.2f} minutes")

print("\nComparison of Agent Overtime Costs:")
print(f"With Longest Waiting Customer Function: {agent_overtime_longest:.2f}")
print(f"Without Longest Waiting Customer Function: {agent_overtime_fcfs:.2f}")
print(f"Difference in Agent Overtime Cost: {agent_overtime_fcfs - agent_overtime_longest:.2f}")

#######################################################3

import pandas as pd

# Prepare the results for the table
results_data = {
    "Metric": [
        "Total Waiting Time (minutes)",
        "Total Agent Overtime Cost",
        "Total Customers Served"
    ],
    "With Longest Waiting": [
        waiting_time_longest,
        agent_overtime_longest,
        served_longest
    ],
    "Without Longest Waiting": [
        waiting_time_fcfs,
        agent_overtime_fcfs,
        served_fcfs
    ],
    "Difference (Without - With)": [
        waiting_time_fcfs - waiting_time_longest,
        agent_overtime_fcfs - agent_overtime_longest,
        served_fcfs - served_longest
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(results_data)

# Display the results as a table
print(results_df.to_string(index=False))
# Out:
# At time 0.09: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 0.19: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 0.60: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.21 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 0.75: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.24: Customer type 1 served by Agent 1 in 0.94 minutes, waited 0.94 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.30: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 1.48: Customer type 2 served by Agent 2 in 0.32 minutes, waited 0.32 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 1.71: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 1.77: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 1.88: Customer type 2 served by Agent 1 in 0.46 minutes, waited 0.46 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 2.14: Customer type 1 served by Agent 1 in 0.26 minutes, waited 0.37 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (4, 0)
# At time 2.19: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.59 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (3, 0)
# At time 2.29: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.39 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (2, 0)
# At time 2.46: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.53 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (1, 0)
# At time 2.58: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.62 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (0, 0)
# At time 2.77: Customer type 1 served by Agent 2 in 0.31 minutes, waited 0.79 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (4, 1)
# At time 2.88: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.25 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (3, 1)
# At time 2.92: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.27 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 1)
# At time 3.22: Customer type 1 served by Agent 2 in 0.30 minutes, waited 0.54 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 1)
# At time 3.47: Customer type 2 served by Agent 1 in 0.87 minutes, waited 0.87 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (3, 0)
# At time 3.64: Customer type 2 served by Agent 2 in 0.42 minutes, waited 0.91 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (3, 0)
# At time 3.71: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.68 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (2, 0)
# At time 3.89: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.67 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 0)
# At time 3.95: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.32 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 4.51: Customer type 1 served by Agent 2 in 0.56 minutes, waited 0.65 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 2)
# At time 4.54: Customer type 1 served by Agent 1 in 1.07 minutes, waited 1.79 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (1, 1)
# At time 4.71: Customer type 2 served by Agent 2 in 0.19 minutes, waited 0.56 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (2, 1)
# At time 4.95: Customer type 2 served by Agent 1 in 0.40 minutes, waited 0.57 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (2, 1)
# At time 4.96: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 0)
# At time 5.00: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.30 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 0)
# At time 5.01: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.56 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 0)
# At time 5.68: Customer type 1 served by Agent 1 in 0.68 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (3, 2)
# At time 5.78: Customer type 1 served by Agent 2 in 0.76 minutes, waited 0.78 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 2)
# At time 5.85: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.84 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (2, 1)
# At time 5.85: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.77 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 1)
# At time 6.00: Customer type 1 served by Agent 2 in 0.16 minutes, waited 0.69 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 0)
# At time 6.28: Customer type 2 served by Agent 1 in 0.43 minutes, waited 1.05 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 0)
# At time 6.34: Customer type 1 served by Agent 2 in 0.34 minutes, waited 1.01 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 6.80: Customer type 1 served by Agent 2 in 0.45 minutes, waited 0.57 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 2)
# At time 7.04: Customer type 1 served by Agent 1 in 0.76 minutes, waited 1.13 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 2)
# At time 7.20: Customer type 1 served by Agent 2 in 0.40 minutes, waited 0.68 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (3, 2)
# At time 7.50: Customer type 2 served by Agent 1 in 0.45 minutes, waited 0.88 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (5, 2)
# At time 7.55: Customer type 2 served by Agent 1 in 0.05 minutes, waited 0.79 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (6, 1)
# At time 7.63: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.62 minutes (Overtime cost: 0.00)
#     Transition: State (6, 1) -> State (6, 1)
# At time 7.82: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.78 minutes (Overtime cost: 0.00)
#     Transition: State (6, 1) -> State (5, 1)
# At time 7.85: Customer type 1 served by Agent 2 in 0.65 minutes, waited 1.17 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (5, 0)
# At time 8.18: Customer type 2 served by Agent 1 in 0.36 minutes, waited 1.09 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (5, 0)
# At time 8.21: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.88 minutes (Overtime cost: 0.00)
#     Transition: State (5, 0) -> State (5, 0)
# At time 8.29: Customer type 1 served by Agent 2 in 0.44 minutes, waited 1.07 minutes (Overtime cost: 0.00)
#     Transition: State (5, 0) -> State (4, 0)
# At time 8.46: Customer type 1 served by Agent 1 in 0.24 minutes, waited 1.11 minutes (Overtime cost: 0.00)
#     Transition: State (5, 0) -> State (3, 1)
# At time 8.60: Customer type 1 served by Agent 2 in 0.31 minutes, waited 1.07 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (2, 2)
# At time 8.66: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.64 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 9.01: Customer type 1 served by Agent 1 in 0.55 minutes, waited 1.43 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (4, 3)
# At time 9.02: Customer type 1 served by Agent 2 in 0.36 minutes, waited 0.82 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (4, 2)
# At time 9.04: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.69 minutes (Overtime cost: 0.00)
#     Transition: State (4, 3) -> State (4, 1)
# At time 9.12: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.65 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (4, 0)
# At time 9.12: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.40 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (3, 0)
# At time 9.16: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.27 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (2, 0)
# At time 9.21: Customer type 2 served by Agent 1 in 0.17 minutes, waited 0.53 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (1, 0)
# At time 9.52: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.53 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 2)
# At time 9.69: Customer type 2 served by Agent 1 in 0.17 minutes, waited 0.46 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (2, 3)
# At time 9.72: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.47 minutes (Overtime cost: 0.00)
#     Transition: State (2, 3) -> State (1, 3)
# At time 9.76: Customer type 1 served by Agent 2 in 0.60 minutes, waited 0.81 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 2)
# At time 9.77: Customer type 2 served by Agent 2 in 0.01 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 1)
# At time 9.86: Customer type 2 served by Agent 2 in 0.08 minutes, waited 0.25 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (2, 1)
# At time 9.99: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.34 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (1, 1)
# At time 10.11: Customer type 2 served by Agent 2 in 0.12 minutes, waited 0.30 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (2, 0)
# At time 10.14: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.31 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 10.24: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 10.43: Customer type 2 served by Agent 1 in 0.71 minutes, waited 1.04 minutes (Overtime cost: 0.00)
#     Transition: State (1, 3) -> State (0, 0)
# At time 10.77: Customer type 1 served by Agent 1 in 0.33 minutes, waited 0.33 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 10.87: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 11.17: Customer type 1 served by Agent 2 in 0.72 minutes, waited 0.72 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 11.59: Customer type 2 served by Agent 2 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 0)
# At time 11.72: Customer type 1 served by Agent 1 in 0.58 minutes, waited 0.58 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 12.11: Customer type 1 served by Agent 2 in 0.52 minutes, waited 0.80 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (3, 1)
# At time 12.36: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.65 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 1)
# At time 12.68: Customer type 1 served by Agent 2 in 0.32 minutes, waited 0.88 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (4, 2)
# At time 12.85: Customer type 1 served by Agent 2 in 0.17 minutes, waited 1.03 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (3, 2)
# At time 12.98: Customer type 2 served by Agent 2 in 0.13 minutes, waited 1.15 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (5, 1)
# At time 13.18: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.78 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (5, 1)
# At time 13.19: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.62 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (4, 1)
# At time 13.33: Customer type 1 served by Agent 1 in 1.60 minutes, waited 1.83 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (4, 1)
# At time 13.53: Customer type 2 served by Agent 1 in 0.20 minutes, waited 0.86 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (5, 1)
# At time 13.67: Customer type 1 served by Agent 2 in 0.48 minutes, waited 1.09 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (4, 2)
# At time 14.41: Customer type 1 served by Agent 2 in 0.74 minutes, waited 1.44 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (5, 5)
# At time 14.53: Customer type 1 served by Agent 1 in 1.00 minutes, waited 1.61 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (4, 5)
# At time 14.61: Customer type 1 served by Agent 1 in 0.08 minutes, waited 1.33 minutes (Overtime cost: 0.00)
#     Transition: State (4, 5) -> State (3, 5)
# At time 14.91: Customer type 1 served by Agent 1 in 0.29 minutes, waited 1.49 minutes (Overtime cost: 0.00)
#     Transition: State (3, 5) -> State (2, 6)
# At time 14.99: Customer type 1 served by Agent 2 in 0.58 minutes, waited 1.85 minutes (Overtime cost: 0.00)
#     Transition: State (5, 5) -> State (3, 5)
# At time 15.17: Customer type 2 served by Agent 2 in 0.17 minutes, waited 1.51 minutes (Overtime cost: 0.00)
#     Transition: State (3, 5) -> State (4, 4)
# At time 15.25: Customer type 2 served by Agent 1 in 0.34 minutes, waited 1.79 minutes (Overtime cost: 0.00)
#     Transition: State (2, 6) -> State (4, 3)
# At time 15.48: Customer type 2 served by Agent 1 in 0.24 minutes, waited 1.50 minutes (Overtime cost: 0.00)
#     Transition: State (4, 3) -> State (6, 2)
# At time 16.09: Customer type 2 served by Agent 2 in 0.92 minutes, waited 2.37 minutes (Overtime cost: 0.00)
#     Transition: State (4, 4) -> State (10, 1)
# At time 16.19: Customer type 2 served by Agent 1 in 0.70 minutes, waited 2.12 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (9, 1)
# At time 16.22: Customer type 1 served by Agent 1 in 0.03 minutes, waited 1.92 minutes (Overtime cost: 0.00)
#     Transition: State (9, 1) -> State (8, 1)
# At time 16.24: Customer type 1 served by Agent 2 in 0.15 minutes, waited 2.08 minutes (Overtime cost: 0.00)
#     Transition: State (10, 1) -> State (9, 0)
# At time 16.29: Customer type 2 served by Agent 1 in 0.07 minutes, waited 1.49 minutes (Overtime cost: 0.00)
#     Transition: State (8, 1) -> State (8, 0)
# At time 16.29: Customer type 1 served by Agent 1 in 0.00 minutes, waited 1.21 minutes (Overtime cost: 0.00)
#     Transition: State (8, 0) -> State (7, 0)
# At time 16.42: Customer type 1 served by Agent 1 in 0.13 minutes, waited 1.04 minutes (Overtime cost: 0.00)
#     Transition: State (7, 0) -> State (7, 0)
# At time 16.77: Customer type 1 served by Agent 2 in 0.53 minutes, waited 1.83 minutes (Overtime cost: 0.00)
#     Transition: State (9, 0) -> State (7, 0)
# At time 16.90: Customer type 1 served by Agent 1 in 0.48 minutes, waited 1.43 minutes (Overtime cost: 0.00)
#     Transition: State (7, 0) -> State (7, 0)
# At time 16.91: Customer type 1 served by Agent 2 in 0.13 minutes, waited 1.27 minutes (Overtime cost: 0.00)
#     Transition: State (7, 0) -> State (6, 0)
# At time 17.06: Customer type 1 served by Agent 2 in 0.15 minutes, waited 1.23 minutes (Overtime cost: 0.00)
#     Transition: State (6, 0) -> State (6, 0)
# At time 17.20: Customer type 1 served by Agent 1 in 0.30 minutes, waited 1.52 minutes (Overtime cost: 0.00)
#     Transition: State (7, 0) -> State (5, 2)
# At time 17.45: Customer type 1 served by Agent 1 in 0.25 minutes, waited 1.23 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (4, 3)
# At time 17.71: Customer type 1 served by Agent 2 in 0.65 minutes, waited 1.72 minutes (Overtime cost: 0.00)
#     Transition: State (6, 0) -> State (3, 4)
# At time 17.73: Customer type 1 served by Agent 1 in 0.28 minutes, waited 1.33 minutes (Overtime cost: 0.00)
#     Transition: State (4, 3) -> State (2, 4)
# At time 17.82: Customer type 1 served by Agent 1 in 0.08 minutes, waited 1.01 minutes (Overtime cost: 0.00)
#     Transition: State (2, 4) -> State (1, 5)
# At time 18.01: Customer type 1 served by Agent 1 in 0.19 minutes, waited 1.00 minutes (Overtime cost: 0.00)
#     Transition: State (1, 5) -> State (0, 5)
# At time 18.37: Customer type 2 served by Agent 1 in 0.36 minutes, waited 1.26 minutes (Overtime cost: 0.00)
#     Transition: State (0, 5) -> State (0, 5)
# At time 18.48: Customer type 1 served by Agent 2 in 0.77 minutes, waited 1.88 minutes (Overtime cost: 0.00)
#     Transition: State (3, 4) -> State (0, 4)
# At time 18.52: Customer type 2 served by Agent 1 in 0.15 minutes, waited 1.34 minutes (Overtime cost: 0.00)
#     Transition: State (0, 5) -> State (0, 3)
# At time 18.74: Customer type 2 served by Agent 1 in 0.22 minutes, waited 1.24 minutes (Overtime cost: 0.00)
#     Transition: State (0, 3) -> State (2, 2)
# At time 18.78: Customer type 2 served by Agent 2 in 0.30 minutes, waited 1.56 minutes (Overtime cost: 0.00)
#     Transition: State (0, 4) -> State (2, 1)
# At time 18.88: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.55 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 0)
# At time 19.47: Customer type 1 served by Agent 2 in 0.58 minutes, waited 0.92 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (3, 1)
# At time 19.59: Customer type 2 served by Agent 1 in 0.84 minutes, waited 1.80 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (3, 3)
# At time 19.62: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.89 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (3, 2)
# At time 19.63: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.65 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (2, 2)
# At time 19.70: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.48 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 19.94: Customer type 2 served by Agent 2 in 0.24 minutes, waited 0.42 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (2, 1)
# At time 20.47: Customer type 2 served by Agent 1 in 0.88 minutes, waited 1.54 minutes (Overtime cost: 0.00)
#     Transition: State (3, 3) -> State (4, 0)
# At time 20.63: Customer type 2 served by Agent 2 in 0.69 minutes, waited 1.06 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (4, 0)
# At time 20.75: Customer type 1 served by Agent 1 in 0.28 minutes, waited 1.16 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (4, 1)
# At time 20.82: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.73 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (3, 1)
# At time 20.83: Customer type 1 served by Agent 2 in 0.20 minutes, waited 1.07 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (2, 1)
# At time 20.87: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.38 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (1, 1)
# At time 21.02: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.83 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (1, 0)
# At time 21.19: Customer type 2 served by Agent 2 in 0.32 minutes, waited 0.54 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 0)
# At time 21.37: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 21.49: Customer type 1 served by Agent 1 in 0.47 minutes, waited 0.83 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 21.62: Customer type 2 served by Agent 2 in 0.24 minutes, waited 0.33 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 22.02: Customer type 1 served by Agent 1 in 0.53 minutes, waited 0.69 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 3)
# At time 22.16: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.32 minutes (Overtime cost: 0.00)
#     Transition: State (1, 3) -> State (1, 2)
# At time 22.31: Customer type 2 served by Agent 1 in 0.15 minutes, waited 0.42 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 2)
# At time 22.34: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.43 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 1)
# At time 22.35: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.36 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 1)
# At time 22.42: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 22.57: Customer type 1 served by Agent 2 in 0.95 minutes, waited 1.15 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 22.73: Customer type 2 served by Agent 2 in 0.17 minutes, waited 0.23 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 23.05: Customer type 1 served by Agent 2 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (3, 0)
# At time 23.27: Customer type 1 served by Agent 2 in 0.22 minutes, waited 0.49 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (4, 0)
# At time 23.32: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.31 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (3, 0)
# At time 23.37: Customer type 1 served by Agent 1 in 0.95 minutes, waited 0.95 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 23.61: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.58 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (1, 0)
# At time 24.04: Customer type 1 served by Agent 2 in 0.43 minutes, waited 0.95 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (3, 2)
# At time 24.04: Customer type 2 served by Agent 2 in 0.00 minutes, waited 0.32 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (3, 1)
# At time 24.04: Customer type 1 served by Agent 1 in 0.67 minutes, waited 0.98 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 1)
# At time 24.32: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.49 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 2)
# At time 24.32: Customer type 2 served by Agent 1 in 0.00 minutes, waited 0.45 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 1)
# At time 24.48: Customer type 1 served by Agent 2 in 0.44 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 1)
# At time 24.52: Customer type 2 served by Agent 2 in 0.04 minutes, waited 0.44 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (2, 0)
# At time 24.53: Customer type 1 served by Agent 1 in 0.21 minutes, waited 0.63 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (1, 0)
# At time 24.54: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.40 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 24.59: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.06 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 24.62: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 24.92: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 25.25: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 25.25: Customer type 2 served by Agent 2 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 25.46: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 25.84: Customer type 2 served by Agent 2 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 26.07: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 26.17: Customer type 1 served by Agent 1 in 0.75 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 26.27: Customer type 2 served by Agent 2 in 0.19 minutes, waited 0.24 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 26.28: Customer type 2 served by Agent 2 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 26.65: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 26.74: Customer type 1 served by Agent 1 in 0.58 minutes, waited 0.65 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 26.86: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.14 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 27.34: Customer type 1 served by Agent 1 in 0.51 minutes, waited 0.51 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 27.79: Customer type 2 served by Agent 2 in 0.70 minutes, waited 0.70 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 28.07: Customer type 1 served by Agent 2 in 0.28 minutes, waited 0.39 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 28.16: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.31 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 28.42: Customer type 1 served by Agent 1 in 0.75 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 28.52: Customer type 1 served by Agent 2 in 0.35 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 28.63: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.28 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 28.66: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 28.76: Customer type 1 served by Agent 1 in 0.13 minutes, waited 0.14 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.21: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.35: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.41: Customer type 2 served by Agent 2 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 29.51: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.74: Customer type 1 served by Agent 1 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.76: Customer type 1 served by Agent 2 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.83: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.13: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.40: Customer type 2 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 31.29: Customer type 1 served by Agent 1 in 1.00 minutes, waited 1.00 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (3, 1)
# At time 31.47: Customer type 1 served by Agent 2 in 0.97 minutes, waited 0.97 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 1)
# At time 31.48: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.96 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 0)
# At time 31.52: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.66 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (1, 0)
# At time 31.64: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.69 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 31.73: Customer type 1 served by Agent 1 in 0.25 minutes, waited 0.78 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 1)
# At time 31.75: Customer type 2 served by Agent 2 in 0.11 minutes, waited 0.19 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 1)
# At time 31.81: Customer type 2 served by Agent 2 in 0.06 minutes, waited 0.12 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 31.98: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.19 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 32.01: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.36 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 0)
# At time 32.26: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.01 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 33.32: Customer type 2 served by Agent 2 in 0.49 minutes, waited 0.49 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 0)
# At time 33.34: Customer type 1 served by Agent 1 in 0.80 minutes, waited 0.80 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 33.44: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 0)
# At time 33.54: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.14 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 0)
# At time 33.74: Customer type 1 served by Agent 1 in 0.40 minutes, waited 0.63 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 2)
# At time 33.74: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 33.74: Customer type 2 served by Agent 1 in 0.00 minutes, waited 0.10 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 1)
# At time 33.77: Customer type 1 served by Agent 2 in 0.23 minutes, waited 0.34 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 33.77: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.04 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 33.82: Customer type 2 served by Agent 1 in 0.08 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 0)
# At time 33.82: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 34.15: Customer type 2 served by Agent 1 in 0.23 minutes, waited 0.23 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.19: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 34.65: Customer type 1 served by Agent 1 in 0.49 minutes, waited 0.49 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 2)
# At time 35.20: Customer type 1 served by Agent 2 in 1.01 minutes, waited 1.04 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (6, 3)
# At time 35.42: Customer type 2 served by Agent 2 in 0.21 minutes, waited 1.20 minutes (Overtime cost: 0.00)
#     Transition: State (6, 3) -> State (6, 2)
# At time 35.51: Customer type 1 served by Agent 1 in 0.86 minutes, waited 1.33 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (5, 2)
# At time 35.56: Customer type 1 served by Agent 2 in 0.14 minutes, waited 1.15 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (5, 1)
# At time 35.63: Customer type 2 served by Agent 1 in 0.12 minutes, waited 1.03 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (5, 0)
# At time 35.78: Customer type 2 served by Agent 2 in 0.22 minutes, waited 1.11 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (4, 1)
# At time 35.95: Customer type 1 served by Agent 2 in 0.18 minutes, waited 1.11 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (5, 2)
# At time 35.98: Customer type 1 served by Agent 2 in 0.03 minutes, waited 1.09 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (4, 2)
# At time 36.27: Customer type 1 served by Agent 2 in 0.28 minutes, waited 1.31 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (4, 2)
# At time 36.59: Customer type 1 served by Agent 1 in 0.96 minutes, waited 1.81 minutes (Overtime cost: 0.00)
#     Transition: State (5, 0) -> State (4, 2)
# At time 36.63: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.92 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (4, 1)
# At time 36.66: Customer type 1 served by Agent 2 in 0.39 minutes, waited 1.69 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (3, 1)
# At time 36.74: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.86 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (3, 1)
# At time 36.79: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.87 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (3, 0)
# At time 37.27: Customer type 1 served by Agent 2 in 0.48 minutes, waited 1.02 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (4, 0)
# At time 37.88: Customer type 1 served by Agent 1 in 1.25 minutes, waited 2.07 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (5, 3)
# At time 37.94: Customer type 1 served by Agent 2 in 0.67 minutes, waited 1.52 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (4, 3)
# At time 37.95: Customer type 1 served by Agent 2 in 0.01 minutes, waited 1.08 minutes (Overtime cost: 0.00)
#     Transition: State (4, 3) -> State (3, 3)
# At time 38.19: Customer type 1 served by Agent 1 in 0.30 minutes, waited 1.47 minutes (Overtime cost: 0.00)
#     Transition: State (5, 3) -> State (4, 3)
# At time 38.26: Customer type 1 served by Agent 2 in 0.31 minutes, waited 1.20 minutes (Overtime cost: 0.00)
#     Transition: State (3, 3) -> State (4, 2)
# At time 38.27: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.98 minutes (Overtime cost: 0.00)
#     Transition: State (4, 3) -> State (3, 2)
# At time 38.28: Customer type 2 served by Agent 1 in 0.00 minutes, waited 0.83 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (3, 1)
# At time 38.37: Customer type 1 served by Agent 2 in 0.10 minutes, waited 1.01 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (6, 0)
# At time 38.41: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.80 minutes (Overtime cost: 0.00)
#     Transition: State (6, 0) -> State (5, 0)
# At time 38.56: Customer type 2 served by Agent 1 in 0.28 minutes, waited 1.04 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (4, 0)
# At time 38.58: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (3, 0)
# At time 38.61: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.59 minutes (Overtime cost: 0.00)
#     Transition: State (5, 0) -> State (2, 0)
# At time 38.76: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.47 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 38.80: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (0, 0)
# At time 38.84: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.48 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 39.17: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 39.19: Customer type 2 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 39.34: Customer type 2 served by Agent 2 in 0.17 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 0)
# At time 39.43: Customer type 1 served by Agent 1 in 0.24 minutes, waited 0.28 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 39.58: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 39.88: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 39.89: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 40.53: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.01 minutes (Overtime cost: 0.53)
#     Transition: State (1, 0) -> State (0, 0)
# At time 40.56: Customer type 1 served by Agent 1 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 0.56)
#     Transition: State (1, 0) -> State (0, 0)
# At time 41.30: Customer type 1 served by Agent 2 in 0.46 minutes, waited 0.46 minutes (Overtime cost: 1.30)
#     Transition: State (1, 0) -> State (1, 1)
# At time 41.43: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.50 minutes (Overtime cost: 1.43)
#     Transition: State (1, 1) -> State (2, 2)
# At time 41.54: Customer type 1 served by Agent 1 in 0.80 minutes, waited 0.80 minutes (Overtime cost: 1.54)
#     Transition: State (1, 0) -> State (3, 1)
# At time 41.58: Customer type 2 served by Agent 2 in 0.15 minutes, waited 0.28 minutes (Overtime cost: 1.58)
#     Transition: State (2, 2) -> State (2, 1)
# At time 41.95: Customer type 1 served by Agent 1 in 0.41 minutes, waited 0.60 minutes (Overtime cost: 1.95)
#     Transition: State (3, 1) -> State (3, 1)
# At time 42.32: Customer type 1 served by Agent 2 in 0.74 minutes, waited 0.92 minutes (Overtime cost: 2.32)
#     Transition: State (2, 1) -> State (4, 1)
# At time 42.46: Customer type 2 served by Agent 1 in 0.51 minutes, waited 1.04 minutes (Overtime cost: 2.46)
#     Transition: State (3, 1) -> State (3, 2)
# At time 42.59: Customer type 1 served by Agent 2 in 0.27 minutes, waited 1.13 minutes (Overtime cost: 2.59)
#     Transition: State (4, 1) -> State (3, 2)
# At time 42.74: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.95 minutes (Overtime cost: 2.74)
#     Transition: State (3, 2) -> State (3, 3)
# At time 43.34: Customer type 1 served by Agent 1 in 0.88 minutes, waited 1.62 minutes (Overtime cost: 3.34)
#     Transition: State (3, 2) -> State (6, 4)
# At time 43.40: Customer type 2 served by Agent 1 in 0.06 minutes, waited 1.25 minutes (Overtime cost: 3.40)
#     Transition: State (6, 4) -> State (7, 3)
# At time 43.49: Customer type 1 served by Agent 2 in 0.75 minutes, waited 1.34 minutes (Overtime cost: 3.49)
#     Transition: State (3, 3) -> State (7, 2)
# At time 43.53: Customer type 1 served by Agent 2 in 0.05 minutes, waited 1.02 minutes (Overtime cost: 3.53)
#     Transition: State (7, 2) -> State (6, 2)
# At time 43.60: Customer type 2 served by Agent 1 in 0.20 minutes, waited 1.15 minutes (Overtime cost: 3.60)
#     Transition: State (7, 3) -> State (6, 2)
# At time 43.60: Customer type 2 served by Agent 1 in 0.00 minutes, waited 0.90 minutes (Overtime cost: 3.60)
#     Transition: State (6, 2) -> State (6, 1)
# At time 43.80: Customer type 1 served by Agent 2 in 0.27 minutes, waited 1.15 minutes (Overtime cost: 3.80)
#     Transition: State (6, 2) -> State (8, 1)
# At time 44.19: Customer type 2 served by Agent 2 in 0.39 minutes, waited 1.22 minutes (Overtime cost: 4.19)
#     Transition: State (8, 1) -> State (11, 1)
# At time 44.26: Customer type 1 served by Agent 2 in 0.08 minutes, waited 1.28 minutes (Overtime cost: 4.26)
#     Transition: State (11, 1) -> State (11, 2)
# At time 44.49: Customer type 1 served by Agent 2 in 0.22 minutes, waited 1.44 minutes (Overtime cost: 4.49)
#     Transition: State (11, 2) -> State (11, 2)
# At time 44.82: Customer type 1 served by Agent 2 in 0.33 minutes, waited 1.49 minutes (Overtime cost: 4.82)
#     Transition: State (11, 2) -> State (11, 3)
# At time 44.92: Customer type 1 served by Agent 2 in 0.10 minutes, waited 1.56 minutes (Overtime cost: 4.92)
#     Transition: State (11, 3) -> State (10, 3)
# At time 44.97: Customer type 1 served by Agent 2 in 0.06 minutes, waited 1.43 minutes (Overtime cost: 4.97)
#     Transition: State (10, 3) -> State (9, 3)
# At time 45.04: Customer type 1 served by Agent 1 in 1.44 minutes, waited 2.09 minutes (Overtime cost: 5.04)
#     Transition: State (6, 1) -> State (8, 3)
# At time 45.12: Customer type 1 served by Agent 2 in 0.14 minutes, waited 1.51 minutes (Overtime cost: 5.12)
#     Transition: State (9, 3) -> State (7, 3)
# At time 45.21: Customer type 1 served by Agent 2 in 0.09 minutes, waited 1.46 minutes (Overtime cost: 5.21)
#     Transition: State (7, 3) -> State (6, 3)
# At time 45.39: Customer type 1 served by Agent 2 in 0.18 minutes, waited 1.54 minutes (Overtime cost: 5.39)
#     Transition: State (6, 3) -> State (6, 3)
# At time 45.62: Customer type 1 served by Agent 1 in 0.58 minutes, waited 2.01 minutes (Overtime cost: 5.62)
#     Transition: State (8, 3) -> State (8, 3)
# At time 45.80: Customer type 2 served by Agent 2 in 0.40 minutes, waited 1.81 minutes (Overtime cost: 5.80)
#     Transition: State (6, 3) -> State (11, 3)
# At time 45.83: Customer type 1 served by Agent 2 in 0.03 minutes, waited 1.66 minutes (Overtime cost: 5.83)
#     Transition: State (11, 3) -> State (10, 3)
# At time 46.05: Customer type 1 served by Agent 1 in 0.43 minutes, waited 1.94 minutes (Overtime cost: 6.05)
#     Transition: State (8, 3) -> State (10, 2)
# At time 46.07: Customer type 1 served by Agent 1 in 0.02 minutes, waited 1.87 minutes (Overtime cost: 6.07)
#     Transition: State (10, 2) -> State (9, 2)
# At time 46.19: Customer type 1 served by Agent 1 in 0.12 minutes, waited 1.74 minutes (Overtime cost: 6.19)
#     Transition: State (9, 2) -> State (9, 2)
# At time 46.26: Customer type 2 served by Agent 2 in 0.43 minutes, waited 2.07 minutes (Overtime cost: 6.26)
#     Transition: State (10, 3) -> State (8, 2)
# At time 46.36: Customer type 2 served by Agent 2 in 0.10 minutes, waited 1.55 minutes (Overtime cost: 6.36)
#     Transition: State (8, 2) -> State (8, 1)
# At time 46.61: Customer type 1 served by Agent 2 in 0.24 minutes, waited 1.37 minutes (Overtime cost: 6.61)
#     Transition: State (8, 2) -> State (10, 2)
# At time 46.63: Customer type 1 served by Agent 1 in 0.43 minutes, waited 1.86 minutes (Overtime cost: 6.63)
#     Transition: State (9, 2) -> State (9, 2)
# At time 47.14: Customer type 1 served by Agent 1 in 0.51 minutes, waited 1.63 minutes (Overtime cost: 7.14)
#     Transition: State (9, 2) -> State (12, 5)
# At time 47.32: Customer type 2 served by Agent 1 in 0.18 minutes, waited 1.76 minutes (Overtime cost: 7.32)
#     Transition: State (12, 5) -> State (12, 5)
# At time 47.46: Customer type 1 served by Agent 2 in 0.85 minutes, waited 2.01 minutes (Overtime cost: 7.46)
#     Transition: State (10, 2) -> State (11, 5)
# At time 47.56: Customer type 1 served by Agent 1 in 0.25 minutes, waited 1.91 minutes (Overtime cost: 7.56)
#     Transition: State (12, 5) -> State (10, 5)
# At time 47.73: Customer type 1 served by Agent 1 in 0.17 minutes, waited 2.04 minutes (Overtime cost: 7.73)
#     Transition: State (10, 5) -> State (10, 5)
# At time 47.79: Customer type 1 served by Agent 1 in 0.05 minutes, waited 2.06 minutes (Overtime cost: 7.79)
#     Transition: State (10, 5) -> State (9, 5)
# At time 47.87: Customer type 1 served by Agent 2 in 0.41 minutes, waited 2.21 minutes (Overtime cost: 7.87)
#     Transition: State (11, 5) -> State (8, 5)
# At time 47.95: Customer type 2 served by Agent 2 in 0.08 minutes, waited 1.59 minutes (Overtime cost: 7.95)
#     Transition: State (8, 5) -> State (9, 4)
# At time 47.95: Customer type 1 served by Agent 2 in 0.00 minutes, waited 1.54 minutes (Overtime cost: 7.95)
#     Transition: State (9, 4) -> State (8, 4)
# At time 48.00: Customer type 1 served by Agent 2 in 0.05 minutes, waited 1.52 minutes (Overtime cost: 8.00)
#     Transition: State (8, 4) -> State (8, 5)
# At time 48.04: Customer type 1 served by Agent 2 in 0.04 minutes, waited 1.47 minutes (Overtime cost: 8.04)
#     Transition: State (8, 5) -> State (7, 5)
# At time 48.15: Customer type 1 served by Agent 1 in 0.37 minutes, waited 2.02 minutes (Overtime cost: 8.15)
#     Transition: State (9, 5) -> State (8, 4)
# At time 48.22: Customer type 2 served by Agent 2 in 0.18 minutes, waited 1.57 minutes (Overtime cost: 8.22)
#     Transition: State (7, 5) -> State (7, 4)
# At time 48.34: Customer type 1 served by Agent 2 in 0.12 minutes, waited 1.57 minutes (Overtime cost: 8.34)
#     Transition: State (7, 4) -> State (6, 4)
# At time 48.42: Customer type 1 served by Agent 1 in 0.27 minutes, waited 1.75 minutes (Overtime cost: 8.42)
#     Transition: State (8, 4) -> State (6, 3)
# At time 48.45: Customer type 2 served by Agent 2 in 0.11 minutes, waited 1.65 minutes (Overtime cost: 8.45)
#     Transition: State (6, 4) -> State (5, 3)
# At time 48.46: Customer type 1 served by Agent 1 in 0.04 minutes, waited 1.66 minutes (Overtime cost: 8.46)
#     Transition: State (6, 3) -> State (5, 2)
# At time 48.51: Customer type 1 served by Agent 1 in 0.06 minutes, waited 1.52 minutes (Overtime cost: 8.51)
#     Transition: State (5, 2) -> State (4, 3)
# At time 48.76: Customer type 2 served by Agent 2 in 0.31 minutes, waited 1.94 minutes (Overtime cost: 8.76)
#     Transition: State (5, 3) -> State (4, 2)
# At time 48.79: Customer type 1 served by Agent 2 in 0.03 minutes, waited 1.10 minutes (Overtime cost: 8.79)
#     Transition: State (4, 2) -> State (3, 2)
# At time 48.81: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.86 minutes (Overtime cost: 8.81)
#     Transition: State (3, 2) -> State (2, 2)
# At time 48.90: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.91 minutes (Overtime cost: 8.90)
#     Transition: State (2, 2) -> State (2, 1)
# At time 49.11: Customer type 2 served by Agent 1 in 0.59 minutes, waited 1.91 minutes (Overtime cost: 9.11)
#     Transition: State (4, 3) -> State (2, 1)
# At time 49.36: Customer type 1 served by Agent 1 in 0.26 minutes, waited 1.31 minutes (Overtime cost: 9.36)
#     Transition: State (2, 1) -> State (1, 3)
# At time 49.39: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.92 minutes (Overtime cost: 9.39)
#     Transition: State (1, 3) -> State (1, 3)
# At time 49.44: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.51 minutes (Overtime cost: 9.44)
#     Transition: State (1, 3) -> State (0, 3)
# At time 49.46: Customer type 1 served by Agent 2 in 0.57 minutes, waited 1.47 minutes (Overtime cost: 9.46)
# ...
#     Transition: State (1, 0) -> State (0, 0)
# At time 47.14: Customer type 2 served by Agent 2 in 0.34 minutes, waited 0.34 minutes (Overtime cost: 7.14)
#     Transition: State (0, 1) -> State (0, 0)
# At time 47.51: Customer type 1 served by Agent 1 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 7.51)
#     Transition: State (1, 0) -> State (1, 0)
# At time 47.60: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.22 minutes (Overtime cost: 7.60)
#     Transition: State (1, 0) -> State (0, 0)
# At time 47.81: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 7.81)
#     Transition: State (0, 1) -> State (0, 0)
# At time 48.30: Customer type 2 served by Agent 1 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 8.30)
#     Transition: State (0, 1) -> State (1, 0)
# At time 48.31: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.03 minutes (Overtime cost: 8.31)
#     Transition: State (1, 0) -> State (0, 0)
# At time 48.50: Customer type 1 served by Agent 2 in 1.13 minutes, waited 1.13 minutes (Overtime cost: 8.50)
#     Transition: State (1, 0) -> State (0, 0)
# At time 48.87: Customer type 1 served by Agent 1 in 0.34 minutes, waited 0.34 minutes (Overtime cost: 8.87)
#     Transition: State (1, 0) -> State (2, 0)
# At time 48.99: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.42 minutes (Overtime cost: 8.99)
#     Transition: State (1, 0) -> State (2, 0)
# At time 49.05: Customer type 1 served by Agent 1 in 0.18 minutes, waited 0.46 minutes (Overtime cost: 9.05)
#     Transition: State (2, 0) -> State (1, 0)
# At time 49.06: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.35 minutes (Overtime cost: 9.06)
#     Transition: State (2, 0) -> State (0, 0)
# At time 49.19: Customer type 1 served by Agent 1 in 0.13 minutes, waited 0.27 minutes (Overtime cost: 9.19)
#     Transition: State (1, 0) -> State (0, 0)
# At time 49.75: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.27 minutes (Overtime cost: 9.75)
#     Transition: State (1, 0) -> State (0, 2)
# At time 49.86: Customer type 2 served by Agent 1 in 0.11 minutes, waited 0.18 minutes (Overtime cost: 9.86)
#     Transition: State (0, 2) -> State (0, 1)
# At time 49.98: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.25 minutes (Overtime cost: 9.98)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.24: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 10.24)
#     Transition: State (1, 0) -> State (0, 0)
# At time 50.39: Customer type 1 served by Agent 2 in 0.72 minutes, waited 0.72 minutes (Overtime cost: 10.39)
#     Transition: State (1, 0) -> State (0, 1)
# At time 50.50: Customer type 2 served by Agent 2 in 0.11 minutes, waited 0.16 minutes (Overtime cost: 10.50)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.51: Customer type 2 served by Agent 1 in 0.27 minutes, waited 0.27 minutes (Overtime cost: 10.51)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.82: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 10.82)
#     Transition: State (1, 0) -> State (1, 1)
# At time 50.87: Customer type 1 served by Agent 2 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 10.87)
#     Transition: State (1, 0) -> State (0, 1)
# At time 50.89: Customer type 2 served by Agent 2 in 0.02 minutes, waited 0.07 minutes (Overtime cost: 10.89)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.95: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 10.95)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.37: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 11.37)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.44: Customer type 1 served by Agent 1 in 0.62 minutes, waited 0.77 minutes (Overtime cost: 11.44)
#     Transition: State (1, 1) -> State (0, 0)
# At time 51.70: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 11.70)
#     Transition: State (1, 0) -> State (0, 0)
# At time 52.02: Customer type 1 served by Agent 1 in 0.46 minutes, waited 0.46 minutes (Overtime cost: 12.02)
#     Transition: State (1, 0) -> State (0, 1)
# At time 52.07: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 12.07)
#     Transition: State (1, 0) -> State (0, 0)
# At time 52.30: Customer type 2 served by Agent 2 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 12.30)
#     Transition: State (0, 1) -> State (0, 1)
# At time 52.70: Customer type 2 served by Agent 1 in 0.67 minutes, waited 0.74 minutes (Overtime cost: 12.70)
#     Transition: State (0, 1) -> State (1, 1)
# At time 52.81: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.24 minutes (Overtime cost: 12.81)
#     Transition: State (1, 1) -> State (0, 1)
# At time 52.88: Customer type 1 served by Agent 2 in 0.58 minutes, waited 0.58 minutes (Overtime cost: 12.88)
#     Transition: State (1, 1) -> State (0, 0)
# At time 53.23: Customer type 2 served by Agent 1 in 0.42 minutes, waited 0.98 minutes (Overtime cost: 13.23)
#     Transition: State (0, 1) -> State (0, 0)
# At time 53.48: Customer type 1 served by Agent 2 in 0.38 minutes, waited 0.38 minutes (Overtime cost: 13.48)
#     Transition: State (1, 0) -> State (0, 0)
# At time 53.51: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.14 minutes (Overtime cost: 13.51)
#     Transition: State (0, 1) -> State (0, 0)
# At time 53.96: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 13.96)
#     Transition: State (1, 0) -> State (1, 1)
# At time 54.10: Customer type 1 served by Agent 1 in 0.44 minutes, waited 0.44 minutes (Overtime cost: 14.10)
#     Transition: State (1, 0) -> State (0, 1)
# At time 54.29: Customer type 2 served by Agent 1 in 0.18 minutes, waited 0.43 minutes (Overtime cost: 14.29)
#     Transition: State (0, 1) -> State (2, 1)
# At time 54.76: Customer type 1 served by Agent 2 in 0.79 minutes, waited 0.84 minutes (Overtime cost: 14.76)
#     Transition: State (1, 1) -> State (3, 3)
# At time 54.94: Customer type 1 served by Agent 2 in 0.18 minutes, waited 0.69 minutes (Overtime cost: 14.94)
#     Transition: State (3, 3) -> State (4, 3)
# At time 55.50: Customer type 1 served by Agent 2 in 0.57 minutes, waited 1.18 minutes (Overtime cost: 15.50)
#     Transition: State (4, 3) -> State (6, 3)
# At time 55.53: Customer type 1 served by Agent 2 in 0.03 minutes, waited 1.06 minutes (Overtime cost: 15.53)
#     Transition: State (6, 3) -> State (5, 3)
# At time 55.59: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.80 minutes (Overtime cost: 15.59)
#     Transition: State (5, 3) -> State (4, 4)
# At time 55.64: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.82 minutes (Overtime cost: 15.64)
#     Transition: State (4, 4) -> State (3, 4)
# At time 55.74: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.73 minutes (Overtime cost: 15.74)
#     Transition: State (3, 4) -> State (3, 5)
# At time 55.79: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.70 minutes (Overtime cost: 15.79)
#     Transition: State (3, 5) -> State (3, 5)
# At time 56.20: Customer type 1 served by Agent 2 in 0.41 minutes, waited 0.86 minutes (Overtime cost: 16.20)
#     Transition: State (3, 5) -> State (6, 5)
# At time 56.33: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.60 minutes (Overtime cost: 16.33)
#     Transition: State (6, 5) -> State (5, 5)
# At time 56.37: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.60 minutes (Overtime cost: 16.37)
#     Transition: State (5, 5) -> State (4, 5)
# At time 56.41: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.50 minutes (Overtime cost: 16.41)
#     Transition: State (4, 5) -> State (3, 5)
# At time 56.69: Customer type 1 served by Agent 2 in 0.27 minutes, waited 0.54 minutes (Overtime cost: 16.69)
#     Transition: State (3, 5) -> State (4, 6)
# At time 56.69: Customer type 1 served by Agent 1 in 2.40 minutes, waited 2.46 minutes (Overtime cost: 16.69)
#     Transition: State (2, 1) -> State (3, 6)
# At time 56.77: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.57 minutes (Overtime cost: 16.77)
#     Transition: State (3, 6) -> State (3, 6)
# At time 56.84: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.31 minutes (Overtime cost: 16.84)
#     Transition: State (3, 6) -> State (2, 6)
# At time 56.98: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.83 minutes (Overtime cost: 16.98)
#     Transition: State (4, 6) -> State (1, 6)
# At time 57.35: Customer type 1 served by Agent 1 in 0.51 minutes, waited 0.79 minutes (Overtime cost: 17.35)
#     Transition: State (2, 6) -> State (0, 8)
# At time 57.40: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.69 minutes (Overtime cost: 17.40)
#     Transition: State (1, 6) -> State (0, 7)
# At time 57.55: Customer type 2 served by Agent 1 in 0.20 minutes, waited 3.44 minutes (Overtime cost: 17.55)
#     Transition: State (0, 8) -> State (0, 8)
# At time 57.61: Customer type 2 served by Agent 1 in 0.05 minutes, waited 2.96 minutes (Overtime cost: 17.61)
#     Transition: State (0, 8) -> State (0, 7)
# At time 57.83: Customer type 2 served by Agent 2 in 0.43 minutes, waited 3.29 minutes (Overtime cost: 17.83)
#     Transition: State (0, 7) -> State (4, 6)
# At time 57.89: Customer type 2 served by Agent 1 in 0.28 minutes, waited 2.33 minutes (Overtime cost: 17.89)
#     Transition: State (0, 7) -> State (3, 6)
# At time 58.08: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.37 minutes (Overtime cost: 18.08)
#     Transition: State (4, 6) -> State (5, 8)
# At time 58.19: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.38 minutes (Overtime cost: 18.19)
#     Transition: State (3, 6) -> State (6, 8)
# At time 58.23: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.42 minutes (Overtime cost: 18.23)
#     Transition: State (5, 8) -> State (5, 8)
# At time 58.97: Customer type 1 served by Agent 2 in 0.73 minutes, waited 1.07 minutes (Overtime cost: 18.97)
#     Transition: State (5, 8) -> State (6, 8)
# At time 58.98: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.98 minutes (Overtime cost: 18.98)
#     Transition: State (6, 8) -> State (5, 8)
# At time 59.15: Customer type 1 served by Agent 1 in 0.97 minutes, waited 1.33 minutes (Overtime cost: 19.15)
#     Transition: State (6, 8) -> State (4, 9)
# At time 59.34: Customer type 1 served by Agent 2 in 0.36 minutes, waited 1.30 minutes (Overtime cost: 19.34)
#     Transition: State (5, 8) -> State (3, 9)
# At time 59.57: Customer type 1 served by Agent 1 in 0.42 minutes, waited 1.45 minutes (Overtime cost: 19.57)
#     Transition: State (4, 9) -> State (2, 9)
#
# Total customers served: 340
# Total waiting time: 202.35 minutes
# Total agent overtime cost: 1065.46 minutes
# Average waiting time per customer: 0.60 minutes
#
# Transition Probabilities:
#   P((0, 0) | (0, 1)) = 0.6486
#   P((2, 1) | (1, 0)) = 0.0361
#   P((1, 1) | (2, 1)) = 0.4444
#   P((0, 2) | (1, 0)) = 0.0241
#   P((1, 1) | (0, 2)) = 0.3333
#   P((0, 3) | (1, 1)) = 0.0385
#   P((0, 3) | (1, 2)) = 0.2500
#   P((1, 1) | (0, 3)) = 0.1000
#   P((0, 1) | (1, 1)) = 0.4231
#   P((1, 2) | (0, 2)) = 0.0833
#   P((0, 2) | (0, 1)) = 0.0541
#   P((0, 1) | (1, 2)) = 0.2500
#   P((1, 1) | (0, 1)) = 0.0405
#   P((0, 0) | (0, 2)) = 0.2917
#   P((0, 0) | (1, 0)) = 0.5060
#   P((0, 1) | (0, 1)) = 0.0405
#   P((0, 1) | (1, 0)) = 0.1566
#   P((1, 2) | (0, 1)) = 0.0135
#   P((3, 3) | (1, 2)) = 0.0833
#   P((3, 3) | (3, 3)) = 0.3333
#   P((4, 3) | (0, 1)) = 0.0135
#   P((3, 4) | (4, 3)) = 0.5000
#   P((7, 4) | (3, 3)) = 0.3333
#   P((6, 4) | (7, 4)) = 1.0000
#   P((5, 4) | (6, 4)) = 1.0000
#   P((6, 4) | (5, 4)) = 0.5000
#   P((5, 4) | (3, 4)) = 0.2000
#   P((4, 4) | (5, 4)) = 0.2500
#   P((3, 4) | (4, 4)) = 0.7500
#   P((2, 4) | (5, 4)) = 0.2500
#   P((2, 4) | (2, 4)) = 0.2000
#   P((1, 4) | (2, 4)) = 0.6000
#   P((0, 4) | (1, 4)) = 0.4000
#   P((0, 3) | (3, 4)) = 0.2000
#   P((0, 2) | (0, 3)) = 0.3000
#   P((1, 1) | (1, 1)) = 0.0769
#   P((0, 1) | (0, 4)) = 0.1667
#   P((1, 2) | (1, 1)) = 0.0769
#   P((0, 2) | (1, 2)) = 0.2500
#   P((0, 2) | (0, 2)) = 0.0833
#   P((0, 2) | (1, 1)) = 0.1923
#   P((1, 3) | (1, 2)) = 0.0833
#   P((0, 3) | (0, 2)) = 0.0417
#   P((0, 2) | (1, 3)) = 0.2857
#   P((0, 1) | (0, 3)) = 0.2000
#   P((3, 1) | (0, 1)) = 0.0270
#   P((2, 1) | (3, 1)) = 0.5000
#   P((1, 1) | (1, 0)) = 0.0602
#   P((0, 0) | (2, 1)) = 0.2222
#   P((1, 0) | (0, 1)) = 0.0946
#   P((1, 0) | (1, 0)) = 0.0964
#   P((2, 0) | (1, 0)) = 0.0602
#   P((4, 0) | (2, 0)) = 0.1111
#   P((3, 0) | (1, 0)) = 0.0120
#   P((2, 0) | (4, 0)) = 1.0000
#   P((1, 1) | (3, 0)) = 0.5000
#   P((1, 1) | (2, 0)) = 0.1111
#   P((3, 1) | (2, 0)) = 0.1111
#   P((1, 2) | (2, 1)) = 0.1111
#   P((1, 2) | (3, 1)) = 0.2500
#   P((3, 2) | (2, 2)) = 0.1667
#   P((2, 2) | (3, 2)) = 0.2500
#   P((2, 2) | (2, 2)) = 0.3333
#   P((1, 2) | (1, 2)) = 0.0833
#   P((1, 3) | (2, 2)) = 0.1667
#   P((2, 1) | (0, 2)) = 0.0417
#   P((1, 4) | (1, 1)) = 0.0385
#   P((2, 4) | (1, 4)) = 0.2000
#   P((1, 5) | (2, 0)) = 0.1111
#   P((0, 5) | (2, 4)) = 0.2000
#   P((1, 4) | (0, 5)) = 1.0000
#   P((1, 3) | (0, 4)) = 0.1667
#   P((2, 3) | (1, 3)) = 0.1429
#   P((1, 3) | (1, 5)) = 1.0000
#   P((0, 3) | (1, 3)) = 0.4286
#   P((1, 2) | (2, 3)) = 0.5000
#   P((0, 1) | (0, 2)) = 0.1250
#   P((2, 1) | (2, 1)) = 0.1111
#   P((1, 2) | (0, 3)) = 0.1000
#   P((3, 0) | (2, 0)) = 0.1111
#   P((2, 0) | (3, 0)) = 0.5000
#   P((1, 0) | (2, 0)) = 0.3333
#   P((3, 1) | (1, 0)) = 0.0120
#   P((1, 1) | (3, 1)) = 0.2500
#   P((2, 1) | (1, 1)) = 0.0385
#   P((5, 2) | (0, 1)) = 0.0135
#   P((4, 2) | (5, 2)) = 1.0000
#   P((3, 2) | (1, 0)) = 0.0120
#   P((3, 2) | (3, 2)) = 0.5000
#   P((2, 3) | (3, 2)) = 0.2500
#   P((2, 4) | (2, 3)) = 0.5000
#   P((0, 4) | (4, 2)) = 1.0000
#   P((1, 3) | (1, 4)) = 0.2000
#   P((0, 3) | (0, 4)) = 0.1667
#   P((1, 2) | (1, 3)) = 0.1429
#   P((0, 4) | (0, 3)) = 0.1000
#   P((0, 2) | (0, 4)) = 0.1667
#   P((4, 4) | (0, 1)) = 0.0135
#   P((3, 4) | (0, 1)) = 0.0135
#   P((4, 4) | (4, 4)) = 0.2500
#   P((2, 4) | (3, 4)) = 0.2000
#   P((0, 4) | (3, 4)) = 0.2000
#   P((0, 4) | (0, 4)) = 0.1667
#   P((0, 3) | (1, 4)) = 0.2000
#   P((2, 2) | (0, 4)) = 0.1667
#   P((1, 3) | (0, 3)) = 0.1000
#   P((0, 3) | (2, 2)) = 0.1667
#   P((0, 0) | (0, 3)) = 0.1000
#   P((2, 2) | (1, 0)) = 0.0120
#   P((1, 2) | (1, 0)) = 0.0120
#   P((0, 2) | (2, 2)) = 0.1667
#   P((2, 0) | (0, 1)) = 0.0135
#   P((0, 0) | (2, 0)) = 0.1111
#   P((0, 0) | (1, 1)) = 0.0769
#   P((2, 1) | (0, 1)) = 0.0135
#   P((3, 3) | (1, 1)) = 0.0385
#   P((4, 3) | (3, 3)) = 0.3333
#   P((6, 3) | (4, 3)) = 0.5000
#   P((5, 3) | (6, 3)) = 1.0000
#   P((4, 4) | (5, 3)) = 1.0000
#   P((3, 5) | (3, 4)) = 0.2000
#   P((3, 5) | (3, 5)) = 0.3333
#   P((6, 5) | (3, 5)) = 0.3333
#   P((5, 5) | (6, 5)) = 1.0000
#   P((4, 5) | (5, 5)) = 1.0000
#   P((3, 5) | (4, 5)) = 1.0000
#   P((4, 6) | (3, 5)) = 0.3333
#   P((3, 6) | (2, 1)) = 0.1111
#   P((3, 6) | (3, 6)) = 0.3333
#   P((2, 6) | (3, 6)) = 0.3333
#   P((1, 6) | (4, 6)) = 0.5000
#   P((0, 8) | (2, 6)) = 1.0000
#   P((0, 7) | (1, 6)) = 1.0000
#   P((0, 8) | (0, 8)) = 0.5000
#   P((0, 7) | (0, 8)) = 0.5000
#   P((4, 6) | (0, 7)) = 0.5000
#   P((3, 6) | (0, 7)) = 0.5000
#   P((5, 8) | (4, 6)) = 0.5000
#   P((6, 8) | (3, 6)) = 0.3333
#   P((5, 8) | (5, 8)) = 0.3333
#   P((6, 8) | (5, 8)) = 0.3333
#   P((5, 8) | (6, 8)) = 0.5000
#   P((4, 9) | (6, 8)) = 0.5000
#   P((3, 9) | (5, 8)) = 0.3333
#   P((2, 9) | (4, 9)) = 1.0000
#
# Comparison of Waiting Times:
# With Longest Waiting Customer Function: 303.16 minutes
# Without Longest Waiting Customer Function: 202.35 minutes
# Difference in Waiting Time: -100.81 minutes
#
# Comparison of Agent Overtime Costs:
# With Longest Waiting Customer Function: 1339.54
# Without Longest Waiting Customer Function: 1065.46
# Difference in Agent Overtime Cost: -274.08
#                       Metric  With Longest Waiting  Without Longest Waiting  Difference (Without - With)
# Total Waiting Time (minutes)            303.156616               202.347835                  -100.808780
#    Total Agent Overtime Cost           1339.535146              1065.459640                  -274.075507
#       Total Customers Served            380.000000               340.000000                   -40.000000

# %%
import numpy as np
import simpy
import pandas as pd

# Define parameters
lambda_1 = 4  # Arrival rate for primary questions (customers per minute)
lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
mu_1 = 3      # Service rate for less experienced agent (customers per minute)
mu_2 = 4      # Service rate for more experienced agent (customers per minute)
# M = 5         # Maximum number of calls in the system
T = 40        # Simulation time horizon in minutes
dt = 0.6

overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)

class CallCenter:
    def __init__(self, env, dt, use_longest_waiting=True):
        self.env = env
        self.dt = dt
        self.use_longest_waiting = use_longest_waiting
        self.queue_1 = simpy.Store(env)  # Queue for primary questions
        self.queue_2 = simpy.Store(env)  # Queue for complex questions
        self.agent_1 = simpy.Resource(env, capacity=1)
        self.agent_2 = simpy.Resource(env, capacity=1)
        self.total_waiting_time = 0
        self.total_agent_overtime_cost = 0  # Track only agent overtime costs
        self.total_rewards = 0  # Track total rewards
        self.customers_served = 0
        self.transition_counts = {}  # Track state transitions
        self.state_counts = {}  # Count visits to states

    def record_transition(self, current_state, next_state):
        """Records state transitions for computing probabilities."""
        self.transition_counts[(current_state, next_state)] = (
            self.transition_counts.get((current_state, next_state), 0) + 1
        )
        self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

    def calculate_transition_probabilities(self):
        """Calculates transition probabilities from recorded transitions."""
        probabilities = {}
        for (current_state, next_state), count in self.transition_counts.items():
            total_transitions_from_state = self.state_counts[current_state]
            probabilities[(current_state, next_state)] = count / total_transitions_from_state
        return probabilities

    def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
        with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
            yield request
            service_time = np.random.exponential(1 / service_rate)
            end_time = self.env.now + service_time  # Calculate when the service will end

            # Simulate the service time
            yield self.env.timeout(service_time)

            wait_time = self.env.now - arrival_time  # Calculate wait time
            self.total_waiting_time += wait_time

            # Initialize agent_overtime_cost to zero
            agent_overtime_cost = 0

            # Check for overtime due to working beyond T
            if end_time > T:
                overtime_hours = end_time - T
                agent_overtime_cost = overtime_hours * overtime_cost_rate
                self.total_agent_overtime_cost += agent_overtime_cost

            # Update rewards
            reward = -(wait_time + agent_overtime_cost)  # Negative rewards for wait time and overtime
            self.total_rewards += reward

            self.customers_served += 1

            next_state = (len(self.queue_1.items), len(self.queue_2.items))

            # Record the state transition
            self.record_transition(state, next_state)

            # Log details
            print(
                f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
                f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
                f"(Overtime cost: {agent_overtime_cost:.2f}, Reward: {reward:.2f})"
            )
            print(f"    Transition: State {state} -> State {next_state}")

    def assign_customer(self):
        while True:
            if self.agent_1.count == 0 or self.agent_2.count == 0:
                queue, customer_type, arrival_time = self.select_customer()

                if queue is not None:
                    state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state
                    yield queue.get()

                    chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"
                    service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

                    # Start handling the customer
                    self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

            # Update rewards based on current queue lengths
            queue_penalty = -(len(self.queue_1.items) + len(self.queue_2.items))  # Negative reward for queue lengths
            self.total_rewards += queue_penalty

            yield self.env.timeout(dt)  # Allow other processes to run

    def select_customer(self):
        """Selects the customer based on the queue and waiting strategy."""
        if self.use_longest_waiting:
            return self.select_longest_waiting_customer()
        return self.select_first_come_first_served_customer()

    def select_longest_waiting_customer(self):
        """Select the longest waiting customer from the queues."""
        if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            customer_2, arrival_time_2 = self.queue_2.items[0]
            if arrival_time_1 <= arrival_time_2:
                return self.queue_1, customer_1, arrival_time_1
            else:
                return self.queue_2, customer_2, arrival_time_2
        elif len(self.queue_1.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            return self.queue_1, customer_1, arrival_time_1
        elif len(self.queue_2.items) > 0:
            customer_2, arrival_time_2 = self.queue_2.items[0]
            return self.queue_2, customer_2, arrival_time_2
        else:
            return None, None, None

    def select_first_come_first_served_customer(self):
        """Select the first customer from queue 1 or queue 2."""
        if len(self.queue_1.items) > 0:
            return self.queue_1, *self.queue_1.items[0]
        elif len(self.queue_2.items) > 0:
            return self.queue_2, *self.queue_2.items[0]
        return None, None, None

    def customer_arrival(self, customer_type, arrival_rate):
        while True:
            inter_arrival_time = np.random.exponential(1 / arrival_rate)
            yield self.env.timeout(inter_arrival_time)
            arrival_time = self.env.now

            if customer_type == 1:
                self.queue_1.put((customer_type, arrival_time))
            else:
                self.queue_2.put((customer_type, arrival_time))

            self.env.process(self.assign_customer())


def run_simulation(simulation_time, use_longest_waiting=True):
    env = simpy.Environment()
    call_center = CallCenter(env, dt, use_longest_waiting)

    env.process(call_center.customer_arrival(1, lambda_1))
    env.process(call_center.customer_arrival(2, lambda_2))

    env.run(until=simulation_time)

    print(f"\nTotal customers served: {call_center.customers_served}")
    print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
    print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
    print(f"Total rewards: {call_center.total_rewards:.2f}")
    print(f"Average waiting time per customer: "
          f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

    # Calculate and display transition probabilities
    probabilities = call_center.calculate_transition_probabilities()
    print("\nTransition Probabilities:")
    for (initial_state, final_state), prob in probabilities.items():
        print(f"  P({final_state} | {initial_state}) = {prob:.4f}")

    return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, call_center.total_rewards, probabilities


# Run the simulations
simulation_time = 60

# With longest waiting customer function
waiting_time_longest, agent_overtime_longest, served_longest, rewards_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# Without longest waiting customer function
waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, rewards_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)

# Prepare the results for the table
results_data = {
    "Metric": [
        "Total Waiting Time (minutes)",
        "Total Agent Overtime Cost",
        "Total Customers Served",
        "Total Rewards"
    ],
    "With Longest Waiting": [
        waiting_time_longest,
        agent_overtime_longest,
        served_longest,
        rewards_longest
    ],
    "Without Longest Waiting": [
        waiting_time_fcfs,
        agent_overtime_fcfs,
        served_fcfs,
        rewards_fcfs
    ],
    "Difference (Without - With)": [
        waiting_time_fcfs - waiting_time_longest,
        agent_overtime_fcfs - agent_overtime_longest,
        served_fcfs - served_longest,
        rewards_fcfs - rewards_longest
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(results_data)

# Display the results as a table
print(results_df.to_string(index=False))
# Out:
# At time 0.31: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.14 minutes (Overtime cost: 0.00, Reward: -0.14)
#     Transition: State (0, 1) -> State (0, 0)
# At time 0.59: Customer type 1 served by Agent 2 in 0.41 minutes, waited 0.41 minutes (Overtime cost: 0.00, Reward: -0.41)
#     Transition: State (1, 0) -> State (0, 2)
# At time 0.86: Customer type 1 served by Agent 1 in 0.50 minutes, waited 0.50 minutes (Overtime cost: 0.00, Reward: -0.50)
#     Transition: State (1, 0) -> State (0, 1)
# At time 1.10: Customer type 2 served by Agent 2 in 0.32 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (0, 2) -> State (0, 0)
# At time 1.31: Customer type 2 served by Agent 1 in 0.36 minutes, waited 0.83 minutes (Overtime cost: 0.00, Reward: -0.83)
#     Transition: State (0, 1) -> State (1, 1)
# At time 1.39: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00, Reward: -0.12)
#     Transition: State (1, 0) -> State (1, 1)
# At time 1.57: Customer type 2 served by Agent 1 in 0.20 minutes, waited 0.29 minutes (Overtime cost: 0.00, Reward: -0.29)
#     Transition: State (1, 2) -> State (0, 1)
# At time 1.91: Customer type 2 served by Agent 1 in 0.31 minutes, waited 0.54 minutes (Overtime cost: 0.00, Reward: -0.54)
#     Transition: State (1, 1) -> State (4, 1)
# At time 1.98: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.38 minutes (Overtime cost: 0.00, Reward: -0.38)
#     Transition: State (5, 1) -> State (4, 1)
# At time 2.47: Customer type 1 served by Agent 1 in 0.49 minutes, waited 0.83 minutes (Overtime cost: 0.00, Reward: -0.83)
#     Transition: State (4, 1) -> State (5, 1)
# At time 2.77: Customer type 1 served by Agent 2 in 1.21 minutes, waited 1.47 minutes (Overtime cost: 0.00, Reward: -1.47)
#     Transition: State (1, 1) -> State (5, 0)
# At time 2.93: Customer type 2 served by Agent 1 in 0.45 minutes, waited 1.24 minutes (Overtime cost: 0.00, Reward: -1.24)
#     Transition: State (5, 1) -> State (6, 2)
# At time 3.14: Customer type 1 served by Agent 1 in 0.09 minutes, waited 1.27 minutes (Overtime cost: 0.00, Reward: -1.27)
#     Transition: State (6, 2) -> State (5, 2)
# At time 3.31: Customer type 1 served by Agent 2 in 0.51 minutes, waited 1.60 minutes (Overtime cost: 0.00, Reward: -1.60)
#     Transition: State (5, 0) -> State (5, 2)
# At time 3.48: Customer type 1 served by Agent 2 in 0.13 minutes, waited 1.43 minutes (Overtime cost: 0.00, Reward: -1.43)
#     Transition: State (5, 2) -> State (4, 2)
# At time 3.61: Customer type 1 served by Agent 1 in 0.47 minutes, waited 1.69 minutes (Overtime cost: 0.00, Reward: -1.69)
#     Transition: State (6, 2) -> State (3, 2)
# At time 3.64: Customer type 1 served by Agent 2 in 0.15 minutes, waited 1.19 minutes (Overtime cost: 0.00, Reward: -1.19)
#     Transition: State (4, 2) -> State (3, 2)
# At time 3.75: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.88 minutes (Overtime cost: 0.00, Reward: -0.88)
#     Transition: State (3, 1) -> State (3, 1)
# At time 3.84: Customer type 2 served by Agent 1 in 0.19 minutes, waited 1.01 minutes (Overtime cost: 0.00, Reward: -1.01)
#     Transition: State (3, 2) -> State (2, 1)
# At time 3.87: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.94 minutes (Overtime cost: 0.00, Reward: -0.94)
#     Transition: State (2, 1) -> State (2, 0)
# At time 3.87: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.96 minutes (Overtime cost: 0.00, Reward: -0.96)
#     Transition: State (3, 1) -> State (2, 0)
# At time 4.28: Customer type 1 served by Agent 1 in 0.32 minutes, waited 1.13 minutes (Overtime cost: 0.00, Reward: -1.13)
#     Transition: State (2, 0) -> State (1, 1)
# At time 4.39: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.22 minutes (Overtime cost: 0.00, Reward: -0.22)
#     Transition: State (1, 1) -> State (1, 1)
# At time 4.46: Customer type 1 served by Agent 2 in 0.46 minutes, waited 0.71 minutes (Overtime cost: 0.00, Reward: -0.71)
#     Transition: State (1, 0) -> State (1, 0)
# At time 4.77: Customer type 2 served by Agent 1 in 0.32 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (1, 1) -> State (1, 0)
# At time 5.02: Customer type 1 served by Agent 1 in 0.18 minutes, waited 0.46 minutes (Overtime cost: 0.00, Reward: -0.46)
#     Transition: State (1, 0) -> State (1, 0)
# At time 5.43: Customer type 1 served by Agent 2 in 0.88 minutes, waited 1.05 minutes (Overtime cost: 0.00, Reward: -1.05)
#     Transition: State (1, 0) -> State (2, 0)
# At time 5.55: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.34 minutes (Overtime cost: 0.00, Reward: -0.34)
#     Transition: State (2, 0) -> State (1, 0)
# At time 5.67: Customer type 1 served by Agent 1 in 0.62 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (1, 0) -> State (0, 1)
# At time 5.77: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.45 minutes (Overtime cost: 0.00, Reward: -0.45)
#     Transition: State (1, 0) -> State (0, 0)
# At time 5.83: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.21 minutes (Overtime cost: 0.00, Reward: -0.21)
#     Transition: State (0, 1) -> State (0, 0)
# At time 5.96: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (1, 0) -> State (0, 1)
# At time 6.11: Customer type 2 served by Agent 2 in 0.14 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (0, 1) -> State (0, 1)
# At time 6.11: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (1, 0) -> State (0, 1)
# At time 6.18: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.06 minutes (Overtime cost: 0.00, Reward: -0.06)
#     Transition: State (1, 0) -> State (0, 0)
# At time 6.47: Customer type 2 served by Agent 1 in 0.35 minutes, waited 0.38 minutes (Overtime cost: 0.00, Reward: -0.38)
#     Transition: State (1, 1) -> State (1, 1)
# At time 6.68: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (1, 1) -> State (0, 2)
# At time 6.82: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.47 minutes (Overtime cost: 0.00, Reward: -0.47)
#     Transition: State (0, 2) -> State (0, 2)
# At time 6.89: Customer type 1 served by Agent 2 in 0.70 minutes, waited 0.70 minutes (Overtime cost: 0.00, Reward: -0.70)
#     Transition: State (1, 0) -> State (0, 1)
# At time 7.81: Customer type 2 served by Agent 2 in 0.89 minutes, waited 1.00 minutes (Overtime cost: 0.00, Reward: -1.00)
#     Transition: State (1, 1) -> State (6, 1)
# At time 8.00: Customer type 2 served by Agent 1 in 1.15 minutes, waited 1.32 minutes (Overtime cost: 0.00, Reward: -1.32)
#     Transition: State (0, 2) -> State (7, 3)
# At time 8.26: Customer type 1 served by Agent 2 in 0.44 minutes, waited 1.33 minutes (Overtime cost: 0.00, Reward: -1.33)
#     Transition: State (7, 1) -> State (11, 3)
# At time 8.65: Customer type 1 served by Agent 2 in 0.39 minutes, waited 1.43 minutes (Overtime cost: 0.00, Reward: -1.43)
#     Transition: State (11, 3) -> State (10, 3)
# At time 8.67: Customer type 1 served by Agent 2 in 0.01 minutes, waited 1.25 minutes (Overtime cost: 0.00, Reward: -1.25)
#     Transition: State (10, 3) -> State (9, 3)
# At time 8.96: Customer type 1 served by Agent 2 in 0.23 minutes, waited 1.41 minutes (Overtime cost: 0.00, Reward: -1.41)
#     Transition: State (9, 3) -> State (9, 3)
# At time 9.16: Customer type 1 served by Agent 1 in 1.15 minutes, waited 2.08 minutes (Overtime cost: 0.00, Reward: -2.08)
#     Transition: State (7, 3) -> State (9, 2)
# At time 9.18: Customer type 2 served by Agent 2 in 0.21 minutes, waited 1.47 minutes (Overtime cost: 0.00, Reward: -1.47)
#     Transition: State (9, 3) -> State (8, 2)
# At time 9.19: Customer type 1 served by Agent 1 in 0.02 minutes, waited 1.45 minutes (Overtime cost: 0.00, Reward: -1.45)
#     Transition: State (9, 2) -> State (7, 2)
# At time 9.30: Customer type 1 served by Agent 2 in 0.11 minutes, waited 1.48 minutes (Overtime cost: 0.00, Reward: -1.48)
#     Transition: State (8, 2) -> State (7, 1)
# At time 9.39: Customer type 1 served by Agent 2 in 0.07 minutes, waited 1.48 minutes (Overtime cost: 0.00, Reward: -1.48)
#     Transition: State (7, 1) -> State (6, 1)
# At time 9.49: Customer type 2 served by Agent 1 in 0.28 minutes, waited 1.61 minutes (Overtime cost: 0.00, Reward: -1.61)
#     Transition: State (7, 2) -> State (6, 0)
# At time 9.51: Customer type 2 served by Agent 2 in 0.12 minutes, waited 1.55 minutes (Overtime cost: 0.00, Reward: -1.55)
#     Transition: State (6, 1) -> State (5, 0)
# At time 9.69: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.63 minutes (Overtime cost: 0.00, Reward: -1.63)
#     Transition: State (5, 0) -> State (5, 0)
# At time 9.80: Customer type 1 served by Agent 1 in 0.31 minutes, waited 1.79 minutes (Overtime cost: 0.00, Reward: -1.79)
#     Transition: State (6, 0) -> State (5, 0)
# At time 9.85: Customer type 1 served by Agent 1 in 0.04 minutes, waited 1.67 minutes (Overtime cost: 0.00, Reward: -1.67)
#     Transition: State (5, 0) -> State (4, 0)
# At time 9.95: Customer type 1 served by Agent 1 in 0.10 minutes, waited 1.72 minutes (Overtime cost: 0.00, Reward: -1.72)
#     Transition: State (4, 0) -> State (4, 0)
# At time 10.06: Customer type 1 served by Agent 2 in 0.37 minutes, waited 1.88 minutes (Overtime cost: 0.00, Reward: -1.88)
#     Transition: State (5, 0) -> State (3, 0)
# At time 10.50: Customer type 1 served by Agent 2 in 0.43 minutes, waited 0.83 minutes (Overtime cost: 0.00, Reward: -0.83)
#     Transition: State (3, 0) -> State (4, 3)
# At time 10.58: Customer type 1 served by Agent 1 in 0.62 minutes, waited 1.84 minutes (Overtime cost: 0.00, Reward: -1.84)
#     Transition: State (4, 0) -> State (3, 3)
# At time 10.64: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.73 minutes (Overtime cost: 0.00, Reward: -0.73)
#     Transition: State (3, 3) -> State (2, 3)
# At time 10.83: Customer type 1 served by Agent 2 in 0.33 minutes, waited 1.11 minutes (Overtime cost: 0.00, Reward: -1.11)
#     Transition: State (4, 3) -> State (2, 4)
# At time 10.96: Customer type 2 served by Agent 2 in 0.11 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (2, 4) -> State (2, 3)
# At time 11.69: Customer type 2 served by Agent 2 in 0.72 minutes, waited 1.33 minutes (Overtime cost: 0.00, Reward: -1.33)
#     Transition: State (2, 3) -> State (5, 2)
# At time 11.70: Customer type 1 served by Agent 1 in 1.06 minutes, waited 1.60 minutes (Overtime cost: 0.00, Reward: -1.60)
#     Transition: State (2, 3) -> State (5, 1)
# At time 11.94: Customer type 2 served by Agent 2 in 0.25 minutes, waited 1.54 minutes (Overtime cost: 0.00, Reward: -1.54)
#     Transition: State (5, 2) -> State (6, 1)
# At time 12.06: Customer type 2 served by Agent 2 in 0.10 minutes, waited 1.38 minutes (Overtime cost: 0.00, Reward: -1.38)
#     Transition: State (6, 1) -> State (6, 0)
# At time 12.07: Customer type 1 served by Agent 2 in 0.01 minutes, waited 1.39 minutes (Overtime cost: 0.00, Reward: -1.39)
#     Transition: State (6, 0) -> State (5, 0)
# At time 12.26: Customer type 1 served by Agent 1 in 0.56 minutes, waited 1.79 minutes (Overtime cost: 0.00, Reward: -1.79)
#     Transition: State (5, 1) -> State (6, 2)
# At time 12.38: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.88 minutes (Overtime cost: 0.00, Reward: -0.88)
#     Transition: State (6, 2) -> State (5, 2)
# At time 12.47: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.87 minutes (Overtime cost: 0.00, Reward: -0.87)
#     Transition: State (5, 2) -> State (5, 2)
# At time 12.75: Customer type 1 served by Agent 2 in 0.67 minutes, waited 1.65 minutes (Overtime cost: 0.00, Reward: -1.65)
#     Transition: State (5, 0) -> State (5, 2)
# At time 12.90: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (5, 2) -> State (4, 2)
# At time 12.99: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.90 minutes (Overtime cost: 0.00, Reward: -0.90)
#     Transition: State (4, 2) -> State (3, 3)
# At time 13.05: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.94 minutes (Overtime cost: 0.00, Reward: -0.94)
#     Transition: State (3, 3) -> State (3, 2)
# At time 13.15: Customer type 2 served by Agent 2 in 0.10 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (3, 2) -> State (3, 1)
# At time 13.16: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.98 minutes (Overtime cost: 0.00, Reward: -0.98)
#     Transition: State (3, 1) -> State (2, 1)
# At time 13.72: Customer type 1 served by Agent 2 in 0.55 minutes, waited 1.28 minutes (Overtime cost: 0.00, Reward: -1.28)
#     Transition: State (2, 1) -> State (3, 2)
# At time 14.37: Customer type 1 served by Agent 1 in 1.90 minutes, waited 2.64 minutes (Overtime cost: 0.00, Reward: -2.64)
#     Transition: State (5, 2) -> State (4, 2)
# At time 14.54: Customer type 1 served by Agent 2 in 0.81 minutes, waited 1.79 minutes (Overtime cost: 0.00, Reward: -1.79)
#     Transition: State (3, 2) -> State (5, 1)
# At time 14.59: Customer type 1 served by Agent 2 in 0.04 minutes, waited 1.39 minutes (Overtime cost: 0.00, Reward: -1.39)
#     Transition: State (5, 1) -> State (5, 1)
# At time 14.61: Customer type 2 served by Agent 1 in 0.21 minutes, waited 1.67 minutes (Overtime cost: 0.00, Reward: -1.67)
#     Transition: State (4, 2) -> State (4, 1)
# At time 14.73: Customer type 1 served by Agent 2 in 0.13 minutes, waited 1.40 minutes (Overtime cost: 0.00, Reward: -1.40)
#     Transition: State (5, 1) -> State (4, 0)
# At time 14.96: Customer type 1 served by Agent 2 in 0.23 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (4, 0) -> State (3, 0)
# At time 14.99: Customer type 2 served by Agent 1 in 0.37 minutes, waited 1.52 minutes (Overtime cost: 0.00, Reward: -1.52)
#     Transition: State (4, 1) -> State (2, 0)
# At time 15.02: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.52 minutes (Overtime cost: 0.00, Reward: -0.52)
#     Transition: State (2, 0) -> State (1, 0)
# At time 15.12: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.57 minutes (Overtime cost: 0.00, Reward: -0.57)
#     Transition: State (1, 0) -> State (0, 0)
# At time 15.63: Customer type 1 served by Agent 2 in 0.67 minutes, waited 1.52 minutes (Overtime cost: 0.00, Reward: -1.52)
#     Transition: State (3, 0) -> State (3, 1)
# At time 15.78: Customer type 1 served by Agent 1 in 0.61 minutes, waited 0.61 minutes (Overtime cost: 0.00, Reward: -0.61)
#     Transition: State (1, 0) -> State (3, 1)
# At time 15.80: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.55 minutes (Overtime cost: 0.00, Reward: -0.55)
#     Transition: State (3, 1) -> State (2, 1)
# At time 16.02: Customer type 1 served by Agent 2 in 0.38 minutes, waited 0.81 minutes (Overtime cost: 0.00, Reward: -0.81)
#     Transition: State (3, 1) -> State (2, 0)
# At time 16.20: Customer type 2 served by Agent 1 in 0.40 minutes, waited 0.69 minutes (Overtime cost: 0.00, Reward: -0.69)
#     Transition: State (2, 1) -> State (1, 0)
# At time 16.44: Customer type 1 served by Agent 1 in 0.24 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (1, 0) -> State (1, 0)
# At time 17.17: Customer type 1 served by Agent 1 in 0.72 minutes, waited 0.86 minutes (Overtime cost: 0.00, Reward: -0.86)
#     Transition: State (1, 0) -> State (2, 2)
# At time 17.27: Customer type 1 served by Agent 2 in 1.24 minutes, waited 1.66 minutes (Overtime cost: 0.00, Reward: -1.66)
#     Transition: State (2, 0) -> State (2, 1)
# At time 17.28: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.73 minutes (Overtime cost: 0.00, Reward: -0.73)
#     Transition: State (2, 2) -> State (1, 1)
# At time 17.45: Customer type 1 served by Agent 2 in 0.18 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (2, 1) -> State (2, 0)
# At time 17.53: Customer type 2 served by Agent 1 in 0.25 minutes, waited 0.58 minutes (Overtime cost: 0.00, Reward: -0.58)
#     Transition: State (1, 1) -> State (1, 0)
# At time 17.54: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (1, 0) -> State (1, 0)
# At time 17.62: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.70: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.69 minutes (Overtime cost: 0.00, Reward: -0.69)
#     Transition: State (2, 0) -> State (0, 0)
# At time 18.09: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (0, 1) -> State (0, 0)
# At time 18.43: Customer type 1 served by Agent 1 in 0.52 minutes, waited 0.52 minutes (Overtime cost: 0.00, Reward: -0.52)
#     Transition: State (1, 0) -> State (1, 0)
# At time 18.66: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.34 minutes (Overtime cost: 0.00, Reward: -0.34)
#     Transition: State (1, 0) -> State (1, 1)
# At time 18.87: Customer type 1 served by Agent 2 in 0.64 minutes, waited 0.64 minutes (Overtime cost: 0.00, Reward: -0.64)
#     Transition: State (1, 0) -> State (2, 1)
# At time 19.01: Customer type 2 served by Agent 2 in 0.14 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (2, 1) -> State (3, 1)
# At time 19.13: Customer type 1 served by Agent 1 in 0.46 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (1, 1) -> State (2, 1)
# At time 19.36: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.58 minutes (Overtime cost: 0.00, Reward: -0.58)
#     Transition: State (2, 1) -> State (1, 1)
# At time 19.45: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 1) -> State (1, 0)
# At time 19.89: Customer type 1 served by Agent 1 in 0.44 minutes, waited 0.89 minutes (Overtime cost: 0.00, Reward: -0.89)
#     Transition: State (1, 0) -> State (1, 0)
# At time 19.96: Customer type 1 served by Agent 2 in 0.95 minutes, waited 1.29 minutes (Overtime cost: 0.00, Reward: -1.29)
#     Transition: State (3, 1) -> State (1, 0)
# At time 20.05: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 20.05: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.38 minutes (Overtime cost: 0.00, Reward: -0.38)
#     Transition: State (1, 0) -> State (0, 0)
# At time 20.78: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.30 minutes (Overtime cost: 0.00, Reward: -0.30)
#     Transition: State (1, 0) -> State (0, 0)
# At time 21.06: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (1, 0) -> State (0, 0)
# At time 21.15: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (1, 0) -> State (0, 0)
# At time 21.57: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (1, 0) -> State (0, 0)
# At time 21.75: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00, Reward: -0.10)
#     Transition: State (0, 1) -> State (0, 0)
# At time 21.93: Customer type 1 served by Agent 1 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00, Reward: -0.17)
#     Transition: State (1, 0) -> State (0, 0)
# At time 22.03: Customer type 1 served by Agent 2 in 1.08 minutes, waited 1.08 minutes (Overtime cost: 0.00, Reward: -1.08)
#     Transition: State (1, 0) -> State (0, 0)
# At time 22.41: Customer type 1 served by Agent 1 in 0.35 minutes, waited 0.35 minutes (Overtime cost: 0.00, Reward: -0.35)
#     Transition: State (1, 0) -> State (1, 0)
# At time 22.43: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.08 minutes (Overtime cost: 0.00, Reward: -0.08)
#     Transition: State (1, 0) -> State (0, 0)
# At time 22.60: Customer type 2 served by Agent 2 in 0.45 minutes, waited 0.45 minutes (Overtime cost: 0.00, Reward: -0.45)
#     Transition: State (0, 1) -> State (0, 0)
# At time 22.98: Customer type 2 served by Agent 1 in 0.36 minutes, waited 0.36 minutes (Overtime cost: 0.00, Reward: -0.36)
#     Transition: State (0, 1) -> State (2, 0)
# At time 23.02: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.18 minutes (Overtime cost: 0.00, Reward: -0.18)
#     Transition: State (2, 0) -> State (1, 0)
# At time 23.63: Customer type 1 served by Agent 2 in 0.91 minutes, waited 0.91 minutes (Overtime cost: 0.00, Reward: -0.91)
#     Transition: State (1, 0) -> State (1, 3)
# At time 23.75: Customer type 1 served by Agent 1 in 0.73 minutes, waited 0.89 minutes (Overtime cost: 0.00, Reward: -0.89)
#     Transition: State (1, 0) -> State (1, 2)
# At time 23.85: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (1, 2) -> State (0, 2)
# At time 24.26: Customer type 2 served by Agent 2 in 0.61 minutes, waited 1.16 minutes (Overtime cost: 0.00, Reward: -1.16)
#     Transition: State (1, 3) -> State (1, 1)
# At time 24.49: Customer type 2 served by Agent 1 in 0.64 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (0, 2) -> State (2, 0)
# At time 24.97: Customer type 2 served by Agent 2 in 0.70 minutes, waited 1.44 minutes (Overtime cost: 0.00, Reward: -1.44)
#     Transition: State (1, 1) -> State (4, 0)
# At time 25.19: Customer type 1 served by Agent 1 in 0.69 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (2, 0) -> State (4, 0)
# At time 25.19: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.93 minutes (Overtime cost: 0.00, Reward: -0.93)
#     Transition: State (4, 0) -> State (4, 0)
# At time 25.41: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (3, 0) -> State (4, 0)
# At time 25.58: Customer type 1 served by Agent 2 in 0.16 minutes, waited 0.70 minutes (Overtime cost: 0.00, Reward: -0.70)
#     Transition: State (4, 0) -> State (3, 0)
# At time 25.74: Customer type 1 served by Agent 1 in 0.54 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (4, 0) -> State (3, 2)
# At time 25.91: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (3, 2) -> State (2, 2)
# At time 25.99: Customer type 1 served by Agent 2 in 0.41 minutes, waited 0.86 minutes (Overtime cost: 0.00, Reward: -0.86)
#     Transition: State (3, 0) -> State (1, 2)
# At time 26.08: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.40 minutes (Overtime cost: 0.00, Reward: -0.40)
#     Transition: State (1, 2) -> State (1, 1)
# At time 26.34: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (1, 1) -> State (1, 2)
# At time 26.46: Customer type 2 served by Agent 2 in 0.11 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (1, 2) -> State (1, 1)
# At time 26.65: Customer type 1 served by Agent 1 in 0.74 minutes, waited 1.36 minutes (Overtime cost: 0.00, Reward: -1.36)
#     Transition: State (2, 2) -> State (1, 2)
# At time 26.75: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.50 minutes (Overtime cost: 0.00, Reward: -0.50)
#     Transition: State (1, 1) -> State (1, 2)
# At time 26.76: Customer type 2 served by Agent 2 in 0.00 minutes, waited 0.21 minutes (Overtime cost: 0.00, Reward: -0.21)
#     Transition: State (1, 2) -> State (1, 1)
# At time 26.95: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.36 minutes (Overtime cost: 0.00, Reward: -0.36)
#     Transition: State (1, 1) -> State (2, 2)
# At time 27.00: Customer type 2 served by Agent 1 in 0.35 minutes, waited 0.68 minutes (Overtime cost: 0.00, Reward: -0.68)
#     Transition: State (1, 2) -> State (2, 1)
# At time 27.01: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.25 minutes (Overtime cost: 0.00, Reward: -0.25)
#     Transition: State (2, 1) -> State (3, 0)
# At time 27.10: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.21 minutes (Overtime cost: 0.00, Reward: -0.21)
#     Transition: State (3, 0) -> State (2, 0)
# At time 27.11: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (2, 0) -> State (1, 0)
# At time 27.61: Customer type 1 served by Agent 1 in 0.49 minutes, waited 0.61 minutes (Overtime cost: 0.00, Reward: -0.61)
#     Transition: State (1, 0) -> State (0, 1)
# At time 27.73: Customer type 2 served by Agent 2 in 0.78 minutes, waited 0.99 minutes (Overtime cost: 0.00, Reward: -0.99)
#     Transition: State (2, 2) -> State (3, 0)
# At time 27.91: Customer type 1 served by Agent 2 in 0.18 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (3, 0) -> State (3, 0)
# At time 28.32: Customer type 2 served by Agent 1 in 0.70 minutes, waited 0.71 minutes (Overtime cost: 0.00, Reward: -0.71)
#     Transition: State (0, 1) -> State (3, 0)
# At time 28.44: Customer type 1 served by Agent 2 in 0.54 minutes, waited 0.76 minutes (Overtime cost: 0.00, Reward: -0.76)
#     Transition: State (3, 0) -> State (2, 0)
# At time 28.50: Customer type 1 served by Agent 1 in 0.18 minutes, waited 0.79 minutes (Overtime cost: 0.00, Reward: -0.79)
#     Transition: State (3, 0) -> State (1, 0)
# At time 28.75: Customer type 1 served by Agent 2 in 0.31 minutes, waited 0.88 minutes (Overtime cost: 0.00, Reward: -0.88)
#     Transition: State (2, 0) -> State (1, 0)
# At time 28.99: Customer type 1 served by Agent 1 in 0.48 minutes, waited 1.01 minutes (Overtime cost: 0.00, Reward: -1.01)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.29: Customer type 1 served by Agent 2 in 0.54 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (1, 0) -> State (2, 2)
# At time 29.50: Customer type 1 served by Agent 1 in 0.50 minutes, waited 0.50 minutes (Overtime cost: 0.00, Reward: -0.50)
#     Transition: State (1, 0) -> State (4, 2)
# At time 29.80: Customer type 1 served by Agent 1 in 0.29 minutes, waited 0.60 minutes (Overtime cost: 0.00, Reward: -0.60)
#     Transition: State (4, 2) -> State (3, 2)
# At time 29.80: Customer type 1 served by Agent 2 in 0.50 minutes, waited 0.68 minutes (Overtime cost: 0.00, Reward: -0.68)
#     Transition: State (2, 2) -> State (3, 2)
# At time 30.04: Customer type 2 served by Agent 2 in 0.24 minutes, waited 0.75 minutes (Overtime cost: 0.00, Reward: -0.75)
#     Transition: State (3, 1) -> State (4, 1)
# At time 30.32: Customer type 2 served by Agent 1 in 0.52 minutes, waited 1.10 minutes (Overtime cost: 0.00, Reward: -1.10)
#     Transition: State (3, 2) -> State (4, 1)
# At time 30.48: Customer type 1 served by Agent 2 in 0.44 minutes, waited 1.12 minutes (Overtime cost: 0.00, Reward: -1.12)
#     Transition: State (5, 1) -> State (5, 1)
# At time 30.68: Customer type 1 served by Agent 2 in 0.19 minutes, waited 1.29 minutes (Overtime cost: 0.00, Reward: -1.29)
#     Transition: State (5, 1) -> State (5, 1)
# At time 30.76: Customer type 1 served by Agent 1 in 0.44 minutes, waited 1.39 minutes (Overtime cost: 0.00, Reward: -1.39)
#     Transition: State (4, 1) -> State (6, 0)
# At time 31.02: Customer type 2 served by Agent 2 in 0.34 minutes, waited 1.07 minutes (Overtime cost: 0.00, Reward: -1.07)
#     Transition: State (5, 1) -> State (5, 0)
# At time 31.20: Customer type 1 served by Agent 1 in 0.44 minutes, waited 1.17 minutes (Overtime cost: 0.00, Reward: -1.17)
#     Transition: State (6, 0) -> State (4, 0)
# At time 31.28: Customer type 1 served by Agent 2 in 0.26 minutes, waited 1.24 minutes (Overtime cost: 0.00, Reward: -1.24)
#     Transition: State (5, 0) -> State (4, 0)
# At time 31.56: Customer type 1 served by Agent 2 in 0.28 minutes, waited 1.14 minutes (Overtime cost: 0.00, Reward: -1.14)
#     Transition: State (4, 0) -> State (7, 1)
# At time 31.65: Customer type 1 served by Agent 2 in 0.09 minutes, waited 1.07 minutes (Overtime cost: 0.00, Reward: -1.07)
#     Transition: State (7, 1) -> State (6, 1)
# At time 31.71: Customer type 1 served by Agent 1 in 0.51 minutes, waited 1.31 minutes (Overtime cost: 0.00, Reward: -1.31)
#     Transition: State (4, 0) -> State (7, 2)
# At time 31.73: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (7, 2) -> State (6, 2)
# At time 31.82: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.53 minutes (Overtime cost: 0.00, Reward: -0.53)
#     Transition: State (6, 2) -> State (7, 2)
# At time 32.23: Customer type 1 served by Agent 2 in 0.56 minutes, waited 1.54 minutes (Overtime cost: 0.00, Reward: -1.54)
#     Transition: State (6, 1) -> State (8, 1)
# At time 32.31: Customer type 2 served by Agent 1 in 0.48 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (7, 2) -> State (7, 2)
# At time 32.57: Customer type 1 served by Agent 1 in 0.24 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (7, 2) -> State (9, 3)
# At time 32.62: Customer type 1 served by Agent 1 in 0.05 minutes, waited 1.09 minutes (Overtime cost: 0.00, Reward: -1.09)
#     Transition: State (9, 3) -> State (8, 3)
# At time 32.91: Customer type 1 served by Agent 2 in 0.68 minutes, waited 1.45 minutes (Overtime cost: 0.00, Reward: -1.45)
#     Transition: State (8, 1) -> State (9, 4)
# At time 32.97: Customer type 2 served by Agent 2 in 0.06 minutes, waited 1.28 minutes (Overtime cost: 0.00, Reward: -1.28)
#     Transition: State (9, 4) -> State (9, 3)
# At time 33.10: Customer type 1 served by Agent 1 in 0.47 minutes, waited 1.43 minutes (Overtime cost: 0.00, Reward: -1.43)
#     Transition: State (8, 3) -> State (8, 3)
# At time 33.32: Customer type 1 served by Agent 1 in 0.22 minutes, waited 1.54 minutes (Overtime cost: 0.00, Reward: -1.54)
#     Transition: State (8, 3) -> State (7, 5)
# At time 33.36: Customer type 1 served by Agent 1 in 0.04 minutes, waited 1.57 minutes (Overtime cost: 0.00, Reward: -1.57)
#     Transition: State (7, 5) -> State (6, 5)
# At time 33.42: Customer type 1 served by Agent 1 in 0.06 minutes, waited 1.24 minutes (Overtime cost: 0.00, Reward: -1.24)
#     Transition: State (6, 5) -> State (7, 5)
# At time 33.69: Customer type 2 served by Agent 1 in 0.27 minutes, waited 1.44 minutes (Overtime cost: 0.00, Reward: -1.44)
#     Transition: State (7, 5) -> State (9, 4)
# At time 33.91: Customer type 1 served by Agent 2 in 0.94 minutes, waited 2.22 minutes (Overtime cost: 0.00, Reward: -2.22)
#     Transition: State (9, 3) -> State (11, 3)
# At time 34.02: Customer type 1 served by Agent 2 in 0.10 minutes, waited 1.50 minutes (Overtime cost: 0.00, Reward: -1.50)
#     Transition: State (11, 3) -> State (10, 3)
# At time 34.27: Customer type 1 served by Agent 2 in 0.25 minutes, waited 1.75 minutes (Overtime cost: 0.00, Reward: -1.75)
#     Transition: State (10, 3) -> State (11, 4)
# At time 34.28: Customer type 1 served by Agent 2 in 0.01 minutes, waited 1.74 minutes (Overtime cost: 0.00, Reward: -1.74)
#     Transition: State (11, 4) -> State (10, 4)
# At time 34.33: Customer type 2 served by Agent 1 in 0.64 minutes, waited 1.95 minutes (Overtime cost: 0.00, Reward: -1.95)
#     Transition: State (9, 4) -> State (9, 4)
# At time 34.42: Customer type 1 served by Agent 2 in 0.13 minutes, waited 1.67 minutes (Overtime cost: 0.00, Reward: -1.67)
#     Transition: State (10, 4) -> State (8, 4)
# At time 34.76: Customer type 2 served by Agent 2 in 0.34 minutes, waited 1.91 minutes (Overtime cost: 0.00, Reward: -1.91)
#     Transition: State (8, 4) -> State (11, 3)
# At time 34.98: Customer type 2 served by Agent 2 in 0.22 minutes, waited 1.72 minutes (Overtime cost: 0.00, Reward: -1.72)
#     Transition: State (11, 3) -> State (12, 2)
# At time 35.02: Customer type 2 served by Agent 2 in 0.03 minutes, waited 1.74 minutes (Overtime cost: 0.00, Reward: -1.74)
#     Transition: State (12, 2) -> State (12, 1)
# At time 35.19: Customer type 1 served by Agent 1 in 0.86 minutes, waited 2.37 minutes (Overtime cost: 0.00, Reward: -2.37)
#     Transition: State (9, 4) -> State (11, 3)
# At time 35.25: Customer type 1 served by Agent 1 in 0.06 minutes, waited 1.84 minutes (Overtime cost: 0.00, Reward: -1.84)
#     Transition: State (11, 3) -> State (12, 3)
# At time 35.33: Customer type 1 served by Agent 1 in 0.08 minutes, waited 1.82 minutes (Overtime cost: 0.00, Reward: -1.82)
#     Transition: State (12, 3) -> State (12, 3)
# At time 35.47: Customer type 1 served by Agent 1 in 0.14 minutes, waited 1.84 minutes (Overtime cost: 0.00, Reward: -1.84)
#     Transition: State (12, 3) -> State (12, 3)
# At time 35.58: Customer type 1 served by Agent 1 in 0.11 minutes, waited 1.85 minutes (Overtime cost: 0.00, Reward: -1.85)
#     Transition: State (12, 3) -> State (13, 3)
# At time 35.75: Customer type 1 served by Agent 2 in 0.73 minutes, waited 2.39 minutes (Overtime cost: 0.00, Reward: -2.39)
#     Transition: State (12, 1) -> State (12, 3)
# At time 35.79: Customer type 1 served by Agent 1 in 0.21 minutes, waited 1.89 minutes (Overtime cost: 0.00, Reward: -1.89)
#     Transition: State (13, 3) -> State (11, 3)
# At time 35.82: Customer type 1 served by Agent 2 in 0.07 minutes, waited 1.77 minutes (Overtime cost: 0.00, Reward: -1.77)
#     Transition: State (12, 3) -> State (11, 2)
# At time 35.97: Customer type 1 served by Agent 2 in 0.15 minutes, waited 1.72 minutes (Overtime cost: 0.00, Reward: -1.72)
#     Transition: State (11, 2) -> State (10, 2)
# At time 36.19: Customer type 2 served by Agent 1 in 0.40 minutes, waited 2.03 minutes (Overtime cost: 0.00, Reward: -2.03)
#     Transition: State (11, 3) -> State (10, 3)
# At time 36.33: Customer type 1 served by Agent 2 in 0.35 minutes, waited 1.89 minutes (Overtime cost: 0.00, Reward: -1.89)
#     Transition: State (10, 2) -> State (9, 3)
# At time 36.45: Customer type 1 served by Agent 2 in 0.12 minutes, waited 1.71 minutes (Overtime cost: 0.00, Reward: -1.71)
#     Transition: State (9, 3) -> State (8, 3)
# At time 36.45: Customer type 1 served by Agent 2 in 0.00 minutes, waited 1.66 minutes (Overtime cost: 0.00, Reward: -1.66)
#     Transition: State (8, 3) -> State (7, 3)
# At time 36.46: Customer type 2 served by Agent 2 in 0.00 minutes, waited 1.37 minutes (Overtime cost: 0.00, Reward: -1.37)
#     Transition: State (7, 3) -> State (7, 2)
# At time 36.81: Customer type 1 served by Agent 1 in 0.60 minutes, waited 2.27 minutes (Overtime cost: 0.00, Reward: -2.27)
#     Transition: State (10, 3) -> State (10, 1)
# At time 36.85: Customer type 1 served by Agent 1 in 0.04 minutes, waited 1.64 minutes (Overtime cost: 0.00, Reward: -1.64)
#     Transition: State (10, 1) -> State (9, 1)
# At time 37.00: Customer type 1 served by Agent 1 in 0.14 minutes, waited 1.79 minutes (Overtime cost: 0.00, Reward: -1.79)
#     Transition: State (9, 1) -> State (8, 2)
# At time 37.13: Customer type 1 served by Agent 1 in 0.14 minutes, waited 1.88 minutes (Overtime cost: 0.00, Reward: -1.88)
#     Transition: State (8, 2) -> State (7, 3)
# At time 37.29: Customer type 1 served by Agent 1 in 0.16 minutes, waited 1.92 minutes (Overtime cost: 0.00, Reward: -1.92)
#     Transition: State (7, 3) -> State (6, 3)
# At time 37.43: Customer type 2 served by Agent 2 in 0.97 minutes, waited 2.30 minutes (Overtime cost: 0.00, Reward: -2.30)
#     Transition: State (7, 2) -> State (5, 3)
# At time 37.59: Customer type 1 served by Agent 2 in 0.16 minutes, waited 2.03 minutes (Overtime cost: 0.00, Reward: -2.03)
#     Transition: State (5, 3) -> State (4, 3)
# At time 38.02: Customer type 1 served by Agent 2 in 0.42 minutes, waited 2.00 minutes (Overtime cost: 0.00, Reward: -2.00)
#     Transition: State (4, 3) -> State (5, 4)
# At time 38.02: Customer type 1 served by Agent 1 in 0.72 minutes, waited 2.49 minutes (Overtime cost: 0.00, Reward: -2.49)
#     Transition: State (6, 3) -> State (5, 4)
# At time 38.04: Customer type 1 served by Agent 2 in 0.01 minutes, waited 1.53 minutes (Overtime cost: 0.00, Reward: -1.53)
#     Transition: State (5, 3) -> State (4, 3)
# At time 38.09: Customer type 1 served by Agent 2 in 0.05 minutes, waited 1.57 minutes (Overtime cost: 0.00, Reward: -1.57)
#     Transition: State (4, 3) -> State (3, 4)
# At time 38.23: Customer type 2 served by Agent 1 in 0.20 minutes, waited 2.05 minutes (Overtime cost: 0.00, Reward: -2.05)
#     Transition: State (5, 4) -> State (2, 5)
# At time 38.42: Customer type 1 served by Agent 2 in 0.33 minutes, waited 1.73 minutes (Overtime cost: 0.00, Reward: -1.73)
#     Transition: State (3, 4) -> State (5, 5)
# At time 38.50: Customer type 2 served by Agent 1 in 0.27 minutes, waited 1.60 minutes (Overtime cost: 0.00, Reward: -1.60)
#     Transition: State (2, 5) -> State (5, 4)
# At time 38.55: Customer type 2 served by Agent 2 in 0.13 minutes, waited 1.42 minutes (Overtime cost: 0.00, Reward: -1.42)
#     Transition: State (5, 5) -> State (4, 5)
# At time 38.63: Customer type 1 served by Agent 1 in 0.13 minutes, waited 0.92 minutes (Overtime cost: 0.00, Reward: -0.92)
#     Transition: State (5, 4) -> State (4, 4)
# At time 38.67: Customer type 2 served by Agent 2 in 0.12 minutes, waited 0.86 minutes (Overtime cost: 0.00, Reward: -0.86)
#     Transition: State (4, 5) -> State (3, 4)
# At time 38.77: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.70 minutes (Overtime cost: 0.00, Reward: -0.70)
#     Transition: State (3, 4) -> State (3, 3)
# At time 39.01: Customer type 2 served by Agent 2 in 0.24 minutes, waited 0.87 minutes (Overtime cost: 0.00, Reward: -0.87)
#     Transition: State (3, 3) -> State (3, 2)
# At time 39.09: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.75 minutes (Overtime cost: 0.00, Reward: -0.75)
#     Transition: State (3, 2) -> State (5, 1)
# At time 39.10: Customer type 1 served by Agent 1 in 0.46 minutes, waited 1.12 minutes (Overtime cost: 0.00, Reward: -1.12)
#     Transition: State (4, 4) -> State (4, 1)
# At time 39.29: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.95 minutes (Overtime cost: 0.00, Reward: -0.95)
#     Transition: State (5, 1) -> State (3, 1)
# At time 39.52: Customer type 1 served by Agent 2 in 0.22 minutes, waited 1.14 minutes (Overtime cost: 0.00, Reward: -1.14)
#     Transition: State (3, 1) -> State (3, 1)
# At time 39.97: Customer type 1 served by Agent 1 in 0.88 minutes, waited 1.62 minutes (Overtime cost: 0.00, Reward: -1.62)
#     Transition: State (4, 1) -> State (5, 1)
# At time 40.35: Customer type 2 served by Agent 2 in 0.83 minutes, waited 1.84 minutes (Overtime cost: 0.35, Reward: -2.19)
#     Transition: State (3, 1) -> State (6, 1)
# At time 40.44: Customer type 1 served by Agent 1 in 0.46 minutes, waited 1.41 minutes (Overtime cost: 0.44, Reward: -1.85)
#     Transition: State (5, 1) -> State (5, 1)
# At time 40.45: Customer type 1 served by Agent 2 in 0.10 minutes, waited 1.39 minutes (Overtime cost: 0.45, Reward: -1.84)
#     Transition: State (6, 1) -> State (4, 1)
# At time 40.59: Customer type 1 served by Agent 2 in 0.14 minutes, waited 1.00 minutes (Overtime cost: 0.59, Reward: -1.59)
#     Transition: State (4, 1) -> State (3, 1)
# At time 40.66: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.87 minutes (Overtime cost: 0.66, Reward: -1.53)
#     Transition: State (3, 1) -> State (3, 0)
# At time 40.85: Customer type 1 served by Agent 2 in 0.18 minutes, waited 0.97 minutes (Overtime cost: 0.85, Reward: -1.82)
#     Transition: State (3, 0) -> State (2, 0)
# At time 40.87: Customer type 1 served by Agent 1 in 0.43 minutes, waited 1.38 minutes (Overtime cost: 0.87, Reward: -2.25)
#     Transition: State (5, 1) -> State (1, 0)
# At time 40.91: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.61 minutes (Overtime cost: 0.91, Reward: -1.53)
#     Transition: State (1, 0) -> State (0, 1)
# At time 40.95: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.07 minutes (Overtime cost: 0.95, Reward: -1.02)
#     Transition: State (0, 1) -> State (0, 0)
# At time 41.16: Customer type 1 served by Agent 2 in 0.31 minutes, waited 1.14 minutes (Overtime cost: 1.16, Reward: -2.30)
#     Transition: State (2, 0) -> State (0, 0)
# At time 41.79: Customer type 1 served by Agent 2 in 0.62 minutes, waited 0.62 minutes (Overtime cost: 1.79, Reward: -2.42)
#     Transition: State (1, 0) -> State (2, 2)
# At time 41.95: Customer type 2 served by Agent 2 in 0.16 minutes, waited 0.68 minutes (Overtime cost: 1.95, Reward: -2.63)
#     Transition: State (2, 2) -> State (2, 1)
# At time 42.33: Customer type 1 served by Agent 2 in 0.38 minutes, waited 0.83 minutes (Overtime cost: 2.33, Reward: -3.17)
#     Transition: State (2, 1) -> State (3, 1)
# At time 42.36: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.81 minutes (Overtime cost: 2.36, Reward: -3.17)
#     Transition: State (3, 1) -> State (2, 1)
# At time 42.50: Customer type 2 served by Agent 2 in 0.14 minutes, waited 0.87 minutes (Overtime cost: 2.50, Reward: -3.37)
#     Transition: State (2, 1) -> State (3, 0)
# At time 42.56: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.45 minutes (Overtime cost: 2.56, Reward: -3.01)
#     Transition: State (3, 0) -> State (3, 1)
# At time 42.60: Customer type 2 served by Agent 1 in 1.56 minutes, waited 1.56 minutes (Overtime cost: 2.60, Reward: -4.16)
#     Transition: State (0, 1) -> State (3, 1)
# At time 42.84: Customer type 1 served by Agent 2 in 0.27 minutes, waited 0.67 minutes (Overtime cost: 2.84, Reward: -3.51)
#     Transition: State (3, 1) -> State (2, 1)
# At time 43.11: Customer type 1 served by Agent 1 in 0.51 minutes, waited 0.67 minutes (Overtime cost: 3.11, Reward: -3.78)
#     Transition: State (3, 1) -> State (2, 1)
# At time 43.12: Customer type 2 served by Agent 1 in 0.02 minutes, waited 0.59 minutes (Overtime cost: 3.12, Reward: -3.71)
#     Transition: State (2, 1) -> State (2, 0)
# At time 43.18: Customer type 1 served by Agent 2 in 0.34 minutes, waited 0.68 minutes (Overtime cost: 3.18, Reward: -3.86)
#     Transition: State (2, 1) -> State (2, 0)
# At time 43.22: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.65 minutes (Overtime cost: 3.22, Reward: -3.86)
#     Transition: State (2, 0) -> State (1, 0)
# At time 43.28: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.38 minutes (Overtime cost: 3.28, Reward: -3.66)
#     Transition: State (2, 0) -> State (0, 0)
# At time 43.42: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 3.42, Reward: -3.50)
#     Transition: State (1, 0) -> State (1, 0)
# At time 43.77: Customer type 1 served by Agent 2 in 0.35 minutes, waited 0.41 minutes (Overtime cost: 3.77, Reward: -4.19)
#     Transition: State (1, 0) -> State (0, 0)
# At time 43.89: Customer type 1 served by Agent 1 in 0.68 minutes, waited 0.72 minutes (Overtime cost: 3.89, Reward: -4.62)
#     Transition: State (1, 0) -> State (0, 0)
# At time 44.08: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 4.08, Reward: -4.15)
#     Transition: State (0, 1) -> State (0, 0)
# At time 44.19: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 4.19, Reward: -4.31)
#     Transition: State (1, 0) -> State (0, 0)
# At time 44.75: Customer type 2 served by Agent 2 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 4.75, Reward: -5.03)
#     Transition: State (0, 1) -> State (0, 1)
# At time 44.94: Customer type 1 served by Agent 1 in 0.50 minutes, waited 0.50 minutes (Overtime cost: 4.94, Reward: -5.44)
#     Transition: State (1, 0) -> State (4, 1)
# At time 44.96: Customer type 2 served by Agent 2 in 0.21 minutes, waited 0.22 minutes (Overtime cost: 4.96, Reward: -5.18)
#     Transition: State (0, 1) -> State (3, 1)
# At time 45.16: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.36 minutes (Overtime cost: 5.16, Reward: -5.51)
#     Transition: State (3, 1) -> State (3, 1)
# At time 45.19: Customer type 1 served by Agent 1 in 0.25 minutes, waited 0.39 minutes (Overtime cost: 5.19, Reward: -5.58)
#     Transition: State (4, 1) -> State (3, 1)
# At time 45.23: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.37 minutes (Overtime cost: 5.23, Reward: -5.60)
#     Transition: State (3, 1) -> State (2, 1)
# At time 45.61: Customer type 1 served by Agent 2 in 0.46 minutes, waited 0.78 minutes (Overtime cost: 5.61, Reward: -6.39)
#     Transition: State (3, 1) -> State (2, 1)
# At time 45.86: Customer type 2 served by Agent 1 in 0.62 minutes, waited 0.96 minutes (Overtime cost: 5.86, Reward: -6.82)
#     Transition: State (2, 1) -> State (2, 1)
# At time 45.89: Customer type 1 served by Agent 2 in 0.27 minutes, waited 0.80 minutes (Overtime cost: 5.89, Reward: -6.69)
#     Transition: State (2, 1) -> State (1, 1)
# At time 46.20: Customer type 1 served by Agent 1 in 0.34 minutes, waited 1.04 minutes (Overtime cost: 6.20, Reward: -7.23)
#     Transition: State (2, 1) -> State (1, 0)
# At time 46.39: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.74 minutes (Overtime cost: 6.39, Reward: -7.13)
#     Transition: State (1, 0) -> State (1, 0)
# At time 46.60: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.36 minutes (Overtime cost: 6.60, Reward: -6.96)
#     Transition: State (1, 0) -> State (0, 0)
# At time 46.76: Customer type 2 served by Agent 1 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 6.76, Reward: -6.82)
#     Transition: State (0, 1) -> State (0, 0)
# At time 47.29: Customer type 2 served by Agent 2 in 1.40 minutes, waited 1.85 minutes (Overtime cost: 7.29, Reward: -9.14)
#     Transition: State (1, 1) -> State (4, 0)
# At time 47.30: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.41 minutes (Overtime cost: 7.30, Reward: -7.72)
#     Transition: State (4, 0) -> State (4, 0)
# At time 47.34: Customer type 1 served by Agent 1 in 0.52 minutes, waited 0.52 minutes (Overtime cost: 7.34, Reward: -7.86)
#     Transition: State (1, 0) -> State (3, 1)
# At time 47.43: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.34 minutes (Overtime cost: 7.43, Reward: -7.77)
#     Transition: State (4, 0) -> State (2, 1)
# At time 47.45: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.26 minutes (Overtime cost: 7.45, Reward: -7.71)
#     Transition: State (2, 1) -> State (1, 1)
# At time 47.59: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.29 minutes (Overtime cost: 7.59, Reward: -7.88)
#     Transition: State (1, 1) -> State (1, 1)
# At time 47.87: Customer type 1 served by Agent 1 in 0.54 minutes, waited 0.75 minutes (Overtime cost: 7.87, Reward: -8.63)
#     Transition: State (3, 1) -> State (2, 3)
# At time 48.34: Customer type 2 served by Agent 2 in 0.75 minutes, waited 1.04 minutes (Overtime cost: 8.34, Reward: -9.38)
#     Transition: State (2, 1) -> State (4, 3)
# At time 48.35: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.75 minutes (Overtime cost: 8.35, Reward: -9.10)
#     Transition: State (4, 3) -> State (3, 3)
# At time 48.48: Customer type 1 served by Agent 1 in 0.60 minutes, waited 0.91 minutes (Overtime cost: 8.48, Reward: -9.39)
#     Transition: State (2, 3) -> State (3, 2)
# At time 48.49: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.71 minutes (Overtime cost: 8.49, Reward: -9.20)
#     Transition: State (3, 2) -> State (3, 1)
# At time 48.61: Customer type 2 served by Agent 2 in 0.27 minutes, waited 1.01 minutes (Overtime cost: 8.61, Reward: -9.62)
#     Transition: State (3, 3) -> State (3, 0)
# At time 48.68: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.83 minutes (Overtime cost: 8.68, Reward: -9.51)
#     Transition: State (3, 1) -> State (3, 0)
# At time 48.87: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.83 minutes (Overtime cost: 8.87, Reward: -9.70)
# ...
#     Transition: State (2, 2) -> State (1, 0)
# At time 46.39: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.06 minutes (Overtime cost: 6.39, Reward: -6.45)
#     Transition: State (1, 0) -> State (0, 0)
# At time 46.43: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 6.43, Reward: -6.45)
#     Transition: State (1, 0) -> State (1, 0)
# At time 46.70: Customer type 2 served by Agent 2 in 0.42 minutes, waited 1.43 minutes (Overtime cost: 6.70, Reward: -8.12)
#     Transition: State (0, 1) -> State (0, 2)
# At time 46.92: Customer type 2 served by Agent 2 in 0.22 minutes, waited 0.47 minutes (Overtime cost: 6.92, Reward: -7.39)
#     Transition: State (0, 2) -> State (1, 1)
# At time 47.12: Customer type 1 served by Agent 1 in 0.69 minutes, waited 0.70 minutes (Overtime cost: 7.12, Reward: -7.82)
#     Transition: State (1, 0) -> State (2, 1)
# At time 47.21: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.23 minutes (Overtime cost: 7.21, Reward: -7.44)
#     Transition: State (2, 1) -> State (1, 2)
# At time 47.31: Customer type 1 served by Agent 2 in 0.39 minutes, waited 0.59 minutes (Overtime cost: 7.31, Reward: -7.90)
#     Transition: State (1, 1) -> State (0, 2)
# At time 47.43: Customer type 1 served by Agent 1 in 0.22 minutes, waited 0.37 minutes (Overtime cost: 7.43, Reward: -7.80)
#     Transition: State (1, 2) -> State (1, 2)
# At time 47.44: Customer type 2 served by Agent 2 in 0.13 minutes, waited 0.89 minutes (Overtime cost: 7.44, Reward: -8.33)
#     Transition: State (0, 2) -> State (0, 2)
# At time 47.53: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.13 minutes (Overtime cost: 7.53, Reward: -7.67)
#     Transition: State (1, 2) -> State (0, 1)
# At time 47.58: Customer type 2 served by Agent 1 in 0.05 minutes, waited 0.25 minutes (Overtime cost: 7.58, Reward: -7.83)
#     Transition: State (0, 1) -> State (1, 0)
# At time 47.61: Customer type 2 served by Agent 2 in 0.17 minutes, waited 0.43 minutes (Overtime cost: 7.61, Reward: -8.04)
#     Transition: State (0, 2) -> State (0, 0)
# At time 47.78: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 7.78, Reward: -7.82)
#     Transition: State (1, 0) -> State (1, 0)
# At time 47.84: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 7.84, Reward: -7.91)
#     Transition: State (1, 0) -> State (0, 0)
# At time 47.96: Customer type 1 served by Agent 1 in 0.38 minutes, waited 0.43 minutes (Overtime cost: 7.96, Reward: -8.39)
#     Transition: State (1, 0) -> State (0, 0)
# At time 48.68: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 8.68, Reward: -8.68)
#     Transition: State (1, 0) -> State (0, 0)
# At time 48.87: Customer type 2 served by Agent 2 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 8.87, Reward: -8.95)
#     Transition: State (0, 1) -> State (0, 0)
# At time 48.91: Customer type 1 served by Agent 1 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 8.91, Reward: -9.16)
#     Transition: State (1, 0) -> State (0, 0)
# At time 49.02: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 9.02, Reward: -9.06)
#     Transition: State (1, 0) -> State (0, 0)
# At time 49.16: Customer type 2 served by Agent 1 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 9.16, Reward: -9.26)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.09: Customer type 1 served by Agent 1 in 0.59 minutes, waited 0.59 minutes (Overtime cost: 10.09, Reward: -10.68)
#     Transition: State (1, 0) -> State (2, 1)
# At time 50.12: Customer type 1 served by Agent 2 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 10.12, Reward: -10.44)
#     Transition: State (1, 0) -> State (1, 1)
# At time 50.25: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.26 minutes (Overtime cost: 10.25, Reward: -10.51)
#     Transition: State (1, 1) -> State (0, 1)
# At time 50.55: Customer type 2 served by Agent 2 in 0.30 minutes, waited 0.66 minutes (Overtime cost: 10.55, Reward: -11.21)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.58: Customer type 2 served by Agent 2 in 0.01 minutes, waited 0.01 minutes (Overtime cost: 10.58, Reward: -10.60)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.85: Customer type 1 served by Agent 1 in 0.75 minutes, waited 0.92 minutes (Overtime cost: 10.85, Reward: -11.78)
#     Transition: State (2, 1) -> State (1, 0)
# At time 50.87: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.13 minutes (Overtime cost: 10.87, Reward: -11.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 50.89: Customer type 2 served by Agent 2 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 10.89, Reward: -11.09)
#     Transition: State (0, 1) -> State (0, 0)
# At time 51.11: Customer type 2 served by Agent 1 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 11.11, Reward: -11.22)
#     Transition: State (0, 1) -> State (0, 0)
# At time 51.13: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 11.13, Reward: -11.13)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.31: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 11.31, Reward: -11.34)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.58: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 11.58, Reward: -11.58)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.78: Customer type 1 served by Agent 2 in 0.68 minutes, waited 0.68 minutes (Overtime cost: 11.78, Reward: -12.46)
#     Transition: State (1, 0) -> State (1, 0)
# At time 51.81: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.09 minutes (Overtime cost: 11.81, Reward: -11.91)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.98: Customer type 2 served by Agent 1 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 11.98, Reward: -12.26)
#     Transition: State (0, 1) -> State (0, 0)
# At time 52.17: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.14 minutes (Overtime cost: 12.17, Reward: -12.31)
#     Transition: State (1, 0) -> State (0, 0)
# At time 52.57: Customer type 1 served by Agent 1 in 0.24 minutes, waited 0.24 minutes (Overtime cost: 12.57, Reward: -12.81)
#     Transition: State (1, 0) -> State (0, 0)
# At time 53.52: Customer type 1 served by Agent 2 in 0.37 minutes, waited 0.37 minutes (Overtime cost: 13.52, Reward: -13.89)
#     Transition: State (1, 0) -> State (2, 1)
# At time 53.97: Customer type 1 served by Agent 2 in 0.45 minutes, waited 0.62 minutes (Overtime cost: 13.97, Reward: -14.59)
#     Transition: State (2, 1) -> State (2, 1)
# At time 54.22: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.85 minutes (Overtime cost: 14.22, Reward: -15.07)
#     Transition: State (2, 1) -> State (1, 1)
# At time 54.35: Customer type 2 served by Agent 1 in 1.60 minutes, waited 1.60 minutes (Overtime cost: 14.35, Reward: -15.95)
#     Transition: State (0, 1) -> State (0, 1)
# At time 54.41: Customer type 2 served by Agent 1 in 0.05 minutes, waited 1.10 minutes (Overtime cost: 14.41, Reward: -15.51)
#     Transition: State (0, 1) -> State (0, 0)
# At time 54.43: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.60 minutes (Overtime cost: 14.43, Reward: -15.02)
#     Transition: State (1, 1) -> State (0, 0)
# At time 54.71: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.23 minutes (Overtime cost: 14.71, Reward: -14.94)
#     Transition: State (1, 0) -> State (0, 0)
# At time 54.73: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 14.73, Reward: -14.93)
#     Transition: State (1, 0) -> State (0, 0)
# At time 55.38: Customer type 1 served by Agent 1 in 0.34 minutes, waited 0.34 minutes (Overtime cost: 15.38, Reward: -15.72)
#     Transition: State (1, 0) -> State (2, 0)
# At time 55.48: Customer type 1 served by Agent 2 in 0.36 minutes, waited 0.36 minutes (Overtime cost: 15.48, Reward: -15.85)
#     Transition: State (1, 0) -> State (1, 0)
# At time 55.86: Customer type 1 served by Agent 2 in 0.37 minutes, waited 0.61 minutes (Overtime cost: 15.86, Reward: -16.47)
#     Transition: State (1, 0) -> State (2, 1)
# At time 56.11: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.53 minutes (Overtime cost: 16.11, Reward: -16.64)
#     Transition: State (2, 1) -> State (1, 1)
# At time 56.18: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.56 minutes (Overtime cost: 16.18, Reward: -16.74)
#     Transition: State (1, 1) -> State (0, 1)
# At time 56.40: Customer type 1 served by Agent 1 in 1.01 minutes, waited 1.26 minutes (Overtime cost: 16.40, Reward: -17.66)
#     Transition: State (2, 0) -> State (1, 1)
# At time 56.83: Customer type 2 served by Agent 2 in 0.64 minutes, waited 1.18 minutes (Overtime cost: 16.83, Reward: -18.00)
#     Transition: State (0, 1) -> State (1, 2)
# At time 56.90: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.20 minutes (Overtime cost: 16.90, Reward: -17.10)
#     Transition: State (1, 2) -> State (0, 2)
# At time 56.93: Customer type 2 served by Agent 2 in 0.03 minutes, waited 0.63 minutes (Overtime cost: 16.93, Reward: -17.56)
#     Transition: State (0, 2) -> State (0, 1)
# At time 57.00: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.56 minutes (Overtime cost: 17.00, Reward: -17.56)
#     Transition: State (0, 1) -> State (0, 0)
# At time 57.06: Customer type 2 served by Agent 2 in 0.01 minutes, waited 0.01 minutes (Overtime cost: 17.06, Reward: -17.07)
#     Transition: State (0, 1) -> State (0, 0)
# At time 58.04: Customer type 1 served by Agent 1 in 1.64 minutes, waited 1.65 minutes (Overtime cost: 18.04, Reward: -19.69)
#     Transition: State (1, 1) -> State (1, 1)
# At time 58.18: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.54 minutes (Overtime cost: 18.18, Reward: -18.72)
#     Transition: State (1, 1) -> State (0, 1)
# At time 58.22: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.69 minutes (Overtime cost: 18.22, Reward: -18.91)
#     Transition: State (0, 1) -> State (0, 0)
# At time 58.27: Customer type 2 served by Agent 2 in 1.06 minutes, waited 1.06 minutes (Overtime cost: 18.27, Reward: -19.32)
#     Transition: State (0, 1) -> State (0, 0)
# At time 58.64: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.21 minutes (Overtime cost: 18.64, Reward: -18.85)
#     Transition: State (1, 0) -> State (0, 0)
# At time 58.66: Customer type 1 served by Agent 1 in 0.34 minutes, waited 0.34 minutes (Overtime cost: 18.66, Reward: -19.01)
#     Transition: State (1, 0) -> State (0, 0)
# At time 58.87: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 18.87, Reward: -18.98)
#     Transition: State (1, 0) -> State (1, 0)
# At time 59.05: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.30 minutes (Overtime cost: 19.05, Reward: -19.34)
#     Transition: State (1, 0) -> State (0, 0)
# At time 59.20: Customer type 1 served by Agent 2 in 0.32 minutes, waited 0.43 minutes (Overtime cost: 19.20, Reward: -19.62)
#     Transition: State (1, 0) -> State (0, 0)
# At time 59.42: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 19.42, Reward: -19.58)
#     Transition: State (1, 0) -> State (0, 0)
# At time 59.61: Customer type 1 served by Agent 1 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 19.61, Reward: -19.74)
#     Transition: State (1, 0) -> State (0, 0)
#
# Total customers served: 330
# Total waiting time: 202.07 minutes
# Total agent overtime cost: 958.61 minutes
# Total rewards: -33746.67
# Average waiting time per customer: 0.61 minutes
#
# Transition Probabilities:
#   P((0, 0) | (1, 0)) = 0.6139
#   P((1, 1) | (1, 0)) = 0.0396
#   P((0, 2) | (1, 2)) = 0.4286
#   P((0, 2) | (1, 0)) = 0.0099
#   P((0, 2) | (0, 2)) = 0.1111
#   P((0, 2) | (0, 3)) = 0.5714
#   P((0, 0) | (0, 1)) = 0.6667
#   P((3, 2) | (1, 1)) = 0.0625
#   P((2, 2) | (3, 2)) = 0.6000
#   P((1, 2) | (2, 2)) = 0.2500
#   P((2, 2) | (0, 2)) = 0.0556
#   P((1, 2) | (0, 2)) = 0.0556
#   P((0, 2) | (2, 2)) = 0.2500
#   P((1, 2) | (1, 2)) = 0.2857
#   P((1, 1) | (0, 2)) = 0.1111
#   P((0, 1) | (0, 2)) = 0.3889
#   P((1, 1) | (1, 1)) = 0.1250
#   P((0, 1) | (1, 1)) = 0.4375
#   P((1, 0) | (0, 1)) = 0.1404
#   P((0, 1) | (0, 1)) = 0.0702
#   P((1, 0) | (1, 0)) = 0.0990
#   P((2, 0) | (1, 0)) = 0.0495
#   P((1, 0) | (2, 0)) = 0.4167
#   P((2, 1) | (0, 1)) = 0.0175
#   P((1, 1) | (2, 1)) = 0.3333
#   P((1, 1) | (0, 1)) = 0.0351
#   P((2, 0) | (1, 1)) = 0.0625
#   P((3, 0) | (2, 0)) = 0.0833
#   P((2, 0) | (3, 0)) = 0.7500
#   P((0, 0) | (2, 0)) = 0.3333
#   P((2, 1) | (1, 0)) = 0.0693
#   P((5, 2) | (2, 1)) = 0.0833
#   P((4, 2) | (5, 2)) = 1.0000
#   P((4, 3) | (4, 2)) = 0.5000
#   P((3, 3) | (4, 3)) = 0.5000
#   P((2, 3) | (3, 3)) = 1.0000
#   P((2, 3) | (1, 0)) = 0.0198
#   P((1, 3) | (1, 3)) = 0.3333
#   P((0, 3) | (1, 3)) = 0.3333
#   P((0, 3) | (0, 3)) = 0.1429
#   P((0, 2) | (2, 3)) = 0.2000
#   P((0, 1) | (0, 3)) = 0.1429
#   P((0, 1) | (1, 0)) = 0.0297
#   P((0, 2) | (1, 1)) = 0.1250
#   P((2, 1) | (0, 2)) = 0.1111
#   P((0, 1) | (2, 1)) = 0.0833
#   P((3, 1) | (1, 0)) = 0.0099
#   P((2, 1) | (1, 1)) = 0.0625
#   P((1, 2) | (2, 1)) = 0.3333
#   P((0, 2) | (3, 1)) = 0.5000
#   P((2, 1) | (1, 2)) = 0.0714
#   P((2, 2) | (1, 1)) = 0.0625
#   P((2, 0) | (1, 2)) = 0.0714
#   P((3, 2) | (1, 0)) = 0.0198
#   P((4, 3) | (3, 2)) = 0.2000
#   P((3, 3) | (2, 2)) = 0.1250
#   P((2, 3) | (4, 3)) = 0.5000
#   P((1, 3) | (2, 3)) = 0.2000
#   P((0, 1) | (2, 3)) = 0.2000
#   P((0, 0) | (0, 2)) = 0.1111
#   P((3, 0) | (1, 0)) = 0.0297
#   P((3, 1) | (3, 0)) = 0.2500
#   P((1, 4) | (2, 3)) = 0.4000
#   P((1, 5) | (3, 1)) = 0.5000
#   P((0, 5) | (1, 5)) = 1.0000
#   P((1, 4) | (0, 5)) = 0.3333
#   P((0, 4) | (1, 4)) = 0.3333
#   P((0, 3) | (1, 4)) = 0.1667
#   P((0, 2) | (0, 4)) = 0.2000
#   P((0, 4) | (0, 2)) = 0.0556
#   P((1, 3) | (0, 4)) = 0.2000
#   P((1, 3) | (0, 3)) = 0.1429
#   P((2, 3) | (1, 3)) = 0.1667
#   P((1, 6) | (1, 3)) = 0.1667
#   P((0, 6) | (1, 6)) = 0.5000
#   P((4, 7) | (1, 4)) = 0.1667
#   P((3, 7) | (4, 7)) = 1.0000
#   P((2, 7) | (3, 7)) = 0.6667
#   P((2, 7) | (2, 7)) = 0.2500
#   P((1, 7) | (1, 6)) = 0.5000
#   P((0, 10) | (1, 7)) = 0.2500
#   P((0, 9) | (0, 10)) = 1.0000
#   P((0, 8) | (0, 9)) = 1.0000
#   P((2, 7) | (0, 8)) = 0.5000
#   P((1, 7) | (2, 7)) = 0.5000
#   P((0, 8) | (2, 7)) = 0.2500
#   P((0, 7) | (1, 7)) = 0.5000
#   P((3, 7) | (0, 7)) = 0.3333
#   P((3, 7) | (0, 8)) = 0.5000
#   P((0, 7) | (3, 7)) = 0.3333
#   P((0, 6) | (0, 7)) = 0.6667
#   P((1, 6) | (0, 6)) = 0.2000
#   P((0, 5) | (1, 7)) = 0.2500
#   P((1, 5) | (0, 5)) = 0.1667
#   P((0, 4) | (0, 5)) = 0.5000
#   P((3, 4) | (0, 6)) = 0.2000
#   P((3, 5) | (0, 4)) = 0.2000
#   P((4, 5) | (3, 4)) = 1.0000
#   P((3, 6) | (4, 5)) = 1.0000
#   P((2, 6) | (3, 6)) = 1.0000
#   P((2, 6) | (3, 5)) = 1.0000
#   P((1, 6) | (2, 6)) = 0.5000
#   P((0, 6) | (0, 6)) = 0.2000
#   P((0, 5) | (2, 6)) = 0.5000
#   P((0, 5) | (0, 6)) = 0.2000
#   P((0, 3) | (0, 4)) = 0.4000
#   P((0, 0) | (1, 4)) = 0.1667
#   P((2, 0) | (2, 0)) = 0.0833
#   P((2, 2) | (0, 1)) = 0.0175
#   P((2, 4) | (2, 2)) = 0.1250
#   P((1, 4) | (1, 0)) = 0.0099
#   P((1, 5) | (2, 4)) = 0.5000
#   P((0, 6) | (1, 4)) = 0.1667
#   P((2, 4) | (0, 6)) = 0.2000
#   P((1, 2) | (2, 4)) = 0.5000
#   P((0, 0) | (1, 2)) = 0.0714
#   P((4, 2) | (0, 1)) = 0.0175
#   P((3, 2) | (4, 2)) = 0.5000
#   P((3, 2) | (3, 2)) = 0.2000
#   P((2, 2) | (2, 2)) = 0.1250
#   P((1, 0) | (2, 2)) = 0.1250
#   P((0, 2) | (0, 1)) = 0.0175
#   P((0, 1) | (1, 2)) = 0.0714
#   P((1, 0) | (2, 1)) = 0.0833
#   P((2, 1) | (2, 1)) = 0.0833
#   P((0, 0) | (1, 1)) = 0.0625
#   P((1, 1) | (2, 0)) = 0.0833
#   P((1, 2) | (0, 1)) = 0.0175
#                       Metric  With Longest Waiting  Without Longest Waiting  Difference (Without - With)
# Total Waiting Time (minutes)            309.735235               202.066191                  -107.669043
#    Total Agent Overtime Cost           1271.207228               958.605355                  -312.601873
#       Total Customers Served            358.000000               330.000000                   -28.000000
#                Total Rewards         -56498.942463            -33746.671546                 22752.270917

# %% [markdown]
# No new customers are accepted after 40 minutes and the simulation runs till 60 minutes giving time to the agents to serve the remaining customers in the queue. This is the main model

# %%
import numpy as np
import simpy
import pandas as pd

# Define parameters
lambda_1 = 4  # Arrival rate for primary questions (customers per minute)
lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
mu_1 = 3      # Service rate for less experienced agent (customers per minute)
mu_2 = 4      # Service rate for more experienced agent (customers per minute)
M = 5         # Maximum number of calls in the system
T = 40        # Simulation time threshold for accepting new customers
simulation_end_time = 60  # Total simulation time
dt = 0.6

overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)

# Precomputing the value function V using DPL
V = np.full((int(T/dt) + 1, M + 1, M + 1, 2), np.inf)
V[:, 0, 0, :] = 0  # Initial condition: no waiting cost when there are no customers

for t in range(1, int(T/dt) + 1):
    for q1 in range(M + 1):
        for q2 in range(M + 1):
            if q1 + q2 > M:
                continue
            cost_rep1 = (q1 + 1) / mu_1 + q2 / mu_2 if q1 + 1 <= M else np.inf  # Expected cost if assigned to rep 1
            cost_rep2 = q1 / mu_1 + (q2 + 1) / mu_2 if q2 + 1 <= M else np.inf  # Expected cost if assigned to rep 2
            V[t, q1, q2, 0] = min(cost_rep1, cost_rep2)

class CallCenter:
    def __init__(self, env, dt, V, use_longest_waiting=True):
        self.env = env
        self.V = V
        self.dt = dt
        self.use_longest_waiting = use_longest_waiting
        self.queue_1 = simpy.Store(env)  # Queue for primary questions
        self.queue_2 = simpy.Store(env)  # Queue for complex questions
        self.agent_1 = simpy.Resource(env, capacity=1)
        self.agent_2 = simpy.Resource(env, capacity=1)
        self.total_waiting_time = 0
        self.total_agent_overtime_cost = 0  # Track only agent overtime costs
        self.total_rewards = 0  # Track total rewards
        self.customers_served = 0
        self.customers_rejected = 0  # Track customers rejected after T = 40
        self.transition_counts = {}  # Track state transitions
        self.state_counts = {}  # Count visits to states

    def record_transition(self, current_state, next_state):
        """Records state transitions for computing probabilities."""
        self.transition_counts[(current_state, next_state)] = (
            self.transition_counts.get((current_state, next_state), 0) + 1
        )
        self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

    def calculate_transition_probabilities(self):
        """Calculates transition probabilities from recorded transitions."""
        probabilities = {}
        for (current_state, next_state), count in self.transition_counts.items():
            total_transitions_from_state = self.state_counts[current_state]
            probabilities[(current_state, next_state)] = count / total_transitions_from_state
        return probabilities

    def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
        with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
            yield request
            service_time = np.random.exponential(1 / service_rate)
            end_time = self.env.now + service_time  # Calculate when the service will end

            # Simulate the service time
            yield self.env.timeout(service_time)

            wait_time = self.env.now - arrival_time  # Calculate wait time
            self.total_waiting_time += wait_time

            # Initialize agent_overtime_cost to zero
            agent_overtime_cost = 0

            # Check for overtime due to working beyond T
            if end_time > T:
                overtime_hours = end_time - T
                agent_overtime_cost = overtime_hours * overtime_cost_rate
                self.total_agent_overtime_cost += agent_overtime_cost

            # Update rewards
            reward = -(wait_time + agent_overtime_cost)  # Negative rewards for wait time and overtime
            self.total_rewards += reward

            self.customers_served += 1

            next_state = (len(self.queue_1.items), len(self.queue_2.items))

            # Record the state transition
            self.record_transition(state, next_state)

            # Log details
            print(
                f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
                f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
                f"(Overtime cost: {agent_overtime_cost:.2f}, Reward: {reward:.2f})"
            )
            print(f"    Transition: State {state} -> State {next_state}")

    def assign_customer(self):
        while True:
            if self.agent_1.count == 0 or self.agent_2.count == 0:
                state = (len(self.queue_1.items), len(self.queue_2.items))

                # Select action based on policy
                chosen_agent = self.policy.get(state, "Agent 1")
                queue = self.queue_1 if chosen_agent == "Agent 1" else self.queue_2

                if len(queue.items) > 0:
                    customer_type, arrival_time = queue.items[0]
                    yield queue.get()

                    service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2
                    self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

            yield self.env.timeout(self.dt)

    def assign_customer(self):
        while True:
            if self.agent_1.count == 0 or self.agent_2.count == 0:
                queue, customer_type, arrival_time = self.select_customer()

                if queue is not None:
                    state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state
                    yield queue.get()

                    chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"
                    service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

                    # Start handling the customer
                    self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

            # Update rewards based on current queue lengths
            queue_penalty = -(len(self.queue_1.items) + len(self.queue_2.items))  # Negative reward for queue lengths
            self.total_rewards += queue_penalty

            yield self.env.timeout(dt)  # Allow other processes to run

    def select_customer(self):
        """Selects the customer based on the queue and waiting strategy."""
        if self.use_longest_waiting:
            return self.select_longest_waiting_customer()
        return self.select_first_come_first_served_customer()

    def select_longest_waiting_customer(self):
        """Select the longest waiting customer from the queues."""
        if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            customer_2, arrival_time_2 = self.queue_2.items[0]
            if arrival_time_1 <= arrival_time_2:
                return self.queue_1, customer_1, arrival_time_1
            else:
                return self.queue_2, customer_2, arrival_time_2
        elif len(self.queue_1.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            return self.queue_1, customer_1, arrival_time_1
        elif len(self.queue_2.items) > 0:
            customer_2, arrival_time_2 = self.queue_2.items[0]
            return self.queue_2, customer_2, arrival_time_2
        else:
            return None, None, None

    def select_first_come_first_served_customer(self):
        """Select the first customer from queue 1 or queue 2."""
        if len(self.queue_1.items) > 0:
            return self.queue_1, *self.queue_1.items[0]
        elif len(self.queue_2.items) > 0:
            return self.queue_2, *self.queue_2.items[0]
        return None, None, None

    def value_iteration(env, gamma=0.9, iterations=100):
      V = {}
      policy = {}

      # Initialize value function for all states
      for q1 in range(M + 1):
          for q2 in range(M + 1):
              V[(q1, q2)] = 0  # Initial value for all states

      for i in range(iterations):
          new_V = V.copy()
          for q1 in range(M + 1):
              for q2 in range(M + 1):
                  if q1 + q2 > M:  # Invalid state
                      continue

                  # Possible actions: assign to Agent 1 or Agent 2
                  actions = ["Agent 1", "Agent 2"]
                  action_values = []

                  for action in actions:
                      # Immediate reward
                      immediate_cost = -(q1 / mu_1 if action == "Agent 1" else q2 / mu_2)

                      # Future value estimation
                      future_value = 0
                      for next_q1 in range(M + 1):
                          for next_q2 in range(M + 1):
                              if next_q1 + next_q2 > M:  # Invalid state
                                  continue
                              # Transition probability (placeholder: uniform probability)
                              P = 1 / ((M + 1) * (M + 1))  # Example; calculate based on transitions
                              future_value += P * V[(next_q1, next_q2)]

                      action_value = immediate_cost + gamma * future_value
                      action_values.append(action_value)

                  # Update value function and policy
                  new_V[(q1, q2)] = max(action_values)
                  policy[(q1, q2)] = actions[np.argmax(action_values)]

          V = new_V  # Update V for next iteration

      return V, policy

    def customer_arrival(self, customer_type, arrival_rate):
        while True:
            inter_arrival_time = np.random.exponential(1 / arrival_rate)
            yield self.env.timeout(inter_arrival_time)
            arrival_time = self.env.now

            if arrival_time > T:
                self.customers_rejected += 1
                print(f"Customer rejected at time {arrival_time:.2f}: No new arrivals after T = {T}")
                continue

            if customer_type == 1:
                self.queue_1.put((customer_type, arrival_time))
            else:
                self.queue_2.put((customer_type, arrival_time))

            self.env.process(self.assign_customer())


def run_simulation(simulation_time, use_longest_waiting=True):
    env = simpy.Environment()
    call_center = CallCenter(env, dt, V, use_longest_waiting)

    env.process(call_center.customer_arrival(1, lambda_1))
    env.process(call_center.customer_arrival(2, lambda_2))

    env.run(until=simulation_time)

    print(f"\nTotal customers served: {call_center.customers_served}")
    print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
    print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
    print(f"Total rewards: {call_center.total_rewards:.2f}")
    print(f"Total customers rejected after T = {T}: {call_center.customers_rejected}")
    print(f"Average waiting time per customer: "
          f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

    # Calculate and display transition probabilities
    probabilities = call_center.calculate_transition_probabilities()
    print("\nTransition Probabilities:")
    for (initial_state, final_state), prob in probabilities.items():
        print(f"  P({final_state} | {initial_state}) = {prob:.4f}")

    return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, call_center.total_rewards, call_center.customers_rejected, probabilities


# Run the simulations
simulation_time = simulation_end_time

# With longest waiting customer function
waiting_time_longest, agent_overtime_longest, served_longest, rewards_longest, rejected_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# Without longest waiting customer function
waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, rewards_fcfs, rejected_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)


# Prepare the results for the table
results_data = {
    "Metric": [
        "Total Waiting Time (minutes)",
        "Total Agent Overtime Cost",
        "Total Customers Served",
        "Total Rewards",
        "Total Customers Rejected"
    ],
    "With Longest Waiting": [
        waiting_time_longest,
        agent_overtime_longest,
        served_longest,
        rewards_longest,
        rejected_longest
    ],
    "Without Longest Waiting": [
        waiting_time_fcfs,
        agent_overtime_fcfs,
        served_fcfs,
        rewards_fcfs,
        rejected_fcfs
    ],
    "Difference (Without - With)": [
        waiting_time_fcfs - waiting_time_longest,
        agent_overtime_fcfs - agent_overtime_longest,
        served_fcfs - served_longest,
        rewards_fcfs - rewards_longest,
        rejected_fcfs - rejected_longest
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(results_data)

# Display the results as a table
print(results_df.to_string(index=False))
# Out:
# At time 0.24: Customer type 2 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00, Reward: -0.02)
#     Transition: State (0, 1) -> State (0, 0)
# At time 0.39: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (3, 0)
# At time 0.51: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.27 minutes (Overtime cost: 0.00, Reward: -0.27)
#     Transition: State (1, 0) -> State (3, 0)
# At time 0.59: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.29 minutes (Overtime cost: 0.00, Reward: -0.29)
#     Transition: State (4, 0) -> State (3, 0)
# At time 1.12: Customer type 1 served by Agent 1 in 0.44 minutes, waited 0.80 minutes (Overtime cost: 0.00, Reward: -0.80)
#     Transition: State (4, 0) -> State (2, 0)
# At time 1.25: Customer type 1 served by Agent 2 in 0.43 minutes, waited 0.92 minutes (Overtime cost: 0.00, Reward: -0.92)
#     Transition: State (3, 0) -> State (1, 1)
# At time 1.34: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (2, 1) -> State (1, 1)
# At time 1.78: Customer type 2 served by Agent 1 in 0.36 minutes, waited 0.54 minutes (Overtime cost: 0.00, Reward: -0.54)
#     Transition: State (1, 1) -> State (2, 2)
# At time 2.01: Customer type 1 served by Agent 2 in 0.74 minutes, waited 1.34 minutes (Overtime cost: 0.00, Reward: -1.34)
#     Transition: State (1, 1) -> State (2, 4)
# At time 2.14: Customer type 2 served by Agent 2 in 0.11 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (2, 4) -> State (3, 3)
# At time 2.62: Customer type 1 served by Agent 2 in 0.33 minutes, waited 0.90 minutes (Overtime cost: 0.00, Reward: -0.90)
#     Transition: State (3, 3) -> State (3, 3)
# At time 3.07: Customer type 2 served by Agent 2 in 0.43 minutes, waited 1.31 minutes (Overtime cost: 0.00, Reward: -1.31)
#     Transition: State (3, 3) -> State (4, 5)
# At time 3.83: Customer type 1 served by Agent 2 in 0.76 minutes, waited 1.95 minutes (Overtime cost: 0.00, Reward: -1.95)
#     Transition: State (4, 5) -> State (5, 6)
# At time 3.89: Customer type 2 served by Agent 2 in 0.05 minutes, waited 1.99 minutes (Overtime cost: 0.00, Reward: -1.99)
#     Transition: State (5, 6) -> State (5, 5)
# At time 3.99: Customer type 2 served by Agent 2 in 0.09 minutes, waited 2.00 minutes (Overtime cost: 0.00, Reward: -2.00)
#     Transition: State (5, 5) -> State (6, 4)
# At time 4.04: Customer type 1 served by Agent 2 in 0.04 minutes, waited 1.94 minutes (Overtime cost: 0.00, Reward: -1.94)
#     Transition: State (7, 4) -> State (7, 4)
# At time 4.08: Customer type 1 served by Agent 2 in 0.02 minutes, waited 1.58 minutes (Overtime cost: 0.00, Reward: -1.58)
#     Transition: State (7, 4) -> State (6, 4)
# At time 4.10: Customer type 2 served by Agent 2 in 0.02 minutes, waited 1.37 minutes (Overtime cost: 0.00, Reward: -1.37)
#     Transition: State (6, 4) -> State (6, 3)
# At time 4.16: Customer type 1 served by Agent 1 in 2.32 minutes, waited 2.87 minutes (Overtime cost: 0.00, Reward: -2.87)
#     Transition: State (2, 2) -> State (6, 2)
# At time 4.43: Customer type 2 served by Agent 1 in 0.27 minutes, waited 1.55 minutes (Overtime cost: 0.00, Reward: -1.55)
#     Transition: State (6, 2) -> State (6, 2)
# At time 4.51: Customer type 2 served by Agent 2 in 0.39 minutes, waited 1.74 minutes (Overtime cost: 0.00, Reward: -1.74)
#     Transition: State (6, 3) -> State (5, 2)
# At time 4.52: Customer type 1 served by Agent 1 in 0.08 minutes, waited 1.53 minutes (Overtime cost: 0.00, Reward: -1.53)
#     Transition: State (6, 2) -> State (5, 2)
# At time 4.68: Customer type 1 served by Agent 1 in 0.15 minutes, waited 1.22 minutes (Overtime cost: 0.00, Reward: -1.22)
#     Transition: State (5, 2) -> State (4, 2)
# At time 4.73: Customer type 1 served by Agent 2 in 0.22 minutes, waited 1.57 minutes (Overtime cost: 0.00, Reward: -1.57)
#     Transition: State (5, 2) -> State (4, 1)
# At time 4.76: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (4, 2) -> State (3, 2)
# At time 5.11: Customer type 2 served by Agent 1 in 0.42 minutes, waited 1.62 minutes (Overtime cost: 0.00, Reward: -1.62)
#     Transition: State (4, 2) -> State (3, 4)
# At time 5.28: Customer type 1 served by Agent 1 in 0.16 minutes, waited 1.25 minutes (Overtime cost: 0.00, Reward: -1.25)
#     Transition: State (3, 4) -> State (2, 4)
# At time 5.38: Customer type 1 served by Agent 2 in 0.62 minutes, waited 1.39 minutes (Overtime cost: 0.00, Reward: -1.39)
#     Transition: State (3, 2) -> State (3, 3)
# At time 5.83: Customer type 1 served by Agent 2 in 0.44 minutes, waited 1.31 minutes (Overtime cost: 0.00, Reward: -1.31)
#     Transition: State (3, 3) -> State (3, 6)
# At time 6.03: Customer type 2 served by Agent 2 in 0.17 minutes, waited 1.27 minutes (Overtime cost: 0.00, Reward: -1.27)
#     Transition: State (4, 6) -> State (6, 5)
# At time 6.05: Customer type 2 served by Agent 1 in 0.77 minutes, waited 1.74 minutes (Overtime cost: 0.00, Reward: -1.74)
#     Transition: State (3, 4) -> State (6, 4)
# At time 6.22: Customer type 2 served by Agent 2 in 0.18 minutes, waited 1.42 minutes (Overtime cost: 0.00, Reward: -1.42)
#     Transition: State (6, 5) -> State (5, 4)
# At time 6.36: Customer type 1 served by Agent 1 in 0.29 minutes, waited 1.49 minutes (Overtime cost: 0.00, Reward: -1.49)
#     Transition: State (6, 4) -> State (5, 4)
# At time 6.37: Customer type 2 served by Agent 2 in 0.13 minutes, waited 1.33 minutes (Overtime cost: 0.00, Reward: -1.33)
#     Transition: State (5, 4) -> State (5, 4)
# At time 6.45: Customer type 2 served by Agent 2 in 0.07 minutes, waited 1.06 minutes (Overtime cost: 0.00, Reward: -1.06)
#     Transition: State (5, 4) -> State (5, 3)
# At time 6.46: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.96 minutes (Overtime cost: 0.00, Reward: -0.96)
#     Transition: State (5, 3) -> State (4, 3)
# At time 6.50: Customer type 1 served by Agent 1 in 0.12 minutes, waited 1.22 minutes (Overtime cost: 0.00, Reward: -1.22)
#     Transition: State (5, 4) -> State (4, 2)
# At time 6.53: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.83 minutes (Overtime cost: 0.00, Reward: -0.83)
#     Transition: State (4, 3) -> State (4, 1)
# At time 6.56: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.71 minutes (Overtime cost: 0.00, Reward: -0.71)
#     Transition: State (4, 1) -> State (3, 1)
# At time 6.62: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.90 minutes (Overtime cost: 0.00, Reward: -0.90)
#     Transition: State (4, 2) -> State (2, 1)
# At time 6.64: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.63 minutes (Overtime cost: 0.00, Reward: -0.63)
#     Transition: State (2, 1) -> State (1, 1)
# At time 6.72: Customer type 2 served by Agent 1 in 0.05 minutes, waited 0.41 minutes (Overtime cost: 0.00, Reward: -0.41)
#     Transition: State (1, 1) -> State (1, 0)
# At time 6.84: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.96 minutes (Overtime cost: 0.00, Reward: -0.96)
#     Transition: State (3, 1) -> State (1, 0)
# At time 6.90: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.10 minutes (Overtime cost: 0.00, Reward: -0.10)
#     Transition: State (1, 0) -> State (0, 0)
# At time 6.97: Customer type 1 served by Agent 1 in 0.21 minutes, waited 0.60 minutes (Overtime cost: 0.00, Reward: -0.60)
#     Transition: State (1, 0) -> State (0, 0)
# At time 7.36: Customer type 2 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (0, 1) -> State (0, 0)
# At time 7.59: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (1, 0) -> State (0, 0)
# At time 7.71: Customer type 2 served by Agent 2 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 0.00, Reward: -0.29)
#     Transition: State (0, 1) -> State (0, 1)
# At time 7.76: Customer type 1 served by Agent 1 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 0.00, Reward: -0.13)
#     Transition: State (1, 0) -> State (0, 0)
# At time 8.27: Customer type 2 served by Agent 2 in 0.54 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (0, 1) -> State (0, 0)
# At time 8.67: Customer type 2 served by Agent 2 in 0.18 minutes, waited 0.18 minutes (Overtime cost: 0.00, Reward: -0.18)
#     Transition: State (0, 1) -> State (1, 0)
# At time 8.72: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.14 minutes (Overtime cost: 0.00, Reward: -0.14)
#     Transition: State (1, 0) -> State (0, 0)
# At time 9.23: Customer type 1 served by Agent 1 in 0.89 minutes, waited 0.89 minutes (Overtime cost: 0.00, Reward: -0.89)
#     Transition: State (1, 0) -> State (0, 0)
# At time 9.45: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (0, 1) -> State (0, 0)
# At time 10.34: Customer type 1 served by Agent 2 in 0.23 minutes, waited 0.23 minutes (Overtime cost: 0.00, Reward: -0.23)
#     Transition: State (1, 0) -> State (0, 0)
# At time 10.74: Customer type 1 served by Agent 2 in 0.23 minutes, waited 0.23 minutes (Overtime cost: 0.00, Reward: -0.23)
#     Transition: State (1, 0) -> State (0, 0)
# At time 10.74: Customer type 1 served by Agent 1 in 1.09 minutes, waited 1.09 minutes (Overtime cost: 0.00, Reward: -1.09)
#     Transition: State (1, 0) -> State (0, 0)
# At time 11.11: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (0, 1) -> State (0, 0)
# At time 11.68: Customer type 1 served by Agent 2 in 0.72 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (1, 0) -> State (0, 0)
# At time 11.83: Customer type 1 served by Agent 1 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00, Reward: -0.17)
#     Transition: State (1, 0) -> State (0, 0)
# At time 12.06: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (0, 1) -> State (0, 1)
# At time 12.09: Customer type 2 served by Agent 1 in 0.02 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (0, 1) -> State (0, 0)
# At time 12.28: Customer type 1 served by Agent 2 in 0.50 minutes, waited 0.50 minutes (Overtime cost: 0.00, Reward: -0.50)
#     Transition: State (1, 0) -> State (0, 0)
# At time 12.54: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 0.00, Reward: -0.13)
#     Transition: State (1, 0) -> State (0, 0)
# At time 12.58: Customer type 1 served by Agent 1 in 0.48 minutes, waited 0.48 minutes (Overtime cost: 0.00, Reward: -0.48)
#     Transition: State (1, 0) -> State (0, 0)
# At time 12.85: Customer type 1 served by Agent 1 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 0.00, Reward: -0.26)
#     Transition: State (1, 0) -> State (1, 0)
# At time 12.85: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 0.00, Reward: -0.26)
#     Transition: State (1, 0) -> State (1, 0)
# At time 13.02: Customer type 1 served by Agent 1 in 0.17 minutes, waited 0.21 minutes (Overtime cost: 0.00, Reward: -0.21)
#     Transition: State (1, 0) -> State (1, 0)
# At time 13.28: Customer type 1 served by Agent 1 in 0.24 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (1, 0) -> State (1, 2)
# At time 13.48: Customer type 2 served by Agent 2 in 0.51 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (0, 1) -> State (1, 2)
# At time 13.80: Customer type 2 served by Agent 2 in 0.31 minutes, waited 0.70 minutes (Overtime cost: 0.00, Reward: -0.70)
#     Transition: State (1, 2) -> State (2, 2)
# At time 13.97: Customer type 2 served by Agent 2 in 0.17 minutes, waited 0.74 minutes (Overtime cost: 0.00, Reward: -0.74)
#     Transition: State (2, 2) -> State (2, 1)
# At time 14.13: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.68 minutes (Overtime cost: 0.00, Reward: -0.68)
#     Transition: State (2, 1) -> State (1, 2)
# At time 14.44: Customer type 1 served by Agent 2 in 0.30 minutes, waited 0.80 minutes (Overtime cost: 0.00, Reward: -0.80)
#     Transition: State (1, 2) -> State (0, 2)
# At time 14.76: Customer type 2 served by Agent 2 in 0.32 minutes, waited 0.96 minutes (Overtime cost: 0.00, Reward: -0.96)
#     Transition: State (0, 2) -> State (1, 2)
# At time 15.09: Customer type 2 served by Agent 2 in 0.32 minutes, waited 0.98 minutes (Overtime cost: 0.00, Reward: -0.98)
#     Transition: State (1, 2) -> State (2, 1)
# At time 15.10: Customer type 1 served by Agent 1 in 1.81 minutes, waited 2.03 minutes (Overtime cost: 0.00, Reward: -2.03)
#     Transition: State (1, 2) -> State (2, 0)
# At time 15.13: Customer type 2 served by Agent 2 in 0.03 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (2, 1) -> State (1, 0)
# At time 15.39: Customer type 1 served by Agent 2 in 0.23 minutes, waited 0.31 minutes (Overtime cost: 0.00, Reward: -0.31)
#     Transition: State (1, 0) -> State (0, 2)
# At time 15.46: Customer type 1 served by Agent 1 in 0.36 minutes, waited 0.80 minutes (Overtime cost: 0.00, Reward: -0.80)
#     Transition: State (2, 0) -> State (0, 1)
# At time 15.53: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (0, 1) -> State (0, 0)
# At time 15.85: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00, Reward: -0.04)
#     Transition: State (0, 1) -> State (0, 1)
# At time 15.86: Customer type 2 served by Agent 2 in 0.47 minutes, waited 0.55 minutes (Overtime cost: 0.00, Reward: -0.55)
#     Transition: State (0, 2) -> State (0, 0)
# At time 16.06: Customer type 2 served by Agent 1 in 0.20 minutes, waited 0.25 minutes (Overtime cost: 0.00, Reward: -0.25)
#     Transition: State (0, 1) -> State (0, 0)
# At time 16.47: Customer type 1 served by Agent 2 in 0.49 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 0) -> State (0, 1)
# At time 16.59: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.17 minutes (Overtime cost: 0.00, Reward: -0.17)
#     Transition: State (0, 1) -> State (0, 0)
# At time 17.20: Customer type 2 served by Agent 1 in 0.87 minutes, waited 0.87 minutes (Overtime cost: 0.00, Reward: -0.87)
#     Transition: State (0, 1) -> State (0, 0)
# At time 17.36: Customer type 1 served by Agent 2 in 0.40 minutes, waited 0.40 minutes (Overtime cost: 0.00, Reward: -0.40)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.45: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 0.00, Reward: -0.07)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.78: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00, Reward: -0.06)
#     Transition: State (1, 0) -> State (0, 1)
# At time 17.91: Customer type 2 served by Agent 2 in 0.13 minutes, waited 0.14 minutes (Overtime cost: 0.00, Reward: -0.14)
#     Transition: State (0, 1) -> State (0, 0)
# At time 18.06: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (1, 0) -> State (0, 0)
# At time 18.39: Customer type 1 served by Agent 2 in 0.33 minutes, waited 0.33 minutes (Overtime cost: 0.00, Reward: -0.33)
#     Transition: State (1, 0) -> State (0, 0)
# At time 18.52: Customer type 1 served by Agent 1 in 0.89 minutes, waited 0.89 minutes (Overtime cost: 0.00, Reward: -0.89)
#     Transition: State (1, 0) -> State (0, 0)
# At time 19.20: Customer type 1 served by Agent 1 in 0.37 minutes, waited 0.37 minutes (Overtime cost: 0.00, Reward: -0.37)
#     Transition: State (1, 0) -> State (0, 0)
# At time 19.78: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 0.00, Reward: -0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 19.89: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00, Reward: -0.02)
#     Transition: State (1, 0) -> State (0, 0)
# At time 20.54: Customer type 1 served by Agent 1 in 0.71 minutes, waited 0.71 minutes (Overtime cost: 0.00, Reward: -0.71)
#     Transition: State (1, 0) -> State (3, 1)
# At time 20.83: Customer type 1 served by Agent 2 in 0.88 minutes, waited 0.88 minutes (Overtime cost: 0.00, Reward: -0.88)
#     Transition: State (1, 0) -> State (2, 1)
# At time 20.92: Customer type 1 served by Agent 1 in 0.36 minutes, waited 0.92 minutes (Overtime cost: 0.00, Reward: -0.92)
#     Transition: State (3, 1) -> State (2, 1)
# At time 21.08: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (2, 1) -> State (2, 1)
# At time 21.22: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (2, 1) -> State (3, 1)
# At time 21.23: Customer type 2 served by Agent 1 in 0.31 minutes, waited 0.87 minutes (Overtime cost: 0.00, Reward: -0.87)
#     Transition: State (2, 1) -> State (2, 2)
# At time 21.51: Customer type 2 served by Agent 1 in 0.28 minutes, waited 0.56 minutes (Overtime cost: 0.00, Reward: -0.56)
#     Transition: State (2, 2) -> State (2, 1)
# At time 21.84: Customer type 1 served by Agent 1 in 0.33 minutes, waited 0.73 minutes (Overtime cost: 0.00, Reward: -0.73)
#     Transition: State (2, 1) -> State (1, 2)
# At time 21.93: Customer type 1 served by Agent 2 in 0.71 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (3, 1) -> State (0, 2)
# At time 21.98: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (1, 2) -> State (0, 1)
# At time 22.02: Customer type 2 served by Agent 2 in 0.08 minutes, waited 0.79 minutes (Overtime cost: 0.00, Reward: -0.79)
#     Transition: State (0, 2) -> State (0, 0)
# At time 22.62: Customer type 2 served by Agent 1 in 0.64 minutes, waited 0.95 minutes (Overtime cost: 0.00, Reward: -0.95)
#     Transition: State (0, 1) -> State (3, 1)
# At time 22.69: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (3, 1) -> State (2, 1)
# At time 22.78: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.29 minutes (Overtime cost: 0.00, Reward: -0.29)
#     Transition: State (2, 1) -> State (2, 1)
# At time 22.84: Customer type 2 served by Agent 2 in 0.70 minutes, waited 0.70 minutes (Overtime cost: 0.00, Reward: -0.70)
#     Transition: State (0, 1) -> State (2, 0)
# At time 23.04: Customer type 2 served by Agent 1 in 0.26 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (2, 1) -> State (2, 1)
# At time 23.13: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.53 minutes (Overtime cost: 0.00, Reward: -0.53)
#     Transition: State (2, 0) -> State (2, 1)
# At time 23.19: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.47 minutes (Overtime cost: 0.00, Reward: -0.47)
#     Transition: State (2, 1) -> State (1, 1)
# At time 23.34: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 1) -> State (1, 0)
# At time 23.75: Customer type 1 served by Agent 2 in 0.61 minutes, waited 0.90 minutes (Overtime cost: 0.00, Reward: -0.90)
#     Transition: State (2, 1) -> State (2, 0)
# At time 24.22: Customer type 1 served by Agent 1 in 0.88 minutes, waited 1.13 minutes (Overtime cost: 0.00, Reward: -1.13)
#     Transition: State (1, 0) -> State (2, 0)
# At time 24.33: Customer type 1 served by Agent 2 in 0.58 minutes, waited 0.92 minutes (Overtime cost: 0.00, Reward: -0.92)
#     Transition: State (2, 0) -> State (1, 0)
# At time 24.54: Customer type 1 served by Agent 1 in 0.31 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (2, 0) -> State (1, 1)
# At time 24.54: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.51 minutes (Overtime cost: 0.00, Reward: -0.51)
#     Transition: State (1, 0) -> State (1, 0)
# At time 24.55: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (1, 0) -> State (0, 0)
# At time 24.64: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.26 minutes (Overtime cost: 0.00, Reward: -0.26)
#     Transition: State (1, 1) -> State (0, 0)
# At time 25.12: Customer type 2 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (0, 1) -> State (0, 0)
# At time 25.80: Customer type 2 served by Agent 2 in 0.68 minutes, waited 0.68 minutes (Overtime cost: 0.00, Reward: -0.68)
#     Transition: State (0, 1) -> State (4, 1)
# At time 25.82: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.34 minutes (Overtime cost: 0.00, Reward: -0.34)
#     Transition: State (4, 1) -> State (3, 1)
# At time 26.02: Customer type 2 served by Agent 2 in 0.20 minutes, waited 0.47 minutes (Overtime cost: 0.00, Reward: -0.47)
#     Transition: State (3, 1) -> State (3, 0)
# At time 26.16: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.48 minutes (Overtime cost: 0.00, Reward: -0.48)
#     Transition: State (3, 0) -> State (2, 0)
# At time 26.20: Customer type 1 served by Agent 1 in 1.08 minutes, waited 1.08 minutes (Overtime cost: 0.00, Reward: -1.08)
#     Transition: State (1, 0) -> State (1, 0)
# At time 26.23: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (2, 0) -> State (1, 0)
# At time 26.28: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 0) -> State (0, 0)
# At time 27.05: Customer type 1 served by Agent 2 in 0.81 minutes, waited 0.83 minutes (Overtime cost: 0.00, Reward: -0.83)
#     Transition: State (1, 0) -> State (1, 0)
# At time 27.14: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.58 minutes (Overtime cost: 0.00, Reward: -0.58)
#     Transition: State (1, 0) -> State (0, 0)
# At time 27.54: Customer type 2 served by Agent 2 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 0.00, Reward: -0.31)
#     Transition: State (0, 1) -> State (1, 1)
# At time 27.80: Customer type 1 served by Agent 1 in 1.43 minutes, waited 1.43 minutes (Overtime cost: 0.00, Reward: -1.43)
#     Transition: State (1, 0) -> State (0, 2)
# At time 27.81: Customer type 1 served by Agent 2 in 0.27 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 1) -> State (0, 1)
# At time 28.24: Customer type 2 served by Agent 1 in 0.44 minutes, waited 0.80 minutes (Overtime cost: 0.00, Reward: -0.80)
#     Transition: State (0, 2) -> State (5, 0)
# At time 28.32: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.40 minutes (Overtime cost: 0.00, Reward: -0.40)
#     Transition: State (5, 0) -> State (4, 1)
# At time 28.38: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.39 minutes (Overtime cost: 0.00, Reward: -0.39)
#     Transition: State (4, 1) -> State (4, 1)
# At time 28.50: Customer type 2 served by Agent 2 in 0.69 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (0, 1) -> State (3, 2)
# At time 28.83: Customer type 1 served by Agent 1 in 0.45 minutes, waited 0.76 minutes (Overtime cost: 0.00, Reward: -0.76)
#     Transition: State (4, 1) -> State (3, 2)
# At time 28.90: Customer type 1 served by Agent 2 in 0.39 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (3, 2) -> State (2, 2)
# At time 29.11: Customer type 2 served by Agent 2 in 0.21 minutes, waited 0.84 minutes (Overtime cost: 0.00, Reward: -0.84)
#     Transition: State (2, 2) -> State (2, 1)
# At time 29.25: Customer type 1 served by Agent 1 in 0.41 minutes, waited 1.08 minutes (Overtime cost: 0.00, Reward: -1.08)
#     Transition: State (3, 2) -> State (1, 1)
# At time 29.40: Customer type 1 served by Agent 2 in 0.30 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (2, 1) -> State (3, 0)
# At time 29.44: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.82 minutes (Overtime cost: 0.00, Reward: -0.82)
#     Transition: State (3, 0) -> State (2, 0)
# At time 29.66: Customer type 2 served by Agent 1 in 0.40 minutes, waited 1.17 minutes (Overtime cost: 0.00, Reward: -1.17)
#     Transition: State (1, 1) -> State (1, 0)
# At time 29.69: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.33 minutes (Overtime cost: 0.00, Reward: -0.33)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.87: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.61 minutes (Overtime cost: 0.00, Reward: -0.61)
#     Transition: State (2, 0) -> State (0, 0)
# At time 30.08: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.18: Customer type 2 served by Agent 1 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00, Reward: -0.06)
#     Transition: State (0, 1) -> State (0, 0)
# At time 30.30: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00, Reward: -0.06)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.32: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (0, 1) -> State (0, 0)
# At time 30.62: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00, Reward: -0.04)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.72: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (0, 1) -> State (0, 0)
# At time 30.93: Customer type 2 served by Agent 1 in 0.59 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (0, 1) -> State (0, 0)
# At time 31.18: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.77: Customer type 2 served by Agent 1 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 0.00, Reward: -0.26)
#     Transition: State (0, 1) -> State (1, 0)
# At time 31.78: Customer type 2 served by Agent 2 in 0.21 minutes, waited 0.21 minutes (Overtime cost: 0.00, Reward: -0.21)
#     Transition: State (0, 1) -> State (0, 0)
# At time 31.79: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.18 minutes (Overtime cost: 0.00, Reward: -0.18)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.88: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.94: Customer type 2 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (0, 1) -> State (0, 0)
# At time 32.13: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (0, 1) -> State (0, 0)
# At time 32.20: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 0.00, Reward: -0.20)
#     Transition: State (1, 0) -> State (0, 0)
# At time 32.44: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.23 minutes (Overtime cost: 0.00, Reward: -0.23)
#     Transition: State (1, 0) -> State (0, 0)
# At time 32.61: Customer type 1 served by Agent 2 in 0.32 minutes, waited 0.32 minutes (Overtime cost: 0.00, Reward: -0.32)
#     Transition: State (1, 0) -> State (0, 0)
# At time 32.99: Customer type 2 served by Agent 1 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (0, 1) -> State (0, 0)
# At time 33.20: Customer type 2 served by Agent 1 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00, Reward: -0.17)
#     Transition: State (0, 1) -> State (0, 0)
# At time 33.54: Customer type 1 served by Agent 2 in 0.66 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (1, 0) -> State (0, 1)
# At time 33.55: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (0, 1) -> State (0, 1)
# At time 33.93: Customer type 2 served by Agent 1 in 0.38 minutes, waited 0.39 minutes (Overtime cost: 0.00, Reward: -0.39)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.42: Customer type 1 served by Agent 2 in 0.24 minutes, waited 0.24 minutes (Overtime cost: 0.00, Reward: -0.24)
#     Transition: State (1, 0) -> State (0, 0)
# At time 34.64: Customer type 2 served by Agent 2 in 0.01 minutes, waited 0.01 minutes (Overtime cost: 0.00, Reward: -0.01)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.88: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 0.00, Reward: -0.08)
#     Transition: State (1, 0) -> State (0, 0)
# At time 35.00: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (0, 1) -> State (0, 0)
# At time 35.01: Customer type 2 served by Agent 1 in 1.05 minutes, waited 1.05 minutes (Overtime cost: 0.00, Reward: -1.05)
#     Transition: State (0, 1) -> State (0, 0)
# At time 35.29: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (1, 0) -> State (0, 0)
# At time 35.56: Customer type 1 served by Agent 2 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (1, 0) -> State (1, 0)
# At time 35.77: Customer type 1 served by Agent 1 in 0.44 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (1, 0) -> State (0, 1)
# At time 35.98: Customer type 1 served by Agent 2 in 0.41 minutes, waited 0.47 minutes (Overtime cost: 0.00, Reward: -0.47)
#     Transition: State (1, 0) -> State (1, 0)
# At time 36.04: Customer type 2 served by Agent 1 in 0.27 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (0, 1) -> State (0, 0)
# At time 36.06: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (1, 0) -> State (0, 0)
# At time 36.32: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 0.00, Reward: -0.08)
#     Transition: State (1, 0) -> State (0, 0)
# At time 36.37: Customer type 2 served by Agent 1 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (0, 1) -> State (0, 0)
# At time 36.87: Customer type 2 served by Agent 2 in 0.14 minutes, waited 0.14 minutes (Overtime cost: 0.00, Reward: -0.14)
#     Transition: State (0, 1) -> State (0, 0)
# At time 36.89: Customer type 2 served by Agent 1 in 0.22 minutes, waited 0.22 minutes (Overtime cost: 0.00, Reward: -0.22)
#     Transition: State (0, 1) -> State (0, 0)
# At time 37.08: Customer type 2 served by Agent 1 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 0.00, Reward: -0.13)
#     Transition: State (0, 1) -> State (0, 0)
# At time 37.25: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00, Reward: -0.12)
#     Transition: State (1, 0) -> State (0, 0)
# At time 37.37: Customer type 2 served by Agent 1 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 0.00, Reward: -0.26)
#     Transition: State (0, 1) -> State (0, 0)
# At time 37.99: Customer type 2 served by Agent 2 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 0.00, Reward: -0.16)
#     Transition: State (0, 1) -> State (1, 1)
# At time 38.02: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.14 minutes (Overtime cost: 0.00, Reward: -0.14)
#     Transition: State (1, 1) -> State (0, 1)
# At time 38.21: Customer type 1 served by Agent 1 in 0.39 minutes, waited 0.39 minutes (Overtime cost: 0.00, Reward: -0.39)
#     Transition: State (1, 0) -> State (0, 1)
# At time 38.43: Customer type 2 served by Agent 2 in 0.41 minutes, waited 0.45 minutes (Overtime cost: 0.00, Reward: -0.45)
#     Transition: State (0, 1) -> State (1, 0)
# At time 38.50: Customer type 2 served by Agent 1 in 0.28 minutes, waited 0.29 minutes (Overtime cost: 0.00, Reward: -0.29)
#     Transition: State (0, 1) -> State (1, 0)
# At time 38.91: Customer type 1 served by Agent 1 in 0.41 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (1, 0) -> State (3, 2)
# At time 39.13: Customer type 1 served by Agent 2 in 0.70 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (1, 0) -> State (4, 1)
# At time 39.17: Customer type 2 served by Agent 2 in 0.04 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (4, 1) -> State (4, 0)
# At time 39.23: Customer type 2 served by Agent 1 in 0.31 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (3, 2) -> State (3, 0)
# At time 39.25: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (3, 0) -> State (2, 0)
# At time 39.38: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.58 minutes (Overtime cost: 0.00, Reward: -0.58)
#     Transition: State (4, 0) -> State (2, 2)
# At time 39.51: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.50 minutes (Overtime cost: 0.00, Reward: -0.50)
#     Transition: State (2, 2) -> State (3, 4)
# At time 39.54: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.23 minutes (Overtime cost: 0.00, Reward: -0.23)
#     Transition: State (3, 4) -> State (2, 4)
# At time 39.67: Customer type 1 served by Agent 1 in 0.42 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (2, 0) -> State (3, 3)
# At time 39.68: Customer type 2 served by Agent 2 in 0.13 minutes, waited 0.36 minutes (Overtime cost: 0.00, Reward: -0.36)
#     Transition: State (2, 4) -> State (3, 2)
# At time 40.14: Customer type 2 served by Agent 1 in 0.47 minutes, waited 0.80 minutes (Overtime cost: 0.14, Reward: -0.94)
#     Transition: State (3, 3) -> State (3, 1)
# At time 40.35: Customer type 2 served by Agent 1 in 0.20 minutes, waited 0.92 minutes (Overtime cost: 0.35, Reward: -1.27)
#     Transition: State (3, 1) -> State (3, 0)
# Customer rejected at time 40.36: No new arrivals after T = 40
# At time 40.41: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.96 minutes (Overtime cost: 0.41, Reward: -1.36)
#     Transition: State (3, 0) -> State (2, 0)
# Customer rejected at time 40.41: No new arrivals after T = 40
# At time 40.50: Customer type 2 served by Agent 2 in 0.81 minutes, waited 1.09 minutes (Overtime cost: 0.50, Reward: -1.59)
#     Transition: State (3, 2) -> State (1, 0)
# At time 40.56: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.92 minutes (Overtime cost: 0.56, Reward: -1.48)
#     Transition: State (1, 0) -> State (0, 0)
# Customer rejected at time 40.71: No new arrivals after T = 40
# Customer rejected at time 41.00: No new arrivals after T = 40
# At time 41.16: Customer type 1 served by Agent 1 in 0.75 minutes, waited 1.68 minutes (Overtime cost: 1.16, Reward: -2.84)
#     Transition: State (2, 0) -> State (0, 0)
# Customer rejected at time 41.29: No new arrivals after T = 40
# Customer rejected at time 41.59: No new arrivals after T = 40
# Customer rejected at time 41.74: No new arrivals after T = 40
# Customer rejected at time 41.79: No new arrivals after T = 40
# Customer rejected at time 41.80: No new arrivals after T = 40
# Customer rejected at time 42.14: No new arrivals after T = 40
# Customer rejected at time 42.64: No new arrivals after T = 40
# Customer rejected at time 42.70: No new arrivals after T = 40
# Customer rejected at time 42.99: No new arrivals after T = 40
# Customer rejected at time 43.27: No new arrivals after T = 40
# Customer rejected at time 43.44: No new arrivals after T = 40
# Customer rejected at time 43.60: No new arrivals after T = 40
# Customer rejected at time 43.66: No new arrivals after T = 40
# Customer rejected at time 43.87: No new arrivals after T = 40
# Customer rejected at time 44.38: No new arrivals after T = 40
# Customer rejected at time 44.42: No new arrivals after T = 40
# Customer rejected at time 44.62: No new arrivals after T = 40
# Customer rejected at time 44.86: No new arrivals after T = 40
# Customer rejected at time 45.01: No new arrivals after T = 40
# Customer rejected at time 45.17: No new arrivals after T = 40
# Customer rejected at time 45.38: No new arrivals after T = 40
# Customer rejected at time 45.86: No new arrivals after T = 40
# Customer rejected at time 46.25: No new arrivals after T = 40
# Customer rejected at time 46.27: No new arrivals after T = 40
# Customer rejected at time 46.29: No new arrivals after T = 40
# Customer rejected at time 46.30: No new arrivals after T = 40
# Customer rejected at time 46.33: No new arrivals after T = 40
# Customer rejected at time 46.46: No new arrivals after T = 40
# Customer rejected at time 46.57: No new arrivals after T = 40
# Customer rejected at time 46.62: No new arrivals after T = 40
# Customer rejected at time 46.98: No new arrivals after T = 40
# Customer rejected at time 47.14: No new arrivals after T = 40
# Customer rejected at time 47.54: No new arrivals after T = 40
# Customer rejected at time 47.58: No new arrivals after T = 40
# Customer rejected at time 47.67: No new arrivals after T = 40
# Customer rejected at time 47.73: No new arrivals after T = 40
# Customer rejected at time 47.93: No new arrivals after T = 40
# Customer rejected at time 47.97: No new arrivals after T = 40
# Customer rejected at time 48.10: No new arrivals after T = 40
# Customer rejected at time 48.29: No new arrivals after T = 40
# Customer rejected at time 48.46: No new arrivals after T = 40
# Customer rejected at time 48.62: No new arrivals after T = 40
# Customer rejected at time 48.83: No new arrivals after T = 40
# Customer rejected at time 49.00: No new arrivals after T = 40
# Customer rejected at time 49.10: No new arrivals after T = 40
# Customer rejected at time 49.20: No new arrivals after T = 40
# Customer rejected at time 49.35: No new arrivals after T = 40
# Customer rejected at time 49.60: No new arrivals after T = 40
# Customer rejected at time 50.06: No new arrivals after T = 40
# Customer rejected at time 50.11: No new arrivals after T = 40
# Customer rejected at time 50.22: No new arrivals after T = 40
# Customer rejected at time 50.51: No new arrivals after T = 40
# Customer rejected at time 50.64: No new arrivals after T = 40
# Customer rejected at time 50.80: No new arrivals after T = 40
# Customer rejected at time 50.80: No new arrivals after T = 40
# Customer rejected at time 50.88: No new arrivals after T = 40
# Customer rejected at time 51.18: No new arrivals after T = 40
# Customer rejected at time 51.28: No new arrivals after T = 40
# Customer rejected at time 51.30: No new arrivals after T = 40
# Customer rejected at time 51.40: No new arrivals after T = 40
# Customer rejected at time 51.65: No new arrivals after T = 40
# Customer rejected at time 51.72: No new arrivals after T = 40
# Customer rejected at time 52.05: No new arrivals after T = 40
# Customer rejected at time 52.50: No new arrivals after T = 40
# Customer rejected at time 52.73: No new arrivals after T = 40
# Customer rejected at time 52.81: No new arrivals after T = 40
# Customer rejected at time 52.83: No new arrivals after T = 40
# Customer rejected at time 52.92: No new arrivals after T = 40
# Customer rejected at time 52.99: No new arrivals after T = 40
# Customer rejected at time 53.07: No new arrivals after T = 40
# Customer rejected at time 53.18: No new arrivals after T = 40
# Customer rejected at time 53.63: No new arrivals after T = 40
# Customer rejected at time 53.88: No new arrivals after T = 40
# Customer rejected at time 53.93: No new arrivals after T = 40
# Customer rejected at time 54.32: No new arrivals after T = 40
# Customer rejected at time 54.59: No new arrivals after T = 40
# Customer rejected at time 54.65: No new arrivals after T = 40
# Customer rejected at time 56.09: No new arrivals after T = 40
# Customer rejected at time 56.12: No new arrivals after T = 40
# Customer rejected at time 56.24: No new arrivals after T = 40
# Customer rejected at time 56.43: No new arrivals after T = 40
# Customer rejected at time 56.46: No new arrivals after T = 40
# Customer rejected at time 56.63: No new arrivals after T = 40
# Customer rejected at time 56.90: No new arrivals after T = 40
# Customer rejected at time 57.11: No new arrivals after T = 40
# Customer rejected at time 57.30: No new arrivals after T = 40
# Customer rejected at time 57.35: No new arrivals after T = 40
# Customer rejected at time 57.38: No new arrivals after T = 40
# Customer rejected at time 57.56: No new arrivals after T = 40
# Customer rejected at time 57.74: No new arrivals after T = 40
# Customer rejected at time 57.84: No new arrivals after T = 40
# Customer rejected at time 58.02: No new arrivals after T = 40
# Customer rejected at time 58.13: No new arrivals after T = 40
# Customer rejected at time 58.18: No new arrivals after T = 40
# Customer rejected at time 58.54: No new arrivals after T = 40
# Customer rejected at time 58.68: No new arrivals after T = 40
# Customer rejected at time 58.71: No new arrivals after T = 40
# Customer rejected at time 58.80: No new arrivals after T = 40
# Customer rejected at time 58.90: No new arrivals after T = 40
# Customer rejected at time 59.20: No new arrivals after T = 40
# Customer rejected at time 59.39: No new arrivals after T = 40
# Customer rejected at time 59.46: No new arrivals after T = 40
# Customer rejected at time 59.52: No new arrivals after T = 40
# Customer rejected at time 59.68: No new arrivals after T = 40
# Customer rejected at time 59.82: No new arrivals after T = 40
# Customer rejected at time 59.86: No new arrivals after T = 40
#
# Total customers served: 210
# Total waiting time: 130.57 minutes
# Total agent overtime cost: 3.11 minutes
# Total rewards: -8984.68
# Total customers rejected after T = 40: 110
# Average waiting time per customer: 0.62 minutes
#
# Transition Probabilities:
#   P((0, 0) | (0, 1)) = 0.6739
#   P((3, 0) | (1, 0)) = 0.0308
#   P((3, 0) | (4, 0)) = 0.3333
#   P((2, 0) | (4, 0)) = 0.3333
#   P((1, 1) | (3, 0)) = 0.2000
#   P((1, 1) | (2, 1)) = 0.2308
#   P((2, 2) | (1, 1)) = 0.1250
#   P((2, 4) | (1, 1)) = 0.1250
#   P((3, 3) | (2, 4)) = 0.5000
#   P((3, 3) | (3, 3)) = 0.2500
#   P((4, 5) | (3, 3)) = 0.2500
#   P((5, 6) | (4, 5)) = 1.0000
#   P((5, 5) | (5, 6)) = 1.0000
#   P((6, 4) | (5, 5)) = 1.0000
#   P((7, 4) | (7, 4)) = 0.5000
#   P((6, 4) | (7, 4)) = 0.5000
#   P((6, 3) | (6, 4)) = 0.5000
#   P((6, 2) | (2, 2)) = 0.2000
#   P((6, 2) | (6, 2)) = 0.5000
#   P((5, 2) | (6, 3)) = 1.0000
#   P((5, 2) | (6, 2)) = 0.5000
#   P((4, 2) | (5, 2)) = 0.5000
#   P((4, 1) | (5, 2)) = 0.5000
#   P((3, 2) | (4, 2)) = 0.3333
#   P((3, 4) | (4, 2)) = 0.3333
#   P((2, 4) | (3, 4)) = 0.6667
#   P((3, 3) | (3, 2)) = 0.2000
#   P((3, 6) | (3, 3)) = 0.2500
#   P((6, 5) | (4, 6)) = 1.0000
#   P((6, 4) | (3, 4)) = 0.3333
#   P((5, 4) | (6, 5)) = 1.0000
#   P((5, 4) | (6, 4)) = 0.5000
#   P((5, 4) | (5, 4)) = 0.3333
#   P((5, 3) | (5, 4)) = 0.3333
#   P((4, 3) | (5, 3)) = 1.0000
#   P((4, 2) | (5, 4)) = 0.3333
#   P((4, 1) | (4, 3)) = 1.0000
#   P((3, 1) | (4, 1)) = 0.4000
#   P((2, 1) | (4, 2)) = 0.3333
#   P((1, 0) | (1, 1)) = 0.3750
#   P((1, 0) | (3, 1)) = 0.1667
#   P((0, 0) | (1, 0)) = 0.6462
#   P((0, 1) | (0, 1)) = 0.0870
#   P((1, 0) | (0, 1)) = 0.0870
#   P((1, 0) | (1, 0)) = 0.1231
#   P((1, 2) | (1, 0)) = 0.0154
#   P((1, 2) | (0, 1)) = 0.0217
#   P((2, 2) | (1, 2)) = 0.2000
#   P((2, 1) | (2, 2)) = 0.6000
#   P((1, 2) | (2, 1)) = 0.1538
#   P((0, 2) | (1, 2)) = 0.2000
#   P((1, 2) | (0, 2)) = 0.2500
#   P((2, 1) | (1, 2)) = 0.2000
#   P((2, 0) | (1, 2)) = 0.2000
#   P((1, 0) | (2, 1)) = 0.0769
#   P((0, 2) | (1, 0)) = 0.0308
#   P((0, 1) | (2, 0)) = 0.1250
#   P((0, 0) | (0, 2)) = 0.5000
#   P((0, 1) | (1, 0)) = 0.0769
#   P((3, 1) | (1, 0)) = 0.0154
#   P((2, 1) | (1, 0)) = 0.0154
#   P((2, 1) | (3, 1)) = 0.3333
#   P((2, 1) | (2, 1)) = 0.2308
#   P((3, 1) | (2, 1)) = 0.0769
#   P((2, 2) | (2, 1)) = 0.0769
#   P((0, 2) | (3, 1)) = 0.1667
#   P((0, 1) | (1, 2)) = 0.2000
#   P((3, 1) | (0, 1)) = 0.0217
#   P((2, 0) | (0, 1)) = 0.0217
#   P((2, 1) | (2, 0)) = 0.1250
#   P((2, 0) | (2, 1)) = 0.0769
#   P((2, 0) | (1, 0)) = 0.0154
#   P((1, 0) | (2, 0)) = 0.2500
#   P((1, 1) | (2, 0)) = 0.1250
#   P((0, 0) | (1, 1)) = 0.1250
#   P((4, 1) | (0, 1)) = 0.0217
#   P((3, 0) | (3, 1)) = 0.3333
#   P((2, 0) | (3, 0)) = 0.8000
#   P((1, 1) | (0, 1)) = 0.0435
#   P((0, 1) | (1, 1)) = 0.2500
#   P((5, 0) | (0, 2)) = 0.2500
#   P((4, 1) | (5, 0)) = 1.0000
#   P((4, 1) | (4, 1)) = 0.2000
#   P((3, 2) | (0, 1)) = 0.0217
#   P((3, 2) | (4, 1)) = 0.2000
#   P((2, 2) | (3, 2)) = 0.2000
#   P((1, 1) | (3, 2)) = 0.2000
#   P((3, 0) | (2, 1)) = 0.0769
#   P((0, 0) | (2, 0)) = 0.2500
#   P((3, 2) | (1, 0)) = 0.0154
#   P((4, 1) | (1, 0)) = 0.0154
#   P((4, 0) | (4, 1)) = 0.2000
#   P((3, 0) | (3, 2)) = 0.2000
#   P((2, 2) | (4, 0)) = 0.3333
#   P((3, 4) | (2, 2)) = 0.2000
#   P((3, 3) | (2, 0)) = 0.1250
#   P((3, 2) | (2, 4)) = 0.5000
#   P((3, 1) | (3, 3)) = 0.2500
#   P((1, 0) | (3, 2)) = 0.2000
# At time 0.37: Customer type 2 served by Agent 1 in 0.30 minutes, waited 0.30 minutes (Overtime cost: 0.00, Reward: -0.30)
#     Transition: State (0, 1) -> State (0, 0)
# At time 0.57: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 0.00, Reward: -0.20)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.06: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 0.00, Reward: -0.11)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.29: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.00: Customer type 2 served by Agent 1 in 0.55 minutes, waited 0.55 minutes (Overtime cost: 0.00, Reward: -0.55)
#     Transition: State (0, 1) -> State (2, 1)
# At time 2.20: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (2, 1) -> State (1, 1)
# At time 2.37: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.46 minutes (Overtime cost: 0.00, Reward: -0.46)
#     Transition: State (1, 1) -> State (0, 1)
# At time 2.56: Customer type 2 served by Agent 1 in 0.09 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (0, 1) -> State (0, 1)
# At time 2.69: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.20 minutes (Overtime cost: 0.00, Reward: -0.20)
#     Transition: State (0, 1) -> State (0, 0)
# At time 2.80: Customer type 2 served by Agent 2 in 1.52 minutes, waited 1.52 minutes (Overtime cost: 0.00, Reward: -1.52)
#     Transition: State (0, 1) -> State (0, 0)
# At time 2.95: Customer type 2 served by Agent 1 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 0.00, Reward: -0.20)
#     Transition: State (0, 1) -> State (1, 0)
# At time 3.07: Customer type 2 served by Agent 2 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 0.00, Reward: -0.26)
#     Transition: State (0, 1) -> State (1, 1)
# At time 3.17: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.11 minutes (Overtime cost: 0.00, Reward: -0.11)
#     Transition: State (1, 1) -> State (1, 1)
# At time 3.33: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (1, 1) -> State (0, 1)
# At time 3.41: Customer type 1 served by Agent 2 in 0.16 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (1, 1) -> State (1, 0)
# At time 3.77: Customer type 2 served by Agent 1 in 0.43 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (0, 1) -> State (1, 0)
# ...
#     Transition: State (0, 14) -> State (2, 13)
# At time 39.93: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.07 minutes (Overtime cost: 0.00, Reward: -0.07)
#     Transition: State (2, 13) -> State (1, 13)
# At time 40.16: Customer type 1 served by Agent 2 in 0.37 minutes, waited 0.56 minutes (Overtime cost: 0.16, Reward: -0.73)
#     Transition: State (1, 13) -> State (2, 13)
# Customer rejected at time 40.17: No new arrivals after T = 40
# Customer rejected at time 40.18: No new arrivals after T = 40
# At time 40.18: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.22 minutes (Overtime cost: 0.18, Reward: -0.40)
#     Transition: State (2, 13) -> State (1, 13)
# Customer rejected at time 40.23: No new arrivals after T = 40
# Customer rejected at time 40.30: No new arrivals after T = 40
# At time 40.43: Customer type 1 served by Agent 2 in 0.24 minutes, waited 0.44 minutes (Overtime cost: 0.43, Reward: -0.87)
#     Transition: State (1, 13) -> State (0, 13)
# Customer rejected at time 40.44: No new arrivals after T = 40
# At time 40.45: Customer type 2 served by Agent 2 in 0.03 minutes, waited 6.34 minutes (Overtime cost: 0.45, Reward: -6.79)
#     Transition: State (0, 13) -> State (0, 12)
# At time 40.51: Customer type 1 served by Agent 1 in 0.57 minutes, waited 0.63 minutes (Overtime cost: 0.51, Reward: -1.14)
#     Transition: State (1, 13) -> State (0, 11)
# At time 40.51: Customer type 2 served by Agent 2 in 0.06 minutes, waited 5.49 minutes (Overtime cost: 0.51, Reward: -6.00)
#     Transition: State (0, 12) -> State (0, 11)
# At time 40.65: Customer type 2 served by Agent 2 in 0.13 minutes, waited 4.33 minutes (Overtime cost: 0.65, Reward: -4.98)
#     Transition: State (0, 10) -> State (0, 9)
# Customer rejected at time 40.71: No new arrivals after T = 40
# Customer rejected at time 40.79: No new arrivals after T = 40
# At time 40.85: Customer type 2 served by Agent 2 in 0.20 minutes, waited 4.45 minutes (Overtime cost: 0.85, Reward: -5.30)
#     Transition: State (0, 9) -> State (0, 8)
# Customer rejected at time 40.87: No new arrivals after T = 40
# Customer rejected at time 40.89: No new arrivals after T = 40
# Customer rejected at time 40.91: No new arrivals after T = 40
# At time 40.94: Customer type 2 served by Agent 2 in 0.09 minutes, waited 4.23 minutes (Overtime cost: 0.94, Reward: -5.17)
#     Transition: State (0, 8) -> State (0, 7)
# At time 40.95: Customer type 2 served by Agent 2 in 0.01 minutes, waited 4.16 minutes (Overtime cost: 0.95, Reward: -5.11)
#     Transition: State (0, 7) -> State (0, 6)
# At time 41.04: Customer type 2 served by Agent 2 in 0.08 minutes, waited 3.39 minutes (Overtime cost: 1.04, Reward: -4.43)
#     Transition: State (0, 6) -> State (0, 5)
# At time 41.26: Customer type 2 served by Agent 1 in 0.75 minutes, waited 5.55 minutes (Overtime cost: 1.26, Reward: -6.81)
#     Transition: State (0, 11) -> State (0, 4)
# Customer rejected at time 41.38: No new arrivals after T = 40
# Customer rejected at time 41.41: No new arrivals after T = 40
# Customer rejected at time 41.48: No new arrivals after T = 40
# At time 41.49: Customer type 2 served by Agent 1 in 0.21 minutes, waited 1.95 minutes (Overtime cost: 1.49, Reward: -3.43)
#     Transition: State (0, 4) -> State (0, 3)
# Customer rejected at time 41.52: No new arrivals after T = 40
# Customer rejected at time 41.55: No new arrivals after T = 40
# At time 41.60: Customer type 2 served by Agent 2 in 0.56 minutes, waited 2.46 minutes (Overtime cost: 1.60, Reward: -4.06)
#     Transition: State (0, 5) -> State (0, 2)
# At time 42.02: Customer type 2 served by Agent 1 in 0.54 minutes, waited 2.47 minutes (Overtime cost: 2.02, Reward: -4.50)
#     Transition: State (0, 3) -> State (0, 1)
# At time 42.03: Customer type 2 served by Agent 2 in 0.42 minutes, waited 2.46 minutes (Overtime cost: 2.03, Reward: -4.49)
#     Transition: State (0, 2) -> State (0, 0)
# Customer rejected at time 42.05: No new arrivals after T = 40
# At time 42.17: Customer type 2 served by Agent 1 in 0.14 minutes, waited 2.35 minutes (Overtime cost: 2.17, Reward: -4.52)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 42.25: No new arrivals after T = 40
# Customer rejected at time 42.31: No new arrivals after T = 40
# Customer rejected at time 42.44: No new arrivals after T = 40
# Customer rejected at time 42.56: No new arrivals after T = 40
# Customer rejected at time 42.59: No new arrivals after T = 40
# Customer rejected at time 42.66: No new arrivals after T = 40
# Customer rejected at time 42.97: No new arrivals after T = 40
# Customer rejected at time 43.04: No new arrivals after T = 40
# Customer rejected at time 43.33: No new arrivals after T = 40
# Customer rejected at time 43.38: No new arrivals after T = 40
# Customer rejected at time 43.49: No new arrivals after T = 40
# Customer rejected at time 43.94: No new arrivals after T = 40
# Customer rejected at time 43.94: No new arrivals after T = 40
# Customer rejected at time 43.95: No new arrivals after T = 40
# Customer rejected at time 44.46: No new arrivals after T = 40
# Customer rejected at time 44.71: No new arrivals after T = 40
# Customer rejected at time 45.13: No new arrivals after T = 40
# Customer rejected at time 45.18: No new arrivals after T = 40
# Customer rejected at time 45.27: No new arrivals after T = 40
# Customer rejected at time 45.27: No new arrivals after T = 40
# Customer rejected at time 45.75: No new arrivals after T = 40
# Customer rejected at time 46.15: No new arrivals after T = 40
# Customer rejected at time 46.44: No new arrivals after T = 40
# Customer rejected at time 46.83: No new arrivals after T = 40
# Customer rejected at time 46.85: No new arrivals after T = 40
# Customer rejected at time 46.98: No new arrivals after T = 40
# Customer rejected at time 46.98: No new arrivals after T = 40
# Customer rejected at time 47.14: No new arrivals after T = 40
# Customer rejected at time 47.16: No new arrivals after T = 40
# Customer rejected at time 47.36: No new arrivals after T = 40
# Customer rejected at time 47.60: No new arrivals after T = 40
# Customer rejected at time 47.80: No new arrivals after T = 40
# Customer rejected at time 47.94: No new arrivals after T = 40
# Customer rejected at time 48.09: No new arrivals after T = 40
# Customer rejected at time 48.14: No new arrivals after T = 40
# Customer rejected at time 48.59: No new arrivals after T = 40
# Customer rejected at time 48.61: No new arrivals after T = 40
# Customer rejected at time 48.72: No new arrivals after T = 40
# Customer rejected at time 49.10: No new arrivals after T = 40
# Customer rejected at time 49.12: No new arrivals after T = 40
# Customer rejected at time 49.21: No new arrivals after T = 40
# Customer rejected at time 49.64: No new arrivals after T = 40
# Customer rejected at time 49.74: No new arrivals after T = 40
# Customer rejected at time 49.92: No new arrivals after T = 40
# Customer rejected at time 50.08: No new arrivals after T = 40
# Customer rejected at time 50.18: No new arrivals after T = 40
# Customer rejected at time 50.28: No new arrivals after T = 40
# Customer rejected at time 50.32: No new arrivals after T = 40
# Customer rejected at time 50.64: No new arrivals after T = 40
# Customer rejected at time 50.92: No new arrivals after T = 40
# Customer rejected at time 51.31: No new arrivals after T = 40
# Customer rejected at time 51.55: No new arrivals after T = 40
# Customer rejected at time 51.69: No new arrivals after T = 40
# Customer rejected at time 51.70: No new arrivals after T = 40
# Customer rejected at time 51.77: No new arrivals after T = 40
# Customer rejected at time 51.83: No new arrivals after T = 40
# Customer rejected at time 52.53: No new arrivals after T = 40
# Customer rejected at time 52.61: No new arrivals after T = 40
# Customer rejected at time 52.63: No new arrivals after T = 40
# Customer rejected at time 52.74: No new arrivals after T = 40
# Customer rejected at time 52.83: No new arrivals after T = 40
# Customer rejected at time 52.95: No new arrivals after T = 40
# Customer rejected at time 53.24: No new arrivals after T = 40
# Customer rejected at time 53.27: No new arrivals after T = 40
# Customer rejected at time 53.31: No new arrivals after T = 40
# Customer rejected at time 53.38: No new arrivals after T = 40
# Customer rejected at time 53.58: No new arrivals after T = 40
# Customer rejected at time 54.06: No new arrivals after T = 40
# Customer rejected at time 54.07: No new arrivals after T = 40
# Customer rejected at time 54.15: No new arrivals after T = 40
# Customer rejected at time 54.48: No new arrivals after T = 40
# Customer rejected at time 54.63: No new arrivals after T = 40
# Customer rejected at time 54.80: No new arrivals after T = 40
# Customer rejected at time 54.97: No new arrivals after T = 40
# Customer rejected at time 55.09: No new arrivals after T = 40
# Customer rejected at time 55.27: No new arrivals after T = 40
# Customer rejected at time 55.37: No new arrivals after T = 40
# Customer rejected at time 55.43: No new arrivals after T = 40
# Customer rejected at time 55.52: No new arrivals after T = 40
# Customer rejected at time 55.93: No new arrivals after T = 40
# Customer rejected at time 55.95: No new arrivals after T = 40
# Customer rejected at time 55.95: No new arrivals after T = 40
# Customer rejected at time 56.01: No new arrivals after T = 40
# Customer rejected at time 56.28: No new arrivals after T = 40
# Customer rejected at time 56.88: No new arrivals after T = 40
# Customer rejected at time 58.28: No new arrivals after T = 40
# Customer rejected at time 58.33: No new arrivals after T = 40
# Customer rejected at time 58.40: No new arrivals after T = 40
# Customer rejected at time 58.48: No new arrivals after T = 40
# Customer rejected at time 58.54: No new arrivals after T = 40
# Customer rejected at time 58.68: No new arrivals after T = 40
# Customer rejected at time 59.13: No new arrivals after T = 40
# Customer rejected at time 59.31: No new arrivals after T = 40
# Customer rejected at time 59.52: No new arrivals after T = 40
# Customer rejected at time 59.59: No new arrivals after T = 40
# Customer rejected at time 59.71: No new arrivals after T = 40
# Customer rejected at time 59.82: No new arrivals after T = 40
# Customer rejected at time 59.86: No new arrivals after T = 40
# Customer rejected at time 59.90: No new arrivals after T = 40
# Customer rejected at time 59.99: No new arrivals after T = 40
# Customer rejected at time 60.00: No new arrivals after T = 40
#
# Total customers served: 242
# Total waiting time: 296.97 minutes
# Total agent overtime cost: 17.25 minutes
# Total rewards: -71847.22
# Total customers rejected after T = 40: 117
# Average waiting time per customer: 1.23 minutes
#
# Transition Probabilities:
#   P((0, 0) | (0, 1)) = 0.6667
#   P((0, 0) | (1, 0)) = 0.7632
#   P((2, 1) | (0, 1)) = 0.0444
#   P((1, 1) | (2, 1)) = 0.5000
#   P((0, 1) | (1, 1)) = 0.3333
#   P((0, 1) | (0, 1)) = 0.0444
#   P((1, 0) | (0, 1)) = 0.0889
#   P((1, 1) | (0, 1)) = 0.0889
#   P((1, 1) | (1, 1)) = 0.1111
#   P((1, 0) | (1, 1)) = 0.2222
#   P((1, 0) | (1, 0)) = 0.0789
#   P((0, 0) | (2, 0)) = 0.4000
#   P((0, 0) | (1, 1)) = 0.1111
#   P((2, 2) | (1, 0)) = 0.0526
#   P((1, 2) | (2, 2)) = 0.5000
#   P((2, 2) | (1, 2)) = 0.1667
#   P((0, 2) | (1, 2)) = 0.5000
#   P((0, 1) | (0, 2)) = 0.4286
#   P((1, 0) | (2, 2)) = 0.5000
#   P((1, 3) | (0, 1)) = 0.0222
#   P((0, 3) | (1, 3)) = 1.0000
#   P((0, 2) | (0, 1)) = 0.0222
#   P((0, 0) | (0, 3)) = 0.3333
#   P((2, 0) | (2, 0)) = 0.2000
#   P((1, 0) | (2, 0)) = 0.2000
#   P((1, 2) | (1, 1)) = 0.1111
#   P((1, 2) | (1, 2)) = 0.1667
#   P((1, 2) | (0, 1)) = 0.0222
#   P((1, 1) | (0, 2)) = 0.1429
#   P((2, 1) | (0, 2)) = 0.1429
#   P((3, 3) | (2, 1)) = 0.2500
#   P((2, 4) | (1, 2)) = 0.1667
#   P((4, 4) | (2, 4)) = 0.5000
#   P((3, 5) | (4, 4)) = 0.5000
#   P((2, 5) | (3, 5)) = 1.0000
#   P((1, 5) | (3, 3)) = 1.0000
#   P((0, 5) | (2, 5)) = 1.0000
#   P((0, 4) | (0, 5)) = 0.5000
#   P((0, 4) | (0, 4)) = 0.2500
#   P((1, 4) | (0, 4)) = 0.2500
#   P((1, 4) | (1, 5)) = 1.0000
#   P((0, 3) | (1, 4)) = 1.0000
#   P((0, 2) | (0, 3)) = 0.3333
#   P((1, 1) | (0, 4)) = 0.2500
#   P((0, 2) | (1, 1)) = 0.1111
#   P((1, 0) | (0, 2)) = 0.1429
#   P((3, 1) | (1, 0)) = 0.0263
#   P((3, 1) | (3, 1)) = 0.5000
#   P((2, 1) | (3, 1)) = 0.5000
#   P((0, 1) | (2, 1)) = 0.2500
#   P((0, 1) | (1, 0)) = 0.0263
#   P((2, 0) | (1, 0)) = 0.0263
#   P((4, 1) | (2, 0)) = 0.2000
#   P((5, 2) | (4, 1)) = 1.0000
#   P((5, 2) | (5, 2)) = 0.3333
#   P((5, 2) | (1, 0)) = 0.0263
#   P((4, 3) | (5, 2)) = 0.3333
#   P((3, 4) | (5, 2)) = 0.3333
#   P((2, 4) | (3, 4)) = 1.0000
#   P((4, 6) | (2, 4)) = 0.5000
#   P((3, 7) | (4, 4)) = 0.5000
#   P((2, 7) | (4, 6)) = 1.0000
#   P((3, 7) | (2, 7)) = 0.5000
#   P((2, 7) | (3, 7)) = 0.5000
#   P((1, 8) | (3, 7)) = 0.5000
#   P((0, 9) | (2, 7)) = 0.5000
#   P((3, 8) | (1, 8)) = 0.5000
#   P((2, 8) | (0, 9)) = 0.5000
#   P((1, 8) | (2, 8)) = 1.0000
#   P((4, 9) | (3, 8)) = 1.0000
#   P((3, 9) | (1, 8)) = 0.5000
#   P((2, 9) | (4, 9)) = 1.0000
#   P((1, 11) | (3, 9)) = 1.0000
#   P((2, 11) | (1, 11)) = 0.3333
#   P((1, 11) | (2, 11)) = 1.0000
#   P((1, 11) | (2, 9)) = 0.5000
#   P((1, 12) | (1, 11)) = 0.3333
#   P((0, 12) | (1, 12)) = 0.3333
#   P((4, 11) | (1, 11)) = 0.3333
#   P((3, 12) | (0, 12)) = 0.3333
#   P((4, 15) | (4, 11)) = 1.0000
#   P((5, 15) | (4, 15)) = 0.2500
#   P((4, 15) | (3, 12)) = 0.5000
#   P((4, 15) | (5, 15)) = 1.0000
#   P((4, 15) | (4, 15)) = 0.2500
#   P((3, 16) | (4, 15)) = 0.2500
#   P((2, 16) | (3, 16)) = 0.5000
#   P((1, 16) | (2, 16)) = 1.0000
#   P((1, 16) | (1, 16)) = 0.3333
#   P((0, 16) | (1, 16)) = 0.6667
#   P((0, 15) | (0, 16)) = 0.3333
#   P((0, 14) | (4, 15)) = 0.2500
#   P((1, 14) | (0, 14)) = 0.2857
#   P((0, 14) | (0, 15)) = 0.3333
#   P((0, 13) | (0, 14)) = 0.2857
#   P((3, 12) | (1, 14)) = 0.2000
#   P((2, 13) | (3, 12)) = 0.5000
#   P((1, 13) | (0, 13)) = 0.1667
#   P((1, 14) | (1, 13)) = 0.2857
#   P((3, 16) | (2, 13)) = 0.2000
#   P((2, 17) | (1, 14)) = 0.2000
#   P((1, 17) | (2, 17)) = 1.0000
#   P((0, 19) | (1, 17)) = 0.5000
#   P((0, 19) | (3, 16)) = 0.5000
#   P((1, 19) | (0, 19)) = 0.3333
#   P((0, 19) | (1, 19)) = 1.0000
#   P((0, 18) | (0, 19)) = 0.3333
#   P((1, 17) | (0, 18)) = 1.0000
#   P((0, 17) | (0, 19)) = 0.3333
#   P((0, 16) | (0, 17)) = 1.0000
#   P((2, 16) | (1, 17)) = 0.5000
#   P((1, 15) | (0, 16)) = 0.3333
#   P((0, 15) | (1, 15)) = 1.0000
#   P((0, 14) | (0, 16)) = 0.3333
#   P((0, 14) | (0, 14)) = 0.1429
#   P((2, 13) | (0, 15)) = 0.3333
#   P((1, 13) | (2, 13)) = 0.8000
#   P((1, 13) | (1, 13)) = 0.2857
#   P((1, 14) | (1, 14)) = 0.2000
#   P((0, 14) | (1, 14)) = 0.2000
#   P((0, 13) | (1, 14)) = 0.2000
#   P((0, 13) | (0, 13)) = 0.1667
#   P((1, 12) | (0, 13)) = 0.3333
#   P((2, 14) | (0, 13)) = 0.1667
#   P((3, 14) | (1, 12)) = 0.3333
#   P((2, 15) | (3, 14)) = 1.0000
#   P((1, 15) | (2, 15)) = 1.0000
#   P((0, 15) | (2, 14)) = 1.0000
#   P((0, 13) | (0, 15)) = 0.3333
#   P((0, 12) | (0, 14)) = 0.1429
#   P((0, 11) | (1, 12)) = 0.3333
#   P((1, 10) | (0, 12)) = 0.3333
#   P((0, 10) | (1, 10)) = 1.0000
#   P((2, 9) | (0, 11)) = 0.5000
#   P((3, 10) | (0, 10)) = 0.5000
#   P((2, 10) | (3, 10)) = 1.0000
#   P((2, 13) | (2, 10)) = 1.0000
#   P((0, 14) | (2, 9)) = 0.5000
#   P((2, 13) | (0, 14)) = 0.1429
#   P((2, 13) | (1, 13)) = 0.1429
#   P((0, 13) | (1, 13)) = 0.1429
#   P((0, 12) | (0, 13)) = 0.1667
#   P((0, 11) | (1, 13)) = 0.1429
#   P((0, 11) | (0, 12)) = 0.3333
#   P((0, 9) | (0, 10)) = 0.5000
#   P((0, 8) | (0, 9)) = 0.5000
#   P((0, 7) | (0, 8)) = 1.0000
#   P((0, 6) | (0, 7)) = 1.0000
#   P((0, 5) | (0, 6)) = 1.0000
#   P((0, 4) | (0, 11)) = 0.5000
#   P((0, 3) | (0, 4)) = 0.2500
#   P((0, 2) | (0, 5)) = 0.5000
#   P((0, 1) | (0, 3)) = 0.3333
#   P((0, 0) | (0, 2)) = 0.1429
#                       Metric  With Longest Waiting  Without Longest Waiting  Difference (Without - With)
# Total Waiting Time (minutes)            130.571260               296.968630                   166.397369
#    Total Agent Overtime Cost              3.112304                17.252343                    14.140039
#       Total Customers Served            210.000000               242.000000                    32.000000
#                Total Rewards          -8984.683564            -71847.220972                -62862.537408
#     Total Customers Rejected            110.000000               117.000000                     7.000000

# %%
# import numpy as np
# import simpy
# import pandas as pd

# # Define parameters
# lambda_1 = 2  # Arrival rate for primary questions (customers per minute)
# lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
# mu_1 = 3      # Service rate for less experienced agent (customers per minute)
# mu_2 = 4      # Service rate for more experienced agent (customers per minute)
# M = 6         # Maximum number of calls in the system
# T = 40        # Simulation time threshold for accepting new customers
# simulation_end_time = 60  # Total simulation time
# dt = 0.1

# overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)

# # Precomputing the value function V using DPL
# V = np.full((int(T/dt) + 1, M + 1, M + 1, 2), np.inf)
# V[:, 0, 0, :] = 0  # Initial condition: no waiting cost when there are no customers

# for t in range(1, int(T/dt) + 1):
#     for q1 in range(M + 1):
#         for q2 in range(M + 1):
#             if q1 + q2 > M:
#                 continue
#             cost_rep1 = (q1 + 1) / mu_1 + q2 / mu_2 if q1 + 1 <= M else np.inf  # Expected cost if assigned to rep 1
#             cost_rep2 = q1 / mu_1 + (q2 + 1) / mu_2 if q2 + 1 <= M else np.inf  # Expected cost if assigned to rep 2
#             V[t, q1, q2, 0] = min(cost_rep1, cost_rep2)

# class CallCenter:
#     def __init__(self, env, dt, V, use_longest_waiting=True):
#         self.env = env
#         self.V = V
#         self.dt = dt
#         self.use_longest_waiting = use_longest_waiting
#         self.queue_1 = simpy.Store(env)  # Queue for primary questions
#         self.queue_2 = simpy.Store(env)  # Queue for complex questions
#         self.agent_1 = simpy.Resource(env, capacity=1)
#         self.agent_2 = simpy.Resource(env, capacity=1)
#         self.total_waiting_time = 0
#         self.total_agent_overtime_cost = 0  # Track only agent overtime costs
#         self.total_rewards = 0  # Track total rewards
#         self.customers_served = 0
#         self.customers_rejected = 0  # Track customers rejected after T = 40
#         self.transition_counts = {}  # Track state transitions
#         self.state_counts = {}  # Count visits to states
#         self.value_function, self.policy = self.value_iteration()

#     def record_transition(self, current_state, next_state):
#         """Records state transitions for computing probabilities."""
#         self.transition_counts[(current_state, next_state)] = (
#             self.transition_counts.get((current_state, next_state), 0) + 1
#         )
#         self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

#     def calculate_transition_probabilities(self):
#         """Calculates transition probabilities from recorded transitions."""
#         probabilities = {}
#         for (current_state, next_state), count in self.transition_counts.items():
#             total_transitions_from_state = self.state_counts[current_state]
#             probabilities[(current_state, next_state)] = count / total_transitions_from_state
#         return probabilities

#     def value_iteration(env, gamma=0.9, iterations=100):
#       V = {}
#       policy = {}

#       # Initialize value function for all states
#       for q1 in range(M + 1):
#           for q2 in range(M + 1):
#               V[(q1, q2)] = 0  # Initial value for all states

#       for i in range(iterations):
#           new_V = V.copy()
#           for q1 in range(M + 1):
#               for q2 in range(M + 1):
#                   if q1 + q2 > M:  # Invalid state
#                       continue

#                   # Possible actions: assign to Agent 1 or Agent 2
#                   actions = ["Agent 1", "Agent 2"]
#                   action_values = []

#                   for action in actions:
#                       # Immediate reward
#                       immediate_cost = -(q1 / mu_1 if action == "Agent 1" else q2 / mu_2)

#                       # Future value estimation
#                       future_value = 0
#                       for next_q1 in range(M + 1):
#                           for next_q2 in range(M + 1):
#                               if next_q1 + next_q2 > M:  # Invalid state
#                                   continue
#                               # Transition probability (placeholder: uniform probability)
#                               P = 1 / ((M + 1) * (M + 1))  # Example; calculate based on transitions
#                               future_value += P * V[(next_q1, next_q2)]

#                       action_value = immediate_cost + gamma * future_value
#                       action_values.append(action_value)

#                   # Update value function and policy
#                   new_V[(q1, q2)] = max(action_values)
#                   policy[(q1, q2)] = actions[np.argmax(action_values)]

#           V = new_V  # Update V for next iteration

#       return V, policy

#     def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
#         with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
#             yield request
#             service_time = np.random.exponential(1 / service_rate)
#             end_time = self.env.now + service_time  # Calculate when the service will end

#             # Simulate the service time
#             yield self.env.timeout(service_time)

#             wait_time = self.env.now - arrival_time  # Calculate wait time
#             self.total_waiting_time += wait_time

#             # Initialize agent_overtime_cost to zero
#             agent_overtime_cost = 0

#             # Check for overtime due to working beyond T
#             if end_time > T:
#                 overtime_hours = end_time - T
#                 agent_overtime_cost = overtime_hours * overtime_cost_rate
#                 self.total_agent_overtime_cost += agent_overtime_cost

#             # Update rewards
#             reward = -(wait_time + agent_overtime_cost)  # Negative rewards for wait time and overtime
#             self.total_rewards += reward

#             self.customers_served += 1

#             next_state = (len(self.queue_1.items), len(self.queue_2.items))

#             # Record the state transition
#             self.record_transition(state, next_state)

#             # Log details
#             print(
#                 f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
#                 f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
#                 f"(Overtime cost: {agent_overtime_cost:.2f}, Reward: {reward:.2f})"
#             )
#             print(f"    Transition: State {state} -> State {next_state}")

#     def assign_customer(self):
#         while True:
#             if self.agent_1.count == 0 or self.agent_2.count == 0:
#                 state = (len(self.queue_1.items), len(self.queue_2.items))

#                 # Select action based on policy
#                 chosen_agent = self.policy.get(state, "Agent 1")
#                 queue = self.queue_1 if chosen_agent == "Agent 1" else self.queue_2

#                 if len(queue.items) > 0:
#                     customer_type, arrival_time = queue.items[0]
#                     yield queue.get()

#                     service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2
#                     self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

#             queue_penalty = -(len(self.queue_1.items) + len(self.queue_2.items))  # Negative reward for queue lengths
#             self.total_rewards += queue_penalty

#             yield self.env.timeout(self.dt)

#     # def assign_customer(self):
#     #     while True:
#     #         if self.agent_1.count == 0 or self.agent_2.count == 0:
#     #             queue, customer_type, arrival_time = self.select_customer()

#     #             if queue is not None:
#     #                 state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state
#     #                 yield queue.get()

#     #                 chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"
#     #                 service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

#     #                 # Start handling the customer
#     #                 self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

#     #         # Update rewards based on current queue lengths
#     #         queue_penalty = -(len(self.queue_1.items) + len(self.queue_2.items))  # Negative reward for queue lengths
#     #         self.total_rewards += queue_penalty

#     #         yield self.env.timeout(dt)  # Allow other processes to run

#     def select_customer(self):
#         """Selects the customer based on the queue and waiting strategy."""
#         if self.use_longest_waiting:
#             return self.select_longest_waiting_customer()
#         return self.select_first_come_first_served_customer()

#     def select_longest_waiting_customer(self):
#         """Select the longest waiting customer from the queues."""
#         if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
#             customer_1, arrival_time_1 = self.queue_1.items[0]
#             customer_2, arrival_time_2 = self.queue_2.items[0]
#             if arrival_time_1 <= arrival_time_2:
#                 return self.queue_1, customer_1, arrival_time_1
#             else:
#                 return self.queue_2, customer_2, arrival_time_2
#         elif len(self.queue_1.items) > 0:
#             customer_1, arrival_time_1 = self.queue_1.items[0]
#             return self.queue_1, customer_1, arrival_time_1
#         elif len(self.queue_2.items) > 0:
#             customer_2, arrival_time_2 = self.queue_2.items[0]
#             return self.queue_2, customer_2, arrival_time_2
#         else:
#             return None, None, None

#     def select_first_come_first_served_customer(self):
#         """Select the first customer from queue 1 or queue 2."""
#         if len(self.queue_1.items) > 0:
#             return self.queue_1, *self.queue_1.items[0]
#         elif len(self.queue_2.items) > 0:
#             return self.queue_2, *self.queue_2.items[0]
#         return None, None, None



#     def customer_arrival(self, customer_type, arrival_rate):
#         while True:
#             inter_arrival_time = np.random.exponential(1 / arrival_rate)
#             yield self.env.timeout(inter_arrival_time)
#             arrival_time = self.env.now

#             if arrival_time > T:
#                 self.customers_rejected += 1
#                 print(f"Customer rejected at time {arrival_time:.2f}: No new arrivals after T = {T}")
#                 continue

#             if customer_type == 1:
#                 self.queue_1.put((customer_type, arrival_time))
#             else:
#                 self.queue_2.put((customer_type, arrival_time))

#             self.env.process(self.assign_customer())


# def run_simulation(simulation_time, use_longest_waiting=True):
#     env = simpy.Environment()
#     call_center = CallCenter(env, dt, V, use_longest_waiting)

#     env.process(call_center.customer_arrival(1, lambda_1))
#     env.process(call_center.customer_arrival(2, lambda_2))

#     env.run(until=simulation_time)

#     print(f"\nTotal customers served: {call_center.customers_served}")
#     print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
#     print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
#     print(f"Total rewards: {call_center.total_rewards:.2f}")
#     print(f"Total customers rejected after T = {T}: {call_center.customers_rejected}")
#     print(f"Average waiting time per customer: "
#           f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

#     # Calculate and display transition probabilities
#     probabilities = call_center.calculate_transition_probabilities()
#     print("\nTransition Probabilities:")
#     for (initial_state, final_state), prob in probabilities.items():
#         print(f"  P({final_state} | {initial_state}) = {prob:.4f}")

#     return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, call_center.total_rewards, call_center.customers_rejected, probabilities


# # Run the simulations
# simulation_time = simulation_end_time

# # With longest waiting customer function
# waiting_time_longest, agent_overtime_longest, served_longest, rewards_longest, rejected_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# # Without longest waiting customer function
# waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, rewards_fcfs, rejected_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)


# # Prepare the results for the table
# results_data = {
#     "Metric": [
#         "Total Waiting Time (minutes)",
#         "Total Agent Overtime Cost",
#         "Total Customers Served",
#         "Total Rewards",
#         "Total Customers Rejected"
#     ],
#     "With Longest Waiting": [
#         waiting_time_longest,
#         agent_overtime_longest,
#         served_longest,
#         rewards_longest,
#         rejected_longest
#     ],
#     "Without Longest Waiting": [
#         waiting_time_fcfs,
#         agent_overtime_fcfs,
#         served_fcfs,
#         rewards_fcfs,
#         rejected_fcfs
#     ],
#     "Difference (Without - With)": [
#         waiting_time_fcfs - waiting_time_longest,
#         agent_overtime_fcfs - agent_overtime_longest,
#         served_fcfs - served_longest,
#         rewards_fcfs - rewards_longest,
#         rejected_fcfs - rejected_longest
#     ]
# }

# # Create the DataFrame
# results_df = pd.DataFrame(results_data)

# # Display the results as a table
# print(results_df.to_string(index=False))

# %%
# import numpy as np
# import simpy
# import pandas as pd

# # Define parameters
# lambda_1 = 4  # Arrival rate for primary questions (customers per minute)
# lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
# mu_1 = 3      # Service rate for less experienced agent (customers per minute)
# mu_2 = 4      # Service rate for more experienced agent (customers per minute)
# M = 20         # Maximum number of calls in the system
# T = 40        # Simulation time threshold for accepting new customers
# simulation_end_time = 60  # Total simulation time
# dt = 0.6

# overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)


# class CallCenter:
#     def __init__(self, env, dt, use_longest_waiting=True):
#         self.env = env
#         self.dt = dt
#         self.use_longest_waiting = use_longest_waiting
#         self.queue_1 = simpy.Store(env)  # Queue for primary questions
#         self.queue_2 = simpy.Store(env)  # Queue for complex questions
#         self.agent_1 = simpy.Resource(env, capacity=1)
#         self.agent_2 = simpy.Resource(env, capacity=1)
#         self.total_waiting_time = 0
#         self.total_agent_overtime_cost = 0
#         self.total_rewards = 0
#         self.customers_served = 0
#         self.customers_rejected = 0
#         self.transition_counts = {}
#         self.state_counts = {}
#         self.value_function = {}  # Stores the value function
#         self.policy = {}  # Stores the optimal policy for each state

#     def record_transition(self, current_state, next_state):
#         """Records state transitions for computing probabilities."""
#         self.transition_counts[(current_state, next_state)] = (
#             self.transition_counts.get((current_state, next_state), 0) + 1
#         )
#         self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

#     def calculate_transition_probabilities(self):
#         """Calculates transition probabilities from recorded transitions."""
#         probabilities = {}
#         for (current_state, next_state), count in self.transition_counts.items():
#             total_transitions_from_state = self.state_counts[current_state]
#             probabilities[(current_state, next_state)] = count / total_transitions_from_state
#         return probabilities

#     def value_iteration(self, gamma=0.9, iterations=100):
#         """Performs value iteration to compute the value function and optimal policy."""
#         states = [(q1, q2) for q1 in range(M + 1) for q2 in range(M + 1)]
#         self.value_function = {state: 0 for state in states}
#         self.policy = {state: None for state in states}

#         for _ in range(iterations):
#             new_value_function = {}
#             for state in states:
#                 q1, q2 = state
#                 values = []

#                 # Action: Assign to Agent 1
#                 if q1 > 0:
#                     reward = -1  # Example reward: negative wait penalty
#                     next_state = (max(q1 - 1, 0), q2)
#                     value = reward + gamma * self.value_function[next_state]
#                     values.append((value, "Agent 1"))

#                 # Action: Assign to Agent 2
#                 if q2 > 0:
#                     reward = -1  # Example reward: negative wait penalty
#                     next_state = (q1, max(q2 - 1, 0))
#                     value = reward + gamma * self.value_function[next_state]
#                     values.append((value, "Agent 2"))

#                 # Take the best action
#                 if values:
#                     new_value_function[state], self.policy[state] = max(values)
#                 else:
#                     new_value_function[state] = 0  # No actions available

#             self.value_function = new_value_function

#     def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
#         with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
#             yield request
#             service_time = np.random.exponential(1 / service_rate)
#             end_time = self.env.now + service_time  # Calculate when the service will end

#             # Simulate the service time
#             yield self.env.timeout(service_time)

#             wait_time = self.env.now - arrival_time  # Calculate wait time
#             self.total_waiting_time += wait_time

#             # Initialize agent_overtime_cost to zero
#             agent_overtime_cost = 0

#             # Check for overtime due to working beyond T
#             if end_time > T:
#                 overtime_hours = end_time - T
#                 agent_overtime_cost = overtime_hours * overtime_cost_rate
#                 self.total_agent_overtime_cost += agent_overtime_cost

#             # Update rewards
#             reward = -(wait_time + agent_overtime_cost)  # Negative rewards for wait time and overtime
#             self.total_rewards += reward

#             self.customers_served += 1

#             next_state = (len(self.queue_1.items), len(self.queue_2.items))

#             # Record the state transition
#             self.record_transition(state, next_state)

#             # Log details
#             print(
#                 f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
#                 f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
#                 f"(Overtime cost: {agent_overtime_cost:.2f}, Reward: {reward:.2f})"
#             )
#             print(f"    Transition: State {state} -> State {next_state}")

#     def assign_customer(self):
#       while True:
#           if self.agent_1.count == 0 or self.agent_2.count == 0:
#               queue, customer_type, arrival_time = self.select_customer()

#               if queue is not None:
#                   state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state

#                   # Validate the state
#                   if len(self.queue_1.items) + len(self.queue_2.items) > M:
#                       print(f"Invalid state encountered: {state}. Skipping.")
#                       continue

#                   yield queue.get()

#                   # Use the policy to select the agent, with a fallback for missing states
#                   if state in self.policy:
#                       chosen_agent = self.policy[state]
#                   else:
#                       print(f"Warning: State {state} not found in policy. Using default fallback.")
#                       chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"

#                   service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

#                   # Start handling the customer
#                   self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

#           # Update rewards based on current queue lengths
#           queue_penalty = -(len(self.queue_1.items) + len(self.queue_2.items))  # Negative reward for queue lengths
#           self.total_rewards += queue_penalty

#           yield self.env.timeout(dt)  # Allow other processes to run

#     def select_customer(self):
#         """Selects the customer based on the queue and waiting strategy."""
#         if self.use_longest_waiting:
#             return self.select_longest_waiting_customer()
#         return self.select_first_come_first_served_customer()

#     def select_longest_waiting_customer(self):
#         """Select the longest waiting customer from the queues."""
#         if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
#             customer_1, arrival_time_1 = self.queue_1.items[0]
#             customer_2, arrival_time_2 = self.queue_2.items[0]
#             if arrival_time_1 <= arrival_time_2:
#                 return self.queue_1, customer_1, arrival_time_1
#             else:
#                 return self.queue_2, customer_2, arrival_time_2
#         elif len(self.queue_1.items) > 0:
#             customer_1, arrival_time_1 = self.queue_1.items[0]
#             return self.queue_1, customer_1, arrival_time_1
#         elif len(self.queue_2.items) > 0:
#             customer_2, arrival_time_2 = self.queue_2.items[0]
#             return self.queue_2, customer_2, arrival_time_2
#         else:
#             return None, None, None

#     def select_first_come_first_served_customer(self):
#         """Select the first customer from queue 1 or queue 2."""
#         if len(self.queue_1.items) > 0:
#             return self.queue_1, *self.queue_1.items[0]
#         elif len(self.queue_2.items) > 0:
#             return self.queue_2, *self.queue_2.items[0]
#         return None, None, None

#     def customer_arrival(self, customer_type, arrival_rate):
#         while True:
#             inter_arrival_time = np.random.exponential(1 / arrival_rate)
#             yield self.env.timeout(inter_arrival_time)
#             arrival_time = self.env.now

#             if arrival_time > T:
#                 self.customers_rejected += 1
#                 print(f"Customer rejected at time {arrival_time:.2f}: No new arrivals after T = {T}")
#                 continue

#             if customer_type == 1:
#                 self.queue_1.put((customer_type, arrival_time))
#             else:
#                 self.queue_2.put((customer_type, arrival_time))

#             self.env.process(self.assign_customer())


# def run_simulation(simulation_time, use_longest_waiting=True):
#     env = simpy.Environment()
#     call_center = CallCenter(env, dt, use_longest_waiting)

#     # Perform value iteration before running the simulation
#     call_center.value_iteration(gamma=0.9, iterations=100)

#     env.process(call_center.customer_arrival(1, lambda_1))
#     env.process(call_center.customer_arrival(2, lambda_2))

#     env.run(until=simulation_time)

#     print(f"\nTotal customers served: {call_center.customers_served}")
#     print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
#     print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
#     print(f"Total rewards: {call_center.total_rewards:.2f}")
#     print(f"Total customers rejected after T = {T}: {call_center.customers_rejected}")
#     print(f"Average waiting time per customer: "
#           f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

#     # Calculate and display transition probabilities
#     probabilities = call_center.calculate_transition_probabilities()
#     print("\nTransition Probabilities:")
#     for (initial_state, final_state), prob in probabilities.items():
#         print(f"  P({final_state} | {initial_state}) = {prob:.4f}")


#     print("\nValue Function:")
#     for state, value in call_center.value_function.items():
#         print(f"State {state}: Value = {value:.2f}")

#     print("\nOptimal Policy:")
#     for state, action in call_center.policy.items():
#         print(f"State {state}: Action = {action}")

#     return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, call_center.total_rewards, call_center.customers_rejected, call_center.policy


# # Run the simulations
# simulation_time = simulation_end_time

# # With longest waiting customer function
# waiting_time_longest, agent_overtime_longest, served_longest, rewards_longest, rejected_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# # Without longest waiting customer function
# waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, rewards_fcfs, rejected_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)


# # Prepare the results for the table
# results_data = {
#     "Metric": [
#         "Total Waiting Time (minutes)",
#         "Total Agent Overtime Cost",
#         "Total Customers Served",
#         "Total Rewards",
#         "Total Customers Rejected"
#     ],
#     "With Longest Waiting": [
#         waiting_time_longest,
#         agent_overtime_longest,
#         served_longest,
#         rewards_longest,
#         rejected_longest
#     ],
#     "Without Longest Waiting": [
#         waiting_time_fcfs,
#         agent_overtime_fcfs,
#         served_fcfs,
#         rewards_fcfs,
#         rejected_fcfs
#     ],
#     "Difference (Without - With)": [
#         waiting_time_fcfs - waiting_time_longest,
#         agent_overtime_fcfs - agent_overtime_longest,
#         served_fcfs - served_longest,
#         rewards_fcfs - rewards_longest,
#         rejected_fcfs - rejected_longest
#     ]
# }

# # Create the DataFrame
# results_df = pd.DataFrame(results_data)

# # Display the results as a table
# print(results_df.to_string(index=False))
# Out:
# At time 0.08: Customer type 2 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00, Reward: -0.02)
#     Transition: State (0, 1) -> State (1, 0)
# At time 0.38: Customer type 1 served by Agent 2 in 0.24 minutes, waited 0.24 minutes (Overtime cost: 0.00, Reward: -0.24)
#     Transition: State (1, 1) -> State (3, 2)
# At time 0.68: Customer type 2 served by Agent 2 in 0.08 minutes, waited 0.54 minutes (Overtime cost: 0.00, Reward: -0.54)
#     Transition: State (3, 2) -> State (4, 1)
# At time 0.70: Customer type 1 served by Agent 1 in 0.70 minutes, waited 0.70 minutes (Overtime cost: 0.00, Reward: -0.70)
#     Transition: State (1, 0) -> State (4, 1)
# At time 0.84: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (4, 1) -> State (5, 1)
# At time 1.04: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.74 minutes (Overtime cost: 0.00, Reward: -0.74)
#     Transition: State (5, 1) -> State (6, 1)
# At time 1.07: Customer type 1 served by Agent 1 in 0.36 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (1, 0) -> State (6, 1)
# At time 1.22: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.89 minutes (Overtime cost: 0.00, Reward: -0.89)
#     Transition: State (7, 1) -> State (6, 1)
# At time 1.30: Customer type 1 served by Agent 1 in 0.24 minutes, waited 1.23 minutes (Overtime cost: 0.00, Reward: -1.23)
#     Transition: State (2, 0) -> State (7, 1)
# At time 1.88: Customer type 2 served by Agent 2 in 0.66 minutes, waited 1.50 minutes (Overtime cost: 0.00, Reward: -1.50)
#     Transition: State (6, 1) -> State (0, 0)
# At time 2.06: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.11: Customer type 1 served by Agent 2 in 0.22 minutes, waited 1.45 minutes (Overtime cost: 0.00, Reward: -1.45)
#     Transition: State (7, 1) -> State (0, 0)
# At time 2.19: Customer type 1 served by Agent 2 in 0.08 minutes, waited 1.44 minutes (Overtime cost: 0.00, Reward: -1.44)
#     Transition: State (6, 1) -> State (0, 0)
# At time 2.27: Customer type 1 served by Agent 2 in 0.09 minutes, waited 1.50 minutes (Overtime cost: 0.00, Reward: -1.50)
#     Transition: State (5, 1) -> State (0, 0)
# At time 2.37: Customer type 1 served by Agent 2 in 0.09 minutes, waited 1.47 minutes (Overtime cost: 0.00, Reward: -1.47)
#     Transition: State (4, 2) -> State (0, 0)
# At time 2.45: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00, Reward: -0.04)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.65: Customer type 1 served by Agent 2 in 0.28 minutes, waited 1.71 minutes (Overtime cost: 0.00, Reward: -1.71)
#     Transition: State (3, 2) -> State (0, 0)
# At time 2.67: Customer type 1 served by Agent 2 in 0.02 minutes, waited 1.46 minutes (Overtime cost: 0.00, Reward: -1.46)
#     Transition: State (2, 2) -> State (0, 0)
# At time 2.98: Customer type 2 served by Agent 2 in 0.32 minutes, waited 1.75 minutes (Overtime cost: 0.00, Reward: -1.75)
#     Transition: State (1, 2) -> State (3, 0)
# At time 3.38: Customer type 1 served by Agent 2 in 0.40 minutes, waited 2.10 minutes (Overtime cost: 0.00, Reward: -2.10)
#     Transition: State (1, 1) -> State (5, 0)
# At time 3.41: Customer type 2 served by Agent 2 in 0.03 minutes, waited 2.03 minutes (Overtime cost: 0.00, Reward: -2.03)
#     Transition: State (0, 1) -> State (5, 0)
# At time 3.54: Customer type 2 served by Agent 2 in 0.13 minutes, waited 2.00 minutes (Overtime cost: 0.00, Reward: -2.00)
#     Transition: State (0, 1) -> State (5, 1)
# At time 3.73: Customer type 1 served by Agent 1 in 0.93 minutes, waited 0.93 minutes (Overtime cost: 0.00, Reward: -0.93)
#     Transition: State (1, 0) -> State (6, 1)
# At time 3.85: Customer type 2 served by Agent 2 in 0.31 minutes, waited 1.10 minutes (Overtime cost: 0.00, Reward: -1.10)
#     Transition: State (0, 1) -> State (1, 0)
# At time 4.65: Customer type 2 served by Agent 2 in 0.79 minutes, waited 1.88 minutes (Overtime cost: 0.00, Reward: -1.88)
#     Transition: State (0, 1) -> State (2, 3)
# At time 4.69: Customer type 2 served by Agent 2 in 0.05 minutes, waited 1.93 minutes (Overtime cost: 0.00, Reward: -1.93)
#     Transition: State (0, 1) -> State (2, 3)
# At time 4.70: Customer type 1 served by Agent 1 in 0.87 minutes, waited 1.10 minutes (Overtime cost: 0.00, Reward: -1.10)
#     Transition: State (2, 0) -> State (2, 3)
# At time 4.88: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 5.02: Customer type 1 served by Agent 2 in 0.32 minutes, waited 2.20 minutes (Overtime cost: 0.00, Reward: -2.20)
#     Transition: State (6, 1) -> State (0, 0)
# At time 5.57: Customer type 1 served by Agent 2 in 0.55 minutes, waited 2.68 minutes (Overtime cost: 0.00, Reward: -2.68)
#     Transition: State (5, 1) -> State (3, 2)
# At time 5.73: Customer type 1 served by Agent 2 in 0.16 minutes, waited 2.83 minutes (Overtime cost: 0.00, Reward: -2.83)
#     Transition: State (4, 1) -> State (3, 2)
# At time 5.99: Customer type 1 served by Agent 2 in 0.26 minutes, waited 3.00 minutes (Overtime cost: 0.00, Reward: -3.00)
#     Transition: State (3, 1) -> State (3, 3)
# At time 6.04: Customer type 1 served by Agent 2 in 0.05 minutes, waited 2.72 minutes (Overtime cost: 0.00, Reward: -2.72)
#     Transition: State (2, 1) -> State (3, 3)
# At time 6.31: Customer type 1 served by Agent 1 in 1.04 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (1, 0) -> State (5, 3)
# At time 6.37: Customer type 2 served by Agent 2 in 0.33 minutes, waited 2.92 minutes (Overtime cost: 0.00, Reward: -2.92)
#     Transition: State (1, 1) -> State (1, 0)
# At time 6.78: Customer type 1 served by Agent 2 in 0.41 minutes, waited 2.95 minutes (Overtime cost: 0.00, Reward: -2.95)
#     Transition: State (2, 3) -> State (3, 0)
# At time 7.12: Customer type 1 served by Agent 2 in 0.35 minutes, waited 3.22 minutes (Overtime cost: 0.00, Reward: -3.22)
#     Transition: State (1, 4) -> State (4, 1)
# At time 7.19: Customer type 1 served by Agent 1 in 0.83 minutes, waited 0.95 minutes (Overtime cost: 0.00, Reward: -0.95)
#     Transition: State (2, 0) -> State (4, 1)
# At time 7.34: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 0.00, Reward: -0.07)
#     Transition: State (1, 0) -> State (1, 0)
# At time 7.37: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.07 minutes (Overtime cost: 0.00, Reward: -0.07)
#     Transition: State (1, 0) -> State (0, 0)
# At time 7.69: Customer type 2 served by Agent 2 in 0.57 minutes, waited 3.57 minutes (Overtime cost: 0.00, Reward: -3.57)
#     Transition: State (0, 4) -> State (1, 1)
# At time 7.97: Customer type 2 served by Agent 2 in 0.28 minutes, waited 3.58 minutes (Overtime cost: 0.00, Reward: -3.58)
#     Transition: State (1, 3) -> State (1, 1)
# At time 8.12: Customer type 1 served by Agent 1 in 0.54 minutes, waited 0.54 minutes (Overtime cost: 0.00, Reward: -0.54)
#     Transition: State (1, 0) -> State (2, 1)
# At time 8.25: Customer type 2 served by Agent 2 in 0.27 minutes, waited 3.72 minutes (Overtime cost: 0.00, Reward: -3.72)
#     Transition: State (1, 2) -> State (0, 0)
# At time 8.25: Customer type 1 served by Agent 1 in 0.12 minutes, waited 0.20 minutes (Overtime cost: 0.00, Reward: -0.20)
#     Transition: State (1, 0) -> State (0, 0)
# At time 8.62: Customer type 2 served by Agent 2 in 0.38 minutes, waited 3.90 minutes (Overtime cost: 0.00, Reward: -3.90)
#     Transition: State (1, 1) -> State (0, 0)
# At time 8.81: Customer type 1 served by Agent 2 in 0.19 minutes, waited 3.50 minutes (Overtime cost: 0.00, Reward: -3.50)
#     Transition: State (5, 3) -> State (0, 0)
# At time 9.04: Customer type 1 served by Agent 2 in 0.23 minutes, waited 3.65 minutes (Overtime cost: 0.00, Reward: -3.65)
#     Transition: State (4, 3) -> State (0, 0)
# At time 9.29: Customer type 1 served by Agent 2 in 0.25 minutes, waited 3.89 minutes (Overtime cost: 0.00, Reward: -3.89)
#     Transition: State (3, 3) -> State (1, 1)
# At time 9.32: Customer type 2 served by Agent 2 in 0.03 minutes, waited 3.89 minutes (Overtime cost: 0.00, Reward: -3.89)
#     Transition: State (2, 3) -> State (1, 1)
# At time 9.62: Customer type 2 served by Agent 2 in 0.30 minutes, waited 4.11 minutes (Overtime cost: 0.00, Reward: -4.11)
#     Transition: State (2, 2) -> State (5, 3)
# At time 9.85: Customer type 1 served by Agent 1 in 0.84 minutes, waited 0.84 minutes (Overtime cost: 0.00, Reward: -0.84)
#     Transition: State (1, 0) -> State (7, 4)
# At time 10.18: Customer type 2 served by Agent 2 in 0.56 minutes, waited 4.35 minutes (Overtime cost: 0.00, Reward: -4.35)
#     Transition: State (2, 1) -> State (0, 0)
# At time 10.24: Customer type 1 served by Agent 2 in 0.06 minutes, waited 3.94 minutes (Overtime cost: 0.00, Reward: -3.94)
#     Transition: State (4, 1) -> State (0, 0)
# At time 10.30: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (1, 0) -> State (1, 0)
# At time 10.53: Customer type 1 served by Agent 2 in 0.29 minutes, waited 4.12 minutes (Overtime cost: 0.00, Reward: -4.12)
#     Transition: State (3, 1) -> State (0, 2)
# At time 10.72: Customer type 1 served by Agent 1 in 0.41 minutes, waited 0.47 minutes (Overtime cost: 0.00, Reward: -0.47)
#     Transition: State (1, 0) -> State (1, 2)
# At time 10.79: Customer type 1 served by Agent 2 in 0.26 minutes, waited 4.09 minutes (Overtime cost: 0.00, Reward: -4.09)
#     Transition: State (2, 1) -> State (2, 0)
# At time 10.85: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (2, 0) -> State (3, 1)
# At time 11.08: Customer type 1 served by Agent 2 in 0.29 minutes, waited 4.19 minutes (Overtime cost: 0.00, Reward: -4.19)
#     Transition: State (1, 1) -> State (0, 0)
# At time 11.17: Customer type 1 served by Agent 1 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00, Reward: -0.12)
#     Transition: State (1, 0) -> State (0, 0)
# At time 11.18: Customer type 2 served by Agent 2 in 0.10 minutes, waited 4.17 minutes (Overtime cost: 0.00, Reward: -4.17)
#     Transition: State (0, 1) -> State (0, 0)
# At time 11.33: Customer type 1 served by Agent 2 in 0.15 minutes, waited 3.71 minutes (Overtime cost: 0.00, Reward: -3.71)
#     Transition: State (2, 1) -> State (0, 0)
# At time 11.66: Customer type 2 served by Agent 2 in 0.33 minutes, waited 3.98 minutes (Overtime cost: 0.00, Reward: -3.98)
#     Transition: State (1, 1) -> State (1, 0)
# At time 11.73: Customer type 2 served by Agent 2 in 0.07 minutes, waited 3.44 minutes (Overtime cost: 0.00, Reward: -3.44)
#     Transition: State (0, 1) -> State (2, 0)
# At time 11.74: Customer type 2 served by Agent 2 in 0.01 minutes, waited 3.04 minutes (Overtime cost: 0.00, Reward: -3.04)
#     Transition: State (0, 1) -> State (2, 0)
# At time 11.95: Customer type 1 served by Agent 1 in 0.77 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (1, 0) -> State (3, 0)
# At time 12.01: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (3, 0) -> State (3, 0)
# At time 12.06: Customer type 1 served by Agent 2 in 0.31 minutes, waited 2.99 minutes (Overtime cost: 0.00, Reward: -2.99)
#     Transition: State (7, 4) -> State (3, 0)
# At time 12.39: Customer type 1 served by Agent 1 in 0.38 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (3, 0) -> State (4, 2)
# At time 12.58: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.20 minutes (Overtime cost: 0.00, Reward: -0.20)
#     Transition: State (1, 0) -> State (0, 2)
# At time 12.70: Customer type 2 served by Agent 2 in 0.64 minutes, waited 3.46 minutes (Overtime cost: 0.00, Reward: -3.46)
#     Transition: State (6, 4) -> State (0, 0)
# At time 12.99: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (1, 0) -> State (0, 0)
# At time 13.01: Customer type 1 served by Agent 2 in 0.31 minutes, waited 3.66 minutes (Overtime cost: 0.00, Reward: -3.66)
#     Transition: State (6, 3) -> State (0, 0)
# At time 13.03: Customer type 2 served by Agent 2 in 0.02 minutes, waited 3.63 minutes (Overtime cost: 0.00, Reward: -3.63)
#     Transition: State (5, 3) -> State (0, 0)
# At time 13.17: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00, Reward: -0.06)
#     Transition: State (1, 0) -> State (1, 0)
# At time 13.56: Customer type 2 served by Agent 2 in 0.54 minutes, waited 4.14 minutes (Overtime cost: 0.00, Reward: -4.14)
#     Transition: State (5, 2) -> State (1, 0)
# At time 13.57: Customer type 1 served by Agent 1 in 0.39 minutes, waited 0.45 minutes (Overtime cost: 0.00, Reward: -0.45)
#     Transition: State (1, 0) -> State (1, 0)
# At time 13.61: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.12 minutes (Overtime cost: 0.00, Reward: -0.12)
#     Transition: State (1, 0) -> State (1, 0)
# At time 13.90: Customer type 1 served by Agent 2 in 0.33 minutes, waited 4.40 minutes (Overtime cost: 0.00, Reward: -4.40)
#     Transition: State (5, 1) -> State (3, 0)
# At time 14.01: Customer type 1 served by Agent 2 in 0.12 minutes, waited 4.42 minutes (Overtime cost: 0.00, Reward: -4.42)
#     Transition: State (4, 1) -> State (3, 0)
# At time 14.25: Customer type 1 served by Agent 2 in 0.24 minutes, waited 4.64 minutes (Overtime cost: 0.00, Reward: -4.64)
#     Transition: State (3, 1) -> State (3, 1)
# At time 14.25: Customer type 1 served by Agent 1 in 0.64 minutes, waited 0.67 minutes (Overtime cost: 0.00, Reward: -0.67)
#     Transition: State (1, 0) -> State (3, 1)
# At time 14.52: Customer type 1 served by Agent 2 in 0.27 minutes, waited 4.81 minutes (Overtime cost: 0.00, Reward: -4.81)
#     Transition: State (2, 1) -> State (0, 0)
# At time 14.83: Customer type 1 served by Agent 1 in 0.24 minutes, waited 0.24 minutes (Overtime cost: 0.00, Reward: -0.24)
#     Transition: State (1, 0) -> State (1, 1)
# At time 14.92: Customer type 1 served by Agent 2 in 0.40 minutes, waited 5.18 minutes (Overtime cost: 0.00, Reward: -5.18)
#     Transition: State (1, 1) -> State (0, 1)
# At time 15.21: Customer type 2 served by Agent 2 in 0.30 minutes, waited 5.44 minutes (Overtime cost: 0.00, Reward: -5.44)
#     Transition: State (0, 1) -> State (2, 4)
# At time 15.26: Customer type 1 served by Agent 1 in 0.39 minutes, waited 0.61 minutes (Overtime cost: 0.00, Reward: -0.61)
#     Transition: State (1, 0) -> State (3, 4)
# At time 15.39: Customer type 2 served by Agent 2 in 0.18 minutes, waited 4.95 minutes (Overtime cost: 0.00, Reward: -4.95)
#     Transition: State (1, 2) -> State (0, 0)
# At time 15.40: Customer type 2 served by Agent 2 in 0.01 minutes, waited 4.90 minutes (Overtime cost: 0.00, Reward: -4.90)
#     Transition: State (1, 1) -> State (0, 0)
# At time 15.63: Customer type 1 served by Agent 2 in 0.23 minutes, waited 4.89 minutes (Overtime cost: 0.00, Reward: -4.89)
#     Transition: State (3, 1) -> State (0, 0)
# At time 15.73: Customer type 1 served by Agent 2 in 0.09 minutes, waited 4.95 minutes (Overtime cost: 0.00, Reward: -4.95)
#     Transition: State (2, 1) -> State (0, 0)
# At time 15.81: Customer type 1 served by Agent 1 in 0.51 minutes, waited 0.56 minutes (Overtime cost: 0.00, Reward: -0.56)
#     Transition: State (1, 0) -> State (0, 0)
# At time 15.94: Customer type 1 served by Agent 2 in 0.21 minutes, waited 5.15 minutes (Overtime cost: 0.00, Reward: -5.15)
#     Transition: State (1, 1) -> State (0, 0)
# At time 15.98: Customer type 2 served by Agent 2 in 0.04 minutes, waited 5.15 minutes (Overtime cost: 0.00, Reward: -5.15)
#     Transition: State (0, 1) -> State (0, 0)
# At time 16.24: Customer type 2 served by Agent 2 in 0.26 minutes, waited 5.28 minutes (Overtime cost: 0.00, Reward: -5.28)
#     Transition: State (0, 1) -> State (0, 0)
# At time 16.66: Customer type 1 served by Agent 1 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 0.00, Reward: -0.31)
#     Transition: State (1, 0) -> State (1, 0)
# At time 16.77: Customer type 1 served by Agent 2 in 0.53 minutes, waited 4.87 minutes (Overtime cost: 0.00, Reward: -4.87)
#     Transition: State (4, 2) -> State (0, 0)
# At time 16.94: Customer type 1 served by Agent 2 in 0.17 minutes, waited 4.97 minutes (Overtime cost: 0.00, Reward: -4.97)
#     Transition: State (3, 2) -> State (0, 0)
# At time 17.33: Customer type 1 served by Agent 1 in 0.39 minutes, waited 0.39 minutes (Overtime cost: 0.00, Reward: -0.39)
#     Transition: State (1, 0) -> State (1, 0)
# At time 17.43: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.38 minutes (Overtime cost: 0.00, Reward: -0.38)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.54: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (1, 0) -> State (1, 0)
# At time 17.60: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.11 minutes (Overtime cost: 0.00, Reward: -0.11)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.70: Customer type 1 served by Agent 2 in 0.76 minutes, waited 5.65 minutes (Overtime cost: 0.00, Reward: -5.65)
#     Transition: State (2, 2) -> State (0, 0)
# At time 18.03: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00, Reward: -0.02)
#     Transition: State (1, 0) -> State (0, 1)
# At time 18.35: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.31 minutes (Overtime cost: 0.00, Reward: -0.31)
#     Transition: State (1, 0) -> State (1, 0)
# At time 18.44: Customer type 2 served by Agent 2 in 0.74 minutes, waited 6.32 minutes (Overtime cost: 0.00, Reward: -6.32)
#     Transition: State (1, 2) -> State (0, 0)
# At time 18.56: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.22 minutes (Overtime cost: 0.00, Reward: -0.22)
#     Transition: State (1, 0) -> State (1, 1)
# At time 18.61: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 18.83: Customer type 2 served by Agent 2 in 0.39 minutes, waited 6.50 minutes (Overtime cost: 0.00, Reward: -6.50)
#     Transition: State (1, 1) -> State (0, 0)
# At time 19.01: Customer type 2 served by Agent 2 in 0.18 minutes, waited 6.59 minutes (Overtime cost: 0.00, Reward: -6.59)
#     Transition: State (0, 2) -> State (3, 0)
# At time 19.11: Customer type 2 served by Agent 2 in 0.10 minutes, waited 6.59 minutes (Overtime cost: 0.00, Reward: -6.59)
#     Transition: State (0, 1) -> State (4, 1)
# At time 19.11: Customer type 1 served by Agent 2 in 0.00 minutes, waited 5.38 minutes (Overtime cost: 0.00, Reward: -5.38)
#     Transition: State (3, 1) -> State (5, 1)
# At time 19.14: Customer type 1 served by Agent 1 in 0.48 minutes, waited 0.48 minutes (Overtime cost: 0.00, Reward: -0.48)
#     Transition: State (1, 0) -> State (5, 1)
# At time 19.59: Customer type 1 served by Agent 1 in 0.40 minutes, waited 0.48 minutes (Overtime cost: 0.00, Reward: -0.48)
#     Transition: State (2, 0) -> State (2, 0)
# At time 19.80: Customer type 1 served by Agent 1 in 0.21 minutes, waited 0.66 minutes (Overtime cost: 0.00, Reward: -0.66)
#     Transition: State (2, 0) -> State (5, 0)
# At time 19.87: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.39 minutes (Overtime cost: 0.00, Reward: -0.39)
#     Transition: State (5, 0) -> State (5, 0)
# At time 20.45: Customer type 1 served by Agent 2 in 1.33 minutes, waited 6.62 minutes (Overtime cost: 0.00, Reward: -6.62)
#     Transition: State (2, 1) -> State (10, 0)
# At time 20.56: Customer type 1 served by Agent 2 in 0.11 minutes, waited 6.67 minutes (Overtime cost: 0.00, Reward: -6.67)
#     Transition: State (1, 2) -> State (10, 0)
# At time 20.56: Customer type 2 served by Agent 2 in 0.01 minutes, waited 6.50 minutes (Overtime cost: 0.00, Reward: -6.50)
#     Transition: State (0, 2) -> State (10, 0)
# At time 20.82: Customer type 2 served by Agent 2 in 0.26 minutes, waited 6.54 minutes (Overtime cost: 0.00, Reward: -6.54)
#     Transition: State (0, 1) -> State (11, 1)
# At time 20.85: Customer type 1 served by Agent 1 in 0.98 minutes, waited 1.19 minutes (Overtime cost: 0.00, Reward: -1.19)
#     Transition: State (5, 0) -> State (11, 1)
# At time 21.01: Customer type 2 served by Agent 2 in 0.19 minutes, waited 6.48 minutes (Overtime cost: 0.00, Reward: -6.48)
#     Transition: State (0, 1) -> State (2, 1)
# At time 21.53: Customer type 2 served by Agent 2 in 0.52 minutes, waited 6.88 minutes (Overtime cost: 0.00, Reward: -6.88)
#     Transition: State (1, 1) -> State (3, 4)
# At time 21.68: Customer type 2 served by Agent 2 in 0.16 minutes, waited 6.80 minutes (Overtime cost: 0.00, Reward: -6.80)
#     Transition: State (3, 4) -> State (3, 4)
# At time 21.87: Customer type 1 served by Agent 1 in 0.99 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (3, 0) -> State (4, 4)
# At time 22.77: Customer type 1 served by Agent 1 in 0.86 minutes, waited 1.08 minutes (Overtime cost: 0.00, Reward: -1.08)
#     Transition: State (1, 0) -> State (3, 0)
# At time 22.85: Customer type 1 served by Agent 2 in 1.17 minutes, waited 7.90 minutes (Overtime cost: 0.00, Reward: -7.90)
#     Transition: State (3, 3) -> State (2, 0)
# At time 22.97: Customer type 2 served by Agent 2 in 0.12 minutes, waited 7.97 minutes (Overtime cost: 0.00, Reward: -7.97)
#     Transition: State (2, 3) -> State (2, 0)
# At time 23.00: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.72 minutes (Overtime cost: 0.00, Reward: -0.72)
#     Transition: State (3, 0) -> State (2, 0)
# At time 23.11: Customer type 1 served by Agent 2 in 0.14 minutes, waited 8.08 minutes (Overtime cost: 0.00, Reward: -8.08)
#     Transition: State (2, 2) -> State (0, 0)
# At time 23.46: Customer type 2 served by Agent 2 in 0.35 minutes, waited 8.32 minutes (Overtime cost: 0.00, Reward: -8.32)
#     Transition: State (1, 2) -> State (0, 0)
# At time 23.58: Customer type 2 served by Agent 2 in 0.11 minutes, waited 8.41 minutes (Overtime cost: 0.00, Reward: -8.41)
#     Transition: State (1, 1) -> State (0, 0)
# At time 23.70: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 0.00, Reward: -0.05)
#     Transition: State (1, 0) -> State (0, 0)
# At time 23.76: Customer type 1 served by Agent 2 in 0.19 minutes, waited 7.28 minutes (Overtime cost: 0.00, Reward: -7.28)
#     Transition: State (1, 1) -> State (0, 0)
# At time 23.92: Customer type 2 served by Agent 2 in 0.16 minutes, waited 7.26 minutes (Overtime cost: 0.00, Reward: -7.26)
#     Transition: State (0, 1) -> State (1, 0)
# At time 24.03: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.30 minutes (Overtime cost: 0.00, Reward: -0.30)
#     Transition: State (1, 0) -> State (1, 0)
# At time 24.12: Customer type 2 served by Agent 2 in 0.20 minutes, waited 6.11 minutes (Overtime cost: 0.00, Reward: -6.11)
#     Transition: State (1, 1) -> State (0, 0)
# At time 24.33: Customer type 2 served by Agent 2 in 0.21 minutes, waited 5.88 minutes (Overtime cost: 0.00, Reward: -5.88)
#     Transition: State (1, 1) -> State (0, 0)
# At time 24.50: Customer type 1 served by Agent 2 in 0.17 minutes, waited 5.66 minutes (Overtime cost: 0.00, Reward: -5.66)
#     Transition: State (6, 1) -> State (2, 0)
# At time 24.63: Customer type 1 served by Agent 2 in 0.13 minutes, waited 5.70 minutes (Overtime cost: 0.00, Reward: -5.70)
#     Transition: State (5, 1) -> State (2, 0)
# At time 25.34: Customer type 1 served by Agent 1 in 1.31 minutes, waited 1.48 minutes (Overtime cost: 0.00, Reward: -1.48)
#     Transition: State (1, 0) -> State (7, 1)
# At time 25.85: Customer type 1 served by Agent 2 in 1.22 minutes, waited 6.89 minutes (Overtime cost: 0.00, Reward: -6.89)
#     Transition: State (4, 1) -> State (7, 0)
# At time 25.88: Customer type 1 served by Agent 2 in 0.02 minutes, waited 6.81 minutes (Overtime cost: 0.00, Reward: -6.81)
#     Transition: State (3, 1) -> State (7, 0)
# At time 26.12: Customer type 1 served by Agent 1 in 0.77 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (4, 0) -> State (7, 0)
# At time 26.24: Customer type 2 served by Agent 2 in 0.37 minutes, waited 7.16 minutes (Overtime cost: 0.00, Reward: -7.16)
#     Transition: State (2, 1) -> State (7, 0)
# At time 26.53: Customer type 1 served by Agent 1 in 0.41 minutes, waited 1.38 minutes (Overtime cost: 0.00, Reward: -1.38)
#     Transition: State (7, 0) -> State (8, 0)
# At time 26.59: Customer type 1 served by Agent 2 in 0.35 minutes, waited 6.85 minutes (Overtime cost: 0.00, Reward: -6.85)
#     Transition: State (11, 1) -> State (7, 0)
# At time 26.80: Customer type 1 served by Agent 2 in 0.21 minutes, waited 7.06 minutes (Overtime cost: 0.00, Reward: -7.06)
#     Transition: State (11, 1) -> State (7, 1)
# At time 26.81: Customer type 1 served by Agent 1 in 0.27 minutes, waited 1.64 minutes (Overtime cost: 0.00, Reward: -1.64)
#     Transition: State (8, 0) -> State (7, 1)
# At time 26.86: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (1, 0) -> State (0, 0)
# At time 26.94: Customer type 1 served by Agent 2 in 0.14 minutes, waited 7.17 minutes (Overtime cost: 0.00, Reward: -7.17)
#     Transition: State (10, 1) -> State (0, 0)
# At time 27.10: Customer type 1 served by Agent 2 in 0.16 minutes, waited 7.29 minutes (Overtime cost: 0.00, Reward: -7.29)
#     Transition: State (9, 1) -> State (0, 0)
# At time 27.18: Customer type 1 served by Agent 2 in 0.08 minutes, waited 7.24 minutes (Overtime cost: 0.00, Reward: -7.24)
#     Transition: State (8, 1) -> State (2, 0)
# At time 27.19: Customer type 1 served by Agent 2 in 0.01 minutes, waited 7.24 minutes (Overtime cost: 0.00, Reward: -7.24)
#     Transition: State (7, 1) -> State (2, 0)
# At time 27.22: Customer type 1 served by Agent 2 in 0.02 minutes, waited 7.17 minutes (Overtime cost: 0.00, Reward: -7.17)
#     Transition: State (6, 1) -> State (2, 0)
# At time 27.28: Customer type 1 served by Agent 2 in 0.06 minutes, waited 7.04 minutes (Overtime cost: 0.00, Reward: -7.04)
#     Transition: State (5, 1) -> State (2, 1)
# At time 27.41: Customer type 1 served by Agent 1 in 0.38 minutes, waited 0.38 minutes (Overtime cost: 0.00, Reward: -0.38)
#     Transition: State (1, 0) -> State (2, 1)
# At time 27.92: Customer type 1 served by Agent 2 in 0.64 minutes, waited 7.61 minutes (Overtime cost: 0.00, Reward: -7.61)
#     Transition: State (4, 1) -> State (0, 0)
# At time 28.19: Customer type 1 served by Agent 2 in 0.27 minutes, waited 7.85 minutes (Overtime cost: 0.00, Reward: -7.85)
#     Transition: State (4, 1) -> State (1, 1)
# At time 28.22: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00, Reward: -0.15)
#     Transition: State (1, 0) -> State (1, 1)
# At time 28.74: Customer type 1 served by Agent 1 in 0.49 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 0) -> State (2, 0)
# At time 28.75: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.22 minutes (Overtime cost: 0.00, Reward: -0.22)
#     Transition: State (2, 0) -> State (1, 0)
# At time 29.00: Customer type 1 served by Agent 2 in 0.81 minutes, waited 8.37 minutes (Overtime cost: 0.00, Reward: -8.37)
#     Transition: State (3, 1) -> State (0, 1)
# At time 29.01: Customer type 2 served by Agent 2 in 0.01 minutes, waited 8.38 minutes (Overtime cost: 0.00, Reward: -8.38)
#     Transition: State (2, 1) -> State (0, 1)
# At time 29.39: Customer type 1 served by Agent 2 in 0.38 minutes, waited 8.51 minutes (Overtime cost: 0.00, Reward: -8.51)
#     Transition: State (4, 4) -> State (1, 1)
# At time 29.42: Customer type 1 served by Agent 2 in 0.03 minutes, waited 8.54 minutes (Overtime cost: 0.00, Reward: -8.54)
#     Transition: State (3, 4) -> State (1, 1)
# At time 29.72: Customer type 2 served by Agent 2 in 0.30 minutes, waited 8.77 minutes (Overtime cost: 0.00, Reward: -8.77)
#     Transition: State (2, 4) -> State (2, 1)
# At time 30.49: Customer type 1 served by Agent 1 in 1.74 minutes, waited 1.79 minutes (Overtime cost: 0.00, Reward: -1.79)
#     Transition: State (1, 0) -> State (10, 2)
# At time 30.65: Customer type 2 served by Agent 2 in 0.93 minutes, waited 9.63 minutes (Overtime cost: 0.00, Reward: -9.63)
#     Transition: State (2, 3) -> State (8, 0)
# At time 30.70: Customer type 1 served by Agent 2 in 0.06 minutes, waited 9.62 minutes (Overtime cost: 0.00, Reward: -9.62)
#     Transition: State (2, 2) -> State (9, 0)
# At time 30.72: Customer type 2 served by Agent 2 in 0.01 minutes, waited 9.63 minutes (Overtime cost: 0.00, Reward: -9.63)
#     Transition: State (1, 2) -> State (9, 0)
# At time 30.74: Customer type 2 served by Agent 2 in 0.02 minutes, waited 9.40 minutes (Overtime cost: 0.00, Reward: -9.40)
#     Transition: State (1, 1) -> State (9, 0)
# At time 31.05: Customer type 1 served by Agent 1 in 0.55 minutes, waited 1.13 minutes (Overtime cost: 0.00, Reward: -1.13)
#     Transition: State (8, 0) -> State (11, 3)
# At time 31.11: Customer type 1 served by Agent 2 in 0.37 minutes, waited 8.75 minutes (Overtime cost: 0.00, Reward: -8.75)
#     Transition: State (2, 1) -> State (0, 0)
# At time 31.24: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00, Reward: -0.04)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.40: Customer type 1 served by Agent 2 in 0.29 minutes, waited 8.77 minutes (Overtime cost: 0.00, Reward: -8.77)
#     Transition: State (1, 1) -> State (0, 0)
# At time 31.48: Customer type 2 served by Agent 2 in 0.08 minutes, waited 8.46 minutes (Overtime cost: 0.00, Reward: -8.46)
#     Transition: State (0, 1) -> State (0, 0)
# At time 31.53: Customer type 2 served by Agent 2 in 0.04 minutes, waited 7.83 minutes (Overtime cost: 0.00, Reward: -7.83)
#     Transition: State (0, 1) -> State (0, 0)
# At time 31.80: Customer type 1 served by Agent 2 in 0.27 minutes, waited 7.43 minutes (Overtime cost: 0.00, Reward: -7.43)
#     Transition: State (7, 1) -> State (0, 0)
# At time 32.21: Customer type 1 served by Agent 2 in 0.41 minutes, waited 7.78 minutes (Overtime cost: 0.00, Reward: -7.78)
#     Transition: State (6, 1) -> State (0, 0)
# At time 32.34: Customer type 1 served by Agent 2 in 0.13 minutes, waited 7.53 minutes (Overtime cost: 0.00, Reward: -7.53)
#     Transition: State (5, 1) -> State (0, 0)
# At time 32.50: Customer type 2 served by Agent 2 in 0.16 minutes, waited 7.65 minutes (Overtime cost: 0.00, Reward: -7.65)
#     Transition: State (4, 1) -> State (0, 0)
# At time 32.59: Customer type 1 served by Agent 2 in 0.09 minutes, waited 7.40 minutes (Overtime cost: 0.00, Reward: -7.40)
#     Transition: State (7, 1) -> State (0, 1)
# At time 32.60: Customer type 1 served by Agent 2 in 0.01 minutes, waited 7.14 minutes (Overtime cost: 0.00, Reward: -7.14)
#     Transition: State (6, 1) -> State (0, 1)
# At time 32.73: Customer type 1 served by Agent 2 in 0.13 minutes, waited 7.21 minutes (Overtime cost: 0.00, Reward: -7.21)
#     Transition: State (5, 1) -> State (0, 1)
# At time 33.03: Customer type 1 served by Agent 1 in 0.65 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (1, 0) -> State (0, 3)
# At time 33.32: Customer type 1 served by Agent 1 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00, Reward: -0.12)
#     Transition: State (1, 0) -> State (0, 0)
# At time 33.47: Customer type 1 served by Agent 2 in 0.75 minutes, waited 7.94 minutes (Overtime cost: 0.00, Reward: -7.94)
#     Transition: State (4, 1) -> State (0, 0)
# At time 33.83: Customer type 1 served by Agent 2 in 0.35 minutes, waited 8.02 minutes (Overtime cost: 0.00, Reward: -8.02)
#     Transition: State (3, 1) -> State (0, 0)
# At time 33.86: Customer type 1 served by Agent 2 in 0.04 minutes, waited 7.68 minutes (Overtime cost: 0.00, Reward: -7.68)
#     Transition: State (2, 1) -> State (0, 0)
# At time 34.07: Customer type 1 served by Agent 1 in 0.57 minutes, waited 0.57 minutes (Overtime cost: 0.00, Reward: -0.57)
#     Transition: State (1, 0) -> State (2, 0)
# At time 34.17: Customer type 1 served by Agent 2 in 0.30 minutes, waited 7.65 minutes (Overtime cost: 0.00, Reward: -7.65)
#     Transition: State (2, 1) -> State (2, 1)
# At time 34.18: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.25 minutes (Overtime cost: 0.00, Reward: -0.25)
#     Transition: State (2, 0) -> State (2, 1)
# At time 34.32: Customer type 2 served by Agent 2 in 0.15 minutes, waited 7.52 minutes (Overtime cost: 0.00, Reward: -7.52)
#     Transition: State (1, 1) -> State (0, 0)
# At time 34.43: Customer type 1 served by Agent 2 in 0.12 minutes, waited 7.31 minutes (Overtime cost: 0.00, Reward: -7.31)
#     Transition: State (2, 1) -> State (0, 0)
# At time 34.49: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.01 minutes (Overtime cost: 0.00, Reward: -0.01)
#     Transition: State (1, 0) -> State (0, 0)
# At time 34.55: Customer type 1 served by Agent 2 in 0.11 minutes, waited 7.37 minutes (Overtime cost: 0.00, Reward: -7.37)
#     Transition: State (1, 1) -> State (0, 0)
# At time 34.62: Customer type 2 served by Agent 2 in 0.07 minutes, waited 7.38 minutes (Overtime cost: 0.00, Reward: -7.38)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.82: Customer type 2 served by Agent 2 in 0.20 minutes, waited 7.21 minutes (Overtime cost: 0.00, Reward: -7.21)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.87: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00, Reward: -0.02)
#     Transition: State (1, 0) -> State (0, 0)
# At time 34.90: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00, Reward: -0.02)
#     Transition: State (1, 0) -> State (0, 0)
# At time 35.09: Customer type 1 served by Agent 2 in 0.28 minutes, waited 6.95 minutes (Overtime cost: 0.00, Reward: -6.95)
#     Transition: State (1, 1) -> State (0, 0)
# At time 35.39: Customer type 2 served by Agent 2 in 0.30 minutes, waited 7.23 minutes (Overtime cost: 0.00, Reward: -7.23)
#     Transition: State (0, 1) -> State (0, 0)
# At time 35.85: Customer type 2 served by Agent 2 in 0.46 minutes, waited 7.01 minutes (Overtime cost: 0.00, Reward: -7.01)
#     Transition: State (10, 2) -> State (2, 0)
# At time 36.40: Customer type 1 served by Agent 2 in 0.54 minutes, waited 7.19 minutes (Overtime cost: 0.00, Reward: -7.19)
#     Transition: State (10, 1) -> State (4, 2)
# At time 36.65: Customer type 1 served by Agent 1 in 1.22 minutes, waited 1.22 minutes (Overtime cost: 0.00, Reward: -1.22)
#     Transition: State (1, 0) -> State (6, 2)
# At time 36.93: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (3, 0) -> State (3, 0)
# At time 36.94: Customer type 1 served by Agent 2 in 0.54 minutes, waited 7.32 minutes (Overtime cost: 0.00, Reward: -7.32)
#     Transition: State (9, 1) -> State (2, 0)
# At time 36.98: Customer type 1 served by Agent 1 in 0.05 minutes, waited 0.54 minutes (Overtime cost: 0.00, Reward: -0.54)
#     Transition: State (3, 0) -> State (2, 0)
# At time 37.18: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.64 minutes (Overtime cost: 0.00, Reward: -0.64)
#     Transition: State (2, 0) -> State (3, 1)
# At time 37.59: Customer type 2 served by Agent 2 in 0.65 minutes, waited 7.70 minutes (Overtime cost: 0.00, Reward: -7.70)
#     Transition: State (8, 1) -> State (3, 2)
# At time 37.65: Customer type 1 served by Agent 1 in 0.46 minutes, waited 0.57 minutes (Overtime cost: 0.00, Reward: -0.57)
#     Transition: State (2, 0) -> State (4, 2)
# At time 37.67: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (1, 0) -> State (0, 0)
# At time 38.07: Customer type 1 served by Agent 2 in 0.48 minutes, waited 8.10 minutes (Overtime cost: 0.00, Reward: -8.10)
#     Transition: State (11, 3) -> State (3, 2)
# At time 38.23: Customer type 1 served by Agent 1 in 0.35 minutes, waited 0.35 minutes (Overtime cost: 0.00, Reward: -0.35)
#     Transition: State (1, 0) -> State (4, 2)
# At time 38.49: Customer type 1 served by Agent 2 in 0.42 minutes, waited 8.51 minutes (Overtime cost: 0.00, Reward: -8.51)
#     Transition: State (10, 3) -> State (5, 1)
# At time 38.58: Customer type 1 served by Agent 2 in 0.09 minutes, waited 8.38 minutes (Overtime cost: 0.00, Reward: -8.38)
#     Transition: State (9, 3) -> State (6, 1)
# At time 38.58: Customer type 1 served by Agent 2 in 0.00 minutes, waited 8.38 minutes (Overtime cost: 0.00, Reward: -8.38)
#     Transition: State (8, 3) -> State (6, 1)
# At time 38.62: Customer type 1 served by Agent 2 in 0.03 minutes, waited 8.39 minutes (Overtime cost: 0.00, Reward: -8.39)
#     Transition: State (7, 3) -> State (6, 1)
# At time 38.68: Customer type 1 served by Agent 2 in 0.06 minutes, waited 8.35 minutes (Overtime cost: 0.00, Reward: -8.35)
#     Transition: State (6, 3) -> State (6, 1)
# At time 38.84: Customer type 1 served by Agent 2 in 0.16 minutes, waited 8.37 minutes (Overtime cost: 0.00, Reward: -8.37)
#     Transition: State (5, 3) -> State (7, 1)
# At time 38.90: Customer type 1 served by Agent 2 in 0.05 minutes, waited 8.37 minutes (Overtime cost: 0.00, Reward: -8.37)
#     Transition: State (4, 3) -> State (7, 1)
# At time 39.06: Customer type 1 served by Agent 2 in 0.16 minutes, waited 8.39 minutes (Overtime cost: 0.00, Reward: -8.39)
#     Transition: State (3, 3) -> State (7, 2)
# At time 39.32: Customer type 1 served by Agent 1 in 1.07 minutes, waited 1.29 minutes (Overtime cost: 0.00, Reward: -1.29)
#     Transition: State (4, 0) -> State (9, 2)
# At time 39.64: Customer type 2 served by Agent 2 in 0.58 minutes, waited 8.84 minutes (Overtime cost: 0.00, Reward: -8.84)
#     Transition: State (2, 3) -> State (3, 0)
# At time 39.72: Customer type 1 served by Agent 1 in 0.38 minutes, waited 0.65 minutes (Overtime cost: 0.00, Reward: -0.65)
#     Transition: State (2, 0) -> State (3, 0)
# At time 39.81: Customer type 1 served by Agent 2 in 0.17 minutes, waited 9.00 minutes (Overtime cost: 0.00, Reward: -9.00)
#     Transition: State (2, 2) -> State (2, 0)
# At time 39.99: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.82 minutes (Overtime cost: 0.00, Reward: -0.82)
#     Transition: State (3, 0) -> State (3, 1)
# Customer rejected at time 40.31: No new arrivals after T = 40
# Customer rejected at time 40.36: No new arrivals after T = 40
# Customer rejected at time 40.64: No new arrivals after T = 40
# At time 40.68: Customer type 2 served by Agent 2 in 0.87 minutes, waited 9.79 minutes (Overtime cost: 0.68, Reward: -10.47)
#     Transition: State (1, 2) -> State (0, 0)
# Customer rejected at time 40.79: No new arrivals after T = 40
# Customer rejected at time 40.93: No new arrivals after T = 40
# Customer rejected at time 40.94: No new arrivals after T = 40
# Customer rejected at time 40.94: No new arrivals after T = 40
# At time 41.07: Customer type 1 served by Agent 2 in 0.38 minutes, waited 10.12 minutes (Overtime cost: 1.07, Reward: -11.19)
#     Transition: State (1, 1) -> State (0, 0)
# At time 41.25: Customer type 2 served by Agent 2 in 0.18 minutes, waited 10.29 minutes (Overtime cost: 1.25, Reward: -11.54)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 41.38: No new arrivals after T = 40
# Customer rejected at time 41.41: No new arrivals after T = 40
# Customer rejected at time 41.43: No new arrivals after T = 40
# Customer rejected at time 41.46: No new arrivals after T = 40
# At time 41.55: Customer type 2 served by Agent 2 in 0.30 minutes, waited 10.20 minutes (Overtime cost: 1.55, Reward: -11.75)
#     Transition: State (0, 1) -> State (0, 0)
# At time 41.99: Customer type 2 served by Agent 2 in 0.44 minutes, waited 9.85 minutes (Overtime cost: 1.99, Reward: -11.83)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 41.99: No new arrivals after T = 40
# Customer rejected at time 42.40: No new arrivals after T = 40
# Customer rejected at time 42.41: No new arrivals after T = 40
# At time 42.48: Customer type 2 served by Agent 2 in 0.50 minutes, waited 10.32 minutes (Overtime cost: 2.48, Reward: -12.81)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 43.00: No new arrivals after T = 40
# Customer rejected at time 43.04: No new arrivals after T = 40
# At time 43.19: Customer type 2 served by Agent 2 in 0.71 minutes, waited 10.60 minutes (Overtime cost: 3.19, Reward: -13.80)
#     Transition: State (0, 3) -> State (0, 0)
# At time 43.43: Customer type 2 served by Agent 2 in 0.24 minutes, waited 10.66 minutes (Overtime cost: 3.43, Reward: -14.09)
#     Transition: State (0, 2) -> State (0, 0)
# Customer rejected at time 43.49: No new arrivals after T = 40
# Customer rejected at time 43.59: No new arrivals after T = 40
# Customer rejected at time 43.71: No new arrivals after T = 40
# At time 43.97: Customer type 2 served by Agent 2 in 0.54 minutes, waited 10.99 minutes (Overtime cost: 3.97, Reward: -14.96)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 44.14: No new arrivals after T = 40
# Customer rejected at time 44.21: No new arrivals after T = 40
# Customer rejected at time 44.26: No new arrivals after T = 40
# At time 44.29: Customer type 2 served by Agent 2 in 0.32 minutes, waited 10.86 minutes (Overtime cost: 4.29, Reward: -15.15)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 44.37: No new arrivals after T = 40
# Customer rejected at time 44.38: No new arrivals after T = 40
# Customer rejected at time 44.44: No new arrivals after T = 40
# At time 44.47: Customer type 2 served by Agent 2 in 0.18 minutes, waited 10.98 minutes (Overtime cost: 4.47, Reward: -15.45)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 44.53: No new arrivals after T = 40
# Customer rejected at time 44.68: No new arrivals after T = 40
# Customer rejected at time 45.01: No new arrivals after T = 40
# Customer rejected at time 45.03: No new arrivals after T = 40
# Customer rejected at time 45.05: No new arrivals after T = 40
# Customer rejected at time 45.07: No new arrivals after T = 40
# Customer rejected at time 45.12: No new arrivals after T = 40
# Customer rejected at time 45.15: No new arrivals after T = 40
# Customer rejected at time 45.27: No new arrivals after T = 40
# Customer rejected at time 45.32: No new arrivals after T = 40
# Customer rejected at time 45.32: No new arrivals after T = 40
# Customer rejected at time 45.59: No new arrivals after T = 40
# Customer rejected at time 45.63: No new arrivals after T = 40
# Customer rejected at time 45.90: No new arrivals after T = 40
# At time 46.18: Customer type 1 served by Agent 2 in 1.70 minutes, waited 12.19 minutes (Overtime cost: 6.18, Reward: -18.37)
#     Transition: State (2, 1) -> State (0, 0)
# At time 46.59: Customer type 1 served by Agent 2 in 0.41 minutes, waited 12.51 minutes (Overtime cost: 6.59, Reward: -19.10)
#     Transition: State (1, 1) -> State (0, 0)
# Customer rejected at time 46.77: No new arrivals after T = 40
# Customer rejected at time 47.00: No new arrivals after T = 40
# Customer rejected at time 47.04: No new arrivals after T = 40
# Customer rejected at time 47.13: No new arrivals after T = 40
# At time 47.26: Customer type 2 served by Agent 2 in 0.67 minutes, waited 13.17 minutes (Overtime cost: 7.26, Reward: -20.43)
#     Transition: State (0, 1) -> State (0, 0)
# Customer rejected at time 47.32: No new arrivals after T = 40
# At time 47.33: Customer type 2 served by Agent 2 in 0.07 minutes, waited 12.27 minutes (Overtime cost: 7.33, Reward: -19.60)
#     Transition: State (0, 1) -> State (0, 0)
# At time 47.35: Customer type 2 served by Agent 2 in 0.02 minutes, waited 11.97 minutes (Overtime cost: 7.35, Reward: -19.32)
#     Transition: State (0, 1) -> State (0, 0)
# At time 47.40: Customer type 1 served by Agent 2 in 0.05 minutes, waited 11.90 minutes (Overtime cost: 7.40, Reward: -19.31)
#     Transition: State (6, 2) -> State (0, 0)
# At time 47.69: Customer type 1 served by Agent 2 in 0.29 minutes, waited 11.98 minutes (Overtime cost: 7.69, Reward: -19.68)
#     Transition: State (5, 2) -> State (0, 0)
# At time 47.85: Customer type 1 served by Agent 2 in 0.15 minutes, waited 11.86 minutes (Overtime cost: 7.85, Reward: -19.71)
#     Transition: State (4, 2) -> State (0, 0)
# At time 47.88: Customer type 2 served by Agent 2 in 0.04 minutes, waited 11.59 minutes (Overtime cost: 7.88, Reward: -19.47)
#     Transition: State (3, 2) -> State (0, 0)
# Customer rejected at time 47.96: No new arrivals after T = 40
# At time 48.02: Customer type 2 served by Agent 2 in 0.14 minutes, waited 11.72 minutes (Overtime cost: 8.02, Reward: -19.74)
#     Transition: State (3, 1) -> State (0, 0)
# At time 48.03: Customer type 1 served by Agent 2 in 0.01 minutes, waited 11.34 minutes (Overtime cost: 8.03, Reward: -19.37)
#     Transition: State (3, 1) -> State (0, 0)
# Customer rejected at time 48.06: No new arrivals after T = 40
# At time 48.22: Customer type 2 served by Agent 2 in 0.19 minutes, waited 11.22 minutes (Overtime cost: 8.22, Reward: -19.44)
#     Transition: State (2, 1) -> State (0, 0)
# Customer rejected at time 48.34: No new arrivals after T = 40
# Customer rejected at time 48.41: No new arrivals after T = 40
# Customer rejected at time 48.42: No new arrivals after T = 40
# Customer rejected at time 48.44: No new arrivals after T = 40
# At time 48.51: Customer type 1 served by Agent 2 in 0.29 minutes, waited 11.41 minutes (Overtime cost: 8.51, Reward: -19.91)
#     Transition: State (4, 2) -> State (0, 0)
# Customer rejected at time 48.80: No new arrivals after T = 40
# At time 49.12: Customer type 1 served by Agent 2 in 0.61 minutes, waited 11.80 minutes (Overtime cost: 9.12, Reward: -20.92)
#     Transition: State (3, 2) -> State (0, 0)
# Customer rejected at time 49.31: No new arrivals after T = 40
# At time 49.45: Customer type 1 served by Agent 2 in 0.33 minutes, waited 12.09 minutes (Overtime cost: 9.45, Reward: -21.54)
#     Transition: State (2, 2) -> State (0, 0)
# At time 49.47: Customer type 2 served by Agent 2 in 0.02 minutes, waited 12.04 minutes (Overtime cost: 9.47, Reward: -21.51)
#     Transition: State (1, 2) -> State (0, 0)
# At time 49.64: Customer type 2 served by Agent 2 in 0.17 minutes, waited 12.11 minutes (Overtime cost: 9.64, Reward: -21.75)
#     Transition: State (1, 1) -> State (0, 0)
# Customer rejected at time 49.78: No new arrivals after T = 40
# At time 49.78: Customer type 2 served by Agent 2 in 0.14 minutes, waited 11.87 minutes (Overtime cost: 9.78, Reward: -21.65)
#     Transition: State (4, 2) -> State (0, 0)
# At time 49.79: Customer type 1 served by Agent 2 in 0.01 minutes, waited 11.87 minutes (Overtime cost: 9.79, Reward: -21.66)
#     Transition: State (4, 1) -> State (0, 0)
# At time 49.81: Customer type 2 served by Agent 2 in 0.01 minutes, waited 11.82 minutes (Overtime cost: 9.81, Reward: -21.63)
#     Transition: State (3, 1) -> State (0, 0)
# At time 49.82: Customer type 1 served by Agent 2 in 0.01 minutes, waited 11.77 minutes (Overtime cost: 9.82, Reward: -21.59)
#     Transition: State (9, 2) -> State (0, 0)
# At time 49.85: Customer type 1 served by Agent 2 in 0.03 minutes, waited 11.66 minutes (Overtime cost: 9.85, Reward: -21.51)
#     Transition: State (8, 2) -> State (0, 0)
# Customer rejected at time 49.95: No new arrivals after T = 40
# Customer rejected at time 49.96: No new arrivals after T = 40
# Customer rejected at time 50.16: No new arrivals after T = 40
# Customer rejected at time 50.22: No new arrivals after T = 40
# Customer rejected at time 50.39: No new arrivals after T = 40
# Customer rejected at time 50.39: No new arrivals after T = 40
# Customer rejected at time 50.65: No new arrivals after T = 40
# Customer rejected at time 50.72: No new arrivals after T = 40
# Customer rejected at time 50.81: No new arrivals after T = 40
# Customer rejected at time 50.86: No new arrivals after T = 40
# ...
# State (19, 1): Value = -8.78
# State (19, 2): Value = -8.91
# State (19, 3): Value = -9.02
# State (19, 4): Value = -9.11
# State (19, 5): Value = -9.20
# State (19, 6): Value = -9.28
# State (19, 7): Value = -9.35
# State (19, 8): Value = -9.42
# State (19, 9): Value = -9.48
# State (19, 10): Value = -9.53
# State (19, 11): Value = -9.58
# State (19, 12): Value = -9.62
# State (19, 13): Value = -9.66
# State (19, 14): Value = -9.69
# State (19, 15): Value = -9.72
# State (19, 16): Value = -9.75
# State (19, 17): Value = -9.77
# State (19, 18): Value = -9.80
# State (19, 19): Value = -9.82
# State (19, 20): Value = -9.84
# State (20, 0): Value = -8.78
# State (20, 1): Value = -8.91
# State (20, 2): Value = -9.02
# State (20, 3): Value = -9.11
# State (20, 4): Value = -9.20
# State (20, 5): Value = -9.28
# State (20, 6): Value = -9.35
# State (20, 7): Value = -9.42
# State (20, 8): Value = -9.48
# State (20, 9): Value = -9.53
# State (20, 10): Value = -9.58
# State (20, 11): Value = -9.62
# State (20, 12): Value = -9.66
# State (20, 13): Value = -9.69
# State (20, 14): Value = -9.72
# State (20, 15): Value = -9.75
# State (20, 16): Value = -9.77
# State (20, 17): Value = -9.80
# State (20, 18): Value = -9.82
# State (20, 19): Value = -9.84
# State (20, 20): Value = -9.85
#
# Optimal Policy:
# State (0, 0): Action = None
# State (0, 1): Action = Agent 2
# State (0, 2): Action = Agent 2
# State (0, 3): Action = Agent 2
# State (0, 4): Action = Agent 2
# State (0, 5): Action = Agent 2
# State (0, 6): Action = Agent 2
# State (0, 7): Action = Agent 2
# State (0, 8): Action = Agent 2
# State (0, 9): Action = Agent 2
# State (0, 10): Action = Agent 2
# State (0, 11): Action = Agent 2
# State (0, 12): Action = Agent 2
# State (0, 13): Action = Agent 2
# State (0, 14): Action = Agent 2
# State (0, 15): Action = Agent 2
# State (0, 16): Action = Agent 2
# State (0, 17): Action = Agent 2
# State (0, 18): Action = Agent 2
# State (0, 19): Action = Agent 2
# State (0, 20): Action = Agent 2
# State (1, 0): Action = Agent 1
# State (1, 1): Action = Agent 2
# State (1, 2): Action = Agent 2
# State (1, 3): Action = Agent 2
# State (1, 4): Action = Agent 2
# State (1, 5): Action = Agent 2
# State (1, 6): Action = Agent 2
# State (1, 7): Action = Agent 2
# State (1, 8): Action = Agent 2
# State (1, 9): Action = Agent 2
# State (1, 10): Action = Agent 2
# State (1, 11): Action = Agent 2
# State (1, 12): Action = Agent 2
# State (1, 13): Action = Agent 2
# State (1, 14): Action = Agent 2
# State (1, 15): Action = Agent 2
# State (1, 16): Action = Agent 2
# State (1, 17): Action = Agent 2
# State (1, 18): Action = Agent 2
# State (1, 19): Action = Agent 2
# State (1, 20): Action = Agent 2
# State (2, 0): Action = Agent 1
# State (2, 1): Action = Agent 2
# State (2, 2): Action = Agent 2
# State (2, 3): Action = Agent 2
# State (2, 4): Action = Agent 2
# State (2, 5): Action = Agent 2
# State (2, 6): Action = Agent 2
# State (2, 7): Action = Agent 2
# State (2, 8): Action = Agent 2
# State (2, 9): Action = Agent 2
# State (2, 10): Action = Agent 2
# State (2, 11): Action = Agent 2
# State (2, 12): Action = Agent 2
# State (2, 13): Action = Agent 2
# State (2, 14): Action = Agent 2
# State (2, 15): Action = Agent 2
# State (2, 16): Action = Agent 2
# State (2, 17): Action = Agent 2
# State (2, 18): Action = Agent 2
# State (2, 19): Action = Agent 2
# State (2, 20): Action = Agent 2
# State (3, 0): Action = Agent 1
# State (3, 1): Action = Agent 2
# State (3, 2): Action = Agent 2
# State (3, 3): Action = Agent 2
# State (3, 4): Action = Agent 2
# State (3, 5): Action = Agent 2
# State (3, 6): Action = Agent 2
# State (3, 7): Action = Agent 2
# State (3, 8): Action = Agent 2
# State (3, 9): Action = Agent 2
# State (3, 10): Action = Agent 2
# State (3, 11): Action = Agent 2
# State (3, 12): Action = Agent 2
# State (3, 13): Action = Agent 2
# State (3, 14): Action = Agent 2
# State (3, 15): Action = Agent 2
# State (3, 16): Action = Agent 2
# State (3, 17): Action = Agent 2
# State (3, 18): Action = Agent 2
# State (3, 19): Action = Agent 2
# State (3, 20): Action = Agent 2
# State (4, 0): Action = Agent 1
# State (4, 1): Action = Agent 2
# State (4, 2): Action = Agent 2
# State (4, 3): Action = Agent 2
# State (4, 4): Action = Agent 2
# State (4, 5): Action = Agent 2
# State (4, 6): Action = Agent 2
# State (4, 7): Action = Agent 2
# State (4, 8): Action = Agent 2
# State (4, 9): Action = Agent 2
# State (4, 10): Action = Agent 2
# State (4, 11): Action = Agent 2
# State (4, 12): Action = Agent 2
# State (4, 13): Action = Agent 2
# State (4, 14): Action = Agent 2
# State (4, 15): Action = Agent 2
# State (4, 16): Action = Agent 2
# State (4, 17): Action = Agent 2
# State (4, 18): Action = Agent 2
# State (4, 19): Action = Agent 2
# State (4, 20): Action = Agent 2
# State (5, 0): Action = Agent 1
# State (5, 1): Action = Agent 2
# State (5, 2): Action = Agent 2
# State (5, 3): Action = Agent 2
# State (5, 4): Action = Agent 2
# State (5, 5): Action = Agent 2
# State (5, 6): Action = Agent 2
# State (5, 7): Action = Agent 2
# State (5, 8): Action = Agent 2
# State (5, 9): Action = Agent 2
# State (5, 10): Action = Agent 2
# State (5, 11): Action = Agent 2
# State (5, 12): Action = Agent 2
# State (5, 13): Action = Agent 2
# State (5, 14): Action = Agent 2
# State (5, 15): Action = Agent 2
# State (5, 16): Action = Agent 2
# State (5, 17): Action = Agent 2
# State (5, 18): Action = Agent 2
# State (5, 19): Action = Agent 2
# State (5, 20): Action = Agent 2
# State (6, 0): Action = Agent 1
# State (6, 1): Action = Agent 2
# State (6, 2): Action = Agent 2
# State (6, 3): Action = Agent 2
# State (6, 4): Action = Agent 2
# State (6, 5): Action = Agent 2
# State (6, 6): Action = Agent 2
# State (6, 7): Action = Agent 2
# State (6, 8): Action = Agent 2
# State (6, 9): Action = Agent 2
# State (6, 10): Action = Agent 2
# State (6, 11): Action = Agent 2
# State (6, 12): Action = Agent 2
# State (6, 13): Action = Agent 2
# State (6, 14): Action = Agent 2
# State (6, 15): Action = Agent 2
# State (6, 16): Action = Agent 2
# State (6, 17): Action = Agent 2
# State (6, 18): Action = Agent 2
# State (6, 19): Action = Agent 2
# State (6, 20): Action = Agent 2
# State (7, 0): Action = Agent 1
# State (7, 1): Action = Agent 2
# State (7, 2): Action = Agent 2
# State (7, 3): Action = Agent 2
# State (7, 4): Action = Agent 2
# State (7, 5): Action = Agent 2
# State (7, 6): Action = Agent 2
# State (7, 7): Action = Agent 2
# State (7, 8): Action = Agent 2
# State (7, 9): Action = Agent 2
# State (7, 10): Action = Agent 2
# State (7, 11): Action = Agent 2
# State (7, 12): Action = Agent 2
# State (7, 13): Action = Agent 2
# State (7, 14): Action = Agent 2
# State (7, 15): Action = Agent 2
# State (7, 16): Action = Agent 2
# State (7, 17): Action = Agent 2
# State (7, 18): Action = Agent 2
# State (7, 19): Action = Agent 2
# State (7, 20): Action = Agent 2
# State (8, 0): Action = Agent 1
# State (8, 1): Action = Agent 2
# State (8, 2): Action = Agent 2
# State (8, 3): Action = Agent 2
# State (8, 4): Action = Agent 2
# State (8, 5): Action = Agent 2
# State (8, 6): Action = Agent 2
# State (8, 7): Action = Agent 2
# State (8, 8): Action = Agent 2
# State (8, 9): Action = Agent 2
# State (8, 10): Action = Agent 2
# State (8, 11): Action = Agent 2
# State (8, 12): Action = Agent 2
# State (8, 13): Action = Agent 2
# State (8, 14): Action = Agent 2
# State (8, 15): Action = Agent 2
# State (8, 16): Action = Agent 2
# State (8, 17): Action = Agent 2
# State (8, 18): Action = Agent 2
# State (8, 19): Action = Agent 2
# State (8, 20): Action = Agent 2
# State (9, 0): Action = Agent 1
# State (9, 1): Action = Agent 2
# State (9, 2): Action = Agent 2
# State (9, 3): Action = Agent 2
# State (9, 4): Action = Agent 2
# State (9, 5): Action = Agent 2
# State (9, 6): Action = Agent 2
# State (9, 7): Action = Agent 2
# State (9, 8): Action = Agent 2
# State (9, 9): Action = Agent 2
# State (9, 10): Action = Agent 2
# State (9, 11): Action = Agent 2
# State (9, 12): Action = Agent 2
# State (9, 13): Action = Agent 2
# State (9, 14): Action = Agent 2
# State (9, 15): Action = Agent 2
# State (9, 16): Action = Agent 2
# State (9, 17): Action = Agent 2
# State (9, 18): Action = Agent 2
# State (9, 19): Action = Agent 2
# State (9, 20): Action = Agent 2
# State (10, 0): Action = Agent 1
# State (10, 1): Action = Agent 2
# State (10, 2): Action = Agent 2
# State (10, 3): Action = Agent 2
# State (10, 4): Action = Agent 2
# State (10, 5): Action = Agent 2
# State (10, 6): Action = Agent 2
# State (10, 7): Action = Agent 2
# State (10, 8): Action = Agent 2
# State (10, 9): Action = Agent 2
# State (10, 10): Action = Agent 2
# State (10, 11): Action = Agent 2
# State (10, 12): Action = Agent 2
# State (10, 13): Action = Agent 2
# State (10, 14): Action = Agent 2
# State (10, 15): Action = Agent 2
# State (10, 16): Action = Agent 2
# State (10, 17): Action = Agent 2
# State (10, 18): Action = Agent 2
# State (10, 19): Action = Agent 2
# State (10, 20): Action = Agent 2
# State (11, 0): Action = Agent 1
# State (11, 1): Action = Agent 2
# State (11, 2): Action = Agent 2
# State (11, 3): Action = Agent 2
# State (11, 4): Action = Agent 2
# State (11, 5): Action = Agent 2
# State (11, 6): Action = Agent 2
# State (11, 7): Action = Agent 2
# State (11, 8): Action = Agent 2
# State (11, 9): Action = Agent 2
# State (11, 10): Action = Agent 2
# State (11, 11): Action = Agent 2
# State (11, 12): Action = Agent 2
# State (11, 13): Action = Agent 2
# State (11, 14): Action = Agent 2
# State (11, 15): Action = Agent 2
# State (11, 16): Action = Agent 2
# State (11, 17): Action = Agent 2
# State (11, 18): Action = Agent 2
# State (11, 19): Action = Agent 2
# State (11, 20): Action = Agent 2
# State (12, 0): Action = Agent 1
# State (12, 1): Action = Agent 2
# State (12, 2): Action = Agent 2
# State (12, 3): Action = Agent 2
# State (12, 4): Action = Agent 2
# State (12, 5): Action = Agent 2
# State (12, 6): Action = Agent 2
# State (12, 7): Action = Agent 2
# State (12, 8): Action = Agent 2
# State (12, 9): Action = Agent 2
# State (12, 10): Action = Agent 2
# State (12, 11): Action = Agent 2
# State (12, 12): Action = Agent 2
# State (12, 13): Action = Agent 2
# State (12, 14): Action = Agent 2
# State (12, 15): Action = Agent 2
# State (12, 16): Action = Agent 2
# State (12, 17): Action = Agent 2
# State (12, 18): Action = Agent 2
# State (12, 19): Action = Agent 2
# State (12, 20): Action = Agent 2
# State (13, 0): Action = Agent 1
# State (13, 1): Action = Agent 2
# State (13, 2): Action = Agent 2
# State (13, 3): Action = Agent 2
# State (13, 4): Action = Agent 2
# State (13, 5): Action = Agent 2
# State (13, 6): Action = Agent 2
# State (13, 7): Action = Agent 2
# State (13, 8): Action = Agent 2
# State (13, 9): Action = Agent 2
# State (13, 10): Action = Agent 2
# State (13, 11): Action = Agent 2
# State (13, 12): Action = Agent 2
# State (13, 13): Action = Agent 2
# State (13, 14): Action = Agent 2
# State (13, 15): Action = Agent 2
# State (13, 16): Action = Agent 2
# State (13, 17): Action = Agent 2
# State (13, 18): Action = Agent 2
# State (13, 19): Action = Agent 2
# State (13, 20): Action = Agent 2
# State (14, 0): Action = Agent 1
# State (14, 1): Action = Agent 2
# State (14, 2): Action = Agent 2
# State (14, 3): Action = Agent 2
# State (14, 4): Action = Agent 2
# State (14, 5): Action = Agent 2
# State (14, 6): Action = Agent 2
# State (14, 7): Action = Agent 2
# State (14, 8): Action = Agent 2
# State (14, 9): Action = Agent 2
# State (14, 10): Action = Agent 2
# State (14, 11): Action = Agent 2
# State (14, 12): Action = Agent 2
# State (14, 13): Action = Agent 2
# State (14, 14): Action = Agent 2
# State (14, 15): Action = Agent 2
# State (14, 16): Action = Agent 2
# State (14, 17): Action = Agent 2
# State (14, 18): Action = Agent 2
# State (14, 19): Action = Agent 2
# State (14, 20): Action = Agent 2
# State (15, 0): Action = Agent 1
# State (15, 1): Action = Agent 2
# State (15, 2): Action = Agent 2
# State (15, 3): Action = Agent 2
# State (15, 4): Action = Agent 2
# State (15, 5): Action = Agent 2
# State (15, 6): Action = Agent 2
# State (15, 7): Action = Agent 2
# State (15, 8): Action = Agent 2
# State (15, 9): Action = Agent 2
# State (15, 10): Action = Agent 2
# State (15, 11): Action = Agent 2
# State (15, 12): Action = Agent 2
# State (15, 13): Action = Agent 2
# State (15, 14): Action = Agent 2
# State (15, 15): Action = Agent 2
# State (15, 16): Action = Agent 2
# State (15, 17): Action = Agent 2
# State (15, 18): Action = Agent 2
# State (15, 19): Action = Agent 2
# State (15, 20): Action = Agent 2
# State (16, 0): Action = Agent 1
# State (16, 1): Action = Agent 2
# State (16, 2): Action = Agent 2
# State (16, 3): Action = Agent 2
# State (16, 4): Action = Agent 2
# State (16, 5): Action = Agent 2
# State (16, 6): Action = Agent 2
# State (16, 7): Action = Agent 2
# State (16, 8): Action = Agent 2
# State (16, 9): Action = Agent 2
# State (16, 10): Action = Agent 2
# State (16, 11): Action = Agent 2
# State (16, 12): Action = Agent 2
# State (16, 13): Action = Agent 2
# State (16, 14): Action = Agent 2
# State (16, 15): Action = Agent 2
# State (16, 16): Action = Agent 2
# State (16, 17): Action = Agent 2
# State (16, 18): Action = Agent 2
# State (16, 19): Action = Agent 2
# State (16, 20): Action = Agent 2
# State (17, 0): Action = Agent 1
# State (17, 1): Action = Agent 2
# State (17, 2): Action = Agent 2
# State (17, 3): Action = Agent 2
# State (17, 4): Action = Agent 2
# State (17, 5): Action = Agent 2
# State (17, 6): Action = Agent 2
# State (17, 7): Action = Agent 2
# State (17, 8): Action = Agent 2
# State (17, 9): Action = Agent 2
# State (17, 10): Action = Agent 2
# State (17, 11): Action = Agent 2
# State (17, 12): Action = Agent 2
# State (17, 13): Action = Agent 2
# State (17, 14): Action = Agent 2
# State (17, 15): Action = Agent 2
# State (17, 16): Action = Agent 2
# State (17, 17): Action = Agent 2
# State (17, 18): Action = Agent 2
# State (17, 19): Action = Agent 2
# State (17, 20): Action = Agent 2
# State (18, 0): Action = Agent 1
# State (18, 1): Action = Agent 2
# State (18, 2): Action = Agent 2
# State (18, 3): Action = Agent 2
# State (18, 4): Action = Agent 2
# State (18, 5): Action = Agent 2
# State (18, 6): Action = Agent 2
# State (18, 7): Action = Agent 2
# State (18, 8): Action = Agent 2
# State (18, 9): Action = Agent 2
# State (18, 10): Action = Agent 2
# State (18, 11): Action = Agent 2
# State (18, 12): Action = Agent 2
# State (18, 13): Action = Agent 2
# State (18, 14): Action = Agent 2
# State (18, 15): Action = Agent 2
# State (18, 16): Action = Agent 2
# State (18, 17): Action = Agent 2
# State (18, 18): Action = Agent 2
# State (18, 19): Action = Agent 2
# State (18, 20): Action = Agent 2
# State (19, 0): Action = Agent 1
# State (19, 1): Action = Agent 2
# State (19, 2): Action = Agent 2
# State (19, 3): Action = Agent 2
# State (19, 4): Action = Agent 2
# State (19, 5): Action = Agent 2
# State (19, 6): Action = Agent 2
# State (19, 7): Action = Agent 2
# State (19, 8): Action = Agent 2
# State (19, 9): Action = Agent 2
# State (19, 10): Action = Agent 2
# State (19, 11): Action = Agent 2
# State (19, 12): Action = Agent 2
# State (19, 13): Action = Agent 2
# State (19, 14): Action = Agent 2
# State (19, 15): Action = Agent 2
# State (19, 16): Action = Agent 2
# State (19, 17): Action = Agent 2
# State (19, 18): Action = Agent 2
# State (19, 19): Action = Agent 2
# State (19, 20): Action = Agent 2
# State (20, 0): Action = Agent 1
# State (20, 1): Action = Agent 2
# State (20, 2): Action = Agent 2
# State (20, 3): Action = Agent 2
# State (20, 4): Action = Agent 2
# State (20, 5): Action = Agent 2
# State (20, 6): Action = Agent 2
# State (20, 7): Action = Agent 2
# State (20, 8): Action = Agent 2
# State (20, 9): Action = Agent 2
# State (20, 10): Action = Agent 2
# State (20, 11): Action = Agent 2
# State (20, 12): Action = Agent 2
# State (20, 13): Action = Agent 2
# State (20, 14): Action = Agent 2
# State (20, 15): Action = Agent 2
# State (20, 16): Action = Agent 2
# State (20, 17): Action = Agent 2
# State (20, 18): Action = Agent 2
# State (20, 19): Action = Agent 2
# State (20, 20): Action = Agent 2
#                       Metric  With Longest Waiting  Without Longest Waiting  Difference (Without - With)
# Total Waiting Time (minutes)           1398.773226               355.718399                 -1043.054827
#    Total Agent Overtime Cost            342.071980                 6.378444                  -335.693536
#       Total Customers Served            273.000000               239.000000                   -34.000000
#                Total Rewards         -27105.845206            -19280.096843                  7825.748363
#     Total Customers Rejected            110.000000               113.000000                     3.000000
