# %% [markdown]
# <a href="https://colab.research.google.com/github/kshero18/Research-Project/blob/main/Final_Research_Project_Code_Part_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# !pip install ace_tools
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)
# Collecting ace_tools
#   Downloading ace_tools-0.0-py3-none-any.whl.metadata (300 bytes)
# Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Installing collected packages: ace_tools
# Successfully installed ace_tools-0.0

# %%
import numpy as np
import simpy

# Define parameters
lambda_1 = 4  # Arrival rate for primary questions (customers per minute)
lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
mu_1 = 3      # Service rate for less experienced agent (customers per minute)
mu_2 = 4      # Service rate for more experienced agent (customers per minute)
M = 5         # Maximum number of calls in the system
T = 40        # Simulation time horizon in minutes
dt = 0.1

overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)


class CallCenter:
    def __init__(self, env, dt, use_longest_waiting=True):
        self.env = env
        self.dt = dt
        self.use_longest_waiting = use_longest_waiting
        self.queue_1 = simpy.Store(env)  # Queue for primary questions
        self.queue_2 = simpy.Store(env)  # Queue for complex questions
        self.agent_1 = simpy.Resource(env, capacity=1)
        self.agent_2 = simpy.Resource(env, capacity=1)
        self.total_waiting_time = 0
        self.total_agent_overtime_cost = 0  # Track only agent overtime costs
        self.customers_served = 0
        self.transition_counts = {}  # Track state transitions
        self.state_counts = {}  # Count visits to states
        self.total_rewards = 0

    def record_transition(self, current_state, next_state):
        """Records state transitions for computing probabilities."""
        self.transition_counts[(current_state, next_state)] = (
            self.transition_counts.get((current_state, next_state), 0) + 1
        )
        self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

    def calculate_transition_probabilities(self):
        """Calculates transition probabilities from recorded transitions."""
        probabilities = {}
        for (current_state, next_state), count in self.transition_counts.items():
            total_transitions_from_state = self.state_counts[current_state]
            probabilities[(current_state, next_state)] = count / total_transitions_from_state
        return probabilities

    def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
      with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
          yield request
          service_time = np.random.exponential(1 / service_rate)
          end_time = self.env.now + service_time  # Calculate when the service will end

          # Simulate the service time
          yield self.env.timeout(service_time)

          wait_time = self.env.now - arrival_time  # Calculate wait time
          self.total_waiting_time += wait_time

          # Initialize agent_overtime_cost to zero
          agent_overtime_cost = 0

          # Check for overtime due to working beyond T
          if end_time > T:
              overtime_hours = end_time - T
              agent_overtime_cost = overtime_hours * overtime_cost_rate
              self.total_agent_overtime_cost += agent_overtime_cost

          self.customers_served += 1

          next_state = (len(self.queue_1.items), len(self.queue_2.items))

          # Record the state transition
          self.record_transition(state, next_state)

          # Log details
          print(
              f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
              f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
              f"(Overtime cost: {agent_overtime_cost:.2f})"
          )
          print(f"    Transition: State {state} -> State {next_state}")

    def assign_customer(self):
        while True:
            if self.agent_1.count == 0 or self.agent_2.count == 0:
                queue, customer_type, arrival_time = self.select_customer()

                if queue is not None:
                    state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state
                    yield queue.get()

                    chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"
                    service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

                    # Start handling the customer
                    self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

            # Update rewards based on current queue lengths
            self.total_rewards += -(len(self.queue_1.items) + len(self.queue_2.items))

            yield self.env.timeout(dt)  # Allow other processes to run

    def select_customer(self):
        """Selects the customer based on the queue and waiting strategy."""
        if self.use_longest_waiting:
            return self.select_longest_waiting_customer()
        return self.select_first_come_first_served_customer()

    def select_longest_waiting_customer(self):
        """Select the longest waiting customer from the queues."""
        if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            customer_2, arrival_time_2 = self.queue_2.items[0]
            if arrival_time_1 <= arrival_time_2:
                return self.queue_1, customer_1, arrival_time_1
            else:
                return self.queue_2, customer_2, arrival_time_2
        elif len(self.queue_1.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            return self.queue_1, customer_1, arrival_time_1
        elif len(self.queue_2.items) > 0:
            customer_2, arrival_time_2 = self.queue_2.items[0]
            return self.queue_2, customer_2, arrival_time_2
        else:
            return None, None, None

    def select_first_come_first_served_customer(self):
        """Select the first customer from queue 1 or queue 2."""
        if len(self.queue_1.items) > 0:
            return self.queue_1, *self.queue_1.items[0]
        elif len(self.queue_2.items) > 0:
            return self.queue_2, *self.queue_2.items[0]
        return None, None, None

    def customer_arrival(self, customer_type, arrival_rate):
        while True:
            inter_arrival_time = np.random.exponential(1 / arrival_rate)
            yield self.env.timeout(inter_arrival_time)
            arrival_time = self.env.now

            if customer_type == 1:
                self.queue_1.put((customer_type, arrival_time))
            else:
                self.queue_2.put((customer_type, arrival_time))

            self.env.process(self.assign_customer())


def run_simulation(simulation_time, use_longest_waiting=True):
    env = simpy.Environment()
    call_center = CallCenter(env, dt, use_longest_waiting)

    env.process(call_center.customer_arrival(1, lambda_1))
    env.process(call_center.customer_arrival(2, lambda_2))

    env.run(until=simulation_time)

    print(f"\nTotal customers served: {call_center.customers_served}")
    print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
    print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
    print(f"Average waiting time per customer: "
          f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

    # Calculate and display transition probabilities
    probabilities = call_center.calculate_transition_probabilities()
    print("\nTransition Probabilities:")
    for (initial_state, final_state), prob in probabilities.items():
        print(f"  P({final_state} | {initial_state}) = {prob:.4f}")

    return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, probabilities


# Run the simulations
simulation_time = 60

# With longest waiting customer function
waiting_time_longest, agent_overtime_longest, served_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# Without longest waiting customer function
waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)

# Comparison of results
print("\nComparison of Waiting Times:")
print(f"With Longest Waiting Customer Function: {waiting_time_longest:.2f} minutes")
print(f"Without Longest Waiting Customer Function: {waiting_time_fcfs:.2f} minutes")
print(f"Difference in Waiting Time: {waiting_time_fcfs - waiting_time_longest:.2f} minutes")

print("\nComparison of Agent Overtime Costs:")
print(f"With Longest Waiting Customer Function: {agent_overtime_longest:.2f}")
print(f"Without Longest Waiting Customer Function: {agent_overtime_fcfs:.2f}")
print(f"Difference in Agent Overtime Cost: {agent_overtime_fcfs - agent_overtime_longest:.2f}")

#######################################################3

import pandas as pd

# Prepare the results for the table
results_data = {
    "Metric": [
        "Total Waiting Time (minutes)",
        "Total Agent Overtime Cost",
        "Total Customers Served"
    ],
    "With Longest Waiting": [
        waiting_time_longest,
        agent_overtime_longest,
        served_longest
    ],
    "Without Longest Waiting": [
        waiting_time_fcfs,
        agent_overtime_fcfs,
        served_fcfs
    ],
    "Difference (Without - With)": [
        waiting_time_fcfs - waiting_time_longest,
        agent_overtime_fcfs - agent_overtime_longest,
        served_fcfs - served_longest
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(results_data)

# Display the results as a table
print(results_df.to_string(index=False))
# Out:
# At time 1.16: Customer type 2 served by Agent 2 in 0.32 minutes, waited 0.32 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 0)
# At time 1.20: Customer type 2 served by Agent 1 in 0.64 minutes, waited 0.64 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 1.29: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.41 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (0, 0)
# At time 1.50: Customer type 1 served by Agent 1 in 0.26 minutes, waited 0.46 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.92: Customer type 1 served by Agent 2 in 0.22 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 2)
# At time 1.99: Customer type 1 served by Agent 1 in 0.39 minutes, waited 0.39 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 2)
# At time 2.08: Customer type 2 served by Agent 2 in 0.14 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 1)
# At time 2.08: Customer type 2 served by Agent 1 in 0.08 minutes, waited 0.18 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 1)
# At time 2.27: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.32 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 2.77: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 2.92: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.16 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 3.00: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 3.17: Customer type 2 served by Agent 1 in 0.75 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 3.27: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 3.34: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 1)
# At time 3.51: Customer type 2 served by Agent 1 in 0.17 minutes, waited 0.23 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 2)
# At time 3.55: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.19 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 3.69: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.43 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 2)
# At time 3.90: Customer type 2 served by Agent 2 in 0.20 minutes, waited 0.51 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (2, 2)
# At time 3.90: Customer type 2 served by Agent 1 in 0.35 minutes, waited 0.53 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 2)
# At time 3.98: Customer type 2 served by Agent 1 in 0.08 minutes, waited 0.41 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 1)
# At time 3.99: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 4.07: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.26 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 4.09: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.08 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 4.63: Customer type 2 served by Agent 1 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 4.73: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.33 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 2)
# At time 4.74: Customer type 1 served by Agent 2 in 0.84 minutes, waited 1.33 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (0, 2)
# At time 4.74: Customer type 2 served by Agent 2 in 0.00 minutes, waited 0.06 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 1)
# At time 4.82: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.17 minutes (Overtime cost: 0.00)
#     Transition: State (0, 3) -> State (0, 1)
# At time 4.87: Customer type 2 served by Agent 2 in 0.13 minutes, waited 0.14 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 5.17: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 2)
# At time 5.56: Customer type 2 served by Agent 1 in 0.73 minutes, waited 0.81 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 2)
# At time 5.71: Customer type 2 served by Agent 2 in 0.54 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (3, 1)
# At time 5.90: Customer type 2 served by Agent 1 in 0.35 minutes, waited 0.89 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 1)
# At time 5.91: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.79 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (1, 1)
# At time 5.94: Customer type 2 served by Agent 2 in 0.03 minutes, waited 0.43 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 6.13: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.69 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (1, 1)
# At time 6.18: Customer type 1 served by Agent 2 in 0.24 minutes, waited 0.62 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 6.56: Customer type 1 served by Agent 2 in 0.37 minutes, waited 0.46 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 2)
# At time 6.59: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.44 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 2)
# At time 6.60: Customer type 2 served by Agent 1 in 0.46 minutes, waited 0.55 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 1)
# At time 6.61: Customer type 2 served by Agent 2 in 0.02 minutes, waited 0.12 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 0)
# At time 6.71: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.12 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 6.86: Customer type 2 served by Agent 1 in 0.26 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 6.96: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.21 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 7.32: Customer type 1 served by Agent 1 in 0.46 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 7.35: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.26 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 7.42: Customer type 1 served by Agent 2 in 0.46 minutes, waited 0.51 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 7.51: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 7.79: Customer type 2 served by Agent 2 in 0.28 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 1)
# At time 7.82: Customer type 1 served by Agent 1 in 0.46 minutes, waited 0.63 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 7.94: Customer type 2 served by Agent 2 in 0.15 minutes, waited 0.42 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 8.06: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 8.38: Customer type 1 served by Agent 2 in 0.44 minutes, waited 0.47 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 1)
# At time 9.16: Customer type 1 served by Agent 2 in 0.78 minutes, waited 1.16 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (3, 1)
# At time 9.34: Customer type 2 served by Agent 1 in 1.28 minutes, waited 1.36 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (4, 1)
# At time 9.34: Customer type 2 served by Agent 2 in 0.18 minutes, waited 1.21 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (3, 1)
# At time 9.39: Customer type 1 served by Agent 1 in 0.05 minutes, waited 1.19 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (2, 2)
# At time 9.47: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.59 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (1, 3)
# At time 10.09: Customer type 1 served by Agent 2 in 0.62 minutes, waited 0.82 minutes (Overtime cost: 0.00)
#     Transition: State (1, 3) -> State (4, 6)
# At time 10.19: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.92 minutes (Overtime cost: 0.00)
#     Transition: State (4, 6) -> State (4, 5)
# At time 10.29: Customer type 1 served by Agent 1 in 0.90 minutes, waited 1.37 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (4, 4)
# At time 10.71: Customer type 2 served by Agent 1 in 0.41 minutes, waited 1.24 minutes (Overtime cost: 0.00)
#     Transition: State (4, 4) -> State (5, 3)
# At time 10.77: Customer type 2 served by Agent 2 in 0.57 minutes, waited 1.41 minutes (Overtime cost: 0.00)
#     Transition: State (4, 5) -> State (5, 2)
# At time 10.83: Customer type 1 served by Agent 2 in 0.06 minutes, waited 1.13 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (4, 2)
# At time 10.96: Customer type 1 served by Agent 2 in 0.13 minutes, waited 1.23 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (3, 2)
# At time 11.03: Customer type 2 served by Agent 1 in 0.32 minutes, waited 1.52 minutes (Overtime cost: 0.00)
#     Transition: State (5, 3) -> State (2, 2)
# At time 11.09: Customer type 2 served by Agent 1 in 0.06 minutes, waited 1.30 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 1)
# At time 11.16: Customer type 1 served by Agent 2 in 0.19 minutes, waited 1.40 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (1, 2)
# At time 11.64: Customer type 1 served by Agent 1 in 0.54 minutes, waited 1.79 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (3, 3)
# At time 11.74: Customer type 1 served by Agent 1 in 0.10 minutes, waited 1.21 minutes (Overtime cost: 0.00)
#     Transition: State (3, 3) -> State (3, 3)
# At time 12.02: Customer type 2 served by Agent 2 in 0.86 minutes, waited 2.01 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (4, 4)
# At time 12.40: Customer type 2 served by Agent 1 in 0.66 minutes, waited 1.25 minutes (Overtime cost: 0.00)
#     Transition: State (3, 3) -> State (8, 4)
# At time 12.56: Customer type 1 served by Agent 2 in 0.54 minutes, waited 1.23 minutes (Overtime cost: 0.00)
#     Transition: State (4, 4) -> State (7, 4)
# At time 12.67: Customer type 2 served by Agent 2 in 0.11 minutes, waited 1.21 minutes (Overtime cost: 0.00)
#     Transition: State (7, 4) -> State (7, 3)
# At time 12.70: Customer type 1 served by Agent 1 in 0.30 minutes, waited 1.29 minutes (Overtime cost: 0.00)
#     Transition: State (8, 4) -> State (7, 2)
# At time 12.96: Customer type 2 served by Agent 2 in 0.29 minutes, waited 1.45 minutes (Overtime cost: 0.00)
#     Transition: State (7, 3) -> State (6, 2)
# At time 13.01: Customer type 2 served by Agent 2 in 0.05 minutes, waited 1.24 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (6, 2)
# At time 13.07: Customer type 1 served by Agent 2 in 0.06 minutes, waited 1.29 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (5, 2)
# At time 13.61: Customer type 1 served by Agent 1 in 0.91 minutes, waited 1.96 minutes (Overtime cost: 0.00)
#     Transition: State (7, 2) -> State (5, 2)
# At time 13.94: Customer type 1 served by Agent 1 in 0.33 minutes, waited 1.87 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (7, 2)
# At time 14.00: Customer type 1 served by Agent 1 in 0.06 minutes, waited 1.86 minutes (Overtime cost: 0.00)
#     Transition: State (7, 2) -> State (6, 2)
# At time 14.11: Customer type 2 served by Agent 2 in 1.03 minutes, waited 2.27 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (6, 2)
# At time 14.37: Customer type 1 served by Agent 2 in 0.27 minutes, waited 2.06 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (7, 3)
# At time 14.45: Customer type 1 served by Agent 2 in 0.08 minutes, waited 2.05 minutes (Overtime cost: 0.00)
#     Transition: State (7, 3) -> State (6, 3)
# At time 14.53: Customer type 2 served by Agent 2 in 0.08 minutes, waited 1.53 minutes (Overtime cost: 0.00)
#     Transition: State (6, 3) -> State (6, 2)
# At time 14.64: Customer type 1 served by Agent 1 in 0.63 minutes, waited 2.37 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (6, 1)
# At time 14.66: Customer type 2 served by Agent 2 in 0.13 minutes, waited 1.51 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (5, 1)
# At time 14.73: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.98 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (4, 1)
# At time 14.74: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.93 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (3, 1)
# At time 14.90: Customer type 1 served by Agent 1 in 0.26 minutes, waited 1.20 minutes (Overtime cost: 0.00)
#     Transition: State (6, 1) -> State (2, 1)
# At time 15.03: Customer type 1 served by Agent 2 in 0.29 minutes, waited 1.03 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 0)
# At time 15.08: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.85 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 15.34: Customer type 1 served by Agent 2 in 0.26 minutes, waited 1.02 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 15.37: Customer type 2 served by Agent 1 in 0.47 minutes, waited 1.17 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (0, 0)
# At time 15.56: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 1)
# At time 15.56: Customer type 2 served by Agent 2 in 0.22 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 1)
# At time 15.64: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.19 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (0, 1)
# At time 15.64: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.16 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 1)
# At time 15.75: Customer type 2 served by Agent 1 in 0.11 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 15.92: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 16.57: Customer type 2 served by Agent 2 in 0.14 minutes, waited 0.14 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 1)
# At time 16.69: Customer type 1 served by Agent 1 in 0.51 minutes, waited 0.51 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 16.83: Customer type 2 served by Agent 2 in 0.26 minutes, waited 0.33 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (2, 0)
# At time 16.97: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.37 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 16.98: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.23 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.12: Customer type 1 served by Agent 1 in 0.42 minutes, waited 0.60 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 2)
# At time 17.15: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.16 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 1)
# At time 17.21: Customer type 1 served by Agent 2 in 0.22 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 17.22: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.21 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 17.29: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 17.42: Customer type 1 served by Agent 1 in 0.12 minutes, waited 0.16 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.45: Customer type 1 served by Agent 2 in 0.22 minutes, waited 0.24 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.88: Customer type 1 served by Agent 1 in 0.37 minutes, waited 0.37 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 17.96: Customer type 1 served by Agent 2 in 0.35 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 18.09: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.14 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 18.42: Customer type 1 served by Agent 1 in 0.53 minutes, waited 0.53 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 18.65: Customer type 2 served by Agent 2 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 18.68: Customer type 2 served by Agent 1 in 0.25 minutes, waited 0.25 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 18.93: Customer type 1 served by Agent 1 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 18.97: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 19.05: Customer type 1 served by Agent 2 in 0.40 minutes, waited 0.61 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 19.46: Customer type 2 served by Agent 1 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 19.79: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 20.17: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 20.39: Customer type 2 served by Agent 2 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 0)
# At time 20.45: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.30 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 20.78: Customer type 1 served by Agent 2 in 0.40 minutes, waited 0.56 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (0, 2)
# At time 20.97: Customer type 2 served by Agent 2 in 0.18 minutes, waited 0.55 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 1)
# At time 21.04: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.59 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 21.18: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 21.44: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.33 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 21.79: Customer type 1 served by Agent 1 in 1.35 minutes, waited 1.52 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 0)
# At time 22.08: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 1)
# At time 22.52: Customer type 1 served by Agent 1 in 0.67 minutes, waited 0.67 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 2)
# At time 22.69: Customer type 2 served by Agent 2 in 0.61 minutes, waited 0.69 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 4)
# At time 22.70: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.61 minutes (Overtime cost: 0.00)
#     Transition: State (1, 4) -> State (0, 4)
# At time 22.85: Customer type 2 served by Agent 2 in 0.15 minutes, waited 0.66 minutes (Overtime cost: 0.00)
#     Transition: State (0, 4) -> State (0, 4)
# At time 22.96: Customer type 2 served by Agent 2 in 0.12 minutes, waited 0.53 minutes (Overtime cost: 0.00)
#     Transition: State (0, 4) -> State (0, 3)
# At time 23.04: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.41 minutes (Overtime cost: 0.00)
#     Transition: State (0, 3) -> State (0, 2)
# At time 23.13: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.46 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (1, 1)
# At time 23.18: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 23.30: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 23.54: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 1)
# At time 24.18: Customer type 1 served by Agent 1 in 1.66 minutes, waited 2.18 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 2)
# At time 24.21: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 2)
# At time 24.28: Customer type 1 served by Agent 2 in 0.74 minutes, waited 0.86 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (4, 1)
# At time 24.75: Customer type 2 served by Agent 2 in 0.47 minutes, waited 0.84 minutes (Overtime cost: 0.00)
#     Transition: State (4, 1) -> State (6, 2)
# At time 24.89: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.93 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (6, 2)
# At time 24.90: Customer type 2 served by Agent 1 in 0.69 minutes, waited 1.38 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (5, 2)
# At time 24.98: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.73 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (4, 2)
# At time 25.19: Customer type 1 served by Agent 2 in 0.30 minutes, waited 0.99 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (3, 2)
# At time 25.25: Customer type 1 served by Agent 1 in 0.26 minutes, waited 0.97 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (3, 1)
# At time 25.25: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.79 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (3, 0)
# At time 25.82: Customer type 2 served by Agent 2 in 0.63 minutes, waited 1.37 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (5, 1)
# At time 25.97: Customer type 1 served by Agent 1 in 0.71 minutes, waited 1.39 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (7, 1)
# At time 26.01: Customer type 1 served by Agent 2 in 0.19 minutes, waited 1.33 minutes (Overtime cost: 0.00)
#     Transition: State (5, 1) -> State (6, 1)
# At time 26.53: Customer type 1 served by Agent 1 in 0.56 minutes, waited 1.73 minutes (Overtime cost: 0.00)
#     Transition: State (7, 1) -> State (7, 1)
# At time 26.80: Customer type 1 served by Agent 2 in 0.78 minutes, waited 1.47 minutes (Overtime cost: 0.00)
#     Transition: State (6, 1) -> State (7, 2)
# At time 26.99: Customer type 1 served by Agent 1 in 0.46 minutes, waited 1.58 minutes (Overtime cost: 0.00)
#     Transition: State (7, 1) -> State (6, 2)
# At time 27.25: Customer type 1 served by Agent 2 in 0.45 minutes, waited 1.68 minutes (Overtime cost: 0.00)
#     Transition: State (7, 2) -> State (7, 2)
# At time 27.29: Customer type 2 served by Agent 1 in 0.29 minutes, waited 1.60 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (6, 2)
# At time 27.47: Customer type 1 served by Agent 1 in 0.18 minutes, waited 1.54 minutes (Overtime cost: 0.00)
#     Transition: State (6, 2) -> State (5, 2)
# At time 27.72: Customer type 1 served by Agent 2 in 0.47 minutes, waited 1.86 minutes (Overtime cost: 0.00)
#     Transition: State (7, 2) -> State (6, 3)
# At time 27.88: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.49 minutes (Overtime cost: 0.00)
#     Transition: State (6, 3) -> State (6, 3)
# At time 27.94: Customer type 1 served by Agent 2 in 0.06 minutes, waited 1.54 minutes (Overtime cost: 0.00)
#     Transition: State (6, 3) -> State (5, 3)
# At time 28.00: Customer type 1 served by Agent 1 in 0.54 minutes, waited 2.08 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (5, 2)
# At time 28.01: Customer type 2 served by Agent 2 in 0.07 minutes, waited 1.27 minutes (Overtime cost: 0.00)
#     Transition: State (5, 3) -> State (4, 2)
# At time 28.03: Customer type 1 served by Agent 2 in 0.02 minutes, waited 1.01 minutes (Overtime cost: 0.00)
#     Transition: State (4, 2) -> State (3, 2)
# At time 28.16: Customer type 2 served by Agent 2 in 0.13 minutes, waited 1.06 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (6, 1)
# At time 28.17: Customer type 1 served by Agent 1 in 0.16 minutes, waited 1.42 minutes (Overtime cost: 0.00)
#     Transition: State (5, 2) -> State (6, 0)
# At time 28.37: Customer type 2 served by Agent 2 in 0.21 minutes, waited 0.88 minutes (Overtime cost: 0.00)
#     Transition: State (6, 1) -> State (5, 0)
# At time 28.39: Customer type 1 served by Agent 1 in 0.23 minutes, waited 0.84 minutes (Overtime cost: 0.00)
#     Transition: State (6, 0) -> State (4, 0)
# At time 28.40: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.75 minutes (Overtime cost: 0.00)
#     Transition: State (5, 0) -> State (3, 0)
# At time 28.70: Customer type 1 served by Agent 1 in 0.31 minutes, waited 0.95 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (3, 1)
# At time 28.74: Customer type 1 served by Agent 2 in 0.34 minutes, waited 0.67 minutes (Overtime cost: 0.00)
#     Transition: State (3, 0) -> State (2, 1)
# At time 28.84: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.77 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (3, 2)
# At time 29.00: Customer type 1 served by Agent 2 in 0.25 minutes, waited 0.91 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (3, 1)
# At time 29.05: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.42 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 2)
# At time 29.09: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.30 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 29.14: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 1)
# At time 29.31: Customer type 2 served by Agent 1 in 0.47 minutes, waited 0.79 minutes (Overtime cost: 0.00)
#     Transition: State (3, 2) -> State (0, 3)
# At time 29.39: Customer type 2 served by Agent 1 in 0.08 minutes, waited 0.38 minutes (Overtime cost: 0.00)
#     Transition: State (0, 3) -> State (0, 2)
# At time 29.58: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.43 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 1)
# At time 29.61: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.39 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 1)
# At time 29.70: Customer type 1 served by Agent 2 in 0.56 minutes, waited 0.88 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 0)
# At time 29.96: Customer type 2 served by Agent 1 in 0.35 minutes, waited 0.36 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 30.09: Customer type 1 served by Agent 1 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.84: Customer type 1 served by Agent 1 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 31.43: Customer type 1 served by Agent 2 in 1.50 minutes, waited 1.50 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (4, 0)
# At time 31.47: Customer type 2 served by Agent 1 in 0.64 minutes, waited 0.74 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (4, 0)
# At time 31.56: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.68 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (3, 1)
# At time 31.69: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.87 minutes (Overtime cost: 0.00)
#     Transition: State (4, 0) -> State (2, 2)
# At time 31.76: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 31.79: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (2, 2)
# At time 31.82: Customer type 1 served by Agent 1 in 0.26 minutes, waited 0.67 minutes (Overtime cost: 0.00)
#     Transition: State (3, 1) -> State (2, 1)
# At time 31.88: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.40 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (2, 0)
# At time 31.94: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.31 minutes (Overtime cost: 0.00)
#     Transition: State (2, 1) -> State (1, 0)
# At time 31.95: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.18 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (0, 0)
# At time 31.99: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 32.01: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.02 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 32.24: Customer type 2 served by Agent 2 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 32.34: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 32.46: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 33.04: Customer type 1 served by Agent 2 in 0.59 minutes, waited 0.59 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 2)
# At time 33.11: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (0, 2)
# At time 33.16: Customer type 2 served by Agent 2 in 0.04 minutes, waited 0.31 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 1)
# At time 33.21: Customer type 2 served by Agent 1 in 0.74 minutes, waited 0.74 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 33.47: Customer type 2 served by Agent 2 in 0.31 minutes, waited 0.54 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 33.74: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 33.79: Customer type 2 served by Agent 1 in 0.49 minutes, waited 0.49 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.15: Customer type 1 served by Agent 2 in 0.41 minutes, waited 0.44 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 1)
# At time 34.43: Customer type 1 served by Agent 2 in 0.28 minutes, waited 0.42 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (0, 1)
# At time 34.48: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.33 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 1)
# At time 34.60: Customer type 1 served by Agent 1 in 0.76 minutes, waited 0.76 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 34.64: Customer type 2 served by Agent 2 in 0.16 minutes, waited 0.17 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 34.87: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.30 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 35.23: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 35.51: Customer type 1 served by Agent 2 in 0.30 minutes, waited 0.30 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 1)
# At time 35.61: Customer type 1 served by Agent 1 in 0.37 minutes, waited 0.40 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 35.77: Customer type 2 served by Agent 2 in 0.26 minutes, waited 0.37 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 35.96: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 35.97: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.05 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (1, 0)
# At time 35.97: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.05 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 35.98: Customer type 1 served by Agent 1 in 0.25 minutes, waited 0.25 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 36.15: Customer type 2 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 36.38: Customer type 2 served by Agent 1 in 0.22 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 36.58: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 1)
# At time 36.61: Customer type 2 served by Agent 2 in 0.18 minutes, waited 0.18 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (1, 0)
# At time 36.62: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.08 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 36.96: Customer type 2 served by Agent 1 in 0.38 minutes, waited 0.42 minutes (Overtime cost: 0.00)
#     Transition: State (1, 1) -> State (1, 0)
# At time 37.14: Customer type 1 served by Agent 1 in 0.18 minutes, waited 0.20 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 37.49: Customer type 1 served by Agent 2 in 0.58 minutes, waited 0.58 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (2, 0)
# At time 37.70: Customer type 1 served by Agent 2 in 0.20 minutes, waited 0.35 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 2)
# At time 37.85: Customer type 1 served by Agent 2 in 0.15 minutes, waited 0.37 minutes (Overtime cost: 0.00)
#     Transition: State (2, 2) -> State (1, 2)
# At time 37.94: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.44 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (1, 2)
# At time 37.97: Customer type 2 served by Agent 1 in 0.71 minutes, waited 0.71 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 2)
# At time 38.02: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.51 minutes (Overtime cost: 0.00)
#     Transition: State (1, 2) -> State (0, 1)
# At time 38.04: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.50 minutes (Overtime cost: 0.00)
#     Transition: State (0, 2) -> State (0, 0)
# At time 38.09: Customer type 2 served by Agent 2 in 0.07 minutes, waited 0.22 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (0, 0)
# At time 38.25: Customer type 2 served by Agent 1 in 0.18 minutes, waited 0.18 minutes (Overtime cost: 0.00)
#     Transition: State (0, 1) -> State (2, 0)
# At time 38.36: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.19 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (2, 0)
# At time 38.48: Customer type 1 served by Agent 2 in 0.36 minutes, waited 0.36 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (1, 0)
# At time 38.85: Customer type 1 served by Agent 2 in 0.37 minutes, waited 0.52 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 38.89: Customer type 1 served by Agent 1 in 0.52 minutes, waited 0.65 minutes (Overtime cost: 0.00)
#     Transition: State (2, 0) -> State (0, 0)
# At time 39.09: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 39.75: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.07 minutes (Overtime cost: 0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 40.03: Customer type 2 served by Agent 2 in 0.22 minutes, waited 0.22 minutes (Overtime cost: 0.03)
#     Transition: State (0, 1) -> State (0, 1)
# At time 40.24: Customer type 1 served by Agent 1 in 0.56 minutes, waited 0.56 minutes (Overtime cost: 0.24)
#     Transition: State (1, 0) -> State (0, 0)
# At time 40.55: Customer type 2 served by Agent 2 in 0.52 minutes, waited 0.66 minutes (Overtime cost: 0.55)
#     Transition: State (0, 1) -> State (1, 0)
# At time 41.01: Customer type 1 served by Agent 2 in 0.46 minutes, waited 0.47 minutes (Overtime cost: 1.01)
#     Transition: State (1, 0) -> State (3, 0)
# At time 41.07: Customer type 1 served by Agent 1 in 0.61 minutes, waited 0.61 minutes (Overtime cost: 1.07)
#     Transition: State (1, 0) -> State (2, 0)
# At time 41.23: Customer type 1 served by Agent 2 in 0.22 minutes, waited 0.39 minutes (Overtime cost: 1.23)
#     Transition: State (3, 0) -> State (3, 1)
# At time 41.59: Customer type 1 served by Agent 2 in 0.36 minutes, waited 0.64 minutes (Overtime cost: 1.59)
#     Transition: State (3, 1) -> State (4, 4)
# At time 41.62: Customer type 1 served by Agent 1 in 0.55 minutes, waited 0.78 minutes (Overtime cost: 1.62)
#     Transition: State (2, 0) -> State (4, 3)
# At time 41.76: Customer type 2 served by Agent 2 in 0.16 minutes, waited 0.68 minutes (Overtime cost: 1.76)
#     Transition: State (4, 4) -> State (3, 3)
# At time 41.90: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.73 minutes (Overtime cost: 1.90)
#     Transition: State (3, 3) -> State (2, 3)
# At time 42.00: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.71 minutes (Overtime cost: 2.00)
#     Transition: State (2, 3) -> State (2, 2)
# At time 42.02: Customer type 1 served by Agent 1 in 0.40 minutes, waited 0.89 minutes (Overtime cost: 2.02)
#     Transition: State (4, 3) -> State (1, 2)
# At time 42.17: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.79 minutes (Overtime cost: 2.17)
#     Transition: State (1, 2) -> State (0, 2)
# At time 42.44: Customer type 1 served by Agent 2 in 0.44 minutes, waited 1.11 minutes (Overtime cost: 2.44)
#     Transition: State (2, 2) -> State (0, 4)
# At time 42.44: Customer type 2 served by Agent 1 in 0.27 minutes, waited 0.96 minutes (Overtime cost: 2.44)
#     Transition: State (0, 2) -> State (0, 3)
# At time 42.83: Customer type 2 served by Agent 1 in 0.39 minutes, waited 0.44 minutes (Overtime cost: 2.83)
#     Transition: State (0, 3) -> State (0, 6)
# At time 42.85: Customer type 2 served by Agent 2 in 0.41 minutes, waited 1.31 minutes (Overtime cost: 2.85)
#     Transition: State (0, 4) -> State (0, 5)
# At time 42.91: Customer type 2 served by Agent 1 in 0.08 minutes, waited 0.51 minutes (Overtime cost: 2.91)
#     Transition: State (0, 6) -> State (0, 4)
# At time 42.94: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.52 minutes (Overtime cost: 2.94)
#     Transition: State (0, 5) -> State (1, 3)
# At time 43.03: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.49 minutes (Overtime cost: 3.03)
#     Transition: State (0, 4) -> State (3, 2)
# At time 43.08: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.32 minutes (Overtime cost: 3.08)
#     Transition: State (3, 2) -> State (3, 1)
# At time 43.11: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.33 minutes (Overtime cost: 3.11)
#     Transition: State (3, 1) -> State (3, 0)
# At time 43.32: Customer type 2 served by Agent 2 in 0.38 minutes, waited 0.68 minutes (Overtime cost: 3.32)
#     Transition: State (1, 3) -> State (3, 0)
# At time 43.40: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.47 minutes (Overtime cost: 3.40)
#     Transition: State (3, 0) -> State (2, 0)
# At time 43.43: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.40 minutes (Overtime cost: 3.43)
#     Transition: State (2, 0) -> State (1, 0)
# At time 43.55: Customer type 1 served by Agent 2 in 0.23 minutes, waited 0.61 minutes (Overtime cost: 3.55)
#     Transition: State (3, 0) -> State (0, 0)
# At time 43.57: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.41 minutes (Overtime cost: 3.57)
#     Transition: State (1, 0) -> State (0, 0)
# At time 44.29: Customer type 1 served by Agent 1 in 0.47 minutes, waited 0.47 minutes (Overtime cost: 4.29)
#     Transition: State (1, 0) -> State (2, 1)
# At time 44.64: Customer type 1 served by Agent 2 in 0.48 minutes, waited 0.48 minutes (Overtime cost: 4.64)
#     Transition: State (1, 0) -> State (1, 1)
# At time 44.88: Customer type 1 served by Agent 1 in 0.60 minutes, waited 0.66 minutes (Overtime cost: 4.88)
#     Transition: State (2, 1) -> State (1, 1)
# At time 44.97: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.69 minutes (Overtime cost: 4.97)
#     Transition: State (1, 1) -> State (2, 0)
# At time 45.05: Customer type 1 served by Agent 2 in 0.41 minutes, waited 0.79 minutes (Overtime cost: 5.05)
#     Transition: State (1, 1) -> State (1, 0)
# At time 45.06: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.34 minutes (Overtime cost: 5.06)
#     Transition: State (2, 0) -> State (0, 0)
# At time 45.12: Customer type 1 served by Agent 2 in 0.07 minutes, waited 0.17 minutes (Overtime cost: 5.12)
#     Transition: State (1, 0) -> State (0, 0)
# At time 45.32: Customer type 2 served by Agent 1 in 0.16 minutes, waited 0.16 minutes (Overtime cost: 5.32)
#     Transition: State (0, 1) -> State (0, 0)
# At time 45.51: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 5.51)
#     Transition: State (1, 0) -> State (0, 0)
# At time 45.69: Customer type 1 served by Agent 1 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 5.69)
#     Transition: State (1, 0) -> State (1, 0)
# At time 45.84: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.26 minutes (Overtime cost: 5.84)
#     Transition: State (1, 0) -> State (1, 0)
# At time 45.95: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.18 minutes (Overtime cost: 5.95)
#     Transition: State (1, 0) -> State (0, 0)
# At time 46.50: Customer type 2 served by Agent 2 in 0.46 minutes, waited 0.46 minutes (Overtime cost: 6.50)
#     Transition: State (0, 1) -> State (2, 1)
# At time 46.54: Customer type 1 served by Agent 1 in 0.85 minutes, waited 0.88 minutes (Overtime cost: 6.54)
#     Transition: State (1, 0) -> State (1, 1)
# At time 46.92: Customer type 1 served by Agent 1 in 0.38 minutes, waited 0.57 minutes (Overtime cost: 6.92)
#     Transition: State (1, 1) -> State (4, 1)
# At time 47.04: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.68 minutes (Overtime cost: 7.04)
#     Transition: State (4, 1) -> State (7, 0)
# At time 47.06: Customer type 1 served by Agent 2 in 0.55 minutes, waited 0.72 minutes (Overtime cost: 7.06)
#     Transition: State (2, 1) -> State (6, 0)
# At time 47.10: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.50 minutes (Overtime cost: 7.10)
#     Transition: State (6, 0) -> State (5, 0)
# At time 47.21: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.61 minutes (Overtime cost: 7.21)
#     Transition: State (5, 0) -> State (4, 0)
# At time 47.37: Customer type 1 served by Agent 1 in 0.33 minutes, waited 0.78 minutes (Overtime cost: 7.37)
#     Transition: State (7, 0) -> State (3, 1)
# At time 47.48: Customer type 1 served by Agent 2 in 0.27 minutes, waited 0.65 minutes (Overtime cost: 7.48)
#     Transition: State (4, 0) -> State (2, 1)
# At time 47.53: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.55 minutes (Overtime cost: 7.53)
#     Transition: State (2, 1) -> State (1, 1)
# At time 47.88: Customer type 1 served by Agent 1 in 0.51 minutes, waited 0.94 minutes (Overtime cost: 7.88)
#     Transition: State (3, 1) -> State (3, 3)
# At time 48.01: Customer type 2 served by Agent 1 in 0.13 minutes, waited 0.79 minutes (Overtime cost: 8.01)
#     Transition: State (3, 3) -> State (3, 3)
# At time 48.03: Customer type 1 served by Agent 2 in 0.49 minutes, waited 0.99 minutes (Overtime cost: 8.03)
#     Transition: State (1, 1) -> State (2, 3)
# At time 48.29: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.75 minutes (Overtime cost: 8.29)
#     Transition: State (3, 3) -> State (3, 2)
# At time 48.31: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.73 minutes (Overtime cost: 8.31)
#     Transition: State (3, 2) -> State (2, 2)
# At time 48.74: Customer type 2 served by Agent 2 in 0.72 minutes, waited 1.18 minutes (Overtime cost: 8.74)
#     Transition: State (2, 3) -> State (5, 2)
# At time 49.01: Customer type 1 served by Agent 2 in 0.27 minutes, waited 1.25 minutes (Overtime cost: 9.01)
#     Transition: State (5, 2) -> State (5, 2)
# At time 49.15: Customer type 2 served by Agent 2 in 0.13 minutes, waited 1.18 minutes (Overtime cost: 9.15)
#     Transition: State (5, 2) -> State (5, 1)
# At time 49.16: Customer type 2 served by Agent 1 in 0.85 minutes, waited 1.55 minutes (Overtime cost: 9.16)
#     Transition: State (2, 2) -> State (4, 1)
# At time 49.18: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.86 minutes (Overtime cost: 9.18)
#     Transition: State (4, 1) -> State (3, 1)
# At time 49.47: Customer type 1 served by Agent 2 in 0.32 minutes, waited 1.24 minutes (Overtime cost: 9.47)
#     Transition: State (5, 1) -> State (3, 1)
# At time 49.63: Customer type 1 served by Agent 1 in 0.45 minutes, waited 1.27 minutes (Overtime cost: 9.63)
#     Transition: State (3, 1) -> State (4, 0)
# At time 49.64: Customer type 2 served by Agent 2 in 0.17 minutes, waited 0.97 minutes (Overtime cost: 9.64)
#     Transition: State (3, 1) -> State (3, 0)
# At time 50.21: Customer type 1 served by Agent 2 in 0.57 minutes, waited 1.34 minutes (Overtime cost: 10.21)
#     Transition: State (3, 0) -> State (3, 1)
# At time 50.38: Customer type 1 served by Agent 2 in 0.17 minutes, waited 1.01 minutes (Overtime cost: 10.38)
#     Transition: State (3, 1) -> State (2, 1)
# At time 50.52: Customer type 1 served by Agent 2 in 0.14 minutes, waited 1.01 minutes (Overtime cost: 10.52)
#     Transition: State (2, 1) -> State (3, 1)
# At time 50.61: Customer type 1 served by Agent 1 in 0.98 minutes, waited 1.88 minutes (Overtime cost: 10.61)
#     Transition: State (4, 0) -> State (2, 1)
# At time 50.65: Customer type 1 served by Agent 2 in 0.14 minutes, waited 0.86 minutes (Overtime cost: 10.65)
#     Transition: State (3, 1) -> State (2, 0)
# ...
#     Transition: State (0, 1) -> State (0, 0)
# At time 49.49: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 9.49)
#     Transition: State (0, 1) -> State (0, 0)
# At time 49.65: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.17 minutes (Overtime cost: 9.65)
#     Transition: State (1, 0) -> State (0, 0)
# At time 49.86: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 9.86)
#     Transition: State (1, 0) -> State (1, 0)
# At time 49.93: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.20 minutes (Overtime cost: 9.93)
#     Transition: State (1, 0) -> State (1, 0)
# At time 50.14: Customer type 1 served by Agent 2 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 10.14)
#     Transition: State (1, 0) -> State (1, 1)
# At time 50.23: Customer type 1 served by Agent 1 in 0.29 minutes, waited 0.30 minutes (Overtime cost: 10.23)
#     Transition: State (1, 0) -> State (0, 2)
# At time 50.31: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.36 minutes (Overtime cost: 10.31)
#     Transition: State (1, 1) -> State (0, 1)
# At time 50.36: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.21 minutes (Overtime cost: 10.36)
#     Transition: State (0, 1) -> State (0, 0)
# At time 50.47: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 10.47)
#     Transition: State (1, 0) -> State (0, 0)
# At time 50.49: Customer type 2 served by Agent 1 in 0.27 minutes, waited 0.44 minutes (Overtime cost: 10.49)
#     Transition: State (0, 2) -> State (0, 0)
# At time 50.64: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 10.64)
#     Transition: State (1, 0) -> State (0, 0)
# At time 50.68: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 10.68)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.25: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 11.25)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.77: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 11.77)
#     Transition: State (1, 0) -> State (0, 0)
# At time 51.89: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 11.89)
#     Transition: State (0, 1) -> State (0, 0)
# At time 52.15: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.05 minutes (Overtime cost: 12.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 52.15: Customer type 1 served by Agent 1 in 0.56 minutes, waited 0.56 minutes (Overtime cost: 12.15)
#     Transition: State (1, 0) -> State (0, 0)
# At time 52.75: Customer type 1 served by Agent 1 in 0.48 minutes, waited 0.48 minutes (Overtime cost: 12.75)
#     Transition: State (1, 0) -> State (2, 2)
# At time 52.83: Customer type 2 served by Agent 2 in 0.38 minutes, waited 0.38 minutes (Overtime cost: 12.83)
#     Transition: State (0, 1) -> State (1, 3)
# At time 52.91: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.18 minutes (Overtime cost: 12.91)
#     Transition: State (1, 3) -> State (0, 3)
# At time 52.96: Customer type 2 served by Agent 2 in 0.04 minutes, waited 0.42 minutes (Overtime cost: 12.96)
#     Transition: State (0, 3) -> State (0, 2)
# At time 53.12: Customer type 2 served by Agent 2 in 0.16 minutes, waited 0.43 minutes (Overtime cost: 13.12)
#     Transition: State (0, 2) -> State (1, 2)
# At time 53.12: Customer type 1 served by Agent 1 in 0.37 minutes, waited 0.56 minutes (Overtime cost: 13.12)
#     Transition: State (2, 2) -> State (0, 2)
# At time 53.57: Customer type 2 served by Agent 1 in 0.45 minutes, waited 0.82 minutes (Overtime cost: 13.57)
#     Transition: State (0, 2) -> State (2, 1)
# At time 53.66: Customer type 1 served by Agent 2 in 0.54 minutes, waited 0.66 minutes (Overtime cost: 13.66)
#     Transition: State (1, 2) -> State (2, 2)
# At time 53.75: Customer type 1 served by Agent 1 in 0.18 minutes, waited 0.27 minutes (Overtime cost: 13.75)
#     Transition: State (2, 1) -> State (1, 3)
# At time 53.83: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.34 minutes (Overtime cost: 13.83)
#     Transition: State (2, 2) -> State (0, 3)
# At time 54.42: Customer type 2 served by Agent 2 in 0.59 minutes, waited 1.36 minutes (Overtime cost: 14.42)
#     Transition: State (0, 3) -> State (2, 3)
# At time 54.54: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.66 minutes (Overtime cost: 14.54)
#     Transition: State (2, 3) -> State (1, 3)
# At time 54.75: Customer type 1 served by Agent 1 in 1.00 minutes, waited 1.12 minutes (Overtime cost: 14.75)
#     Transition: State (1, 3) -> State (2, 4)
# At time 55.30: Customer type 1 served by Agent 2 in 0.76 minutes, waited 1.35 minutes (Overtime cost: 15.30)
#     Transition: State (1, 3) -> State (2, 6)
# At time 55.31: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.68 minutes (Overtime cost: 15.31)
#     Transition: State (2, 6) -> State (1, 6)
# At time 55.41: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.28 minutes (Overtime cost: 15.41)
#     Transition: State (1, 6) -> State (0, 6)
# At time 55.73: Customer type 1 served by Agent 1 in 0.97 minutes, waited 1.10 minutes (Overtime cost: 15.73)
#     Transition: State (2, 4) -> State (0, 6)
# At time 55.87: Customer type 2 served by Agent 2 in 0.46 minutes, waited 2.27 minutes (Overtime cost: 15.87)
#     Transition: State (0, 6) -> State (0, 5)
# At time 55.93: Customer type 2 served by Agent 1 in 0.20 minutes, waited 2.24 minutes (Overtime cost: 15.93)
#     Transition: State (0, 6) -> State (0, 4)
# At time 56.07: Customer type 2 served by Agent 2 in 0.19 minutes, waited 1.86 minutes (Overtime cost: 16.07)
#     Transition: State (0, 5) -> State (0, 3)
# At time 56.28: Customer type 2 served by Agent 1 in 0.34 minutes, waited 1.60 minutes (Overtime cost: 16.28)
#     Transition: State (0, 4) -> State (1, 2)
# At time 56.34: Customer type 2 served by Agent 2 in 0.27 minutes, waited 1.16 minutes (Overtime cost: 16.34)
#     Transition: State (0, 3) -> State (0, 2)
# At time 56.50: Customer type 1 served by Agent 1 in 0.22 minutes, waited 0.32 minutes (Overtime cost: 16.50)
#     Transition: State (1, 2) -> State (0, 2)
# At time 56.75: Customer type 2 served by Agent 2 in 0.41 minutes, waited 1.48 minutes (Overtime cost: 16.75)
#     Transition: State (0, 2) -> State (1, 2)
# At time 56.80: Customer type 2 served by Agent 1 in 0.30 minutes, waited 1.22 minutes (Overtime cost: 16.80)
#     Transition: State (0, 2) -> State (0, 2)
# At time 56.87: Customer type 2 served by Agent 1 in 0.07 minutes, waited 0.39 minutes (Overtime cost: 16.87)
#     Transition: State (0, 2) -> State (0, 1)
# At time 56.91: Customer type 2 served by Agent 1 in 0.05 minutes, waited 0.29 minutes (Overtime cost: 16.91)
#     Transition: State (0, 1) -> State (0, 0)
# At time 57.08: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 17.08)
#     Transition: State (1, 0) -> State (0, 0)
# At time 57.24: Customer type 1 served by Agent 2 in 0.49 minutes, waited 0.62 minutes (Overtime cost: 17.24)
#     Transition: State (1, 2) -> State (0, 0)
# At time 57.40: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.15 minutes (Overtime cost: 17.40)
#     Transition: State (1, 0) -> State (0, 0)
# At time 57.70: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 17.70)
#     Transition: State (1, 0) -> State (0, 0)
# At time 58.13: Customer type 2 served by Agent 1 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 18.13)
#     Transition: State (0, 1) -> State (0, 0)
# At time 58.46: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 18.46)
#     Transition: State (1, 0) -> State (0, 1)
# At time 58.67: Customer type 2 served by Agent 2 in 0.21 minutes, waited 0.27 minutes (Overtime cost: 18.67)
#     Transition: State (0, 1) -> State (0, 1)
# At time 58.70: Customer type 2 served by Agent 2 in 0.02 minutes, waited 0.12 minutes (Overtime cost: 18.70)
#     Transition: State (0, 1) -> State (0, 0)
# At time 59.06: Customer type 1 served by Agent 1 in 0.91 minutes, waited 0.91 minutes (Overtime cost: 19.06)
#     Transition: State (1, 0) -> State (0, 0)
# At time 59.18: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 19.18)
#     Transition: State (1, 0) -> State (0, 0)
# At time 59.36: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 19.36)
#     Transition: State (0, 1) -> State (0, 0)
# At time 59.63: Customer type 1 served by Agent 1 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 19.63)
#     Transition: State (1, 0) -> State (0, 0)
# At time 59.65: Customer type 2 served by Agent 2 in 0.02 minutes, waited 0.02 minutes (Overtime cost: 19.65)
#     Transition: State (0, 1) -> State (0, 0)
#
# Total customers served: 366
# Total waiting time: 289.08 minutes
# Total agent overtime cost: 1134.21 minutes
# Average waiting time per customer: 0.79 minutes
#
# Transition Probabilities:
#   P((0, 0) | (0, 1)) = 0.5532
#   P((0, 0) | (1, 0)) = 0.5294
#   P((2, 0) | (1, 0)) = 0.0294
#   P((1, 0) | (2, 0)) = 0.3333
#   P((0, 1) | (1, 0)) = 0.1324
#   P((1, 0) | (1, 1)) = 0.0556
#   P((3, 0) | (2, 0)) = 0.1667
#   P((4, 1) | (3, 0)) = 0.2500
#   P((3, 1) | (0, 1)) = 0.0426
#   P((3, 2) | (3, 1)) = 0.2500
#   P((4, 3) | (3, 2)) = 0.5000
#   P((3, 4) | (4, 3)) = 0.6000
#   P((2, 6) | (3, 4)) = 0.1250
#   P((2, 6) | (4, 1)) = 1.0000
#   P((1, 6) | (2, 6)) = 0.6667
#   P((1, 6) | (1, 6)) = 0.2143
#   P((0, 6) | (2, 6)) = 0.1667
#   P((0, 5) | (1, 6)) = 0.1429
#   P((1, 4) | (0, 6)) = 0.1000
#   P((3, 4) | (1, 4)) = 0.1111
#   P((2, 4) | (3, 4)) = 0.1250
#   P((1, 4) | (0, 5)) = 0.2500
#   P((1, 4) | (2, 4)) = 0.3333
#   P((0, 3) | (1, 4)) = 0.1111
#   P((4, 3) | (0, 4)) = 0.0769
#   P((3, 3) | (4, 3)) = 0.4000
#   P((2, 3) | (0, 3)) = 0.1333
#   P((1, 3) | (3, 3)) = 0.1667
#   P((0, 3) | (2, 3)) = 0.2000
#   P((3, 3) | (1, 3)) = 0.0625
#   P((3, 3) | (3, 3)) = 0.1667
#   P((2, 3) | (3, 3)) = 0.3333
#   P((1, 3) | (2, 3)) = 0.4000
#   P((1, 3) | (0, 3)) = 0.0667
#   P((0, 3) | (1, 3)) = 0.2500
#   P((0, 2) | (0, 3)) = 0.3333
#   P((0, 1) | (1, 3)) = 0.0625
#   P((0, 0) | (0, 2)) = 0.2222
#   P((2, 0) | (0, 1)) = 0.0426
#   P((1, 3) | (1, 0)) = 0.0147
#   P((0, 4) | (0, 1)) = 0.0213
#   P((0, 3) | (0, 4)) = 0.4615
#   P((1, 2) | (0, 3)) = 0.1333
#   P((1, 3) | (1, 3)) = 0.2500
#   P((0, 4) | (1, 2)) = 0.1429
#   P((1, 1) | (0, 2)) = 0.2222
#   P((5, 4) | (1, 1)) = 0.0556
#   P((4, 4) | (5, 4)) = 0.5000
#   P((3, 4) | (1, 3)) = 0.0625
#   P((3, 4) | (3, 4)) = 0.2500
#   P((2, 4) | (4, 4)) = 0.6667
#   P((1, 5) | (2, 4)) = 0.1667
#   P((0, 5) | (3, 4)) = 0.1250
#   P((0, 4) | (0, 5)) = 0.1250
#   P((0, 4) | (0, 4)) = 0.1538
#   P((0, 1) | (1, 5)) = 0.1667
#   P((1, 0) | (0, 1)) = 0.1277
#   P((1, 0) | (1, 0)) = 0.1176
#   P((0, 1) | (0, 1)) = 0.0426
#   P((1, 1) | (1, 0)) = 0.0441
#   P((0, 1) | (1, 1)) = 0.2778
#   P((1, 1) | (0, 1)) = 0.0426
#   P((1, 1) | (1, 1)) = 0.2222
#   P((3, 0) | (1, 0)) = 0.0147
#   P((1, 0) | (3, 0)) = 0.5000
#   P((0, 0) | (2, 0)) = 0.1667
#   P((4, 0) | (1, 0)) = 0.0147
#   P((3, 1) | (4, 0)) = 1.0000
#   P((2, 2) | (0, 1)) = 0.0213
#   P((1, 3) | (3, 1)) = 0.2500
#   P((0, 2) | (2, 2)) = 0.4286
#   P((0, 1) | (0, 3)) = 0.1333
#   P((0, 0) | (1, 1)) = 0.1667
#   P((4, 3) | (1, 0)) = 0.0294
#   P((2, 5) | (3, 4)) = 0.1250
#   P((1, 5) | (3, 3)) = 0.1667
#   P((3, 5) | (1, 5)) = 0.1667
#   P((2, 5) | (3, 5)) = 0.3333
#   P((3, 5) | (2, 5)) = 0.2500
#   P((3, 6) | (2, 5)) = 0.2500
#   P((2, 6) | (3, 6)) = 1.0000
#   P((1, 6) | (3, 5)) = 0.3333
#   P((0, 6) | (1, 6)) = 0.3571
#   P((0, 4) | (0, 6)) = 0.2000
#   P((0, 2) | (1, 4)) = 0.2222
#   P((1, 1) | (1, 2)) = 0.1429
#   P((0, 2) | (1, 1)) = 0.1111
#   P((0, 1) | (0, 2)) = 0.2222
#   P((2, 1) | (0, 1)) = 0.0426
#   P((3, 1) | (2, 1)) = 0.1429
#   P((2, 1) | (3, 1)) = 0.5000
#   P((4, 2) | (1, 1)) = 0.0556
#   P((3, 2) | (2, 1)) = 0.1429
#   P((2, 2) | (3, 2)) = 0.5000
#   P((4, 3) | (2, 2)) = 0.1429
#   P((3, 4) | (4, 2)) = 1.0000
#   P((4, 4) | (3, 4)) = 0.1250
#   P((4, 4) | (4, 4)) = 0.3333
#   P((1, 4) | (3, 4)) = 0.1250
#   P((0, 4) | (2, 4)) = 0.3333
#   P((1, 3) | (0, 4)) = 0.1538
#   P((2, 2) | (0, 2)) = 0.0556
#   P((2, 2) | (2, 2)) = 0.1429
#   P((1, 2) | (2, 2)) = 0.1429
#   P((0, 2) | (1, 2)) = 0.2857
#   P((3, 3) | (0, 3)) = 0.0667
#   P((5, 4) | (3, 3)) = 0.1667
#   P((4, 5) | (0, 2)) = 0.0556
#   P((3, 5) | (5, 4)) = 0.5000
#   P((2, 5) | (4, 5)) = 1.0000
#   P((1, 5) | (3, 5)) = 0.3333
#   P((1, 5) | (2, 5)) = 0.2500
#   P((2, 5) | (1, 5)) = 0.1667
#   P((1, 6) | (2, 5)) = 0.2500
#   P((1, 5) | (0, 6)) = 0.1000
#   P((0, 5) | (1, 5)) = 0.1667
#   P((1, 4) | (1, 5)) = 0.1667
#   P((1, 4) | (1, 4)) = 0.1111
#   P((1, 5) | (0, 5)) = 0.1250
#   P((3, 7) | (1, 5)) = 0.1667
#   P((2, 7) | (3, 7)) = 1.0000
#   P((2, 7) | (1, 4)) = 0.1111
#   P((2, 8) | (2, 7)) = 0.3333
#   P((2, 9) | (2, 7)) = 0.3333
#   P((3, 10) | (2, 9)) = 1.0000
#   P((3, 11) | (2, 8)) = 0.3333
#   P((2, 11) | (3, 10)) = 0.5000
#   P((1, 11) | (3, 11)) = 1.0000
#   P((0, 11) | (1, 11)) = 1.0000
#   P((3, 10) | (0, 11)) = 1.0000
#   P((2, 10) | (2, 11)) = 1.0000
#   P((1, 10) | (2, 10)) = 1.0000
#   P((0, 10) | (3, 10)) = 0.5000
#   P((0, 9) | (0, 10)) = 0.5000
#   P((0, 8) | (0, 9)) = 0.5000
#   P((0, 7) | (0, 8)) = 0.3333
#   P((1, 6) | (1, 10)) = 1.0000
#   P((0, 7) | (1, 6)) = 0.0714
#   P((0, 6) | (0, 7)) = 0.6667
#   P((0, 5) | (0, 6)) = 0.3000
#   P((0, 4) | (0, 7)) = 0.3333
#   P((1, 3) | (0, 5)) = 0.1250
#   P((0, 3) | (0, 3)) = 0.0667
#   P((0, 2) | (1, 3)) = 0.0625
#   P((2, 1) | (0, 3)) = 0.0667
#   P((1, 1) | (2, 1)) = 0.2857
#   P((0, 1) | (2, 1)) = 0.1429
#   P((3, 0) | (0, 1)) = 0.0426
#   P((2, 1) | (2, 0)) = 0.1667
#   P((1, 1) | (3, 0)) = 0.2500
#   P((2, 2) | (1, 0)) = 0.0294
#   P((1, 2) | (1, 0)) = 0.0147
#   P((1, 0) | (1, 2)) = 0.1429
#   P((2, 3) | (2, 1)) = 0.1429
#   P((2, 3) | (1, 0)) = 0.0147
#   P((2, 6) | (2, 3)) = 0.2000
#   P((1, 6) | (2, 3)) = 0.2000
#   P((0, 6) | (0, 6)) = 0.1000
#   P((0, 5) | (2, 6)) = 0.1667
#   P((2, 4) | (0, 6)) = 0.1000
#   P((2, 4) | (0, 5)) = 0.1250
#   P((1, 3) | (1, 4)) = 0.1111
#   P((0, 4) | (1, 3)) = 0.0625
#   P((1, 4) | (0, 4)) = 0.0769
#   P((1, 6) | (1, 4)) = 0.1111
#   P((2, 6) | (1, 6)) = 0.0714
#   P((0, 6) | (1, 3)) = 0.0625
#   P((1, 6) | (0, 6)) = 0.1000
#   P((2, 7) | (1, 6)) = 0.0714
#   P((1, 7) | (2, 7)) = 0.3333
#   P((0, 8) | (1, 7)) = 1.0000
#   P((5, 7) | (0, 8)) = 0.3333
#   P((5, 7) | (5, 7)) = 0.5000
#   P((4, 7) | (1, 6)) = 0.0714
#   P((3, 8) | (5, 7)) = 0.5000
#   P((2, 8) | (3, 8)) = 1.0000
#   P((2, 8) | (2, 8)) = 0.3333
#   P((1, 8) | (2, 8)) = 0.3333
#   P((1, 8) | (1, 8)) = 0.5000
#   P((0, 10) | (1, 8)) = 0.5000
#   P((1, 9) | (0, 10)) = 0.5000
#   P((0, 9) | (4, 7)) = 1.0000
#   P((0, 8) | (1, 9)) = 1.0000
#   P((0, 7) | (0, 9)) = 0.5000
#   P((1, 4) | (0, 8)) = 0.3333
#   P((0, 4) | (1, 4)) = 0.1111
#   P((0, 2) | (0, 5)) = 0.1250
#   P((2, 0) | (1, 1)) = 0.0556
#   P((0, 1) | (2, 0)) = 0.1667
#   P((0, 2) | (1, 0)) = 0.0147
#   P((1, 3) | (0, 1)) = 0.0213
#   P((1, 2) | (0, 2)) = 0.1111
#   P((2, 1) | (0, 2)) = 0.0556
#   P((2, 2) | (1, 2)) = 0.1429
#   P((1, 3) | (2, 1)) = 0.1429
#   P((0, 3) | (2, 2)) = 0.1429
#   P((2, 4) | (1, 3)) = 0.0625
#   P((2, 6) | (1, 3)) = 0.0625
#   P((0, 6) | (2, 4)) = 0.1667
#   P((0, 3) | (0, 5)) = 0.1250
#   P((1, 2) | (0, 4)) = 0.0769
#   P((0, 2) | (0, 2)) = 0.0556
#   P((0, 0) | (1, 2)) = 0.1429
#
# Comparison of Waiting Times:
# With Longest Waiting Customer Function: 254.46 minutes
# Without Longest Waiting Customer Function: 289.08 minutes
# Difference in Waiting Time: 34.62 minutes
#
# Comparison of Agent Overtime Costs:
# With Longest Waiting Customer Function: 1074.39
# Without Longest Waiting Customer Function: 1134.21
# Difference in Agent Overtime Cost: 59.82
#                       Metric  With Longest Waiting  Without Longest Waiting  Difference (Without - With)
# Total Waiting Time (minutes)            254.461999               289.078056                    34.616057
#    Total Agent Overtime Cost           1074.388529              1134.209722                    59.821193
#       Total Customers Served            361.000000               366.000000                     5.000000

# %%
import numpy as np
import simpy
import pandas as pd

# Define parameters
lambda_1 = 4  # Arrival rate for primary questions (customers per minute)
lambda_2 = 2  # Arrival rate for complex questions (customers per minute)
mu_1 = 3      # Service rate for less experienced agent (customers per minute)
mu_2 = 4      # Service rate for more experienced agent (customers per minute)
M = 5         # Maximum number of calls in the system
T = 40        # Simulation time horizon in minutes
dt = 0.6

overtime_cost_rate = 1  # Overtime cost rate per minute beyond threshold (agent working overtime)

class CallCenter:
    def __init__(self, env, dt, use_longest_waiting=True):
        self.env = env
        self.dt = dt
        self.use_longest_waiting = use_longest_waiting
        self.queue_1 = simpy.Store(env)  # Queue for primary questions
        self.queue_2 = simpy.Store(env)  # Queue for complex questions
        self.agent_1 = simpy.Resource(env, capacity=1)
        self.agent_2 = simpy.Resource(env, capacity=1)
        self.total_waiting_time = 0
        self.total_agent_overtime_cost = 0  # Track only agent overtime costs
        self.total_rewards = 0  # Track total rewards
        self.customers_served = 0
        self.transition_counts = {}  # Track state transitions
        self.state_counts = {}  # Count visits to states

    def record_transition(self, current_state, next_state):
        """Records state transitions for computing probabilities."""
        self.transition_counts[(current_state, next_state)] = (
            self.transition_counts.get((current_state, next_state), 0) + 1
        )
        self.state_counts[current_state] = self.state_counts.get(current_state, 0) + 1

    def calculate_transition_probabilities(self):
        """Calculates transition probabilities from recorded transitions."""
        probabilities = {}
        for (current_state, next_state), count in self.transition_counts.items():
            total_transitions_from_state = self.state_counts[current_state]
            probabilities[(current_state, next_state)] = count / total_transitions_from_state
        return probabilities

    def handle_customer(self, customer_type, agent, service_rate, arrival_time, state):
        with (self.agent_1 if agent == "Agent 1" else self.agent_2).request() as request:
            yield request
            service_time = np.random.exponential(1 / service_rate)
            end_time = self.env.now + service_time  # Calculate when the service will end

            # Simulate the service time
            yield self.env.timeout(service_time)

            wait_time = self.env.now - arrival_time  # Calculate wait time
            self.total_waiting_time += wait_time

            # Initialize agent_overtime_cost to zero
            agent_overtime_cost = 0

            # Check for overtime due to working beyond T
            if end_time > T:
                overtime_hours = end_time - T
                agent_overtime_cost = overtime_hours * overtime_cost_rate
                self.total_agent_overtime_cost += agent_overtime_cost

            # Update rewards
            reward = -(wait_time + agent_overtime_cost)  # Negative rewards for wait time and overtime
            self.total_rewards += reward

            self.customers_served += 1

            next_state = (len(self.queue_1.items), len(self.queue_2.items))

            # Record the state transition
            self.record_transition(state, next_state)

            # Log details
            print(
                f"At time {self.env.now:.2f}: Customer type {customer_type} served by {agent} "
                f"in {service_time:.2f} minutes, waited {wait_time:.2f} minutes "
                f"(Overtime cost: {agent_overtime_cost:.2f}, Reward: {reward:.2f})"
            )
            print(f"    Transition: State {state} -> State {next_state}")

    def assign_customer(self):
        while True:
            if self.agent_1.count == 0 or self.agent_2.count == 0:
                queue, customer_type, arrival_time = self.select_customer()

                if queue is not None:
                    state = (len(self.queue_1.items), len(self.queue_2.items))  # Current state
                    yield queue.get()

                    chosen_agent = "Agent 1" if self.agent_1.count == 0 else "Agent 2"
                    service_rate = mu_1 if chosen_agent == "Agent 1" else mu_2

                    # Start handling the customer
                    self.env.process(self.handle_customer(customer_type, chosen_agent, service_rate, arrival_time, state))

            # Update rewards based on current queue lengths
            queue_penalty = -(len(self.queue_1.items) + len(self.queue_2.items))  # Negative reward for queue lengths
            self.total_rewards += queue_penalty

            yield self.env.timeout(dt)  # Allow other processes to run

    def select_customer(self):
        """Selects the customer based on the queue and waiting strategy."""
        if self.use_longest_waiting:
            return self.select_longest_waiting_customer()
        return self.select_first_come_first_served_customer()

    def select_longest_waiting_customer(self):
        """Select the longest waiting customer from the queues."""
        if len(self.queue_1.items) > 0 and len(self.queue_2.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            customer_2, arrival_time_2 = self.queue_2.items[0]
            if arrival_time_1 <= arrival_time_2:
                return self.queue_1, customer_1, arrival_time_1
            else:
                return self.queue_2, customer_2, arrival_time_2
        elif len(self.queue_1.items) > 0:
            customer_1, arrival_time_1 = self.queue_1.items[0]
            return self.queue_1, customer_1, arrival_time_1
        elif len(self.queue_2.items) > 0:
            customer_2, arrival_time_2 = self.queue_2.items[0]
            return self.queue_2, customer_2, arrival_time_2
        else:
            return None, None, None

    def select_first_come_first_served_customer(self):
        """Select the first customer from queue 1 or queue 2."""
        if len(self.queue_1.items) > 0:
            return self.queue_1, *self.queue_1.items[0]
        elif len(self.queue_2.items) > 0:
            return self.queue_2, *self.queue_2.items[0]
        return None, None, None

    def customer_arrival(self, customer_type, arrival_rate):
        while True:
            inter_arrival_time = np.random.exponential(1 / arrival_rate)
            yield self.env.timeout(inter_arrival_time)
            arrival_time = self.env.now

            if customer_type == 1:
                self.queue_1.put((customer_type, arrival_time))
            else:
                self.queue_2.put((customer_type, arrival_time))

            self.env.process(self.assign_customer())


def run_simulation(simulation_time, use_longest_waiting=True):
    env = simpy.Environment()
    call_center = CallCenter(env, dt, use_longest_waiting)

    env.process(call_center.customer_arrival(1, lambda_1))
    env.process(call_center.customer_arrival(2, lambda_2))

    env.run(until=simulation_time)

    print(f"\nTotal customers served: {call_center.customers_served}")
    print(f"Total waiting time: {call_center.total_waiting_time:.2f} minutes")
    print(f"Total agent overtime cost: {call_center.total_agent_overtime_cost:.2f} minutes")
    print(f"Total rewards: {call_center.total_rewards:.2f}")
    print(f"Average waiting time per customer: "
          f"{(call_center.total_waiting_time / call_center.customers_served):.2f} minutes")

    # Calculate and display transition probabilities
    probabilities = call_center.calculate_transition_probabilities()
    print("\nTransition Probabilities:")
    for (initial_state, final_state), prob in probabilities.items():
        print(f"  P({final_state} | {initial_state}) = {prob:.4f}")

    return call_center.total_waiting_time, call_center.total_agent_overtime_cost, call_center.customers_served, call_center.total_rewards, probabilities


# Run the simulations
simulation_time = 60

# With longest waiting customer function
waiting_time_longest, agent_overtime_longest, served_longest, rewards_longest, probs_longest = run_simulation(simulation_time, use_longest_waiting=True)

# Without longest waiting customer function
waiting_time_fcfs, agent_overtime_fcfs, served_fcfs, rewards_fcfs, probs_fcfs = run_simulation(simulation_time, use_longest_waiting=False)

# Prepare the results for the table
results_data = {
    "Metric": [
        "Total Waiting Time (minutes)",
        "Total Agent Overtime Cost",
        "Total Customers Served",
        "Total Rewards"
    ],
    "With Longest Waiting": [
        waiting_time_longest,
        agent_overtime_longest,
        served_longest,
        rewards_longest
    ],
    "Without Longest Waiting": [
        waiting_time_fcfs,
        agent_overtime_fcfs,
        served_fcfs,
        rewards_fcfs
    ],
    "Difference (Without - With)": [
        waiting_time_fcfs - waiting_time_longest,
        agent_overtime_fcfs - agent_overtime_longest,
        served_fcfs - served_longest,
        rewards_fcfs - rewards_longest
    ]
}

# Create the DataFrame
results_df = pd.DataFrame(results_data)

# Display the results as a table
print(results_df.to_string(index=False))
# Out:
# At time 0.34: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00, Reward: -0.10)
#     Transition: State (0, 1) -> State (0, 0)
# At time 0.97: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.00 minutes (Overtime cost: 0.00, Reward: -0.00)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.32: Customer type 1 served by Agent 1 in 0.49 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (1, 0) -> State (0, 0)
# At time 1.38: Customer type 2 served by Agent 2 in 0.13 minutes, waited 0.13 minutes (Overtime cost: 0.00, Reward: -0.13)
#     Transition: State (0, 1) -> State (0, 0)
# At time 1.78: Customer type 1 served by Agent 1 in 0.25 minutes, waited 0.25 minutes (Overtime cost: 0.00, Reward: -0.25)
#     Transition: State (1, 0) -> State (1, 1)
# At time 1.96: Customer type 2 served by Agent 1 in 0.10 minutes, waited 0.35 minutes (Overtime cost: 0.00, Reward: -0.35)
#     Transition: State (1, 1) -> State (1, 0)
# At time 2.13: Customer type 1 served by Agent 2 in 0.56 minutes, waited 0.56 minutes (Overtime cost: 0.00, Reward: -0.56)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.19: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.51: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.27 minutes (Overtime cost: 0.00, Reward: -0.27)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.60: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.11 minutes (Overtime cost: 0.00, Reward: -0.11)
#     Transition: State (1, 0) -> State (0, 0)
# At time 2.83: Customer type 1 served by Agent 2 in 0.18 minutes, waited 0.18 minutes (Overtime cost: 0.00, Reward: -0.18)
#     Transition: State (1, 0) -> State (2, 1)
# At time 2.98: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.32 minutes (Overtime cost: 0.00, Reward: -0.32)
#     Transition: State (2, 1) -> State (3, 2)
# At time 3.00: Customer type 1 served by Agent 1 in 0.43 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (1, 0) -> State (3, 2)
# At time 3.14: Customer type 2 served by Agent 1 in 0.14 minutes, waited 0.37 minutes (Overtime cost: 0.00, Reward: -0.37)
#     Transition: State (4, 2) -> State (3, 1)
# At time 3.21: Customer type 1 served by Agent 2 in 0.16 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (4, 1) -> State (4, 1)
# At time 3.30: Customer type 1 served by Agent 1 in 0.14 minutes, waited 0.45 minutes (Overtime cost: 0.00, Reward: -0.45)
#     Transition: State (3, 1) -> State (3, 2)
# At time 3.43: Customer type 2 served by Agent 1 in 0.09 minutes, waited 0.55 minutes (Overtime cost: 0.00, Reward: -0.55)
#     Transition: State (3, 2) -> State (3, 1)
# At time 3.64: Customer type 1 served by Agent 1 in 0.19 minutes, waited 0.63 minutes (Overtime cost: 0.00, Reward: -0.63)
#     Transition: State (3, 1) -> State (2, 2)
# At time 4.05: Customer type 1 served by Agent 1 in 0.40 minutes, waited 0.85 minutes (Overtime cost: 0.00, Reward: -0.85)
#     Transition: State (2, 2) -> State (1, 2)
# At time 4.06: Customer type 1 served by Agent 2 in 0.83 minutes, waited 1.19 minutes (Overtime cost: 0.00, Reward: -1.19)
#     Transition: State (4, 1) -> State (0, 2)
# At time 4.07: Customer type 2 served by Agent 2 in 0.00 minutes, waited 0.78 minutes (Overtime cost: 0.00, Reward: -0.78)
#     Transition: State (0, 2) -> State (0, 1)
# At time 4.12: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.53 minutes (Overtime cost: 0.00, Reward: -0.53)
#     Transition: State (0, 1) -> State (0, 0)
# At time 4.36: Customer type 1 served by Agent 1 in 0.31 minutes, waited 1.16 minutes (Overtime cost: 0.00, Reward: -1.16)
#     Transition: State (1, 2) -> State (0, 1)
# At time 4.54: Customer type 2 served by Agent 1 in 0.18 minutes, waited 0.27 minutes (Overtime cost: 0.00, Reward: -0.27)
#     Transition: State (0, 1) -> State (0, 0)
# At time 4.71: Customer type 1 served by Agent 2 in 0.57 minutes, waited 0.57 minutes (Overtime cost: 0.00, Reward: -0.57)
#     Transition: State (1, 0) -> State (0, 0)
# At time 4.73: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.03 minutes (Overtime cost: 0.00, Reward: -0.03)
#     Transition: State (1, 0) -> State (0, 0)
# At time 5.11: Customer type 2 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00, Reward: -0.04)
#     Transition: State (0, 1) -> State (0, 0)
# At time 5.55: Customer type 2 served by Agent 1 in 0.32 minutes, waited 0.32 minutes (Overtime cost: 0.00, Reward: -0.32)
#     Transition: State (0, 1) -> State (0, 0)
# At time 5.72: Customer type 1 served by Agent 1 in 0.10 minutes, waited 0.10 minutes (Overtime cost: 0.00, Reward: -0.10)
#     Transition: State (1, 0) -> State (1, 0)
# At time 5.72: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.21 minutes (Overtime cost: 0.00, Reward: -0.21)
#     Transition: State (1, 0) -> State (1, 0)
# At time 6.09: Customer type 1 served by Agent 2 in 0.24 minutes, waited 0.24 minutes (Overtime cost: 0.00, Reward: -0.24)
#     Transition: State (1, 0) -> State (3, 2)
# At time 6.21: Customer type 2 served by Agent 2 in 0.10 minutes, waited 0.33 minutes (Overtime cost: 0.00, Reward: -0.33)
#     Transition: State (3, 2) -> State (4, 1)
# At time 6.45: Customer type 1 served by Agent 1 in 0.72 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (1, 0) -> State (4, 1)
# At time 6.76: Customer type 2 served by Agent 1 in 0.31 minutes, waited 0.80 minutes (Overtime cost: 0.00, Reward: -0.80)
#     Transition: State (4, 1) -> State (6, 0)
# At time 7.08: Customer type 1 served by Agent 1 in 0.32 minutes, waited 1.10 minutes (Overtime cost: 0.00, Reward: -1.10)
#     Transition: State (6, 0) -> State (8, 1)
# At time 7.19: Customer type 1 served by Agent 2 in 0.97 minutes, waited 1.24 minutes (Overtime cost: 0.00, Reward: -1.24)
#     Transition: State (4, 1) -> State (9, 1)
# At time 7.30: Customer type 1 served by Agent 2 in 0.11 minutes, waited 1.10 minutes (Overtime cost: 0.00, Reward: -1.10)
#     Transition: State (9, 1) -> State (9, 1)
# At time 7.44: Customer type 1 served by Agent 2 in 0.14 minutes, waited 1.20 minutes (Overtime cost: 0.00, Reward: -1.20)
#     Transition: State (9, 1) -> State (9, 1)
# At time 7.91: Customer type 1 served by Agent 2 in 0.47 minutes, waited 1.34 minutes (Overtime cost: 0.00, Reward: -1.34)
#     Transition: State (9, 1) -> State (9, 2)
# At time 7.94: Customer type 1 served by Agent 2 in 0.02 minutes, waited 1.23 minutes (Overtime cost: 0.00, Reward: -1.23)
#     Transition: State (9, 2) -> State (9, 2)
# At time 8.19: Customer type 1 served by Agent 2 in 0.23 minutes, waited 1.33 minutes (Overtime cost: 0.00, Reward: -1.33)
#     Transition: State (10, 2) -> State (11, 4)
# At time 8.24: Customer type 1 served by Agent 2 in 0.04 minutes, waited 1.36 minutes (Overtime cost: 0.00, Reward: -1.36)
#     Transition: State (11, 4) -> State (10, 4)
# At time 8.30: Customer type 1 served by Agent 1 in 1.20 minutes, waited 2.27 minutes (Overtime cost: 0.00, Reward: -2.27)
#     Transition: State (8, 1) -> State (11, 3)
# At time 8.33: Customer type 2 served by Agent 2 in 0.08 minutes, waited 1.33 minutes (Overtime cost: 0.00, Reward: -1.33)
#     Transition: State (10, 4) -> State (10, 3)
# At time 8.68: Customer type 1 served by Agent 1 in 0.37 minutes, waited 1.62 minutes (Overtime cost: 0.00, Reward: -1.62)
#     Transition: State (11, 3) -> State (10, 4)
# At time 8.72: Customer type 1 served by Agent 2 in 0.38 minutes, waited 1.58 minutes (Overtime cost: 0.00, Reward: -1.58)
#     Transition: State (10, 3) -> State (9, 5)
# At time 8.82: Customer type 1 served by Agent 2 in 0.08 minutes, waited 1.62 minutes (Overtime cost: 0.00, Reward: -1.62)
#     Transition: State (9, 5) -> State (8, 5)
# At time 8.93: Customer type 1 served by Agent 2 in 0.10 minutes, waited 1.50 minutes (Overtime cost: 0.00, Reward: -1.50)
#     Transition: State (8, 5) -> State (7, 5)
# At time 8.98: Customer type 1 served by Agent 1 in 0.30 minutes, waited 1.82 minutes (Overtime cost: 0.00, Reward: -1.82)
#     Transition: State (10, 4) -> State (8, 5)
# At time 9.00: Customer type 1 served by Agent 2 in 0.07 minutes, waited 1.44 minutes (Overtime cost: 0.00, Reward: -1.44)
#     Transition: State (7, 5) -> State (9, 4)
# At time 9.34: Customer type 1 served by Agent 2 in 0.34 minutes, waited 1.42 minutes (Overtime cost: 0.00, Reward: -1.42)
#     Transition: State (9, 4) -> State (10, 4)
# At time 9.44: Customer type 1 served by Agent 2 in 0.08 minutes, waited 1.49 minutes (Overtime cost: 0.00, Reward: -1.49)
#     Transition: State (10, 4) -> State (9, 5)
# At time 9.67: Customer type 2 served by Agent 1 in 0.69 minutes, waited 1.91 minutes (Overtime cost: 0.00, Reward: -1.91)
#     Transition: State (9, 5) -> State (9, 6)
# At time 10.31: Customer type 2 served by Agent 1 in 0.64 minutes, waited 2.31 minutes (Overtime cost: 0.00, Reward: -2.31)
#     Transition: State (9, 6) -> State (12, 6)
# At time 10.62: Customer type 1 served by Agent 2 in 1.17 minutes, waited 2.64 minutes (Overtime cost: 0.00, Reward: -2.64)
#     Transition: State (9, 5) -> State (12, 7)
# At time 10.73: Customer type 2 served by Agent 1 in 0.41 minutes, waited 2.70 minutes (Overtime cost: 0.00, Reward: -2.70)
#     Transition: State (12, 6) -> State (12, 7)
# At time 10.96: Customer type 1 served by Agent 1 in 0.23 minutes, waited 2.66 minutes (Overtime cost: 0.00, Reward: -2.66)
#     Transition: State (12, 7) -> State (11, 7)
# At time 11.00: Customer type 1 served by Agent 2 in 0.37 minutes, waited 2.91 minutes (Overtime cost: 0.00, Reward: -2.91)
#     Transition: State (12, 7) -> State (10, 7)
# At time 11.04: Customer type 1 served by Agent 1 in 0.07 minutes, waited 2.57 minutes (Overtime cost: 0.00, Reward: -2.57)
#     Transition: State (11, 7) -> State (10, 6)
# At time 11.42: Customer type 2 served by Agent 1 in 0.38 minutes, waited 2.72 minutes (Overtime cost: 0.00, Reward: -2.72)
#     Transition: State (10, 6) -> State (13, 7)
# At time 11.45: Customer type 1 served by Agent 1 in 0.02 minutes, waited 2.51 minutes (Overtime cost: 0.00, Reward: -2.51)
#     Transition: State (13, 7) -> State (12, 7)
# At time 11.70: Customer type 1 served by Agent 1 in 0.23 minutes, waited 2.75 minutes (Overtime cost: 0.00, Reward: -2.75)
#     Transition: State (12, 7) -> State (11, 7)
# At time 11.87: Customer type 2 served by Agent 2 in 0.87 minutes, waited 3.38 minutes (Overtime cost: 0.00, Reward: -3.38)
#     Transition: State (10, 7) -> State (10, 7)
# At time 12.10: Customer type 1 served by Agent 1 in 0.40 minutes, waited 3.12 minutes (Overtime cost: 0.00, Reward: -3.12)
#     Transition: State (11, 7) -> State (9, 7)
# At time 12.18: Customer type 1 served by Agent 2 in 0.30 minutes, waited 3.11 minutes (Overtime cost: 0.00, Reward: -3.11)
#     Transition: State (10, 7) -> State (9, 7)
# At time 12.34: Customer type 2 served by Agent 2 in 0.14 minutes, waited 2.94 minutes (Overtime cost: 0.00, Reward: -2.94)
#     Transition: State (9, 7) -> State (10, 6)
# At time 12.37: Customer type 2 served by Agent 2 in 0.01 minutes, waited 2.81 minutes (Overtime cost: 0.00, Reward: -2.81)
#     Transition: State (10, 6) -> State (10, 5)
# At time 12.55: Customer type 1 served by Agent 1 in 0.44 minutes, waited 3.37 minutes (Overtime cost: 0.00, Reward: -3.37)
#     Transition: State (9, 7) -> State (10, 5)
# At time 12.57: Customer type 1 served by Agent 1 in 0.01 minutes, waited 2.82 minutes (Overtime cost: 0.00, Reward: -2.82)
#     Transition: State (10, 5) -> State (9, 5)
# At time 12.87: Customer type 1 served by Agent 1 in 0.29 minutes, waited 3.07 minutes (Overtime cost: 0.00, Reward: -3.07)
#     Transition: State (9, 5) -> State (9, 6)
# At time 12.91: Customer type 1 served by Agent 1 in 0.04 minutes, waited 2.94 minutes (Overtime cost: 0.00, Reward: -2.94)
#     Transition: State (9, 6) -> State (8, 6)
# At time 12.99: Customer type 1 served by Agent 2 in 0.62 minutes, waited 3.39 minutes (Overtime cost: 0.00, Reward: -3.39)
#     Transition: State (10, 5) -> State (10, 5)
# At time 13.02: Customer type 2 served by Agent 1 in 0.09 minutes, waited 2.93 minutes (Overtime cost: 0.00, Reward: -2.93)
#     Transition: State (9, 6) -> State (11, 4)
# At time 13.12: Customer type 2 served by Agent 1 in 0.09 minutes, waited 2.52 minutes (Overtime cost: 0.00, Reward: -2.52)
#     Transition: State (11, 4) -> State (11, 4)
# At time 13.23: Customer type 1 served by Agent 1 in 0.10 minutes, waited 2.54 minutes (Overtime cost: 0.00, Reward: -2.54)
#     Transition: State (11, 4) -> State (10, 4)
# At time 13.43: Customer type 1 served by Agent 1 in 0.18 minutes, waited 2.38 minutes (Overtime cost: 0.00, Reward: -2.38)
#     Transition: State (10, 4) -> State (10, 4)
# At time 13.86: Customer type 2 served by Agent 2 in 0.87 minutes, waited 3.43 minutes (Overtime cost: 0.00, Reward: -3.43)
#     Transition: State (11, 5) -> State (9, 4)
# At time 14.29: Customer type 2 served by Agent 2 in 0.42 minutes, waited 3.16 minutes (Overtime cost: 0.00, Reward: -3.16)
#     Transition: State (9, 4) -> State (9, 4)
# At time 14.31: Customer type 2 served by Agent 2 in 0.01 minutes, waited 3.10 minutes (Overtime cost: 0.00, Reward: -3.10)
#     Transition: State (9, 4) -> State (9, 3)
# At time 14.37: Customer type 1 served by Agent 1 in 0.93 minutes, waited 3.30 minutes (Overtime cost: 0.00, Reward: -3.30)
#     Transition: State (10, 4) -> State (8, 3)
# At time 14.78: Customer type 1 served by Agent 1 in 0.40 minutes, waited 2.60 minutes (Overtime cost: 0.00, Reward: -2.60)
#     Transition: State (8, 3) -> State (7, 4)
# At time 14.93: Customer type 1 served by Agent 2 in 0.59 minutes, waited 3.70 minutes (Overtime cost: 0.00, Reward: -3.70)
#     Transition: State (9, 3) -> State (6, 5)
# At time 15.21: Customer type 1 served by Agent 2 in 0.28 minutes, waited 2.82 minutes (Overtime cost: 0.00, Reward: -2.82)
#     Transition: State (6, 5) -> State (5, 5)
# At time 15.26: Customer type 1 served by Agent 1 in 0.48 minutes, waited 2.99 minutes (Overtime cost: 0.00, Reward: -2.99)
#     Transition: State (7, 4) -> State (6, 5)
# At time 15.27: Customer type 1 served by Agent 2 in 0.05 minutes, waited 2.41 minutes (Overtime cost: 0.00, Reward: -2.41)
#     Transition: State (6, 5) -> State (6, 4)
# At time 15.38: Customer type 1 served by Agent 2 in 0.11 minutes, waited 2.45 minutes (Overtime cost: 0.00, Reward: -2.45)
#     Transition: State (6, 4) -> State (6, 4)
# At time 15.58: Customer type 1 served by Agent 2 in 0.20 minutes, waited 2.62 minutes (Overtime cost: 0.00, Reward: -2.62)
#     Transition: State (6, 4) -> State (5, 4)
# At time 15.80: Customer type 2 served by Agent 1 in 0.54 minutes, waited 2.94 minutes (Overtime cost: 0.00, Reward: -2.94)
#     Transition: State (6, 5) -> State (6, 4)
# At time 15.96: Customer type 2 served by Agent 1 in 0.16 minutes, waited 2.86 minutes (Overtime cost: 0.00, Reward: -2.86)
#     Transition: State (6, 4) -> State (7, 3)
# At time 15.97: Customer type 1 served by Agent 2 in 0.39 minutes, waited 2.98 minutes (Overtime cost: 0.00, Reward: -2.98)
#     Transition: State (5, 4) -> State (6, 3)
# At time 16.01: Customer type 2 served by Agent 2 in 0.03 minutes, waited 2.03 minutes (Overtime cost: 0.00, Reward: -2.03)
#     Transition: State (6, 3) -> State (6, 2)
# At time 16.25: Customer type 2 served by Agent 2 in 0.23 minutes, waited 1.57 minutes (Overtime cost: 0.00, Reward: -1.57)
#     Transition: State (6, 2) -> State (6, 1)
# At time 16.33: Customer type 2 served by Agent 2 in 0.07 minutes, waited 1.47 minutes (Overtime cost: 0.00, Reward: -1.47)
#     Transition: State (6, 1) -> State (6, 0)
# At time 16.49: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.27 minutes (Overtime cost: 0.00, Reward: -1.27)
#     Transition: State (6, 0) -> State (7, 0)
# At time 16.73: Customer type 1 served by Agent 1 in 0.77 minutes, waited 3.30 minutes (Overtime cost: 0.00, Reward: -3.30)
#     Transition: State (7, 3) -> State (6, 0)
# At time 16.82: Customer type 1 served by Agent 2 in 0.33 minutes, waited 1.60 minutes (Overtime cost: 0.00, Reward: -1.60)
#     Transition: State (7, 0) -> State (5, 0)
# At time 17.22: Customer type 1 served by Agent 2 in 0.39 minutes, waited 1.49 minutes (Overtime cost: 0.00, Reward: -1.49)
#     Transition: State (5, 0) -> State (6, 0)
# At time 17.23: Customer type 1 served by Agent 2 in 0.00 minutes, waited 1.48 minutes (Overtime cost: 0.00, Reward: -1.48)
#     Transition: State (6, 1) -> State (5, 1)
# At time 17.33: Customer type 1 served by Agent 2 in 0.11 minutes, waited 1.42 minutes (Overtime cost: 0.00, Reward: -1.42)
#     Transition: State (5, 1) -> State (5, 1)
# At time 17.34: Customer type 1 served by Agent 1 in 0.61 minutes, waited 2.01 minutes (Overtime cost: 0.00, Reward: -2.01)
#     Transition: State (6, 0) -> State (4, 1)
# At time 17.45: Customer type 1 served by Agent 1 in 0.10 minutes, waited 1.07 minutes (Overtime cost: 0.00, Reward: -1.07)
#     Transition: State (4, 1) -> State (4, 2)
# At time 17.54: Customer type 1 served by Agent 2 in 0.21 minutes, waited 1.19 minutes (Overtime cost: 0.00, Reward: -1.19)
#     Transition: State (5, 1) -> State (3, 2)
# At time 17.65: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.49 minutes (Overtime cost: 0.00, Reward: -0.49)
#     Transition: State (3, 2) -> State (2, 2)
# At time 17.74: Customer type 2 served by Agent 2 in 0.09 minutes, waited 0.52 minutes (Overtime cost: 0.00, Reward: -0.52)
#     Transition: State (2, 2) -> State (2, 1)
# At time 17.78: Customer type 1 served by Agent 1 in 0.32 minutes, waited 0.63 minutes (Overtime cost: 0.00, Reward: -0.63)
#     Transition: State (4, 2) -> State (1, 1)
# At time 17.79: Customer type 1 served by Agent 2 in 0.04 minutes, waited 0.52 minutes (Overtime cost: 0.00, Reward: -0.52)
#     Transition: State (2, 1) -> State (1, 0)
# At time 17.80: Customer type 2 served by Agent 1 in 0.01 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (1, 1) -> State (0, 0)
# At time 18.16: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.27 minutes (Overtime cost: 0.00, Reward: -0.27)
#     Transition: State (1, 0) -> State (3, 0)
# At time 18.30: Customer type 1 served by Agent 2 in 0.51 minutes, waited 0.92 minutes (Overtime cost: 0.00, Reward: -0.92)
#     Transition: State (1, 0) -> State (2, 0)
# At time 19.08: Customer type 1 served by Agent 1 in 0.92 minutes, waited 1.15 minutes (Overtime cost: 0.00, Reward: -1.15)
#     Transition: State (3, 0) -> State (4, 3)
# At time 19.13: Customer type 1 served by Agent 1 in 0.05 minutes, waited 1.00 minutes (Overtime cost: 0.00, Reward: -1.00)
#     Transition: State (4, 3) -> State (5, 3)
# At time 19.34: Customer type 1 served by Agent 2 in 1.04 minutes, waited 1.25 minutes (Overtime cost: 0.00, Reward: -1.25)
#     Transition: State (2, 0) -> State (5, 4)
# At time 19.50: Customer type 2 served by Agent 1 in 0.37 minutes, waited 1.09 minutes (Overtime cost: 0.00, Reward: -1.09)
#     Transition: State (5, 3) -> State (4, 5)
# At time 19.53: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.90 minutes (Overtime cost: 0.00, Reward: -0.90)
#     Transition: State (5, 4) -> State (4, 4)
# At time 19.58: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (4, 4) -> State (4, 3)
# At time 19.69: Customer type 2 served by Agent 1 in 0.17 minutes, waited 1.03 minutes (Overtime cost: 0.00, Reward: -1.03)
#     Transition: State (4, 5) -> State (4, 3)
# At time 19.77: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.91 minutes (Overtime cost: 0.00, Reward: -0.91)
#     Transition: State (4, 3) -> State (3, 3)
# At time 20.11: Customer type 1 served by Agent 2 in 0.53 minutes, waited 1.27 minutes (Overtime cost: 0.00, Reward: -1.27)
#     Transition: State (4, 3) -> State (3, 3)
# At time 20.14: Customer type 1 served by Agent 1 in 0.36 minutes, waited 1.04 minutes (Overtime cost: 0.00, Reward: -1.04)
#     Transition: State (3, 3) -> State (2, 3)
# At time 20.30: Customer type 1 served by Agent 2 in 0.19 minutes, waited 1.20 minutes (Overtime cost: 0.00, Reward: -1.20)
#     Transition: State (3, 3) -> State (2, 2)
# At time 20.66: Customer type 2 served by Agent 1 in 0.52 minutes, waited 1.48 minutes (Overtime cost: 0.00, Reward: -1.48)
#     Transition: State (2, 3) -> State (3, 1)
# At time 20.83: Customer type 2 served by Agent 1 in 0.17 minutes, waited 1.36 minutes (Overtime cost: 0.00, Reward: -1.36)
#     Transition: State (3, 1) -> State (3, 0)
# At time 21.43: Customer type 1 served by Agent 1 in 0.59 minutes, waited 1.81 minutes (Overtime cost: 0.00, Reward: -1.81)
#     Transition: State (3, 0) -> State (2, 0)
# At time 21.69: Customer type 2 served by Agent 2 in 1.38 minutes, waited 2.42 minutes (Overtime cost: 0.00, Reward: -2.42)
#     Transition: State (2, 2) -> State (3, 0)
# At time 21.87: Customer type 1 served by Agent 2 in 0.18 minutes, waited 1.36 minutes (Overtime cost: 0.00, Reward: -1.36)
#     Transition: State (3, 0) -> State (3, 0)
# At time 21.87: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.40 minutes (Overtime cost: 0.00, Reward: -0.40)
#     Transition: State (3, 0) -> State (2, 0)
# At time 22.12: Customer type 1 served by Agent 1 in 0.67 minutes, waited 2.08 minutes (Overtime cost: 0.00, Reward: -2.08)
#     Transition: State (2, 0) -> State (2, 0)
# At time 22.46: Customer type 1 served by Agent 2 in 0.58 minutes, waited 0.86 minutes (Overtime cost: 0.00, Reward: -0.86)
#     Transition: State (2, 0) -> State (3, 0)
# At time 22.47: Customer type 1 served by Agent 1 in 0.34 minutes, waited 0.71 minutes (Overtime cost: 0.00, Reward: -0.71)
#     Transition: State (2, 0) -> State (2, 1)
# At time 22.51: Customer type 1 served by Agent 2 in 0.06 minutes, waited 0.43 minutes (Overtime cost: 0.00, Reward: -0.43)
#     Transition: State (3, 0) -> State (1, 1)
# At time 22.53: Customer type 1 served by Agent 2 in 0.00 minutes, waited 0.08 minutes (Overtime cost: 0.00, Reward: -0.08)
#     Transition: State (1, 1) -> State (0, 1)
# At time 22.69: Customer type 1 served by Agent 1 in 0.22 minutes, waited 0.25 minutes (Overtime cost: 0.00, Reward: -0.25)
#     Transition: State (2, 1) -> State (0, 0)
# At time 22.87: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.04 minutes (Overtime cost: 0.00, Reward: -0.04)
#     Transition: State (1, 0) -> State (0, 1)
# At time 22.87: Customer type 2 served by Agent 2 in 0.34 minutes, waited 0.41 minutes (Overtime cost: 0.00, Reward: -0.41)
#     Transition: State (0, 1) -> State (0, 0)
# At time 23.08: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (1, 0) -> State (1, 0)
# At time 23.19: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.22 minutes (Overtime cost: 0.00, Reward: -0.22)
#     Transition: State (1, 0) -> State (0, 0)
# At time 23.34: Customer type 2 served by Agent 1 in 0.47 minutes, waited 0.48 minutes (Overtime cost: 0.00, Reward: -0.48)
#     Transition: State (0, 1) -> State (0, 0)
# At time 23.48: Customer type 1 served by Agent 1 in 0.12 minutes, waited 0.12 minutes (Overtime cost: 0.00, Reward: -0.12)
#     Transition: State (1, 0) -> State (0, 0)
# At time 23.85: Customer type 2 served by Agent 1 in 0.30 minutes, waited 0.30 minutes (Overtime cost: 0.00, Reward: -0.30)
#     Transition: State (0, 1) -> State (0, 1)
# At time 24.48: Customer type 2 served by Agent 1 in 0.63 minutes, waited 0.73 minutes (Overtime cost: 0.00, Reward: -0.73)
#     Transition: State (0, 1) -> State (2, 0)
# At time 24.56: Customer type 2 served by Agent 2 in 0.99 minutes, waited 0.99 minutes (Overtime cost: 0.00, Reward: -0.99)
#     Transition: State (0, 1) -> State (1, 0)
# At time 24.92: Customer type 1 served by Agent 1 in 0.44 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (2, 0) -> State (3, 0)
# At time 25.03: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.44 minutes (Overtime cost: 0.00, Reward: -0.44)
#     Transition: State (4, 0) -> State (3, 1)
# At time 25.05: Customer type 1 served by Agent 1 in 0.00 minutes, waited 0.42 minutes (Overtime cost: 0.00, Reward: -0.42)
#     Transition: State (3, 1) -> State (2, 1)
# At time 25.19: Customer type 1 served by Agent 2 in 0.63 minutes, waited 1.28 minutes (Overtime cost: 0.00, Reward: -1.28)
#     Transition: State (1, 0) -> State (4, 1)
# At time 25.52: Customer type 1 served by Agent 2 in 0.32 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (4, 1) -> State (4, 2)
# At time 25.57: Customer type 1 served by Agent 1 in 0.52 minutes, waited 0.87 minutes (Overtime cost: 0.00, Reward: -0.87)
#     Transition: State (2, 1) -> State (4, 1)
# At time 25.84: Customer type 1 served by Agent 1 in 0.27 minutes, waited 0.76 minutes (Overtime cost: 0.00, Reward: -0.76)
#     Transition: State (4, 1) -> State (3, 2)
# At time 25.96: Customer type 2 served by Agent 2 in 0.43 minutes, waited 0.93 minutes (Overtime cost: 0.00, Reward: -0.93)
#     Transition: State (4, 2) -> State (3, 2)
# At time 26.07: Customer type 1 served by Agent 1 in 0.21 minutes, waited 0.90 minutes (Overtime cost: 0.00, Reward: -0.90)
#     Transition: State (3, 2) -> State (3, 2)
# At time 26.31: Customer type 1 served by Agent 1 in 0.24 minutes, waited 1.10 minutes (Overtime cost: 0.00, Reward: -1.10)
#     Transition: State (3, 2) -> State (3, 2)
# At time 26.47: Customer type 2 served by Agent 1 in 0.16 minutes, waited 0.98 minutes (Overtime cost: 0.00, Reward: -0.98)
#     Transition: State (3, 2) -> State (3, 1)
# At time 26.70: Customer type 2 served by Agent 1 in 0.22 minutes, waited 0.94 minutes (Overtime cost: 0.00, Reward: -0.94)
#     Transition: State (3, 1) -> State (3, 0)
# At time 26.76: Customer type 1 served by Agent 2 in 0.79 minutes, waited 1.59 minutes (Overtime cost: 0.00, Reward: -1.59)
#     Transition: State (3, 2) -> State (3, 0)
# At time 26.78: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.75 minutes (Overtime cost: 0.00, Reward: -0.75)
#     Transition: State (3, 0) -> State (2, 0)
# At time 26.86: Customer type 1 served by Agent 1 in 0.16 minutes, waited 0.96 minutes (Overtime cost: 0.00, Reward: -0.96)
#     Transition: State (3, 0) -> State (1, 0)
# At time 26.89: Customer type 1 served by Agent 1 in 0.03 minutes, waited 0.18 minutes (Overtime cost: 0.00, Reward: -0.18)
#     Transition: State (1, 0) -> State (0, 0)
# At time 27.04: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.08 minutes (Overtime cost: 0.00, Reward: -0.08)
#     Transition: State (1, 0) -> State (0, 0)
# At time 27.10: Customer type 1 served by Agent 2 in 0.32 minutes, waited 0.97 minutes (Overtime cost: 0.00, Reward: -0.97)
#     Transition: State (2, 0) -> State (0, 0)
# At time 27.93: Customer type 1 served by Agent 1 in 0.06 minutes, waited 0.06 minutes (Overtime cost: 0.00, Reward: -0.06)
#     Transition: State (1, 0) -> State (0, 0)
# At time 28.12: Customer type 2 served by Agent 1 in 0.19 minutes, waited 0.19 minutes (Overtime cost: 0.00, Reward: -0.19)
#     Transition: State (0, 1) -> State (0, 0)
# At time 28.32: Customer type 1 served by Agent 2 in 0.31 minutes, waited 0.31 minutes (Overtime cost: 0.00, Reward: -0.31)
#     Transition: State (1, 0) -> State (0, 0)
# At time 29.80: Customer type 1 served by Agent 1 in 0.22 minutes, waited 0.22 minutes (Overtime cost: 0.00, Reward: -0.22)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.25: Customer type 1 served by Agent 2 in 0.57 minutes, waited 0.57 minutes (Overtime cost: 0.00, Reward: -0.57)
#     Transition: State (1, 0) -> State (1, 0)
# At time 30.45: Customer type 1 served by Agent 1 in 0.59 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.57: Customer type 1 served by Agent 2 in 0.32 minutes, waited 0.62 minutes (Overtime cost: 0.00, Reward: -0.62)
#     Transition: State (1, 0) -> State (0, 0)
# At time 30.80: Customer type 1 served by Agent 1 in 0.28 minutes, waited 0.28 minutes (Overtime cost: 0.00, Reward: -0.28)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.07: Customer type 1 served by Agent 1 in 0.24 minutes, waited 0.24 minutes (Overtime cost: 0.00, Reward: -0.24)
#     Transition: State (1, 0) -> State (2, 0)
# At time 31.18: Customer type 1 served by Agent 1 in 0.11 minutes, waited 0.25 minutes (Overtime cost: 0.00, Reward: -0.25)
#     Transition: State (2, 0) -> State (1, 0)
# At time 31.20: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.29 minutes (Overtime cost: 0.00, Reward: -0.29)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.40: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.09 minutes (Overtime cost: 0.00, Reward: -0.09)
#     Transition: State (1, 0) -> State (1, 0)
# At time 31.62: Customer type 1 served by Agent 1 in 0.44 minutes, waited 0.56 minutes (Overtime cost: 0.00, Reward: -0.56)
#     Transition: State (1, 0) -> State (0, 0)
# At time 31.96: Customer type 1 served by Agent 2 in 0.55 minutes, waited 0.59 minutes (Overtime cost: 0.00, Reward: -0.59)
#     Transition: State (1, 0) -> State (0, 0)
# At time 32.49: Customer type 1 served by Agent 2 in 0.45 minutes, waited 0.45 minutes (Overtime cost: 0.00, Reward: -0.45)
#     Transition: State (1, 0) -> State (3, 0)
# At time 32.91: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.73 minutes (Overtime cost: 0.00, Reward: -0.73)
#     Transition: State (3, 0) -> State (3, 2)
# At time 33.48: Customer type 1 served by Agent 2 in 0.56 minutes, waited 1.23 minutes (Overtime cost: 0.00, Reward: -1.23)
#     Transition: State (3, 2) -> State (3, 3)
# At time 33.63: Customer type 2 served by Agent 1 in 1.69 minutes, waited 1.69 minutes (Overtime cost: 0.00, Reward: -1.69)
#     Transition: State (0, 1) -> State (2, 3)
# At time 33.73: Customer type 2 served by Agent 1 in 0.10 minutes, waited 1.11 minutes (Overtime cost: 0.00, Reward: -1.11)
#     Transition: State (2, 3) -> State (2, 3)
# At time 33.90: Customer type 2 served by Agent 1 in 0.17 minutes, waited 1.11 minutes (Overtime cost: 0.00, Reward: -1.11)
#     Transition: State (2, 3) -> State (2, 2)
# At time 34.09: Customer type 1 served by Agent 2 in 0.61 minutes, waited 1.77 minutes (Overtime cost: 0.00, Reward: -1.77)
#     Transition: State (3, 3) -> State (1, 3)
# At time 34.12: Customer type 1 served by Agent 1 in 0.21 minutes, waited 1.27 minutes (Overtime cost: 0.00, Reward: -1.27)
#     Transition: State (2, 2) -> State (1, 3)
# At time 34.17: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.93 minutes (Overtime cost: 0.00, Reward: -0.93)
#     Transition: State (1, 3) -> State (1, 2)
# At time 34.24: Customer type 2 served by Agent 1 in 0.12 minutes, waited 0.78 minutes (Overtime cost: 0.00, Reward: -0.78)
#     Transition: State (1, 3) -> State (1, 1)
# At time 34.43: Customer type 2 served by Agent 1 in 0.18 minutes, waited 0.37 minutes (Overtime cost: 0.00, Reward: -0.37)
#     Transition: State (1, 1) -> State (1, 0)
# At time 34.78: Customer type 1 served by Agent 1 in 0.35 minutes, waited 0.68 minutes (Overtime cost: 0.00, Reward: -0.68)
#     Transition: State (1, 0) -> State (4, 0)
# At time 34.86: Customer type 1 served by Agent 1 in 0.08 minutes, waited 0.36 minutes (Overtime cost: 0.00, Reward: -0.36)
#     Transition: State (4, 0) -> State (4, 0)
# At time 35.19: Customer type 2 served by Agent 2 in 1.01 minutes, waited 1.53 minutes (Overtime cost: 0.00, Reward: -1.53)
#     Transition: State (1, 2) -> State (5, 0)
# At time 35.32: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.63 minutes (Overtime cost: 0.00, Reward: -0.63)
#     Transition: State (5, 0) -> State (4, 0)
# At time 35.35: Customer type 1 served by Agent 2 in 0.02 minutes, waited 0.56 minutes (Overtime cost: 0.00, Reward: -0.56)
#     Transition: State (4, 0) -> State (3, 0)
# At time 35.56: Customer type 1 served by Agent 1 in 0.69 minutes, waited 1.02 minutes (Overtime cost: 0.00, Reward: -1.02)
#     Transition: State (4, 0) -> State (3, 0)
# At time 35.76: Customer type 1 served by Agent 2 in 0.42 minutes, waited 0.97 minutes (Overtime cost: 0.00, Reward: -0.97)
#     Transition: State (3, 0) -> State (3, 1)
# At time 36.12: Customer type 1 served by Agent 1 in 0.55 minutes, waited 1.22 minutes (Overtime cost: 0.00, Reward: -1.22)
#     Transition: State (3, 0) -> State (3, 3)
# At time 36.32: Customer type 1 served by Agent 1 in 0.20 minutes, waited 0.82 minutes (Overtime cost: 0.00, Reward: -0.82)
#     Transition: State (3, 3) -> State (2, 3)
# At time 36.33: Customer type 1 served by Agent 1 in 0.01 minutes, waited 0.73 minutes (Overtime cost: 0.00, Reward: -0.73)
#     Transition: State (2, 3) -> State (1, 3)
# At time 36.67: Customer type 1 served by Agent 2 in 0.91 minutes, waited 1.72 minutes (Overtime cost: 0.00, Reward: -1.72)
#     Transition: State (3, 1) -> State (3, 2)
# At time 36.79: Customer type 1 served by Agent 2 in 0.12 minutes, waited 0.95 minutes (Overtime cost: 0.00, Reward: -0.95)
#     Transition: State (3, 2) -> State (3, 2)
# At time 36.86: Customer type 2 served by Agent 1 in 0.52 minutes, waited 1.14 minutes (Overtime cost: 0.00, Reward: -1.14)
#     Transition: State (1, 3) -> State (3, 1)
# At time 37.04: Customer type 2 served by Agent 2 in 0.24 minutes, waited 1.07 minutes (Overtime cost: 0.00, Reward: -1.07)
#     Transition: State (3, 2) -> State (6, 0)
# At time 37.12: Customer type 2 served by Agent 1 in 0.26 minutes, waited 1.05 minutes (Overtime cost: 0.00, Reward: -1.05)
#     Transition: State (3, 1) -> State (5, 0)
# At time 37.42: Customer type 1 served by Agent 1 in 0.30 minutes, waited 0.77 minutes (Overtime cost: 0.00, Reward: -0.77)
#     Transition: State (5, 0) -> State (6, 0)
# At time 37.44: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.68 minutes (Overtime cost: 0.00, Reward: -0.68)
#     Transition: State (6, 0) -> State (5, 0)
# At time 38.02: Customer type 1 served by Agent 2 in 0.97 minutes, waited 1.60 minutes (Overtime cost: 0.00, Reward: -1.60)
#     Transition: State (6, 0) -> State (6, 1)
# At time 38.23: Customer type 1 served by Agent 2 in 0.21 minutes, waited 1.29 minutes (Overtime cost: 0.00, Reward: -1.29)
#     Transition: State (6, 1) -> State (6, 1)
# At time 38.46: Customer type 1 served by Agent 2 in 0.23 minutes, waited 1.45 minutes (Overtime cost: 0.00, Reward: -1.45)
#     Transition: State (6, 1) -> State (5, 2)
# At time 38.61: Customer type 1 served by Agent 1 in 1.17 minutes, waited 1.71 minutes (Overtime cost: 0.00, Reward: -1.71)
#     Transition: State (5, 0) -> State (4, 3)
# At time 38.62: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.32 minutes (Overtime cost: 0.00, Reward: -1.32)
#     Transition: State (5, 2) -> State (3, 3)
# At time 38.73: Customer type 1 served by Agent 1 in 0.12 minutes, waited 1.42 minutes (Overtime cost: 0.00, Reward: -1.42)
#     Transition: State (4, 3) -> State (2, 3)
# At time 38.90: Customer type 1 served by Agent 2 in 0.28 minutes, waited 1.35 minutes (Overtime cost: 0.00, Reward: -1.35)
#     Transition: State (3, 3) -> State (5, 3)
# At time 39.03: Customer type 2 served by Agent 2 in 0.12 minutes, waited 1.17 minutes (Overtime cost: 0.00, Reward: -1.17)
#     Transition: State (5, 3) -> State (5, 2)
# At time 39.06: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.96 minutes (Overtime cost: 0.00, Reward: -0.96)
#     Transition: State (5, 2) -> State (4, 2)
# At time 39.53: Customer type 2 served by Agent 2 in 0.47 minutes, waited 1.27 minutes (Overtime cost: 0.00, Reward: -1.27)
#     Transition: State (4, 2) -> State (5, 1)
# At time 39.74: Customer type 2 served by Agent 2 in 0.21 minutes, waited 1.19 minutes (Overtime cost: 0.00, Reward: -1.19)
#     Transition: State (5, 1) -> State (6, 0)
# At time 39.93: Customer type 1 served by Agent 2 in 0.19 minutes, waited 1.14 minutes (Overtime cost: 0.00, Reward: -1.14)
#     Transition: State (6, 0) -> State (5, 0)
# At time 40.24: Customer type 1 served by Agent 1 in 1.50 minutes, waited 2.53 minutes (Overtime cost: 0.24, Reward: -2.77)
#     Transition: State (2, 3) -> State (6, 0)
# At time 40.45: Customer type 1 served by Agent 1 in 0.20 minutes, waited 1.59 minutes (Overtime cost: 0.45, Reward: -2.04)
#     Transition: State (6, 0) -> State (5, 0)
# At time 40.56: Customer type 1 served by Agent 1 in 0.10 minutes, waited 1.66 minutes (Overtime cost: 0.56, Reward: -2.22)
#     Transition: State (5, 0) -> State (4, 0)
# At time 40.92: Customer type 1 served by Agent 2 in 0.99 minutes, waited 2.08 minutes (Overtime cost: 0.92, Reward: -3.00)
#     Transition: State (5, 0) -> State (4, 1)
# At time 41.05: Customer type 1 served by Agent 1 in 0.50 minutes, waited 1.74 minutes (Overtime cost: 1.05, Reward: -2.79)
#     Transition: State (4, 0) -> State (3, 1)
# At time 41.59: Customer type 1 served by Agent 2 in 0.66 minutes, waited 2.04 minutes (Overtime cost: 1.59, Reward: -3.63)
#     Transition: State (4, 1) -> State (6, 1)
# At time 41.66: Customer type 1 served by Agent 1 in 0.61 minutes, waited 1.71 minutes (Overtime cost: 1.66, Reward: -3.37)
#     Transition: State (3, 1) -> State (5, 1)
# At time 41.97: Customer type 1 served by Agent 2 in 0.37 minutes, waited 1.94 minutes (Overtime cost: 1.97, Reward: -3.91)
#     Transition: State (6, 1) -> State (8, 2)
# At time 42.11: Customer type 2 served by Agent 1 in 0.45 minutes, waited 1.52 minutes (Overtime cost: 2.11, Reward: -3.63)
#     Transition: State (5, 1) -> State (7, 2)
# At time 42.17: Customer type 1 served by Agent 1 in 0.04 minutes, waited 0.99 minutes (Overtime cost: 2.17, Reward: -3.15)
#     Transition: State (7, 2) -> State (7, 2)
# At time 42.44: Customer type 1 served by Agent 2 in 0.47 minutes, waited 1.76 minutes (Overtime cost: 2.44, Reward: -4.20)
#     Transition: State (8, 2) -> State (8, 2)
# At time 42.67: Customer type 1 served by Agent 2 in 0.23 minutes, waited 1.40 minutes (Overtime cost: 2.67, Reward: -4.07)
#     Transition: State (8, 2) -> State (7, 2)
# At time 42.94: Customer type 1 served by Agent 1 in 0.77 minutes, waited 1.70 minutes (Overtime cost: 2.94, Reward: -4.65)
#     Transition: State (7, 2) -> State (6, 2)
# At time 42.98: Customer type 1 served by Agent 2 in 0.30 minutes, waited 1.39 minutes (Overtime cost: 2.98, Reward: -4.37)
#     Transition: State (7, 2) -> State (5, 2)
# At time 43.26: Customer type 1 served by Agent 1 in 0.31 minutes, waited 1.57 minutes (Overtime cost: 3.26, Reward: -4.83)
#     Transition: State (6, 2) -> State (6, 4)
# At time 43.29: Customer type 2 served by Agent 1 in 0.03 minutes, waited 1.47 minutes (Overtime cost: 3.29, Reward: -4.77)
#     Transition: State (6, 4) -> State (6, 3)
# At time 43.38: Customer type 1 served by Agent 2 in 0.41 minutes, waited 1.60 minutes (Overtime cost: 3.38, Reward: -4.99)
#     Transition: State (5, 2) -> State (5, 3)
# At time 43.60: Customer type 1 served by Agent 1 in 0.30 minutes, waited 1.71 minutes (Overtime cost: 3.60, Reward: -5.31)
#     Transition: State (6, 3) -> State (5, 2)
# At time 43.62: Customer type 2 served by Agent 2 in 0.22 minutes, waited 1.71 minutes (Overtime cost: 3.62, Reward: -5.33)
#     Transition: State (5, 3) -> State (4, 2)
# At time 43.71: Customer type 1 served by Agent 1 in 0.10 minutes, waited 1.59 minutes (Overtime cost: 3.71, Reward: -5.30)
#     Transition: State (5, 2) -> State (4, 2)
# At time 43.88: Customer type 1 served by Agent 1 in 0.16 minutes, waited 1.62 minutes (Overtime cost: 3.88, Reward: -5.50)
#     Transition: State (4, 2) -> State (3, 2)
# At time 43.89: Customer type 2 served by Agent 1 in 0.00 minutes, waited 0.89 minutes (Overtime cost: 3.89, Reward: -4.78)
#     Transition: State (3, 2) -> State (3, 1)
# At time 44.17: Customer type 1 served by Agent 2 in 0.55 minutes, waited 1.94 minutes (Overtime cost: 4.17, Reward: -6.11)
#     Transition: State (4, 2) -> State (4, 0)
# At time 44.19: Customer type 2 served by Agent 1 in 0.30 minutes, waited 1.05 minutes (Overtime cost: 4.19, Reward: -5.24)
#     Transition: State (3, 1) -> State (4, 0)
# At time 44.44: Customer type 1 served by Agent 2 in 0.27 minutes, waited 1.27 minutes (Overtime cost: 4.44, Reward: -5.71)
#     Transition: State (5, 0) -> State (4, 4)
# At time 44.56: Customer type 1 served by Agent 1 in 0.37 minutes, waited 1.37 minutes (Overtime cost: 4.56, Reward: -5.93)
#     Transition: State (4, 0) -> State (4, 4)
# At time 44.67: Customer type 1 served by Agent 2 in 0.24 minutes, waited 1.04 minutes (Overtime cost: 4.67, Reward: -5.72)
#     Transition: State (5, 4) -> State (3, 4)
# At time 44.77: Customer type 1 served by Agent 2 in 0.09 minutes, waited 0.60 minutes (Overtime cost: 4.77, Reward: -5.36)
#     Transition: State (3, 4) -> State (2, 4)
# At time 45.17: Customer type 2 served by Agent 2 in 0.40 minutes, waited 0.97 minutes (Overtime cost: 5.17, Reward: -6.14)
#     Transition: State (2, 4) -> State (4, 3)
# At time 45.38: Customer type 2 served by Agent 2 in 0.21 minutes, waited 1.14 minutes (Overtime cost: 5.38, Reward: -6.52)
#     Transition: State (4, 3) -> State (4, 2)
# At time 45.48: Customer type 2 served by Agent 2 in 0.10 minutes, waited 1.24 minutes (Overtime cost: 5.48, Reward: -6.71)
#     Transition: State (4, 2) -> State (5, 2)
# At time 45.90: Customer type 1 served by Agent 1 in 1.33 minutes, waited 1.77 minutes (Overtime cost: 5.90, Reward: -7.66)
#     Transition: State (4, 4) -> State (6, 1)
# At time 46.04: Customer type 2 served by Agent 2 in 0.56 minutes, waited 1.76 minutes (Overtime cost: 6.04, Reward: -7.80)
#     Transition: State (5, 2) -> State (6, 1)
# At time 46.05: Customer type 1 served by Agent 2 in 0.01 minutes, waited 1.61 minutes (Overtime cost: 6.05, Reward: -7.66)
#     Transition: State (6, 1) -> State (5, 1)
# At time 46.19: Customer type 1 served by Agent 2 in 0.14 minutes, waited 1.41 minutes (Overtime cost: 6.19, Reward: -7.60)
#     Transition: State (5, 1) -> State (4, 1)
# At time 46.36: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.49 minutes (Overtime cost: 6.36, Reward: -7.84)
#     Transition: State (4, 1) -> State (4, 1)
# At time 46.36: Customer type 2 served by Agent 2 in 0.00 minutes, waited 0.97 minutes (Overtime cost: 6.36, Reward: -7.33)
#     Transition: State (4, 1) -> State (4, 0)
# At time 46.63: Customer type 1 served by Agent 2 in 0.26 minutes, waited 1.18 minutes (Overtime cost: 6.63, Reward: -7.81)
#     Transition: State (4, 0) -> State (4, 2)
# At time 47.05: Customer type 1 served by Agent 1 in 1.15 minutes, waited 2.66 minutes (Overtime cost: 7.05, Reward: -9.71)
#     Transition: State (6, 1) -> State (5, 3)
# At time 47.12: Customer type 1 served by Agent 1 in 0.06 minutes, waited 1.22 minutes (Overtime cost: 7.12, Reward: -8.34)
#     Transition: State (5, 3) -> State (4, 3)
# At time 47.22: Customer type 1 served by Agent 2 in 0.60 minutes, waited 1.67 minutes (Overtime cost: 7.22, Reward: -8.89)
#     Transition: State (4, 2) -> State (3, 3)
# At time 47.31: Customer type 1 served by Agent 1 in 0.19 minutes, waited 1.03 minutes (Overtime cost: 7.31, Reward: -8.34)
#     Transition: State (4, 3) -> State (3, 3)
# At time 47.39: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.96 minutes (Overtime cost: 7.39, Reward: -8.35)
#     Transition: State (3, 3) -> State (3, 3)
# At time 47.60: Customer type 2 served by Agent 2 in 0.20 minutes, waited 1.07 minutes (Overtime cost: 7.60, Reward: -8.67)
#     Transition: State (3, 3) -> State (5, 3)
# At time 47.69: Customer type 2 served by Agent 2 in 0.08 minutes, waited 0.92 minutes (Overtime cost: 7.69, Reward: -8.60)
#     Transition: State (5, 3) -> State (5, 2)
# At time 47.97: Customer type 1 served by Agent 2 in 0.28 minutes, waited 1.17 minutes (Overtime cost: 7.97, Reward: -9.15)
#     Transition: State (5, 2) -> State (6, 2)
# At time 48.00: Customer type 2 served by Agent 1 in 0.68 minutes, waited 1.53 minutes (Overtime cost: 8.00, Reward: -9.53)
#     Transition: State (3, 3) -> State (5, 2)
# At time 48.34: Customer type 1 served by Agent 1 in 0.34 minutes, waited 1.04 minutes (Overtime cost: 8.34, Reward: -9.38)
#     Transition: State (5, 2) -> State (5, 4)
# At time 48.73: Customer type 1 served by Agent 2 in 0.76 minutes, waited 1.69 minutes (Overtime cost: 8.73, Reward: -10.43)
#     Transition: State (6, 2) -> State (5, 4)
# At time 48.98: Customer type 2 served by Agent 1 in 0.64 minutes, waited 1.59 minutes (Overtime cost: 8.98, Reward: -10.58)
#     Transition: State (5, 4) -> State (5, 5)
# At time 49.35: Customer type 1 served by Agent 2 in 0.61 minutes, waited 1.87 minutes (Overtime cost: 9.35, Reward: -11.21)
#     Transition: State (5, 4) -> State (7, 4)
# At time 49.44: Customer type 2 served by Agent 1 in 0.45 minutes, waited 1.90 minutes (Overtime cost: 9.44, Reward: -11.34)
#     Transition: State (5, 5) -> State (6, 4)
# At time 49.48: Customer type 1 served by Agent 2 in 0.13 minutes, waited 1.92 minutes (Overtime cost: 9.48, Reward: -11.40)
#     Transition: State (7, 4) -> State (5, 4)
# At time 49.66: Customer type 1 served by Agent 2 in 0.18 minutes, waited 1.71 minutes (Overtime cost: 9.66, Reward: -11.37)
#     Transition: State (5, 4) -> State (5, 4)
# At time 49.85: Customer type 2 served by Agent 2 in 0.18 minutes, waited 1.73 minutes (Overtime cost: 9.85, Reward: -11.58)
#     Transition: State (5, 4) -> State (5, 3)
# At time 49.92: Customer type 1 served by Agent 1 in 0.48 minutes, waited 2.10 minutes (Overtime cost: 9.92, Reward: -12.02)
#     Transition: State (6, 4) -> State (5, 2)
# At time 49.96: Customer type 2 served by Agent 2 in 0.11 minutes, waited 1.68 minutes (Overtime cost: 9.96, Reward: -11.63)
#     Transition: State (5, 3) -> State (4, 2)
# At time 50.03: Customer type 1 served by Agent 1 in 0.11 minutes, waited 1.73 minutes (Overtime cost: 10.03, Reward: -11.75)
#     Transition: State (5, 2) -> State (4, 1)
# At time 50.08: Customer type 2 served by Agent 2 in 0.12 minutes, waited 1.66 minutes (Overtime cost: 10.08, Reward: -11.74)
#     Transition: State (4, 2) -> State (4, 1)
# At time 50.12: Customer type 2 served by Agent 2 in 0.04 minutes, waited 1.17 minutes (Overtime cost: 10.12, Reward: -11.30)
#     Transition: State (4, 1) -> State (4, 0)
# At time 50.23: Customer type 1 served by Agent 2 in 0.11 minutes, waited 1.11 minutes (Overtime cost: 10.23, Reward: -11.34)
#     Transition: State (4, 0) -> State (4, 0)
# At time 50.46: Customer type 1 served by Agent 1 in 0.43 minutes, waited 1.67 minutes (Overtime cost: 10.46, Reward: -12.13)
#     Transition: State (4, 1) -> State (3, 1)
# At time 50.48: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.84 minutes (Overtime cost: 10.48, Reward: -11.32)
#     Transition: State (3, 1) -> State (2, 1)
# At time 50.49: Customer type 1 served by Agent 2 in 0.26 minutes, waited 1.34 minutes (Overtime cost: 10.49, Reward: -11.83)
#     Transition: State (4, 0) -> State (1, 1)
# At time 50.62: Customer type 1 served by Agent 2 in 0.13 minutes, waited 0.46 minutes (Overtime cost: 10.62, Reward: -11.09)
#     Transition: State (1, 1) -> State (0, 2)
# At time 50.65: Customer type 2 served by Agent 2 in 0.03 minutes, waited 0.30 minutes (Overtime cost: 10.65, Reward: -10.95)
#     Transition: State (0, 2) -> State (0, 1)
# At time 50.70: Customer type 2 served by Agent 2 in 0.05 minutes, waited 0.11 minutes (Overtime cost: 10.70, Reward: -10.81)
#     Transition: State (0, 1) -> State (0, 0)
# At time 51.03: Customer type 1 served by Agent 1 in 0.55 minutes, waited 1.00 minutes (Overtime cost: 11.03, Reward: -12.03)
#     Transition: State (2, 1) -> State (3, 1)
# At time 51.17: Customer type 2 served by Agent 2 in 0.43 minutes, waited 0.43 minutes (Overtime cost: 11.17, Reward: -11.60)
#     Transition: State (0, 1) -> State (2, 1)
# At time 51.24: Customer type 1 served by Agent 1 in 0.21 minutes, waited 0.39 minutes (Overtime cost: 11.24, Reward: -11.62)
#     Transition: State (3, 1) -> State (1, 4)
# At time 51.37: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.50 minutes (Overtime cost: 11.37, Reward: -11.87)
#     Transition: State (2, 1) -> State (0, 4)
# At time 51.63: Customer type 1 served by Agent 1 in 0.39 minutes, waited 0.75 minutes (Overtime cost: 11.63, Reward: -12.38)
#     Transition: State (1, 4) -> State (0, 5)
# ...
#     Transition: State (1, 8) -> State (0, 7)
# At time 50.14: Customer type 2 served by Agent 1 in 0.04 minutes, waited 3.08 minutes (Overtime cost: 10.14, Reward: -13.22)
#     Transition: State (0, 7) -> State (0, 6)
# At time 50.21: Customer type 2 served by Agent 2 in 0.27 minutes, waited 3.15 minutes (Overtime cost: 10.21, Reward: -13.35)
#     Transition: State (0, 8) -> State (0, 6)
# At time 50.26: Customer type 2 served by Agent 1 in 0.11 minutes, waited 1.91 minutes (Overtime cost: 10.26, Reward: -12.17)
#     Transition: State (0, 6) -> State (1, 6)
# At time 50.41: Customer type 1 served by Agent 1 in 0.15 minutes, waited 0.20 minutes (Overtime cost: 10.41, Reward: -10.61)
#     Transition: State (1, 6) -> State (0, 6)
# At time 50.59: Customer type 2 served by Agent 2 in 0.38 minutes, waited 2.19 minutes (Overtime cost: 10.59, Reward: -12.78)
#     Transition: State (0, 7) -> State (1, 7)
# At time 50.76: Customer type 2 served by Agent 1 in 0.35 minutes, waited 2.11 minutes (Overtime cost: 10.76, Reward: -12.87)
#     Transition: State (0, 6) -> State (0, 7)
# At time 50.83: Customer type 1 served by Agent 2 in 0.23 minutes, waited 0.34 minutes (Overtime cost: 10.83, Reward: -11.17)
#     Transition: State (1, 7) -> State (0, 7)
# At time 51.15: Customer type 2 served by Agent 2 in 0.32 minutes, waited 1.89 minutes (Overtime cost: 11.15, Reward: -13.04)
#     Transition: State (0, 7) -> State (0, 7)
# At time 51.65: Customer type 1 served by Agent 1 in 0.88 minutes, waited 0.88 minutes (Overtime cost: 11.65, Reward: -12.53)
#     Transition: State (1, 7) -> State (1, 8)
# At time 51.67: Customer type 1 served by Agent 1 in 0.02 minutes, waited 0.18 minutes (Overtime cost: 11.67, Reward: -11.85)
#     Transition: State (1, 8) -> State (0, 8)
# At time 51.70: Customer type 2 served by Agent 2 in 0.55 minutes, waited 2.17 minutes (Overtime cost: 11.70, Reward: -13.87)
#     Transition: State (0, 7) -> State (0, 7)
# At time 51.81: Customer type 2 served by Agent 2 in 0.11 minutes, waited 1.67 minutes (Overtime cost: 11.81, Reward: -13.48)
#     Transition: State (0, 7) -> State (0, 6)
# At time 52.06: Customer type 2 served by Agent 1 in 0.38 minutes, waited 2.48 minutes (Overtime cost: 12.06, Reward: -14.53)
#     Transition: State (0, 8) -> State (0, 7)
# At time 52.11: Customer type 2 served by Agent 1 in 0.05 minutes, waited 1.91 minutes (Overtime cost: 12.11, Reward: -14.02)
#     Transition: State (0, 7) -> State (0, 6)
# At time 52.14: Customer type 1 served by Agent 2 in 0.33 minutes, waited 0.33 minutes (Overtime cost: 12.14, Reward: -12.47)
#     Transition: State (1, 6) -> State (0, 5)
# At time 52.17: Customer type 2 served by Agent 2 in 0.03 minutes, waited 1.75 minutes (Overtime cost: 12.17, Reward: -13.92)
#     Transition: State (0, 5) -> State (0, 4)
# At time 52.41: Customer type 2 served by Agent 2 in 0.24 minutes, waited 1.57 minutes (Overtime cost: 12.41, Reward: -13.98)
#     Transition: State (0, 4) -> State (1, 3)
# At time 52.46: Customer type 1 served by Agent 2 in 0.05 minutes, waited 0.16 minutes (Overtime cost: 12.46, Reward: -12.62)
#     Transition: State (1, 3) -> State (0, 3)
# At time 52.95: Customer type 2 served by Agent 2 in 0.49 minutes, waited 1.63 minutes (Overtime cost: 12.95, Reward: -14.58)
#     Transition: State (0, 3) -> State (4, 2)
# At time 53.05: Customer type 2 served by Agent 1 in 0.93 minutes, waited 2.63 minutes (Overtime cost: 13.05, Reward: -15.68)
#     Transition: State (0, 6) -> State (6, 2)
# At time 53.17: Customer type 1 served by Agent 1 in 0.12 minutes, waited 0.57 minutes (Overtime cost: 13.17, Reward: -13.74)
#     Transition: State (6, 2) -> State (6, 2)
# At time 53.25: Customer type 1 served by Agent 2 in 0.29 minutes, waited 0.73 minutes (Overtime cost: 13.25, Reward: -13.98)
#     Transition: State (4, 2) -> State (5, 2)
# At time 53.49: Customer type 1 served by Agent 2 in 0.24 minutes, waited 0.60 minutes (Overtime cost: 13.49, Reward: -14.09)
#     Transition: State (5, 2) -> State (4, 3)
# At time 53.66: Customer type 1 served by Agent 2 in 0.17 minutes, waited 0.68 minutes (Overtime cost: 13.66, Reward: -14.34)
#     Transition: State (4, 3) -> State (4, 3)
# At time 53.67: Customer type 1 served by Agent 2 in 0.01 minutes, waited 0.66 minutes (Overtime cost: 13.67, Reward: -14.33)
#     Transition: State (4, 3) -> State (3, 3)
# At time 54.21: Customer type 1 served by Agent 1 in 1.05 minutes, waited 1.58 minutes (Overtime cost: 14.21, Reward: -15.80)
#     Transition: State (6, 2) -> State (4, 4)
# At time 54.42: Customer type 1 served by Agent 1 in 0.21 minutes, waited 1.36 minutes (Overtime cost: 14.42, Reward: -15.78)
#     Transition: State (4, 4) -> State (6, 5)
# At time 54.52: Customer type 1 served by Agent 2 in 0.85 minutes, waited 1.48 minutes (Overtime cost: 14.52, Reward: -16.01)
#     Transition: State (3, 3) -> State (5, 5)
# At time 54.55: Customer type 1 served by Agent 2 in 0.03 minutes, waited 0.75 minutes (Overtime cost: 14.55, Reward: -15.30)
#     Transition: State (5, 5) -> State (5, 5)
# At time 54.77: Customer type 1 served by Agent 2 in 0.21 minutes, waited 0.83 minutes (Overtime cost: 14.77, Reward: -15.60)
#     Transition: State (5, 5) -> State (4, 5)
# At time 55.07: Customer type 1 served by Agent 1 in 0.65 minutes, waited 1.43 minutes (Overtime cost: 15.07, Reward: -16.50)
#     Transition: State (6, 5) -> State (7, 5)
# At time 55.42: Customer type 1 served by Agent 1 in 0.35 minutes, waited 1.12 minutes (Overtime cost: 15.42, Reward: -16.54)
#     Transition: State (7, 5) -> State (8, 7)
# At time 55.74: Customer type 1 served by Agent 1 in 0.31 minutes, waited 1.35 minutes (Overtime cost: 15.74, Reward: -17.08)
#     Transition: State (8, 7) -> State (8, 9)
# At time 55.88: Customer type 1 served by Agent 2 in 1.11 minutes, waited 1.63 minutes (Overtime cost: 15.88, Reward: -17.51)
#     Transition: State (4, 5) -> State (7, 9)
# At time 56.04: Customer type 1 served by Agent 2 in 0.16 minutes, waited 1.24 minutes (Overtime cost: 16.04, Reward: -17.28)
#     Transition: State (7, 9) -> State (7, 9)
# At time 56.11: Customer type 1 served by Agent 2 in 0.06 minutes, waited 1.18 minutes (Overtime cost: 16.11, Reward: -17.29)
#     Transition: State (7, 9) -> State (6, 9)
# At time 56.14: Customer type 1 served by Agent 1 in 0.40 minutes, waited 1.59 minutes (Overtime cost: 16.14, Reward: -17.73)
#     Transition: State (8, 9) -> State (5, 9)
# At time 56.19: Customer type 1 served by Agent 1 in 0.05 minutes, waited 1.14 minutes (Overtime cost: 16.19, Reward: -17.32)
#     Transition: State (5, 9) -> State (4, 9)
# At time 56.62: Customer type 1 served by Agent 1 in 0.44 minutes, waited 1.51 minutes (Overtime cost: 16.62, Reward: -18.13)
#     Transition: State (4, 9) -> State (4, 9)
# At time 57.00: Customer type 1 served by Agent 1 in 0.37 minutes, waited 1.62 minutes (Overtime cost: 17.00, Reward: -18.62)
#     Transition: State (4, 9) -> State (4, 9)
# At time 57.00: Customer type 1 served by Agent 2 in 0.89 minutes, waited 2.07 minutes (Overtime cost: 17.00, Reward: -19.07)
#     Transition: State (6, 9) -> State (3, 9)
# At time 57.14: Customer type 1 served by Agent 1 in 0.15 minutes, waited 1.58 minutes (Overtime cost: 17.14, Reward: -18.73)
#     Transition: State (4, 9) -> State (2, 9)
# At time 57.27: Customer type 1 served by Agent 2 in 0.27 minutes, waited 1.23 minutes (Overtime cost: 17.27, Reward: -18.50)
#     Transition: State (3, 9) -> State (2, 9)
# At time 57.59: Customer type 1 served by Agent 1 in 0.45 minutes, waited 1.08 minutes (Overtime cost: 17.59, Reward: -18.67)
#     Transition: State (2, 9) -> State (2, 11)
# At time 57.63: Customer type 1 served by Agent 2 in 0.36 minutes, waited 0.98 minutes (Overtime cost: 17.63, Reward: -18.61)
#     Transition: State (2, 9) -> State (1, 11)
# At time 57.89: Customer type 1 served by Agent 2 in 0.26 minutes, waited 0.44 minutes (Overtime cost: 17.89, Reward: -18.33)
#     Transition: State (1, 11) -> State (1, 11)
# At time 57.97: Customer type 1 served by Agent 2 in 0.08 minutes, waited 0.10 minutes (Overtime cost: 17.97, Reward: -18.07)
#     Transition: State (1, 11) -> State (0, 11)
# At time 58.09: Customer type 2 served by Agent 2 in 0.12 minutes, waited 6.54 minutes (Overtime cost: 18.09, Reward: -24.63)
#     Transition: State (0, 11) -> State (1, 10)
# At time 58.20: Customer type 1 served by Agent 2 in 0.11 minutes, waited 0.15 minutes (Overtime cost: 18.20, Reward: -18.36)
#     Transition: State (1, 10) -> State (0, 10)
# At time 58.21: Customer type 1 served by Agent 1 in 0.61 minutes, waited 1.02 minutes (Overtime cost: 18.21, Reward: -19.23)
#     Transition: State (2, 11) -> State (0, 9)
# At time 58.27: Customer type 2 served by Agent 2 in 0.06 minutes, waited 6.45 minutes (Overtime cost: 18.27, Reward: -24.72)
#     Transition: State (0, 10) -> State (0, 9)
# At time 58.33: Customer type 2 served by Agent 2 in 0.06 minutes, waited 4.64 minutes (Overtime cost: 18.33, Reward: -22.97)
#     Transition: State (0, 9) -> State (1, 8)
# At time 59.27: Customer type 2 served by Agent 1 in 1.06 minutes, waited 6.02 minutes (Overtime cost: 19.27, Reward: -25.28)
#     Transition: State (0, 9) -> State (2, 11)
# At time 59.33: Customer type 1 served by Agent 2 in 0.99 minutes, waited 1.05 minutes (Overtime cost: 19.33, Reward: -20.38)
#     Transition: State (1, 8) -> State (1, 12)
# At time 59.67: Customer type 1 served by Agent 2 in 0.34 minutes, waited 0.64 minutes (Overtime cost: 19.67, Reward: -20.31)
#     Transition: State (1, 12) -> State (2, 12)
# At time 59.77: Customer type 1 served by Agent 2 in 0.10 minutes, waited 0.42 minutes (Overtime cost: 19.77, Reward: -20.20)
#     Transition: State (2, 12) -> State (2, 12)
# At time 59.81: Customer type 1 served by Agent 1 in 0.54 minutes, waited 0.86 minutes (Overtime cost: 19.81, Reward: -20.68)
#     Transition: State (2, 11) -> State (1, 12)
# At time 59.96: Customer type 1 served by Agent 2 in 0.19 minutes, waited 0.61 minutes (Overtime cost: 19.96, Reward: -20.57)
#     Transition: State (2, 12) -> State (2, 12)
#
# Total customers served: 325
# Total waiting time: 294.52 minutes
# Total agent overtime cost: 1135.23 minutes
# Total rewards: -85767.75
# Average waiting time per customer: 0.91 minutes
#
# Transition Probabilities:
#   P((0, 0) | (1, 0)) = 0.6812
#   P((0, 1) | (1, 0)) = 0.0725
#   P((1, 0) | (0, 1)) = 0.1250
#   P((0, 1) | (0, 1)) = 0.0625
#   P((0, 0) | (0, 1)) = 0.5625
#   P((0, 0) | (1, 1)) = 0.2941
#   P((1, 1) | (0, 1)) = 0.0625
#   P((0, 1) | (1, 1)) = 0.2353
#   P((2, 1) | (1, 0)) = 0.0145
#   P((1, 1) | (2, 1)) = 0.2000
#   P((1, 0) | (1, 0)) = 0.1304
#   P((3, 0) | (1, 0)) = 0.0290
#   P((3, 0) | (0, 1)) = 0.0417
#   P((2, 0) | (3, 0)) = 0.4000
#   P((2, 0) | (2, 0)) = 0.2000
#   P((1, 1) | (3, 0)) = 0.4000
#   P((2, 1) | (2, 0)) = 0.1000
#   P((2, 1) | (2, 1)) = 0.2000
#   P((1, 1) | (1, 1)) = 0.2941
#   P((2, 3) | (1, 1)) = 0.0588
#   P((2, 3) | (2, 1)) = 0.2000
#   P((0, 3) | (2, 3)) = 0.5000
#   P((0, 2) | (1, 3)) = 0.5000
#   P((4, 3) | (0, 3)) = 0.1250
#   P((3, 3) | (1, 2)) = 0.2500
#   P((3, 3) | (4, 3)) = 0.5000
#   P((2, 4) | (3, 3)) = 0.2500
#   P((1, 4) | (2, 4)) = 0.5000
#   P((3, 5) | (3, 3)) = 0.2500
#   P((3, 5) | (1, 4)) = 0.2500
#   P((2, 5) | (3, 5)) = 0.5000
#   P((1, 5) | (3, 5)) = 0.2500
#   P((2, 5) | (1, 5)) = 1.0000
#   P((3, 5) | (2, 5)) = 0.3333
#   P((3, 5) | (3, 5)) = 0.2500
#   P((1, 6) | (2, 5)) = 0.6667
#   P((0, 5) | (0, 6)) = 0.2000
#   P((0, 4) | (1, 6)) = 0.3333
#   P((0, 3) | (0, 4)) = 0.5000
#   P((0, 2) | (0, 5)) = 0.3333
#   P((1, 2) | (0, 2)) = 0.1667
#   P((0, 2) | (0, 3)) = 0.2500
#   P((1, 1) | (1, 2)) = 0.2500
#   P((0, 1) | (0, 2)) = 0.1667
#   P((2, 1) | (0, 1)) = 0.0417
#   P((0, 0) | (2, 1)) = 0.2000
#   P((2, 0) | (1, 0)) = 0.0435
#   P((1, 1) | (2, 0)) = 0.1000
#   P((0, 3) | (1, 1)) = 0.0588
#   P((3, 1) | (1, 1)) = 0.0588
#   P((2, 2) | (0, 2)) = 0.1667
#   P((2, 3) | (2, 2)) = 0.5000
#   P((3, 4) | (3, 1)) = 0.5000
#   P((2, 4) | (3, 4)) = 0.6667
#   P((3, 8) | (2, 4)) = 0.2500
#   P((4, 9) | (3, 8)) = 0.3333
#   P((3, 9) | (4, 9)) = 0.2500
#   P((3, 10) | (2, 3)) = 0.5000
#   P((2, 10) | (3, 9)) = 0.5000
#   P((1, 10) | (2, 10)) = 0.5000
#   P((2, 10) | (3, 10)) = 1.0000
#   P((1, 10) | (1, 10)) = 0.3333
#   P((0, 10) | (1, 10)) = 0.6667
#   P((0, 9) | (2, 10)) = 0.5000
#   P((0, 8) | (0, 9)) = 0.6000
#   P((2, 8) | (0, 10)) = 0.3333
#   P((3, 8) | (0, 8)) = 0.1667
#   P((2, 8) | (3, 8)) = 0.3333
#   P((1, 8) | (2, 8)) = 0.8333
#   P((0, 8) | (1, 8)) = 0.3750
#   P((1, 7) | (0, 8)) = 0.1667
#   P((2, 7) | (1, 7)) = 0.3333
#   P((2, 8) | (2, 8)) = 0.1667
#   P((2, 8) | (2, 7)) = 1.0000
#   P((0, 7) | (0, 8)) = 0.3333
#   P((0, 6) | (1, 8)) = 0.1250
#   P((0, 5) | (0, 7)) = 0.1429
#   P((0, 4) | (0, 5)) = 0.6667
#   P((2, 3) | (0, 6)) = 0.2000
#   P((0, 4) | (1, 4)) = 0.5000
#   P((4, 3) | (0, 4)) = 0.3333
#   P((4, 3) | (4, 3)) = 0.3750
#   P((5, 3) | (4, 3)) = 0.1250
#   P((4, 4) | (5, 3)) = 0.5000
#   P((3, 4) | (4, 4)) = 0.5000
#   P((3, 4) | (3, 3)) = 0.2500
#   P((1, 4) | (3, 4)) = 0.3333
#   P((0, 2) | (2, 4)) = 0.2500
#   P((0, 1) | (0, 3)) = 0.2500
#   P((0, 0) | (0, 2)) = 0.3333
#   P((0, 3) | (0, 1)) = 0.0208
#   P((1, 4) | (0, 3)) = 0.1250
#   P((0, 4) | (0, 1)) = 0.0208
#   P((0, 3) | (1, 4)) = 0.2500
#   P((1, 2) | (0, 3)) = 0.1250
#   P((0, 2) | (1, 2)) = 0.5000
#   P((1, 1) | (0, 2)) = 0.1667
#   P((1, 1) | (1, 0)) = 0.0290
#   P((2, 0) | (2, 1)) = 0.2000
#   P((0, 0) | (2, 0)) = 0.3000
#   P((3, 0) | (2, 0)) = 0.1000
#   P((1, 0) | (2, 0)) = 0.2000
#   P((4, 1) | (0, 1)) = 0.0208
#   P((3, 1) | (4, 1)) = 1.0000
#   P((2, 2) | (0, 1)) = 0.0208
#   P((1, 2) | (2, 2)) = 0.5000
#   P((0, 1) | (3, 1)) = 0.5000
#   P((8, 2) | (0, 1)) = 0.0208
#   P((7, 3) | (3, 0)) = 0.2000
#   P((6, 3) | (8, 2)) = 1.0000
#   P((5, 3) | (7, 3)) = 1.0000
#   P((7, 4) | (6, 3)) = 1.0000
#   P((6, 4) | (5, 3)) = 0.5000
#   P((5, 4) | (7, 4)) = 1.0000
#   P((4, 6) | (5, 4)) = 1.0000
#   P((4, 6) | (4, 6)) = 0.5000
#   P((3, 6) | (4, 6)) = 0.5000
#   P((2, 6) | (3, 6)) = 1.0000
#   P((3, 6) | (2, 6)) = 0.5000
#   P((3, 8) | (2, 6)) = 0.5000
#   P((2, 8) | (6, 4)) = 1.0000
#   P((1, 9) | (3, 8)) = 0.3333
#   P((0, 9) | (1, 9)) = 1.0000
#   P((2, 8) | (0, 8)) = 0.1667
#   P((0, 10) | (1, 8)) = 0.1250
#   P((0, 9) | (0, 10)) = 0.6667
#   P((1, 8) | (1, 8)) = 0.1250
#   P((0, 7) | (1, 8)) = 0.1250
#   P((0, 6) | (0, 7)) = 0.4286
#   P((0, 6) | (0, 8)) = 0.1667
#   P((1, 6) | (0, 6)) = 0.2000
#   P((0, 6) | (1, 6)) = 0.3333
#   P((1, 7) | (0, 7)) = 0.1429
#   P((0, 7) | (0, 6)) = 0.2000
#   P((0, 7) | (1, 7)) = 0.3333
#   P((0, 7) | (0, 7)) = 0.2857
#   P((1, 8) | (1, 7)) = 0.3333
#   P((0, 5) | (1, 6)) = 0.3333
#   P((1, 3) | (0, 4)) = 0.1667
#   P((0, 3) | (1, 3)) = 0.5000
#   P((4, 2) | (0, 3)) = 0.1250
#   P((6, 2) | (0, 6)) = 0.2000
#   P((6, 2) | (6, 2)) = 0.5000
#   P((5, 2) | (4, 2)) = 1.0000
#   P((4, 3) | (5, 2)) = 1.0000
#   P((4, 4) | (6, 2)) = 0.5000
#   P((6, 5) | (4, 4)) = 0.5000
#   P((5, 5) | (3, 3)) = 0.2500
#   P((5, 5) | (5, 5)) = 0.5000
#   P((4, 5) | (5, 5)) = 0.5000
#   P((7, 5) | (6, 5)) = 1.0000
#   P((8, 7) | (7, 5)) = 1.0000
#   P((8, 9) | (8, 7)) = 1.0000
#   P((7, 9) | (4, 5)) = 1.0000
#   P((7, 9) | (7, 9)) = 0.5000
#   P((6, 9) | (7, 9)) = 0.5000
#   P((5, 9) | (8, 9)) = 1.0000
#   P((4, 9) | (5, 9)) = 1.0000
#   P((4, 9) | (4, 9)) = 0.5000
#   P((3, 9) | (6, 9)) = 1.0000
#   P((2, 9) | (4, 9)) = 0.2500
#   P((2, 9) | (3, 9)) = 0.5000
#   P((2, 11) | (2, 9)) = 0.5000
#   P((1, 11) | (2, 9)) = 0.5000
#   P((1, 11) | (1, 11)) = 0.5000
#   P((0, 11) | (1, 11)) = 0.5000
#   P((1, 10) | (0, 11)) = 1.0000
#   P((0, 9) | (2, 11)) = 0.5000
#   P((1, 8) | (0, 9)) = 0.2000
#   P((2, 11) | (0, 9)) = 0.2000
#   P((1, 12) | (1, 8)) = 0.1250
#   P((2, 12) | (1, 12)) = 1.0000
#   P((2, 12) | (2, 12)) = 1.0000
#   P((1, 12) | (2, 11)) = 0.5000
#                       Metric  With Longest Waiting  Without Longest Waiting  Difference (Without - With)
# Total Waiting Time (minutes)            395.973304               294.522949                  -101.450355
#    Total Agent Overtime Cost           1133.896040              1135.225153                     1.329114
#       Total Customers Served            329.000000               325.000000                    -4.000000
#                Total Rewards         -77024.869344            -85767.748102                 -8742.878759
